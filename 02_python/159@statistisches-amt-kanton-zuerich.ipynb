# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bruttoinvestitionen [Fr./Einw.]

# %% [markdown]
# ### **Description**: Bruttoinvestitionen pro Einwohner. Aussage: Massgrösse für den Infrastrukturausbau ohne Berücksichtigung der Finanzierungsträger. Grundlage ist die Konsolidierte Gemeinde. Der Haushalt der Schulgemeinde wird dabei anteilsmässig in den Haushalt der poltischen Gemeinden umgelegt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **159@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-08-15T13:39:00`
# - **Startdate** `1990-12-31`
# - **Enddate** `2018-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'finanzkennzahlen', 'gemeindefinanzen', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 124
# Title                    : Bruttoinvestitionen [Fr./Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-08-15T13:39:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_412.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_412.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,830 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5830 entries, 0 to 5829
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5830 non-null   int64
#  1   GEBIET_NAME      5830 non-null   object
#  2   THEMA_NAME       5830 non-null   object
#  3   SET_NAME         5830 non-null   object
#  4   SUBSET_NAME      5830 non-null   object
#  5   INDIKATOR_ID     5830 non-null   int64
#  6   INDIKATOR_NAME   5830 non-null   object
#  7   INDIKATOR_JAHR   5830 non-null   int64
#  8   INDIKATOR_VALUE  5830 non-null   int64
#  9   EINHEIT_KURZ     5830 non-null   object
#  10  EINHEIT_LANG     5830 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
#
#            SUBSET_NAME  INDIKATOR_ID                   INDIKATOR_NAME  \
# 0  Gemeindekennziffern           412  Bruttoinvestitionen [Fr./Einw.]
# 1  Gemeindekennziffern           412  Bruttoinvestitionen [Fr./Einw.]
# 2  Gemeindekennziffern           412  Bruttoinvestitionen [Fr./Einw.]
# 3  Gemeindekennziffern           412  Bruttoinvestitionen [Fr./Einw.]
# 4  Gemeindekennziffern           412  Bruttoinvestitionen [Fr./Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ           EINHEIT_LANG
# 0            1990              544    Fr./Einw.  Franken pro Einwohner
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             2504  \
# BFS_NR                                       115
# GEBIET_NAME                               Gossau
# THEMA_NAME                  Öffentliche Finanzen
# SET_NAME                        Gemeindefinanzen
# SUBSET_NAME                  Gemeindekennziffern
# INDIKATOR_ID                                 412
# INDIKATOR_NAME   Bruttoinvestitionen [Fr./Einw.]
# INDIKATOR_JAHR                              2000
# INDIKATOR_VALUE                              181
# EINHEIT_KURZ                           Fr./Einw.
# EINHEIT_LANG               Franken pro Einwohner
#
#                                             5742  \
# BFS_NR                                         0
# GEBIET_NAME            Region Winterthur u. Umg.
# THEMA_NAME                  Öffentliche Finanzen
# SET_NAME                        Gemeindefinanzen
# SUBSET_NAME                  Gemeindekennziffern
# INDIKATOR_ID                                 412
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME          SET_NAME  \
# count          5830                  5830              5830
# unique          202                     1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# freq             29                  5830              5830
#
#                 SUBSET_NAME                   INDIKATOR_NAME EINHEIT_KURZ  \
# count                  5830                             5830         5830
# unique                    1                                1            1
# top     Gemeindekennziffern  Bruttoinvestitionen [Fr./Einw.]    Fr./Einw.
# freq                   5830                             5830         5830
#
#                  EINHEIT_LANG
# count                    5830
# unique                      1
# top     Franken pro Einwohner
# freq                     5830

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,830.00      5,830.00        5,830.00         5,830.00
# mean    111.63        412.00        2,003.94         1,004.66
# std      86.98          0.00            8.34           695.70
# min       0.00        412.00        1,990.00            14.00
# 25%      33.00        412.00        1,997.00           556.00
# 50%      97.00        412.00        2,004.00           844.00
# 75%     182.00        412.00        2,011.00         1,248.75
# max     298.00        412.00        2,018.00         7,883.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

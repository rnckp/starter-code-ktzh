# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Kontaktpersonen des Volksschulamts des Kantons Zürich nach Schulgemeinde und Themen

# %% [markdown]
# ### **Description**: Für Schulbehörden, Schulleitungen, Schulverwaltungen und Lehrpersonen zusammengestellte Kontaktpersonen des Volksschulamts zu Primar- und Sekundarschulen und den Themen 'Personal', 'Lohn', 'Beratung' und 'Sonderpädagogik'.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **735@volksschulamt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-09-06T00:00:00`
# - **Modified** `2021-09-20T15:55:00`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bildung', 'primarschule', 'schulen', 'schulgemeinden', 'sekundarschule', 'volksschule', 'ogd']`
# - **Publisher** `['Volksschulamt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/bildung/informationen-fuer-schulen/informationen-volksschule.html#-536456471`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1875
# Title                    : Tabelle der Kontaktpersonen des Volksschulamts des Kantons Zürich nach Schulgemeinde und Themen
# Description              : Variabeln: 'Code_P' = Primarstufe, 'Name_P' = Name der Primarschulgemeinde, 'Personal_P' = Name der Kontaktperson für das Thema 'Personal', 'Lohn_P' = Name der Kontaktperson für das Thema 'Lohn', 'Beratung_P' = Name der Kontaktperson für das Thema 'Beratung', 'Sonderpädagogik_P' = Name der Kontaktperson für das Thema 'Sonderpädagogik', 'Code_O' = Oberstufe, 'Name_O' = Name der Oberstufenschulgemeinde, 'Personal_O' = Name der Kontaktperson für das Thema 'Personal', 'Lohn_O' = Name der Kontaktperson für das Thema 'Lohn', 'Beratung_O' = Name der Kontaktperson für das Thema 'Beratung', 'Sonderpädagogik_O' = Name der Kontaktperson für das Thema 'Sonderpädagogik'
# Issued                   : 2021-09-06T12:58:32
# Modified                 : 2021-09-20T15:55:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/Visualisierung_VSAKarte/main/Data/VSA_Kantonskarte.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/Visualisierung_VSAKarte/main/Data/VSA_Kantonskarte.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 459 rows (observations) and 14 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Code_P             459 non-null    object
#  1   Feld_P             459 non-null    object
#  2   Name_P             459 non-null    object
#  3   Personal_P         459 non-null    object
#  4   Lohn_P             459 non-null    object
#  5   Beratung_P         459 non-null    object
#  6   Sonderpädagogik_P  459 non-null    object
#  7   Code_O             228 non-null    object
#  8   Feld_O             228 non-null    object
#  9   Name_O             228 non-null    object
#  10  Personal_O         228 non-null    object
#  11  Lohn_O             228 non-null    object
#  12  Beratung_O         228 non-null    object
#  13  Sonderpädagogik_O  224 non-null    object
# dtypes: object(14)
# memory usage: 390.0 KB

# %%
df.head()
# Out:
#   Code_P Feld_P                  Name_P               Personal_P  \
# 0    A01   Name        KSB / Zürich-Uto            Ramona Oertli
# 1    A01  Email        KSB / Zürich-Uto  ramona.oertli@vsa.zh.ch
# 2    A01    Tel        KSB / Zürich-Uto            043 259 22 81
# 3    A02   Name  KSB / Zürich-Limmattal               Jasmin Näf
# 4    A02  Email  KSB / Zürich-Limmattal    jasmin.naef@vsa.zh.ch
#
#                           Lohn_P                 Beratung_P  \
# 0                   Gülcan Akgül            Heidi Schweizer
# 1       guelcan.akguel@vsa.zh.ch  heidi.schweizer@vsa.zh.ch
# 2                  043 259 53 03              043 259 22 74
# 3            Sarina Kilchsperger            Heidi Schweizer
# 4  sarina.kilchsperger@vsa.zh.ch  heidi.schweizer@vsa.zh.ch
#
#               Sonderpädagogik_P Code_O Feld_O Name_O Personal_O Lohn_O  \
# 0            Myriam Autengruber    NaN    NaN    NaN        NaN    NaN
# 1  myriam.autengruber@vsa.zh.ch    NaN    NaN    NaN        NaN    NaN
# 2                 043 259 53 73    NaN    NaN    NaN        NaN    NaN
# 3            Myriam Autengruber    NaN    NaN    NaN        NaN    NaN
# 4  myriam.autengruber@vsa.zh.ch    NaN    NaN    NaN        NaN    NaN
#
#   Beratung_O Sonderpädagogik_O
# 0        NaN               NaN
# 1        NaN               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4        NaN               NaN

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                 251              153  \
# Code_P                          I08              E11
# Feld_P                          Tel             Name
# Name_P                PSP / Altikon    GSP / Zumikon
# Personal_P            043 259 22 52    Corina Ryffel
# Lohn_P                043 259 42 92     Arlene Meier
# Beratung_P            043 259 22 55  Heidi Schweizer
# Sonderpädagogik_P     043 259 22 91     Micha Bollag
# Code_O                          I25              NaN
# Feld_O                          Tel              NaN
# Name_O             SSP / Rickenbach              NaN
# Personal_O           043 259 22 69               NaN
# Lohn_O                043 259 53 87              NaN
# Beratung_O            043 259 22 55              NaN
# Sonderpädagogik_O     043 259 22 91              NaN
#
#                                              445
# Code_P                                       M20
# Feld_P                                     Email
# Name_P                             PSP / Rümlang
# Personal_P               carol.voegeli@vsa.zh.ch
# Lohn_P                     sarah.braem@vsa.zh.ch
# Beratung_P                sabine.meier@vsa.zh.ch
# Sonderpädagogik_P  yvonne.ehrensperger@vsa.zh.ch
# Code_O                                       M21
# Feld_O                                     Email
# Name_O                   SSP / Rümlang-Oberglatt
# Personal_O               carol.voegeli@vsa.zh.ch
# Lohn_O                     sarah.braem@vsa.zh.ch
# Beratung_O                sabine.meier@vsa.zh.ch
# Sonderpädagogik_O  yvonne.ehrensperger@vsa.zh.ch

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        Code_P Feld_P            Name_P     Personal_P  \
# count     459    459               459            459
# unique    153      3               153             51
# top       A01   Name  KSB / Zürich-Uto  043 259 22 52
# freq        3    153                 3             19
#
#                          Lohn_P    Beratung_P Sonderpädagogik_P Code_O Feld_O  \
# count                       459           459               459    228    228
# unique                       37             6                19     30      3
# top     rosita.richli@vsa.zh.ch  Sabine Meier      Micha Bollag    L04   Name
# freq                         26            84                42     15     76
#
#               Name_O     Personal_O      Lohn_O              Beratung_O  \
# count            228            228         228                     228
# unique            30             35          35                       8
# top     SSP / Bülach  043 259 22 69  Sarah Bräm  sabine.meier@vsa.zh.ch
# freq              15             18          24                      44
#
#                     Sonderpädagogik_O
# count                             224
# unique                             15
# top     yvonne.ehrensperger@vsa.zh.ch
# freq                               29

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(include='number'))
    except:
        pass

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, layout=(-1, 5), edgecolor='black');
except:
    pass

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Volksschulamt des Kantons Zürich |  | info@vsa.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Altersstruktur der Stadt Winterthur ab 2014

# %% [markdown]
# ### **Description**: Altersstruktur der Bevölkerung der Stadt Winterthur ab 2014, Endjahresstand 31. Dezember des Jahres. Quelle:  Einwohnerkontrolle der Stadt Winterthur.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1381@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T16:50:48`
# - **Modified** `2022-09-21T10:05:25`
# - **Startdate** `2014-01-01`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['alter', 'altersgruppen', 'altersklassen', 'bevoelkerung', 'gemeinden', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/bevoelkerung`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3062
# Title                    : Altersstruktur Stadt Winterthur ab 2014
# Description              : Altersstruktur der Stadt Winterthur ab 2014. Variablen: 'Jahr'; 'Altersklasse' = 5-Jahres-Altersklassen. Personen älter als 95 sind in der Klasse "95+" zusammengefasst; 'Anzahl' = Anzahl Personen pro Klasse.
# Issued                   : 2022-09-20T16:50:48
# Modified                 : 2022-09-20T16:50:48
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001381_00003062.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001381_00003062.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 140 rows (observations) and 3 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Jahr          140 non-null    int64
#  1   Altersklasse  140 non-null    object
#  2   Anzahl        140 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 15.6 KB

# %%
df.head()
# Out:
#    Jahr Altersklasse  Anzahl
# 0  2014          0–4    5877
# 1  2014          5–9    5356
# 2  2014        10–14    4784
# 3  2014        15–19    5075
# 4  2014        20–24    7585

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                20     124    128
# Jahr          2015   2020   2020
# Altersklasse   0–4  20–24  40–44
# Anzahl        6043   7446   8200

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        Altersklasse
# count           140
# unique           20
# top             0–4
# freq              7

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr    Anzahl
# count   140.00    140.00
# mean  2,017.00  5,649.75
# std       2.01  2,815.42
# min   2,014.00    155.00
# 25%   2,015.00  4,182.75
# 50%   2,017.00  5,679.50
# 75%   2,019.00  7,728.75
# max   2,020.00 10,514.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

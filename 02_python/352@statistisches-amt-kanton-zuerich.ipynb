# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bezügerquote der bedarfsabh. Sozialleistungen [%]

# %% [markdown]
# ### **Description**: Bezügerquote der bedarfsabhängigen Sozialleistungen. Die Bezügerquote der bedarfsabhängigen Sozialleistungen bezieht sich auf alle Personen, die während mindestens einem Monat des Jahres X eine der folgenden bedarfsabhängigen Sozialleistungen bezogen haben: Wirtschaftliche Sozialhilfe, Kleinkindbetreuungsbeiträge (bis und mit 2016), Alimentenbevorschussung, Zusatzleistungen zur Alters-, Invaliden- oder Hinterlassenenrente. Personen, die mehr als eine dieser Leistungen bezogen haben, werden nur einmal gezählt. Bei Gemeinden, die weniger als 5 Fälle haben, wird keine Quote ausgewiesen. (Referenzpopulation im Gemeindeporträt: kantonale Bevölkerungserhebung. Das BFS verwendet für die Berechnung seiner Quoten als Referenzpopulation STATPOP des Vorjahres.)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **352@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-12-22T12:07:18`
# - **Startdate** `2010-12-31`
# - **Enddate** `2015-12-31`
# - **Theme** `['Soziale Sicherheit']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'bezuegerquote', 'gemeinden', 'kanton_zuerich', 'sozialleistungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 273
# Title                    : Bezügerquote der bedarfsabh. Sozialleistungen [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-12-22T12:07:08
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_815.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_815.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,115 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1115 non-null   int64
#  1   GEBIET_NAME      1115 non-null   object
#  2   THEMA_NAME       1115 non-null   object
#  3   SET_NAME         1115 non-null   object
#  4   SUBSET_NAME      1115 non-null   object
#  5   INDIKATOR_ID     1115 non-null   int64
#  6   INDIKATOR_NAME   1115 non-null   object
#  7   INDIKATOR_JAHR   1115 non-null   int64
#  8   INDIKATOR_VALUE  1115 non-null   float64
#  9   EINHEIT_KURZ     1115 non-null   object
#  10  EINHEIT_LANG     1115 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 821.5 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
#
#                          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bedarfsabhängige Sozialleistungen           815
# 1  Bedarfsabhängige Sozialleistungen           815
# 2  Bedarfsabhängige Sozialleistungen           815
# 3  Bedarfsabhängige Sozialleistungen           815
# 4  Bedarfsabhängige Sozialleistungen           815
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Bezügerquote der bedarfsabh. Sozialleistungen [%]            2010
# 1  Bezügerquote der bedarfsabh. Sozialleistungen [%]            2011
# 2  Bezügerquote der bedarfsabh. Sozialleistungen [%]            2012
# 3  Bezügerquote der bedarfsabh. Sozialleistungen [%]            2013
# 4  Bezügerquote der bedarfsabh. Sozialleistungen [%]            2014
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              2.7            %      Prozent
# 1              2.6            %      Prozent
# 2              2.2            %      Prozent
# 3              1.7            %      Prozent
# 4              2.2            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                234  \
# BFS_NR                                                          52
# GEBIET_NAME                                            Bassersdorf
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                                  Soziales
# SUBSET_NAME                      Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                                   815
# INDIKATOR_NAME   Bezügerquote der bedarfsabh. Sozialleistungen [%]
# INDIKATOR_JAHR                                                2010
# INDIKATOR_VALUE                                                4.1
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent
#
#                                                                235  \
# BFS_NR                                                          52
# GEBIET_NAME                                            Bassersdorf
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                                  Soziales
# SUBSET_NAME                      Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                                   815
# INDIKATOR_NAME   Bezügerquote der bedarfsabh. Sozialleistungen [%]
# INDIKATOR_JAHR                                                2011
# INDIKATOR_VALUE                                                4.5
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent
#
#                                                                728
# BFS_NR                                                         176
# GEBIET_NAME                                                 Lindau
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                                  Soziales
# SUBSET_NAME                      Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                                   815
# INDIKATOR_NAME   Bezügerquote der bedarfsabh. Sozialleistungen [%]
# INDIKATOR_JAHR                                                2013
# INDIKATOR_VALUE                                                5.1
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  SET_NAME  \
# count          1115                      1115      1115
# unique          195                         1         1
# top     Aeugst a.A.  Bevölkerung und Soziales  Soziales
# freq              6                      1115      1115
#
#                               SUBSET_NAME  \
# count                                1115
# unique                                  1
# top     Bedarfsabhängige Sozialleistungen
# freq                                 1115
#
#                                            INDIKATOR_NAME EINHEIT_KURZ  \
# count                                                1115         1115
# unique                                                  1            1
# top     Bezügerquote der bedarfsabh. Sozialleistungen [%]            %
# freq                                                 1115         1115
#
#        EINHEIT_LANG
# count          1115
# unique            1
# top         Prozent
# freq           1115

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,115.00      1,115.00        1,115.00         1,115.00
# mean    109.30        815.00        2,012.58             4.84
# std      80.37          0.00            1.69             2.63
# min       0.00        815.00        2,010.00             0.00
# 25%      37.00        815.00        2,011.00             2.90
# 50%      97.00        815.00        2,013.00             4.20
# 75%     178.00        815.00        2,014.00             6.40
# max     298.00        815.00        2,015.00            15.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

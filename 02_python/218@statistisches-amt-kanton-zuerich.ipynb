# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Primarschule [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Anzahl PrimarschülerInnen gemessen an der zivilrechtlichen Bevölkerung Ende Vorjahr

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **218@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'primarschule', 'schueler', 'schuelerinnen', 'schulen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 181
# Title                    : Schül. Primarschule [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_150.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_150.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,240 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6240 entries, 0 to 6239
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6240 non-null   int64
#  1   GEBIET_NAME      6240 non-null   object
#  2   THEMA_NAME       6240 non-null   object
#  3   SET_NAME         6240 non-null   object
#  4   SUBSET_NAME      6240 non-null   object
#  5   INDIKATOR_ID     6240 non-null   int64
#  6   INDIKATOR_NAME   6240 non-null   object
#  7   INDIKATOR_JAHR   6240 non-null   int64
#  8   INDIKATOR_VALUE  6240 non-null   float64
#  9   EINHEIT_KURZ     6240 non-null   object
#  10  EINHEIT_LANG     6240 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#            SUBSET_NAME  INDIKATOR_ID                        INDIKATOR_NAME  \
# 0  Schüler Volksschule           150  Schül. Primarschule [pro 1000 Einw.]
# 1  Schüler Volksschule           150  Schül. Primarschule [pro 1000 Einw.]
# 2  Schüler Volksschule           150  Schül. Primarschule [pro 1000 Einw.]
# 3  Schüler Volksschule           150  Schül. Primarschule [pro 1000 Einw.]
# 4  Schüler Volksschule           150  Schül. Primarschule [pro 1000 Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE    EINHEIT_KURZ           EINHEIT_LANG
# 0            1990             96.7  pro 1000 Einw.  pro Tausend Einwohner
# 1            1991             90.0  pro 1000 Einw.  pro Tausend Einwohner
# 2            1992             84.1  pro 1000 Einw.  pro Tausend Einwohner
# 3            1993             81.3  pro 1000 Einw.  pro Tausend Einwohner
# 4            1994             86.6  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                  4553  \
# BFS_NR                                            218
# GEBIET_NAME                           Ellikon a.d.Th.
# THEMA_NAME                   Bevölkerung und Soziales
# SET_NAME                                      Bildung
# SUBSET_NAME                       Schüler Volksschule
# INDIKATOR_ID                                      150
# INDIKATOR_NAME   Schül. Primarschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                   1991
# INDIKATOR_VALUE                                 107.3
# EINHEIT_KURZ                           pro 1000 Einw.
# EINHEIT_LANG                    pro Tausend Einwohner
#
#                                                  1626  \
# BFS_NR                                             64
# GEBIET_NAME                                Nürensdorf
# THEMA_NAME                   Bevölkerung und Soziales
# SET_NAME                                      Bildung
# SUBSET_NAME                       Schüler Volksschule
# INDIKATOR_ID                                      150
# INDIKATOR_NAME   Schül. Primarschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                   1993
# INDIKATOR_VALUE                                  75.0
# EINHEIT_KURZ                           pro 1000 Einw.
# EINHEIT_LANG                    pro Tausend Einwohner
#
#                                                  5941
# BFS_NR                                              0
# GEBIET_NAME                        Region Knonaueramt
# THEMA_NAME                   Bevölkerung und Soziales
# SET_NAME                                      Bildung
# SUBSET_NAME                       Schüler Volksschule
# INDIKATOR_ID                                      150
# INDIKATOR_NAME   Schül. Primarschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                   2011
# INDIKATOR_VALUE                                  68.8
# EINHEIT_KURZ                           pro 1000 Einw.
# EINHEIT_LANG                    pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME          SUBSET_NAME  \
# count          6240                      6240     6240                 6240
# unique          200                         1        1                    1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler Volksschule
# freq             32                      6240     6240                 6240
#
#                               INDIKATOR_NAME    EINHEIT_KURZ  \
# count                                   6240            6240
# unique                                     1               1
# top     Schül. Primarschule [pro 1000 Einw.]  pro 1000 Einw.
# freq                                    6240            6240
#
#                  EINHEIT_LANG
# count                    6240
# unique                      1
# top     pro Tausend Einwohner
# freq                     6240

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,240.00      6,240.00        6,240.00         6,240.00
# mean    107.63        150.00        2,005.43            72.55
# std      84.42          0.00            9.20            20.31
# min       0.00        150.00        1,990.00             0.00
# 25%      31.00        150.00        1,997.00            61.90
# 50%      94.00        150.00        2,005.00            69.00
# 75%     178.00        150.00        2,013.00            80.90
# max     298.00        150.00        2,021.00           311.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

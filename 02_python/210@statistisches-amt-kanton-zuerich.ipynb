# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Sekundarstufe I [Pers. pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Die Sekundarstufe I umfasst das 7., 8. und 9. Normschuljahr. Gemessen an der zivilrechtlichen Bevölkerung Ende Vorjahr

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **210@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1999-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'schueler', 'schuelerinnen', 'schulen', 'sekundarschule', 'sekundarstufe', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 173
# Title                    : Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_464.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_464.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,461 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4461 entries, 0 to 4460
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4461 non-null   int64
#  1   GEBIET_NAME      4461 non-null   object
#  2   THEMA_NAME       4461 non-null   object
#  3   SET_NAME         4461 non-null   object
#  4   SUBSET_NAME      4461 non-null   object
#  5   INDIKATOR_ID     4461 non-null   int64
#  6   INDIKATOR_NAME   4461 non-null   object
#  7   INDIKATOR_JAHR   4461 non-null   int64
#  8   INDIKATOR_VALUE  4461 non-null   float64
#  9   EINHEIT_KURZ     4461 non-null   object
#  10  EINHEIT_LANG     4461 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME         SUBSET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
#
#    INDIKATOR_ID                                 INDIKATOR_NAME  \
# 0           464  Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# 1           464  Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# 2           464  Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# 3           464  Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# 4           464  Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE          EINHEIT_KURZ  \
# 0            1999             43.4  Pers. pro 1000 Einw.
# 1            2000             43.4  Pers. pro 1000 Einw.
# 2            2001             42.8  Pers. pro 1000 Einw.
# 3            2002             44.6  Pers. pro 1000 Einw.
# 4            2003             45.6  Pers. pro 1000 Einw.
#
#                      EINHEIT_LANG
# 0  Personen pro Tausend Einwohner
# 1  Personen pro Tausend Einwohner
# 2  Personen pro Tausend Einwohner
# 3  Personen pro Tausend Einwohner
# 4  Personen pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                           1591  \
# BFS_NR                                                      90
# GEBIET_NAME                                        Niederhasli
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                               Bildung
# SUBSET_NAME                                 Schüler nach ISCED
# INDIKATOR_ID                                               464
# INDIKATOR_NAME   Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                            2012
# INDIKATOR_VALUE                                           39.6
# EINHEIT_KURZ                              Pers. pro 1000 Einw.
# EINHEIT_LANG                    Personen pro Tausend Einwohner
#
#                                                           4437  \
# BFS_NR                                                       0
# GEBIET_NAME                                      Region Zürich
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                               Bildung
# SUBSET_NAME                                 Schüler nach ISCED
# INDIKATOR_ID                                               464
# INDIKATOR_NAME   Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                            2021
# INDIKATOR_VALUE                                           23.3
# EINHEIT_KURZ                              Pers. pro 1000 Einw.
# EINHEIT_LANG                    Personen pro Tausend Einwohner
#
#                                                           1412
# BFS_NR                                                      82
# GEBIET_NAME                                          Boppelsen
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                               Bildung
# SUBSET_NAME                                 Schüler nach ISCED
# INDIKATOR_ID                                               464
# INDIKATOR_NAME   Schül. Sekundarstufe I [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                            2017
# INDIKATOR_VALUE                                           39.5
# EINHEIT_KURZ                              Pers. pro 1000 Einw.
# EINHEIT_LANG                    Personen pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME         SUBSET_NAME  \
# count          4461                      4461     4461                4461
# unique          200                         1        1                   1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# freq             23                      4461     4461                4461
#
#                                        INDIKATOR_NAME          EINHEIT_KURZ  \
# count                                            4461                  4461
# unique                                              1                     1
# top     Schül. Sekundarstufe I [Pers. pro 1000 Einw.]  Pers. pro 1000 Einw.
# freq                                             4461                  4461
#
#                           EINHEIT_LANG
# count                             4461
# unique                               1
# top     Personen pro Tausend Einwohner
# freq                              4461

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,461.00      4,461.00        4,461.00         4,461.00
# mean    107.17        464.00        2,009.94            35.53
# std      84.20          0.00            6.61             7.70
# min       0.00        464.00        1,999.00             4.50
# 25%      31.00        464.00        2,004.00            30.60
# 50%      94.00        464.00        2,010.00            34.10
# 75%     178.00        464.00        2,016.00            39.40
# max     298.00        464.00        2,021.00            89.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Scheidungen [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Anzahl Scheidungen pro 1000 Einwohner (Rohe Scheidungsziffer). Hinweise: Am 1.Januar 2000 trat das neue Scheidungsrecht in Kraft. Ab 2011 Wechsel der Datenquelle: Es werden nicht mehr alle Scheidungen von zwei ausländischen Personen ausgewiesen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **310@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'ehe', 'ehescheidung', 'gemeinden', 'kanton_zuerich', 'scheidung', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 240
# Title                    : Scheidungen [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_448.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_448.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,053 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6053 entries, 0 to 6052
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6053 non-null   int64
#  1   GEBIET_NAME      6053 non-null   object
#  2   THEMA_NAME       6053 non-null   object
#  3   SET_NAME         6053 non-null   object
#  4   SUBSET_NAME      6053 non-null   object
#  5   INDIKATOR_ID     6053 non-null   int64
#  6   INDIKATOR_NAME   6053 non-null   object
#  7   INDIKATOR_JAHR   6053 non-null   int64
#  8   INDIKATOR_VALUE  6053 non-null   float64
#  9   EINHEIT_KURZ     6053 non-null   object
#  10  EINHEIT_LANG     6053 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.9 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID                INDIKATOR_NAME  \
# 0  Heiraten und Scheidungen           448  Scheidungen [pro 1000 Einw.]
# 1  Heiraten und Scheidungen           448  Scheidungen [pro 1000 Einw.]
# 2  Heiraten und Scheidungen           448  Scheidungen [pro 1000 Einw.]
# 3  Heiraten und Scheidungen           448  Scheidungen [pro 1000 Einw.]
# 4  Heiraten und Scheidungen           448  Scheidungen [pro 1000 Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE    EINHEIT_KURZ           EINHEIT_LANG
# 0            1991              2.5  pro 1000 Einw.  pro Tausend Einwohner
# 1            1992              1.6  pro 1000 Einw.  pro Tausend Einwohner
# 2            1993              2.3  pro 1000 Einw.  pro Tausend Einwohner
# 3            1994              2.3  pro 1000 Einw.  pro Tausend Einwohner
# 4            1995              3.7  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                          1948                          4221  \
# BFS_NR                                     84                           200
# GEBIET_NAME                          Dällikon           Wangen-Brüttisellen
# THEMA_NAME           Bevölkerung und Soziales      Bevölkerung und Soziales
# SET_NAME                 Bevölkerungsbewegung          Bevölkerungsbewegung
# SUBSET_NAME          Heiraten und Scheidungen      Heiraten und Scheidungen
# INDIKATOR_ID                              448                           448
# INDIKATOR_NAME   Scheidungen [pro 1000 Einw.]  Scheidungen [pro 1000 Einw.]
# INDIKATOR_JAHR                           1995                          2017
# INDIKATOR_VALUE                           4.0                           0.9
# EINHEIT_KURZ                   pro 1000 Einw.                pro 1000 Einw.
# EINHEIT_LANG            pro Tausend Einwohner         pro Tausend Einwohner
#
#                                          556
# BFS_NR                                     24
# GEBIET_NAME                         Buch a.I.
# THEMA_NAME           Bevölkerung und Soziales
# SET_NAME                 Bevölkerungsbewegung
# SUBSET_NAME          Heiraten und Scheidungen
# INDIKATOR_ID                              448
# INDIKATOR_NAME   Scheidungen [pro 1000 Einw.]
# INDIKATOR_JAHR                           2020
# INDIKATOR_VALUE                           4.1
# EINHEIT_KURZ                   pro 1000 Einw.
# EINHEIT_LANG            pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#          GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count           6053                      6053                  6053
# unique           200                         1                     1
# top     Wiesendangen  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq              32                      6053                  6053
#
#                      SUBSET_NAME                INDIKATOR_NAME  \
# count                       6053                          6053
# unique                         1                             1
# top     Heiraten und Scheidungen  Scheidungen [pro 1000 Einw.]
# freq                        6053                          6053
#
#           EINHEIT_KURZ           EINHEIT_LANG
# count             6053                   6053
# unique               1                      1
# top     pro 1000 Einw.  pro Tausend Einwohner
# freq              6053                   6053

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,053.00      6,053.00        6,053.00         6,053.00
# mean    107.92        448.00        2,005.93             2.32
# std      84.69          0.00            8.91             1.33
# min       0.00        448.00        1,990.00             0.00
# 25%      31.00        448.00        1,998.00             1.60
# 50%      94.00        448.00        2,006.00             2.30
# 75%     178.00        448.00        2,014.00             2.90
# max     298.00        448.00        2,021.00            26.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

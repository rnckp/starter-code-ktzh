# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungszunahme 1 Jahr [%]

# %% [markdown]
# ### **Description**: Veränderung der Einwohnerzahl (zivilrechtlicher Wohnsitz) gegenüber dem Vorjahr in Prozent. Wert für 1970 aus der Volkszählung (wirtschaftl. Wohnsitz), da keine kant. Erhebung stattgefunden hat.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **67@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:16:54`
# - **Startdate** `1962-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungswachstum', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 57
# Title                    : Bevölkerungszunahme 1 Jahr [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:16:54
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_201.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_201.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 11,744 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11744 entries, 0 to 11743
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           11744 non-null  int64
#  1   GEBIET_NAME      11744 non-null  object
#  2   THEMA_NAME       11744 non-null  object
#  3   SET_NAME         11744 non-null  object
#  4   SUBSET_NAME      11744 non-null  object
#  5   INDIKATOR_ID     11744 non-null  int64
#  6   INDIKATOR_NAME   11744 non-null  object
#  7   INDIKATOR_JAHR   11744 non-null  int64
#  8   INDIKATOR_VALUE  11740 non-null  float64
#  9   EINHEIT_KURZ     11744 non-null  object
#  10  EINHEIT_LANG     11744 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 8.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME              SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           201
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           201
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           201
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           201
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           201
#
#                    INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerungszunahme 1 Jahr [%]            1963              1.4
# 1  Bevölkerungszunahme 1 Jahr [%]            1964             -2.1
# 2  Bevölkerungszunahme 1 Jahr [%]            1965             -1.4
# 3  Bevölkerungszunahme 1 Jahr [%]            1966              7.2
# 4  Bevölkerungszunahme 1 Jahr [%]            1967             -5.5
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                              2633   \
# BFS_NR                                          57
# GEBIET_NAME                     Freienstein-Teufen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   201
# INDIKATOR_NAME      Bevölkerungszunahme 1 Jahr [%]
# INDIKATOR_JAHR                                2009
# INDIKATOR_VALUE                                1.2
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                              6218   \
# BFS_NR                                         151
# GEBIET_NAME                              Erlenbach
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   201
# INDIKATOR_NAME      Bevölkerungszunahme 1 Jahr [%]
# INDIKATOR_JAHR                                2012
# INDIKATOR_VALUE                                1.0
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                              10272
# BFS_NR                                         298
# GEBIET_NAME                           Wiesendangen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   201
# INDIKATOR_NAME      Bevölkerungszunahme 1 Jahr [%]
# INDIKATOR_JAHR                                1966
# INDIKATOR_VALUE                                0.7
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GEBIET_NAME                THEMA_NAME  \
# count        11744                     11744
# unique         200                         1
# top         Horgen  Bevölkerung und Soziales
# freq            60                     11744
#
#                                  SET_NAME              SUBSET_NAME  \
# count                               11744                    11744
# unique                                  1                        1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung
# freq                                11744                    11744
#
#                         INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                            11744        11744        11744
# unique                               1            1            1
# top     Bevölkerungszunahme 1 Jahr [%]            %      Prozent
# freq                             11744        11744        11744

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 11,744.00     11,744.00       11,744.00        11,740.00
# mean     110.79        201.00        1,991.85             1.46
# std       86.86          0.00           16.97             3.20
# min        0.00        201.00        1,962.00           -48.00
# 25%       32.00        201.00        1,977.00             0.00
# 50%       96.00        201.00        1,992.00             1.00
# 75%      181.00        201.00        2,007.00             2.30
# max      298.00        201.00        2,021.00            81.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

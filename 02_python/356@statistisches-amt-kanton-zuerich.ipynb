# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Arbeitsstätten im Tertiärsektor [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Arbeitsstätten des Tertiärsektors (Handel, Instandhaltung/Reparatur, Verkehr/Lagerei, Gastgewerbe/Gastronomie, Information/Kommunikation, Finanz-/Versicherungs-DL, Grundstücks-/Wohnungswesen, weitere DL, öffentliche Verwaltung, Erziehung/Unterrricht, Gesundheit, Kunst). Aktuellstes Jahr provisorisch.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **356@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T07:27:22`
# - **Startdate** `2011-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Arbeit, Erwerb']`
# - **Keyword** `['arbeitsstaetten', 'bezirke', 'dienstleistungssektor', 'gemeinden', 'kanton_zuerich', 'wirtschaftssektor', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 277
# Title                    : Arbeitsstätten im Tertiärsektor [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-01T14:17:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_583.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_583.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,960 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1960 non-null   int64
#  1   GEBIET_NAME      1960 non-null   object
#  2   THEMA_NAME       1960 non-null   object
#  3   SET_NAME         1960 non-null   object
#  4   SUBSET_NAME      1960 non-null   object
#  5   INDIKATOR_ID     1960 non-null   int64
#  6   INDIKATOR_NAME   1960 non-null   object
#  7   INDIKATOR_JAHR   1960 non-null   int64
#  8   INDIKATOR_VALUE  1960 non-null   int64
#  9   EINHEIT_KURZ     1960 non-null   object
#  10  EINHEIT_LANG     1960 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen
# 1       1  Aeugst a.A.  Arbeit und Unternehmen
# 2       1  Aeugst a.A.  Arbeit und Unternehmen
# 3       1  Aeugst a.A.  Arbeit und Unternehmen
# 4       1  Aeugst a.A.  Arbeit und Unternehmen
#
#                                        SET_NAME                SUBSET_NAME  \
# 0  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Arbeitsstätten / Betriebe
# 1  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Arbeitsstätten / Betriebe
# 2  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Arbeitsstätten / Betriebe
# 3  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Arbeitsstätten / Betriebe
# 4  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Arbeitsstätten / Betriebe
#
#    INDIKATOR_ID                          INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           583  Arbeitsstätten im Tertiärsektor [Anz.]            2011
# 1           583  Arbeitsstätten im Tertiärsektor [Anz.]            2012
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                          1233  \
# BFS_NR                                                    182
# GEBIET_NAME                                          Wildberg
# THEMA_NAME                             Arbeit und Unternehmen
# SET_NAME         Betriebe, Beschäftigte (Sektoren 1, 2 und 3)
# SUBSET_NAME                         Arbeitsstätten / Betriebe
# INDIKATOR_ID                                              583
# INDIKATOR_NAME         Arbeitsstätten im Tertiärsektor [Anz.]
# INDIKATOR_JAHR                                           2014
# INDIKATOR_VALUE                                            28
# EINHEIT_KURZ                                             Anz.
# EINHEIT_LANG                                           Anzahl
#
#                                                          985   \
# BFS_NR                                                    137
# GEBIET_NAME                                        Oberrieden
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME  \
# count          1960                    1960
# unique          202                       1
# top     Aeugst a.A.  Arbeit und Unternehmen
# freq             10                    1960
#
#                                             SET_NAME  \
# count                                           1960
# unique                                             1
# top     Betriebe, Beschäftigte (Sektoren 1, 2 und 3)
# freq                                            1960
#
#                       SUBSET_NAME                          INDIKATOR_NAME  \
# count                        1960                                    1960
# unique                          1                                       1
# top     Arbeitsstätten / Betriebe  Arbeitsstätten im Tertiärsektor [Anz.]
# freq                         1960                                    1960
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          1960         1960
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,960.00      1,960.00        1,960.00         1,960.00
# mean    110.28        583.00        2,015.42         2,044.87
# std      87.24          0.00            2.86         8,757.44
# min       0.00        583.00        2,011.00             9.00
# 25%      31.75        583.00        2,013.00            86.75
# 50%      95.00        583.00        2,015.00           222.00
# 75%     181.25        583.00        2,018.00           704.25
# max     298.00        583.00        2,020.00       105,202.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

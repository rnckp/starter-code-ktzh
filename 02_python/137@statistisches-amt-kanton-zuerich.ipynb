# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Ø Reingewinn steuerpfl. jur. Pers. [Fr.]

# %% [markdown]
# ### **Description**: Durchschnittlicher Reingewinn (ehem. Ertrag) steuerpflichtiger juristischer Personen. Hinweis: Sehr hohe Beträge einiger weniger Steuerpflichtigen wirken sich entsprechend stark auf den Mittelwert aus.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **137@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-13T09:49:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'juristische_personen', 'kanton_zuerich', 'reingewinn', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 103
# Title                    : Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-13T09:49:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_278.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_278.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,339 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6339 entries, 0 to 6338
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6339 non-null   int64
#  1   GEBIET_NAME      6339 non-null   object
#  2   THEMA_NAME       6339 non-null   object
#  3   SET_NAME         6339 non-null   object
#  4   SUBSET_NAME      6339 non-null   object
#  5   INDIKATOR_ID     6339 non-null   int64
#  6   INDIKATOR_NAME   6339 non-null   object
#  7   INDIKATOR_JAHR   6339 non-null   int64
#  8   INDIKATOR_VALUE  6337 non-null   float64
#  9   EINHEIT_KURZ     6339 non-null   object
#  10  EINHEIT_LANG     6339 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME         SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
#
#         SUBSET_NAME  INDIKATOR_ID                            INDIKATOR_NAME  \
# 0  Steuergrundlagen           278  Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# 1  Steuergrundlagen           278  Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# 2  Steuergrundlagen           278  Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# 3  Steuergrundlagen           278  Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# 4  Steuergrundlagen           278  Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            1990           1665.0          Fr.      Franken
# 1            1991           8220.0          Fr.      Franken
# 2            1992           3050.0          Fr.      Franken
# 3            1993          21795.0          Fr.      Franken
# 4            1994           8776.0          Fr.      Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                      5079  \
# BFS_NR                                                244
# GEBIET_NAME                                    Geroldswil
# THEMA_NAME                           Öffentliche Finanzen
# SET_NAME                                  Gemeindesteuern
# SUBSET_NAME                              Steuergrundlagen
# INDIKATOR_ID                                          278
# INDIKATOR_NAME   Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# INDIKATOR_JAHR                                       2010
# INDIKATOR_VALUE                                  164398.0
# EINHEIT_KURZ                                          Fr.
# EINHEIT_LANG                                      Franken
#
#                                                      5164  \
# BFS_NR                                                247
# GEBIET_NAME                                     Schlieren
# THEMA_NAME                           Öffentliche Finanzen
# SET_NAME                                  Gemeindesteuern
# SUBSET_NAME                              Steuergrundlagen
# INDIKATOR_ID                                          278
# INDIKATOR_NAME   Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# INDIKATOR_JAHR                                       1999
# INDIKATOR_VALUE                                  141227.0
# EINHEIT_KURZ                                          Fr.
# EINHEIT_LANG                                      Franken
#
#                                                      4391
# BFS_NR                                                211
# GEBIET_NAME                                       Altikon
# THEMA_NAME                           Öffentliche Finanzen
# SET_NAME                                  Gemeindesteuern
# SUBSET_NAME                              Steuergrundlagen
# INDIKATOR_ID                                          278
# INDIKATOR_NAME   Ø Reingewinn steuerpfl. jur. Pers. [Fr.]
# INDIKATOR_JAHR                                       2018
# INDIKATOR_VALUE                                   13375.0
# EINHEIT_KURZ                                          Fr.
# EINHEIT_LANG                                      Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME         SET_NAME       SUBSET_NAME  \
# count          6339                  6339             6339              6339
# unique          200                     1                1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuergrundlagen
# freq             32                  6339             6339              6339
#
#                                   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                       6339         6339         6339
# unique                                         1            1            1
# top     Ø Reingewinn steuerpfl. jur. Pers. [Fr.]          Fr.      Franken
# freq                                        6339         6339         6339

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,339.00      6,339.00        6,339.00         6,337.00
# mean    110.58        278.00        2,005.37        71,910.56
# std      86.89          0.00            9.18        93,625.18
# min       0.00        278.00        1,990.00             0.00
# 25%      32.00        278.00        1,997.00        15,993.00
# 50%      96.00        278.00        2,005.00        42,882.00
# 75%     181.00        278.00        2,013.00        89,500.00
# max     298.00        278.00        2,021.00     1,234,259.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

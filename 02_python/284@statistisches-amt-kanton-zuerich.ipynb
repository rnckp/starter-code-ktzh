# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung: Männeranteil [%]

# %% [markdown]
# ### **Description**: Männeranteil an der Gesamtbevölkerung nach zivilrechtlichem Wohnsitz (ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **284@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:05`
# - **Startdate** `1991-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'geschlecht', 'kanton_zuerich', 'maenneranteil', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 214
# Title                    : Bevölkerung: Männeranteil [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_103.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_103.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,120 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6120 non-null   int64
#  1   GEBIET_NAME      6120 non-null   object
#  2   THEMA_NAME       6120 non-null   object
#  3   SET_NAME         6120 non-null   object
#  4   SUBSET_NAME      6120 non-null   object
#  5   INDIKATOR_ID     6120 non-null   int64
#  6   INDIKATOR_NAME   6120 non-null   object
#  7   INDIKATOR_JAHR   6120 non-null   int64
#  8   INDIKATOR_VALUE  6120 non-null   float64
#  9   EINHEIT_KURZ     6120 non-null   object
#  10  EINHEIT_LANG     6120 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           103
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           103
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           103
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           103
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           103
#
#                   INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerung: Männeranteil [%]            1991             51.0
# 1  Bevölkerung: Männeranteil [%]            1992             50.6
# 2  Bevölkerung: Männeranteil [%]            1993             50.7
# 3  Bevölkerung: Männeranteil [%]            1994             50.5
# 4  Bevölkerung: Männeranteil [%]            1995             51.2
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               4672  \
# BFS_NR                                         226
# GEBIET_NAME                                Schlatt
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   103
# INDIKATOR_NAME       Bevölkerung: Männeranteil [%]
# INDIKATOR_JAHR                                2011
# INDIKATOR_VALUE                               52.4
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               4456  \
# BFS_NR                                         219
# GEBIET_NAME                                  Elsau
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   103
# INDIKATOR_NAME       Bevölkerung: Männeranteil [%]
# INDIKATOR_JAHR                                2008
# INDIKATOR_VALUE                               50.1
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               4548
# BFS_NR                                         222
# GEBIET_NAME                  Hofstetten (bis 2017)
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   103
# INDIKATOR_NAME       Bevölkerung: Männeranteil [%]
# INDIKATOR_JAHR                                2007
# INDIKATOR_VALUE                               51.5
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          6120                      6120
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             31                      6120
#
#                                  SET_NAME          SUBSET_NAME  \
# count                                6120                 6120
# unique                                  1                    1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsbestand
# freq                                 6120                 6120
#
#                        INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                            6120         6120         6120
# unique                              1            1            1
# top     Bevölkerung: Männeranteil [%]            %      Prozent
# freq                             6120         6120         6120

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,120.00      6,120.00        6,120.00         6,120.00
# mean    109.95        103.00        2,005.91            49.83
# std      86.41          0.00            8.88             1.11
# min       0.00        103.00        1,991.00            44.80
# 25%      32.00        103.00        1,998.00            49.20
# 50%      95.50        103.00        2,006.00            49.80
# 75%     180.00        103.00        2,014.00            50.50
# max     298.00        103.00        2,021.00            55.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

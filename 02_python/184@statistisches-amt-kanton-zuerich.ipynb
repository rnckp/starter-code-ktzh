# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bauzonen überbaut pro Kopf [m2/Einw.]

# %% [markdown]
# ### **Description**: Überbaute Bauzonenfläche gemessen an der zivilrechtlichen Wohnbevölkerung Ende Vorjahr

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **184@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-03-17T07:40:27`
# - **Startdate** `1996-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bauzonen', 'bauzonenverbrauch', 'bezirke', 'bodennutzung', 'gemeinden', 'kanton_zuerich', 'zonenart', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 148
# Title                    : Bauzonen überbaut pro Kopf [m2/Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-03-17T07:40:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_50.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_50.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,921 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4921 entries, 0 to 4920
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4921 non-null   int64
#  1   GEBIET_NAME      4921 non-null   object
#  2   THEMA_NAME       4921 non-null   object
#  3   SET_NAME         4921 non-null   object
#  4   SUBSET_NAME      4921 non-null   object
#  5   INDIKATOR_ID     4921 non-null   int64
#  6   INDIKATOR_NAME   4921 non-null   object
#  7   INDIKATOR_JAHR   4921 non-null   int64
#  8   INDIKATOR_VALUE  4921 non-null   float64
#  9   EINHEIT_KURZ     4921 non-null   object
#  10  EINHEIT_LANG     4921 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 1       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 2       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 3       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 4       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
#
#   SUBSET_NAME  INDIKATOR_ID                         INDIKATOR_NAME  \
# 0    Bauzonen            50  Bauzonen überbaut pro Kopf [m2/Einw.]
# 1    Bauzonen            50  Bauzonen überbaut pro Kopf [m2/Einw.]
# 2    Bauzonen            50  Bauzonen überbaut pro Kopf [m2/Einw.]
# 3    Bauzonen            50  Bauzonen überbaut pro Kopf [m2/Einw.]
# 4    Bauzonen            50  Bauzonen überbaut pro Kopf [m2/Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ                EINHEIT_LANG
# 0            1996            310.0     m2/Einw.  Quadratmeter pro Einwohner
# 1            1997            308.0     m2/Einw.  Quadratmeter pro Einwohner
# 2            1998            310.0     m2/Einw.  Quadratmeter pro Einwohner
# 3            1999            310.0     m2/Einw.  Quadratmeter pro Einwohner
# 4            2000            301.0     m2/Einw.  Quadratmeter pro Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                   581   \
# BFS_NR                                              30
# GEBIET_NAME                                Andelfingen
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                   Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                                   Bauzonen
# INDIKATOR_ID                                        50
# INDIKATOR_NAME   Bauzonen überbaut pro Kopf [m2/Einw.]
# INDIKATOR_JAHR                                    2002
# INDIKATOR_VALUE                                  422.0
# EINHEIT_KURZ                                  m2/Einw.
# EINHEIT_LANG                Quadratmeter pro Einwohner
#
#                                                   3395  \
# BFS_NR                                             211
# GEBIET_NAME                                    Altikon
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                   Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                                   Bauzonen
# INDIKATOR_ID                                        50
# INDIKATOR_NAME   Bauzonen überbaut pro Kopf [m2/Einw.]
# INDIKATOR_JAHR                                    1999
# INDIKATOR_VALUE                                  283.0
# EINHEIT_KURZ                                  m2/Einw.
# EINHEIT_LANG                Quadratmeter pro Einwohner
#
#                                                   3420
# BFS_NR                                             213
# GEBIET_NAME                                    Brütten
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                   Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                                   Bauzonen
# INDIKATOR_ID                                        50
# INDIKATOR_NAME   Bauzonen überbaut pro Kopf [m2/Einw.]
# INDIKATOR_JAHR                                    1999
# INDIKATOR_VALUE                                  251.0
# EINHEIT_KURZ                                  m2/Einw.
# EINHEIT_LANG                Quadratmeter pro Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          4921                4921                         4921
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# freq             25                4921                         4921
#
#        SUBSET_NAME                         INDIKATOR_NAME EINHEIT_KURZ  \
# count         4921                                   4921         4921
# unique           1                                      1            1
# top       Bauzonen  Bauzonen überbaut pro Kopf [m2/Einw.]     m2/Einw.
# freq          4921                                   4921         4921
#
#                       EINHEIT_LANG
# count                         4921
# unique                           1
# top     Quadratmeter pro Einwohner
# freq                          4921

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,921.00      4,921.00        4,921.00         4,921.00
# mean    110.00         50.00        2,007.84           249.75
# std      86.58          0.00            7.16            62.39
# min       0.00         50.00        1,996.00           102.70
# 25%      32.00         50.00        2,002.00           206.00
# 50%      95.00         50.00        2,008.00           241.00
# 75%     180.00         50.00        2,014.00           291.00
# max     298.00         50.00        2,020.00           479.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

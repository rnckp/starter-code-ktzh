# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Unfälle [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Anzahl Unfälle pro 1000 Einwohner Total (mit Personen- und/oder Sachschaden)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **393@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-09-22T10:10:00`
# - **Modified** `2022-08-26T14:00:39`
# - **Startdate** `2010-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['kanton_zuerich', 'verkehr', 'verkehrsunfaelle', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 502
# Title                    : Unfälle [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-09-22T10:10:00
# Modified                 : 2022-08-26T14:00:39
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_820.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_820.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,340 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2340 entries, 0 to 2339
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2340 non-null   int64
#  1   GEBIET_NAME      2340 non-null   object
#  2   THEMA_NAME       2340 non-null   object
#  3   SET_NAME         2340 non-null   object
#  4   SUBSET_NAME      2340 non-null   object
#  5   INDIKATOR_ID     2340 non-null   int64
#  6   INDIKATOR_NAME   2340 non-null   object
#  7   INDIKATOR_JAHR   2340 non-null   int64
#  8   INDIKATOR_VALUE  2340 non-null   float64
#  9   EINHEIT_KURZ     2340 non-null   object
#  10  EINHEIT_LANG     2340 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle           820
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle           820
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle           820
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle           820
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle           820
#
#              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE    EINHEIT_KURZ  \
# 0  Unfälle [pro 1000 Einw.]            2010              3.3  pro 1000 Einw.
# 1  Unfälle [pro 1000 Einw.]            2011              6.8  pro 1000 Einw.
# 2  Unfälle [pro 1000 Einw.]            2012              4.6  pro 1000 Einw.
# 3  Unfälle [pro 1000 Einw.]            2013              5.1  pro 1000 Einw.
# 4  Unfälle [pro 1000 Einw.]            2014              4.1  pro 1000 Einw.
#
#             EINHEIT_LANG
# 0  pro Tausend Einwohner
# 1  pro Tausend Einwohner
# 2  pro Tausend Einwohner
# 3  pro Tausend Einwohner
# 4  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      1258                      117   \
# BFS_NR                                153                        10
# GEBIET_NAME                 Hombrechtikon                  Obfelden
# THEMA_NAME                Raum und Umwelt           Raum und Umwelt
# SET_NAME                          Verkehr                   Verkehr
# SUBSET_NAME                       Unfälle                   Unfälle
# INDIKATOR_ID                          820                       820
# INDIKATOR_NAME   Unfälle [pro 1000 Einw.]  Unfälle [pro 1000 Einw.]
# INDIKATOR_JAHR                       2016                      2019
# INDIKATOR_VALUE                       5.1                      11.4
# EINHEIT_KURZ               pro 1000 Einw.            pro 1000 Einw.
# EINHEIT_LANG        pro Tausend Einwohner     pro Tausend Einwohner
#
#                                      821
# BFS_NR                                 90
# GEBIET_NAME                   Niederhasli
# THEMA_NAME                Raum und Umwelt
# SET_NAME                          Verkehr
# SUBSET_NAME                       Unfälle
# INDIKATOR_ID                          820
# INDIKATOR_NAME   Unfälle [pro 1000 Einw.]
# INDIKATOR_JAHR                       2015
# INDIKATOR_VALUE                       6.2
# EINHEIT_KURZ               pro 1000 Einw.
# EINHEIT_LANG        pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  \
# count          2340             2340     2340        2340
# unique          202                1        1           1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr     Unfälle
# freq             12             2340     2340        2340
#
#                   INDIKATOR_NAME    EINHEIT_KURZ           EINHEIT_LANG
# count                       2340            2340                   2340
# unique                         1               1                      1
# top     Unfälle [pro 1000 Einw.]  pro 1000 Einw.  pro Tausend Einwohner
# freq                        2340            2340                   2340

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,340.00      2,340.00        2,340.00         2,340.00
# mean    110.21        820.00        2,015.39             8.50
# std      87.24          0.00            3.44             5.56
# min       0.00        820.00        2,010.00             0.00
# 25%      31.00        820.00        2,012.00             5.30
# 50%      95.00        820.00        2,015.00             7.30
# 75%     182.00        820.00        2,018.00            10.10
# max     298.00        820.00        2,021.00            57.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

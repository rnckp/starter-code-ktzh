# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Quartier-Infokästen der Stadt Uster und Quartiervereinen

# %% [markdown]
# ### **Description**: Quartierkästen sind Schaukästen, in denen Informationsmaterial ausgehängt wird. Es sind Quartierkästen mit Längen- und Breitengrad verzeichnet, die von der Stadt Uster und den Quartiervereinen gemeinsam bewirtschaftet werden (sind im Eigentum der Stadt Uster) und solche die auf private Initiative von den Quartiervereinen bewirtschafet werden. Über die gemeinsam bewirtschafteten Quartierkästen werden wöchentlich die wichtigsten Informationen aus der Stadtverwaltung der Bevölkerung zugänglich gemacht. Fotos der Quartierkästen werden unregelmässig ca. alle 3 bis 5 Jahre aktualisiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **720@geschaeftsfeld-gesellschaft-stadt-uster**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-07-07T11:26:00`
# - **Modified** `2021-07-09T08:09:52`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Kultur, Medien, Informationsgesellschaft, Sport', 'Politik', 'Bevölkerung', 'Volkswirtschaft']`
# - **Keyword** `['quartiervereine', 'gemeinwesen', 'kommunikation', 'quartier', 'information', 'ogd']`
# - **Publisher** `['Geschäftsfeld Gesellschaft der Stadt Uster']`
# - **Landingpage** `https://github.com/GesellschaftStadtUster/quartier_infokaesten`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1803
# Title                    : Tabelle mit allen Quartierkästen der Stadt Uster und Quartiervereinen
# Description              : Variabeln: 'standort', 'quartierverein', 'besitzer' = 'stadt' oder 'quartierverein', 'lat' = Breitengrad, 'lng' = Längengrad, 'bild_kasten' = URL zum Foto des Quartierkastens, 'link_google-streetview' = URL zum Foto des Quartierkastens auf Google Streetview.
# Issued                   : 2021-04-12T15:38:29
# Modified                 : 2021-07-09T08:09:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/quartier_infokaesten/main/liste_quartierinfokaesten.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/quartier_infokaesten/main/liste_quartierinfokaesten.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 10 rows (observations) and 7 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   standort                10 non-null     object
#  1   quartierverein          10 non-null     object
#  2   besitzer                10 non-null     object
#  3   lat                     10 non-null     float64
#  4   lng                     10 non-null     float64
#  5   bild_kasten             10 non-null     object
#  6   link_google-streetview  10 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.6 KB

# %%
df.head()
# Out:
#           standort     quartierverein besitzer        lat       lng  \
# 0  NaenikonBahnhof           Naenikon    stadt  47.369952  8.685233
# 1  NaenikonTuermli           Naenikon    stadt  47.370461  8.692937
# 2      Loren-Allee  Winikon-Gschwader    stadt  47.358209  8.709599
# 3        Gschwader  Winikon-Gschwader    stadt  47.360098  8.714701
# 4       Wermatswil         Wermatswil    stadt  47.361597  8.745930
#
#                                          bild_kasten  \
# 0  https://raw.githubusercontent.com/Gesellschaft...
# 1  https://raw.githubusercontent.com/Gesellschaft...
# 2  https://raw.githubusercontent.com/Gesellschaft...
# 3  https://raw.githubusercontent.com/Gesellschaft...
# 4  https://raw.githubusercontent.com/Gesellschaft...
#
#                   link_google-streetview
# 0  https://goo.gl/maps/8FoQrvXfNWwgp8hw7
# 1  https://goo.gl/maps/eB1uy1LGuwrnbqfH8
# 2  https://goo.gl/maps/s3PTvTyJqwJEcStv6
# 3  https://goo.gl/maps/g1z6M5THwJ3MNwhh6
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                         1  \
# standort                                                  NaenikonTuermli
# quartierverein                                                   Naenikon
# besitzer                                                            stadt
# lat                                                             47.370461
# lng                                                              8.692937
# bild_kasten             https://raw.githubusercontent.com/Gesellschaft...
# link_google-streetview              https://goo.gl/maps/eB1uy1LGuwrnbqfH8
#
#                                                                         5  \
# standort                                                         Freudwil
# quartierverein                                                   Freudwil
# besitzer                                                            stadt
# lat                                                              47.37463
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                standort quartierverein besitzer  \
# count                10             10       10
# unique               10              8        2
# top     NaenikonBahnhof       Naenikon    stadt
# freq                  1              2        9
#
#                                               bild_kasten  \
# count                                                  10
# unique                                                 10
# top     https://raw.githubusercontent.com/Gesellschaft...
# freq                                                    1
#
#                        link_google-streetview
# count                                      10
# unique                                     10
# top     https://goo.gl/maps/8FoQrvXfNWwgp8hw7
# freq                                        1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         lat   lng
# count 10.00 10.00
# mean  47.36  8.71
# std    0.02  0.02
# min   47.33  8.69
# 25%   47.35  8.70
# 50%   47.36  8.71
# 75%   47.37  8.73
# max   47.37  8.75

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Geschäftsfeld Gesellschaft der Stadt Uster | Quartier- und Gemeinwesenarbeit | quartier@uster.ch

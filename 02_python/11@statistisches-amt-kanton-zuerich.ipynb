# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: NRW Wähleranteil AL [%]

# %% [markdown]
# ### **Description**: Wähleranteil AL bei Nationalratswahlen. Hinweis: 2015 werden alle Auslandschweizer zur Stadt Zürich gezählt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **11@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-10-21T10:29:00`
# - **Startdate** `1999-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'nationalratswahlen', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 10
# Title                    : NRW Wähleranteil AL [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-10-21T10:29:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_440.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_440.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,128 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1128 non-null   int64
#  1   GEBIET_NAME      1128 non-null   object
#  2   THEMA_NAME       1128 non-null   object
#  3   SET_NAME         1128 non-null   object
#  4   SUBSET_NAME      1128 non-null   object
#  5   INDIKATOR_ID     1128 non-null   int64
#  6   INDIKATOR_NAME   1128 non-null   object
#  7   INDIKATOR_JAHR   1128 non-null   int64
#  8   INDIKATOR_VALUE  1128 non-null   float64
#  9   EINHEIT_KURZ     1128 non-null   object
#  10  EINHEIT_LANG     1128 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 659.2 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           440
# 1       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           440
# 2       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           440
# 3       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           440
# 4       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           440
#
#             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  NRW Wähleranteil AL [%]            1999              1.6            %
# 1  NRW Wähleranteil AL [%]            2003              1.1            %
# 2  NRW Wähleranteil AL [%]            2007              0.6            %
# 3  NRW Wähleranteil AL [%]            2011              0.2            %
# 4  NRW Wähleranteil AL [%]            2015              1.1            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      159                      769  \
# BFS_NR                                33                      193
# GEBIET_NAME             Kleinandelfingen                Fällanden
# THEMA_NAME                       Politik                  Politik
# SET_NAME                   Wähleranteile            Wähleranteile
# SUBSET_NAME                  Nationalrat              Nationalrat
# INDIKATOR_ID                         440                      440
# INDIKATOR_NAME   NRW Wähleranteil AL [%]  NRW Wähleranteil AL [%]
# INDIKATOR_JAHR                      2011                     2011
# INDIKATOR_VALUE                      0.3                      0.8
# EINHEIT_KURZ                           %                        %
# EINHEIT_LANG                     Prozent                  Prozent
#
#                                      190
# BFS_NR                                38
# GEBIET_NAME                      Rheinau
# THEMA_NAME                       Politik
# SET_NAME                   Wähleranteile
# SUBSET_NAME                  Nationalrat
# INDIKATOR_ID                         440
# INDIKATOR_NAME   NRW Wähleranteil AL [%]
# INDIKATOR_JAHR                      2019
# INDIKATOR_VALUE                      1.5
# EINHEIT_KURZ                           %
# EINHEIT_LANG                     Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  \
# count          1128       1128           1128         1128
# unique          200          1              1            1
# top     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# freq              6       1128           1128         1128
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                      1128         1128         1128
# unique                        1            1            1
# top     NRW Wähleranteil AL [%]            %      Prozent
# freq                       1128         1128         1128

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,128.00      1,128.00        1,128.00         1,128.00
# mean    109.99        440.00        2,008.99             0.80
# std      83.08          0.00            6.72             0.61
# min       0.00        440.00        1,999.00             0.00
# 25%      35.00        440.00        2,003.00             0.40
# 50%      96.50        440.00        2,011.00             0.70
# 75%     179.00        440.00        2,015.00             1.00
# max     298.00        440.00        2,019.00             4.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

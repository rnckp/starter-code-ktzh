# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Hotels [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Hotels im Juni des Erhebungsjahres. Daten des aktuellsten Jahres sind provisorisch! Daten des Jahres 2004 aus der Erhebung der Statistischen Ämter von Stadt und Kanton Zürich, da das BFS 2004 keine Erhebung duchgeführt hat.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **58@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:00:03`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Industrie, Dienstleistungen']`
# - **Keyword** `['betriebe', 'bezirke', 'gastgewerbe', 'gemeinden', 'hotelbetriebe', 'hotellerie', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 51
# Title                    : Hotels [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:00:03
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_303.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_303.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,230 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6230 entries, 0 to 6229
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6230 non-null   int64
#  1   GEBIET_NAME      6230 non-null   object
#  2   THEMA_NAME       6230 non-null   object
#  3   SET_NAME         6230 non-null   object
#  4   SUBSET_NAME      6230 non-null   object
#  5   INDIKATOR_ID     6230 non-null   int64
#  6   INDIKATOR_NAME   6230 non-null   object
#  7   INDIKATOR_JAHR   6230 non-null   int64
#  8   INDIKATOR_VALUE  6230 non-null   int64
#  9   EINHEIT_KURZ     6230 non-null   object
#  10  EINHEIT_LANG     6230 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME                   SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
#
#   SUBSET_NAME  INDIKATOR_ID INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0      Hotels           303  Hotels [Anz.]            1990                0
# 1      Hotels           303  Hotels [Anz.]            1991                0
# 2      Hotels           303  Hotels [Anz.]            1992                0
# 3      Hotels           303  Hotels [Anz.]            1993                0
# 4      Hotels           303  Hotels [Anz.]            1994                0
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0         Anz.       Anzahl
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                       3160                       3104  \
# BFS_NR                                 137                        135
# GEBIET_NAME                     Oberrieden                  Kilchberg
# THEMA_NAME          Arbeit und Unternehmen     Arbeit und Unternehmen
# SET_NAME         Beherbergung, Gastronomie  Beherbergung, Gastronomie
# SUBSET_NAME                         Hotels                     Hotels
# INDIKATOR_ID                           303                        303
# INDIKATOR_NAME               Hotels [Anz.]              Hotels [Anz.]
# INDIKATOR_JAHR                        2002                       2010
# INDIKATOR_VALUE                          0                          0
# EINHEIT_KURZ                          Anz.                       Anz.
# EINHEIT_LANG                        Anzahl                     Anzahl
#
#                                       163
# BFS_NR                                   6
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME                   SET_NAME  \
# count          6230                    6230                       6230
# unique          200                       1                          1
# top     Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# freq             32                    6230                       6230
#
#        SUBSET_NAME INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count         6230           6230         6230         6230
# unique           1              1            1            1
# top         Hotels  Hotels [Anz.]         Anz.       Anzahl
# freq          6230           6230         6230         6230

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,230.00      6,230.00        6,230.00         6,230.00
# mean    107.33        303.00        2,005.43             6.08
# std      84.15          0.00            9.19            25.48
# min       0.00        303.00        1,990.00             0.00
# 25%      31.00        303.00        1,997.00             0.00
# 50%      94.00        303.00        2,005.00             1.00
# 75%     178.00        303.00        2,013.00             2.75
# max     298.00        303.00        2,021.00           319.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

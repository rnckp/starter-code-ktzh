# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Verzeichnis der Personenstammdaten der zentralen Verwaltung des Kantons Zürich

# %% [markdown]
# ### **Description**: Im Rahmen des Impulsprojekts 3.1 "Strategie Datenmanagement und Data-Governance" wurde ein - nicht abschliessendes - Verzeichnis der Personenstammdaten erarbeitet, die von Einheiten der zentralen Verwaltung des Kantons Zürich zu ihrer fachspezifischen Aufgabenerfüllung verwaltet und/oder genutzt werden. Das Verzeichnis ist eine Grundlage für die Einführung eines koordinierten Stammdatenmanagements. Es wird in maschinenlesbarer Form zur Verfügung gestellt, um zweckmässige Anwendungen zu ermöglichen, mit denen es verwaltet und/oder genutzt werden kann. Das Verzeichnis wird unregelmässig aktualisiert. Die Verwaltungseinheiten sind für ihre Angaben verantwortlich. Bei Fragen, Korrekturen und Ergänzungen wenden Sie sich bitte an die Kontaktstelle.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **700@fachstelle-ogd-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-09-29T14:45:00`
# - **Modified** `2020-10-01T11:32:26`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['direktionen', 'kantonale_verwaltung', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/kanton/kantonale-verwaltung/digitale-verwaltung/digitalisierungsprojekte.html#1124425435`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`3` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1723
# Title                    : Verzeichnis der Personenstammdaten ZH - Abkürzungen und Definitionen
# Description              : None
# Issued                   : 2020-09-17T15:19:34
# Modified                 : 2020-09-29T17:56:31
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001723.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001723.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1725
# Title                    : Verzeichnis der Personenstammdaten ZH - Merkmale zu Verwaltungseinheiten
# Description              : Abkürzungen und Definitionen sind in der Ressource "Verzeichnis der Personenstammdaten ZH - Abkürzungen und Definitionen" erklärt.
# Issued                   : 2020-09-17T15:31:37
# Modified                 : 2020-10-01T11:32:36
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001725.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001725.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 1724
# Title                    : Verzeichnis der Personenstammdaten ZH - Merkmale zu Registern und Systemen
# Description              : Abkürzungen und Definitionen sind in der Ressource "Verzeichnis der Personenstammdaten ZH - Abkürzungen und Definitionen" erklärt.
# Issued                   : 2020-09-17T15:27:53
# Modified                 : 2020-10-01T11:32:26
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001724.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000700_00001724.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 100 rows (observations) and 16 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   domaene                     100 non-null    object
#  1   merkmal                     100 non-null    object
#  2   UPI                         1 non-null      object
#  3   ZEMIS                       12 non-null     object
#  4   InfoStar                    36 non-null     object
#  5   PISA                        10 non-null     object
#  6   MOFIS                       5 non-null      object
#  7   kantonales_handelsregister  47 non-null     object
#  8   krebsregister               25 non-null     object
#  9   steuerregister              1 non-null      object
#  10  MILVA                       4 non-null      object
#  11  KEP                         77 non-null     object
#  12  VK                          8 non-null      object
#  13  ELAR                        11 non-null     object
#  14  PuM                         1 non-null      object
#  15  EWR_ und_SR                 78 non-null     object
# dtypes: object(16)
# memory usage: 66.4 KB

# %%
df.head()
# Out:
#          domaene                        merkmal   UPI ZEMIS InfoStar  PISA  \
# 0  Personendaten  AHV_Versichertennummer_AHVN13  CRUD  CRUD      NaN  CRUD
# 1  Personendaten                 Amtlicher_Name   NaN  CRUD     CRUD  CRUD
# 2  Personendaten                      Ledigname   NaN   NaN     CRUD   NaN
# 3  Personendaten                    Allianzname   NaN   NaN     CRUD   NaN
# 4  Personendaten    Name_im_auslaendischen_Pass   NaN   NaN     CRUD   NaN
#
#   MOFIS kantonales_handelsregister krebsregister steuerregister MILVA KEP  \
# 0   NaN                          R             R            NaN   NaN   R
# 1  CRUD                          R            CU            NaN     R   R
# 2   NaN                          R           NaN            NaN   NaN   R
# 3   NaN                          R           NaN            NaN   NaN   R
# 4   NaN                          R           NaN            NaN   NaN   R
#
#      VK  ELAR  PuM EWR_ und_SR
# 0   NaN  CRUD  NaN           R
# 1  CRUD   NaN  NaN           R
# 2   NaN   NaN  NaN           R
# 3   NaN   NaN  NaN           R
# 4   NaN   NaN  NaN           R

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                        15                                44  \
# domaene                     Personendaten                     Personendaten
# merkmal                     Geburtsort_CH  Herkunftsort_Status_Herkunfstaat
# UPI                                   NaN                               NaN
# ZEMIS                                 NaN                               NaN
# InfoStar                             CRUD                               NaN
# PISA                                  NaN                               NaN
# MOFIS                                 NaN                               NaN
# kantonales_handelsregister            NaN                               NaN
# krebsregister                         NaN                               NaN
# steuerregister                        NaN                               NaN
# MILVA                                 NaN                               NaN
# KEP                                     R                                 R
# VK                                    NaN                               NaN
# ELAR                                  NaN                               NaN
# PuM                                   NaN                               NaN
# EWR_ und_SR                             R                              CRUD
#
#                                         96
# domaene                      Personendaten
# merkmal                     Gemeindenummer
# UPI                                    NaN
# ZEMIS                                  NaN
# InfoStar                               NaN
# PISA                                   NaN
# MOFIS                                  NaN
# kantonales_handelsregister             NaN
# krebsregister                          NaN
# steuerregister                         NaN
# MILVA                                  NaN
# KEP                                    NaN
# VK                                     NaN
# ELAR                                   NaN
# PuM                                    NaN
# EWR_ und_SR                           CRUD

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#               domaene                        merkmal   UPI ZEMIS InfoStar  \
# count             100                            100     1    12       36
# unique              1                            100     1     1        1
# top     Personendaten  AHV_Versichertennummer_AHVN13  CRUD  CRUD     CRUD
# freq              100                              1     1    12       36
#
#         PISA MOFIS kantonales_handelsregister krebsregister steuerregister  \
# count     10     5                         47            25              1
# unique     1     1                          2             3              1
# top     CRUD  CRUD                          R             R              R
# freq      10     5                         45            15              1
#
#        MILVA KEP    VK  ELAR   PuM EWR_ und_SR
# count      4  77     8    11     1          78
# unique     1   1     1     1     1           2
# top        R   R  CRUD  CRUD  CRUD        CRUD
# freq       4  77     8    11     1          42

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(include='number'))
    except:
        pass

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, layout=(-1, 5), edgecolor='black');
except:
    pass

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Fachstelle Open Government Data des Kantons Zürich |  | info@open.zh.ch

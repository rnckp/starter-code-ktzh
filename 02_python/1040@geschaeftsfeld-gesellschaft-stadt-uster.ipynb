# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Angebote und Infrastruktur für Kinder, Jugendliche und Familien in der Stadt Uster

# %% [markdown]
# ### **Description**: Angebote und Infrastruktur für Kinder, Jugendliche und Familien in der Stadt Uster. Der Datensatz umfasst Koordinaten, Adressen, Kategorien (siehe Liste der Kategorien im "Readme: Datenstruktur" unter "Weitere Informationen"), Zugänglichkeitsangaben (siehe Optionen der Zugänglichkeit ebenda), Beschreibungen sowie Webseiten-Links.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1040@geschaeftsfeld-gesellschaft-stadt-uster**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-11-22T00:00:00`
# - **Modified** `2021-11-23T08:11:28`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Kultur, Medien, Informationsgesellschaft, Sport', 'Soziale Sicherheit']`
# - **Keyword** `['familie', 'familienberatung', 'jugendberatung', 'kinder', 'kinderbetreuung', 'kindergarten', 'kinderkrippen', 'kleinkinderbetreuung', 'ogd']`
# - **Publisher** `['Geschäftsfeld Gesellschaft der Stadt Uster']`
# - **Landingpage** `https://github.com/GesellschaftStadtUster/kind-jugend-fam_angebote`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1957
# Title                    : Tabelle der Angebote und Infrastruktur für Kinder, Jugendliche und Familien in der Stadt Uster
# Description              : Variabeln: 'lng' = Längengrad, 'lat' = Breitengrad, 'name' = Name des Angebots, 'strasse', 'hausnr', 'plz', 'ort', 'anlage' = Name der Anlage, 'kategorie' = Kategorie des Angebots (siehe Liste der Kategorien im "Readme: Datenstruktur" unter "Weitere Informationen"), 'zugaenglichkeit' = (siehe Optionen der Zugänglichkeit ebenda), 'beschreibung' = Beschreibung des Angebots, 'website' = URL des Angebots.
# Issued                   : 2021-11-22T23:05:02
# Modified                 : 2021-11-23T08:11:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_angebote/main/angebote_kjf_uster.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_angebote/main/angebote_kjf_uster.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 148 rows (observations) and 12 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   lng              148 non-null    float64
#  1   lat              148 non-null    float64
#  2   name             148 non-null    object
#  3   strasse          80 non-null     object
#  4   hausnr           79 non-null     object
#  5   plz              80 non-null     float64
#  6   ort              80 non-null     object
#  7   anlage           71 non-null     object
#  8   kategorie        148 non-null    object
#  9   zugaenglichkeit  141 non-null    object
#  10  beschreibung     25 non-null     object
#  11  website          85 non-null     object
# dtypes: float64(3), object(9)
# memory usage: 99.5 KB

# %%
df.head()
# Out:
#         lng        lat                           name             strasse  \
# 0  8.692224  47.369175            Schulhäuser Nänikon       Baumgartenweg
# 1  8.693179  47.368784  Klairs - Näniker Vereinslokal         Bühlstrasse
# 2  8.691505  47.368917         Kindergarten Vogelsang             Bühlweg
# 3  8.684670  47.369184       Kindergarten Mettmenried  Mettmenriedstrasse
# 4  8.686746  47.371405        Waldspielgruppe Wurzeln      Murggenstrasse
#
#   hausnr     plz      ort                 anlage  \
# 0      6  8606.0  Nänikon  Schulanlage Singvogel
# 1     16  8606.0  Nänikon                    NaN
# 2     10  8606.0  Nänikon                    NaN
# 3      7  8606.0  Nänikon                    NaN
# 4     32  8606.0  Nänikon                    NaN
#
#                               kategorie  \
# 0                  Schule: Primarschule
# 1  Freizeitanlage: Gemeinschaftszentrum
# 2                  Schule: Kindergarten
# 3                  Schule: Kindergarten
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                 91  \
# lng                                                       8.715139
# lat                                                      47.348007
# name                                        Spielplatz Untere Farb
# strasse                                                        NaN
# hausnr                                                         NaN
# plz                                                            NaN
# ort                                                            NaN
# anlage                                                         NaN
# kategorie                               Freizeitanlage: Spielplatz
# zugaenglichkeit  öffentlicher Raum (resp. vergleichbare Zugängl...
# beschreibung     Anschliessend zum Stadtpark, im Schatten eines...
# website                                                        NaN
#
#                                                                 47  \
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                          name        strasse hausnr    ort  \
# count                     148             80     79     80
# unique                    133             51     37      4
# top     Schulanlage Singvogel  Zürichstrasse     32  Uster
# freq                        3              8      6     68
#
#                       anlage                   kategorie zugaenglichkeit  \
# count                     71                         148             141
# unique                    16                          25               4
# top     Sportanlage Buchholz  Freizeitanlage: Spielplatz  Räumlichkeiten
# freq                       9                          30              58
#
#                            beschreibung                           website
# count                                25                                85
# unique                               25                                60
# top     Dreh-Scheibe und Schaukelsessel  http://www.uster.ch/anlagen/9532
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          lng    lat      plz
# count 148.00 148.00    80.00
# mean    8.72  47.35 8,609.99
# std     0.01   0.01     1.81
# min     8.68  47.33 8,606.00
# 25%     8.71  47.35 8,610.00
# 50%     8.72  47.35 8,610.00
# 75%     8.72  47.36 8,610.00
# max     8.75  47.37 8,616.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Geschäftsfeld Gesellschaft der Stadt Uster | Kindheit, Jugend und Familie | kindheit@uster.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ## Dataset: **Sterbefälle [Pers.]**

# %% [markdown]
# ## Description
#
# Anzahl Sterbefälle pro Jahr
#
# **[Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.zhweb-noredirect.zhweb-cache.html?keywords=ogd#/datasets/200@statistisches-amt-kanton-zuerich)**

# %% [markdown]
# *Autogenerated Python starter code for data set with identifier* **200@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Metadata
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungsbewegungen', 'bezirke', 'gemeinden', 'kanton_zuerich', 'sterbefaelle', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for properly reading datasets
def get_dataset(url):
    data = pd.read_csv(url, on_bad_lines='warn', encoding_errors='ignore')
    # if dataframe only has one column or less the "," separator was wrong, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore')
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 163
# Title                    : Sterbefälle [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_101.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,248 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6248 entries, 0 to 6247
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6248 non-null   int64
#  1   GEBIET_NAME      6248 non-null   object
#  2   THEMA_NAME       6248 non-null   object
#  3   SET_NAME         6248 non-null   object
#  4   SUBSET_NAME      6248 non-null   object
#  5   INDIKATOR_ID     6248 non-null   int64
#  6   INDIKATOR_NAME   6248 non-null   object
#  7   INDIKATOR_JAHR   6248 non-null   int64
#  8   INDIKATOR_VALUE  6247 non-null   float64
#  9   EINHEIT_KURZ     6248 non-null   object
#  10  EINHEIT_LANG     6248 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID       INDIKATOR_NAME  \
# 0  Geburten und Sterbefälle           101  Sterbefälle [Pers.]
# 1  Geburten und Sterbefälle           101  Sterbefälle [Pers.]
# 2  Geburten und Sterbefälle           101  Sterbefälle [Pers.]
# 3  Geburten und Sterbefälle           101  Sterbefälle [Pers.]
# 4  Geburten und Sterbefälle           101  Sterbefälle [Pers.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            1990              9.0        Pers.     Personen
# 1            1991              8.0        Pers.     Personen
# 2            1992              8.0        Pers.     Personen
# 3            1993              9.0        Pers.     Personen
# 4            1994              8.0        Pers.     Personen

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      1319                      800   \
# BFS_NR                                 54                        32
# GEBIET_NAME                     Dietlikon                  Humlikon
# THEMA_NAME       Bevölkerung und Soziales  Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbewegung      Bevölkerungsbewegung
# SUBSET_NAME      Geburten und Sterbefälle  Geburten und Sterbefälle
# INDIKATOR_ID                          101                       101
# INDIKATOR_NAME        Sterbefälle [Pers.]       Sterbefälle [Pers.]
# INDIKATOR_JAHR                       2006                      1990
# INDIKATOR_VALUE                      35.0                       4.0
# EINHEIT_KURZ                        Pers.                     Pers.
# EINHEIT_LANG                     Personen                  Personen
#
#                                      182
# BFS_NR                                  6
# GEBIET_NAME                   Kappel a.A.
# THEMA_NAME       Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbewegung
# SUBSET_NAME      Geburten und Sterbefälle
# INDIKATOR_ID                          101
# INDIKATOR_NAME        Sterbefälle [Pers.]
# INDIKATOR_JAHR                       2012
# INDIKATOR_VALUE                       4.0
# EINHEIT_KURZ                        Pers.
# EINHEIT_LANG                     Personen

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          6248                      6248                  6248
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             32                      6248                  6248
#
#                      SUBSET_NAME       INDIKATOR_NAME EINHEIT_KURZ  \
# count                       6248                 6248         6248
# unique                         1                    1            1
# top     Geburten und Sterbefälle  Sterbefälle [Pers.]        Pers.
# freq                        6248                 6248         6248
#
#        EINHEIT_LANG
# count          6248
# unique            1
# top        Personen
# freq           6248

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,248.00      6,248.00        6,248.00         6,247.00
# mean    107.87        101.00        2,005.44           219.95
# std      84.62          0.00            9.20           920.17
# min       0.00        101.00        1,990.00             0.00
# 25%      31.00        101.00        1,997.00             9.00
# 50%      94.00        101.00        2,005.00            24.00
# 75%     178.00        101.00        2,013.00            79.00
# max     298.00        101.00        2,021.00        12,078.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Polizeilich registrierte Verkehrsunfälle im Kanton Zürich seit 2011

# %% [markdown]
# ### **Description**: Die Verkehrsunfallstatistik des Kantons Zürich (VUSTA) enthält die Strassenverkehrsunfälle mit Personen- und Sachschäden, die durch die Kantonspolizei Zürich, die Dienstabteilung Verkehr der Stadt Zürich sowie die Stadtpolizei Winterthur registriert wurden. Sie wird einmal jährlich aktualisiert, jeweils gegen Ende des ersten Quartals des Folgejahres.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **718@kantonspolizei-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-03-09T13:51:00`
# - **Modified** `2022-10-03T14:11:57`
# - **Startdate** `2011-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Gesundheit', 'Mobilität und Verkehr']`
# - **Keyword** `['fahrzeuge', 'langsamverkehr', 'motorfahrzeuge', 'motorraeder', 'sachschaden', 'strassenverkehr', 'strassenverkehrsunfaelle', 'verkehrsunfaelle', 'gesamtverkehrsdaten', 'ogd']`
# - **Publisher** `['Kantonspolizei des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1783
# Title                    : Polizeilich registrierte Verkehrsunfälle im Kanton Zürich
# Description              : Zu jedem Strassenverkehrsunfall sind der Unfallort (geokodiert), das Jahr, der Monat, der Wochentag, die Unfallstunde, die Strassenart, der Unfalltyp (ab 1. Juli 2015 inklusive Bagatellunfälle zB. Parkschäden), die Unfallbeteiligung ('Fussgänger', 'Velo (ohne E-Bikes)', 'Motorrad') und die Unfallschwerekategorie verfügbar. Detaillierte Definitionen der Variabeln sind in der Ressource "Minimales Geodatenmodell Strassenverkehrsunfallorte (ASTRA)" dokumentiert.
# Issued                   : 2021-01-25T15:41:19
# Modified                 : 2022-10-03T13:43:04
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000718_00001783.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000718_00001783.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 163,695 rows (observations) and 36 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163695 entries, 0 to 163694
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   AccidentUID                  163695 non-null  object
#  1   AccidentType                 163695 non-null  object
#  2   AccidentType_de              163695 non-null  object
#  3   AccidentType_fr              163695 non-null  object
#  4   AccidentType_it              163695 non-null  object
#  5   AccidentType_en              163695 non-null  object
#  6   AccidentSeverityCategory     163695 non-null  object
#  7   AccidentSeverityCategory_de  163695 non-null  object
#  8   AccidentSeverityCategory_fr  163695 non-null  object
#  9   AccidentSeverityCategory_it  163695 non-null  object
#  10  AccidentSeverityCategory_en  163695 non-null  object
#  11  AccidentInvolvingPedestrian  163695 non-null  bool
#  12  AccidentInvolvingBicycle     163695 non-null  bool
#  13  AccidentInvolvingMotorcycle  163695 non-null  bool
#  14  RoadType                     163695 non-null  object
#  15  RoadType_de                  163695 non-null  object
#  16  RoadType_fr                  163695 non-null  object
#  17  RoadType_it                  163695 non-null  object
#  18  RoadType_en                  163695 non-null  object
#  19  AccidentLocation_CHLV95_E    163695 non-null  int64
#  20  AccidentLocation_CHLV95_N    163695 non-null  int64
#  21  CantonCode                   163695 non-null  object
#  22  MunicipalityCode             163695 non-null  int64
#  23  AccidentYear                 163695 non-null  int64
#  24  AccidentMonth                163695 non-null  int64
#  25  AccidentMonth_de             163695 non-null  object
#  26  AccidentMonth_fr             163695 non-null  object
#  27  AccidentMonth_it             163695 non-null  object
#  28  AccidentMonth_en             163695 non-null  object
#  29  AccidentWeekDay              163695 non-null  object
#  30  AccidentWeekDay_de           163695 non-null  object
#  31  AccidentWeekDay_fr           163695 non-null  object
#  32  AccidentWeekDay_it           163695 non-null  object
#  33  AccidentWeekDay_en           163695 non-null  object
#  34  AccidentHour                 161839 non-null  float64
#  35  AccidentHour_text            163695 non-null  object
# dtypes: bool(3), float64(1), int64(5), object(27)
# memory usage: 330.7 MB

# %%
df.head()
# Out:
#                         AccidentUID AccidentType  \
# 0  A70191D0D45E00B0E0430A83942700B0          at0
# 1  A2D2677533867004E0430A865E337004          at0
# 2  9FD6441F802C20A6E0430A865E3320A6          at0
# 3  A7016B9BBC3301A8E0430A83942701A8          at0
# 4  9FDA0DC4856A6094E0430A865E336094          at0
#
#                 AccidentType_de                AccidentType_fr  \
# 0  Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
# 1  Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
# 2  Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
# 3  Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
# 4  Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
#
#                                 AccidentType_it  \
# 0  Incidente di sbandamento o per colpa propria
# 1  Incidente di sbandamento o per colpa propria
# 2  Incidente di sbandamento o per colpa propria
# 3  Incidente di sbandamento o per colpa propria
# 4  Incidente di sbandamento o per colpa propria
#
#                            AccidentType_en AccidentSeverityCategory  \
# 0  Accident with skidding or self-accident                      as4
# 1  Accident with skidding or self-accident                      as4
# 2  Accident with skidding or self-accident                      as3
# 3  Accident with skidding or self-accident                      as4
# 4  Accident with skidding or self-accident                      as4
#
#    AccidentSeverityCategory_de       AccidentSeverityCategory_fr  \
# 0       Unfall mit Sachschaden  accident avec dommages matériels
# 1       Unfall mit Sachschaden  accident avec dommages matériels
# 2  Unfall mit Leichtverletzten      accident avec blessés légers
# 3       Unfall mit Sachschaden  accident avec dommages matériels
# 4       Unfall mit Sachschaden  accident avec dommages matériels
#
#      AccidentSeverityCategory_it  ... AccidentMonth_fr  AccidentMonth_it  \
# 0  Incidente con danni materiali  ...          janvier           Gennaio
# 1  Incidente con danni materiali  ...          janvier           Gennaio
# 2   Incidente con feriti leggeri  ...          janvier           Gennaio
# 3  Incidente con danni materiali  ...          janvier           Gennaio
# 4  Incidente con danni materiali  ...          janvier           Gennaio
#
#    AccidentMonth_en  AccidentWeekDay AccidentWeekDay_de AccidentWeekDay_fr  \
# 0           January            aw406            Samstag             samedi
# 1           January            aw406            Samstag             samedi
# 2           January            aw406            Samstag             samedi
# 3           January            aw406            Samstag             samedi
# 4           January            aw406            Samstag             samedi
#
#   AccidentWeekDay_it AccidentWeekDay_en AccidentHour  AccidentHour_text
# 0             Sabato           Saturday          0.0            00h-01h
# 1             Sabato           Saturday          0.0            00h-01h
# 2             Sabato           Saturday          1.0            01h-02h
# 3             Sabato           Saturday          1.0            01h-02h
# 4             Sabato           Saturday          2.0            02h-03h
#
# [5 rows x 36 columns]

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                     73124  \
# AccidentUID                              3707474F0C160054E0530A839427FD26
# AccidentType                                                          at0
# AccidentType_de                              Schleuder- oder Selbstunfall
# AccidentType_fr                             dérapage ou perte de maîtrise
# AccidentType_it              Incidente di sbandamento o per colpa propria
# AccidentType_en                   Accident with skidding or self-accident
# AccidentSeverityCategory                                              as4
# AccidentSeverityCategory_de                        Unfall mit Sachschaden
# AccidentSeverityCategory_fr              accident avec dommages matériels
# AccidentSeverityCategory_it                 Incidente con danni materiali
# AccidentSeverityCategory_en                 Accident with property damage
# AccidentInvolvingPedestrian                                         False
# AccidentInvolvingBicycle                                            False
# AccidentInvolvingMotorcycle                                         False
# RoadType                                                            rt433
# RoadType_de                                                  Nebenstrasse
# RoadType_fr                                              route secondaire
# RoadType_it                                             Strada secondaria
# RoadType_en                                                    Minor road
# AccidentLocation_CHLV95_E                                         2680477
# AccidentLocation_CHLV95_N                                         1252446
# CantonCode                                                             ZH
# MunicipalityCode                                                      261
# AccidentYear                                                         2016
# AccidentMonth                                                           5
# AccidentMonth_de                                                      Mai
# AccidentMonth_fr                                                      mai
# AccidentMonth_it                                                   Maggio
# AccidentMonth_en                                                      May
# AccidentWeekDay                                                     aw405
# AccidentWeekDay_de                                                Freitag
# AccidentWeekDay_fr                                               vendredi
# AccidentWeekDay_it                                                Venerdì
# AccidentWeekDay_en                                                 Friday
# AccidentHour                                                         11.0
# AccidentHour_text                                                 11h-12h
#
#                                                                76215  \
# AccidentUID                         388740F02044016AE0530A8394271ACF
# AccidentType                                                     at4
# AccidentType_de                                       Einbiegeunfall
# AccidentType_fr                accident en s'engageant sur une route
# AccidentType_it              Incidente nell’immettersi in una strada
# AccidentType_en                 Accident when turning-into main road
# AccidentSeverityCategory                                         as4
# AccidentSeverityCategory_de                   Unfall mit Sachschaden
# AccidentSeverityCategory_fr         accident avec dommages matériels
# AccidentSeverityCategory_it            Incidente con danni materiali
# AccidentSeverityCategory_en            Accident with property damage
# AccidentInvolvingPedestrian                                    False
# AccidentInvolvingBicycle                                       False
# AccidentInvolvingMotorcycle                                    False
# RoadType                                                       rt433
# RoadType_de                                             Nebenstrasse
# RoadType_fr                                         route secondaire
# RoadType_it                                        Strada secondaria
# RoadType_en                                               Minor road
# AccidentLocation_CHLV95_E                                    2683217
# AccidentLocation_CHLV95_N                                    1247904
# CantonCode                                                        ZH
# MunicipalityCode                                                 261
# AccidentYear                                                    2016
# AccidentMonth                                                      7
# AccidentMonth_de                                                Juli
# AccidentMonth_fr                                             juillet
# AccidentMonth_it                                              Luglio
# AccidentMonth_en                                                July
# AccidentWeekDay                                                aw403
# AccidentWeekDay_de                                          Mittwoch
# AccidentWeekDay_fr                                          mercredi
# AccidentWeekDay_it                                         Mercoledì
# AccidentWeekDay_en                                         Wednesday
# AccidentHour                                                    13.0
# AccidentHour_text                                            13h-14h
#
#                                                                     22063
# AccidentUID                              CCB7855DF3B80108E0430A839427ECF4
# AccidentType                                                          at0
# AccidentType_de                              Schleuder- oder Selbstunfall
# AccidentType_fr                             dérapage ou perte de maîtrise
# AccidentType_it              Incidente di sbandamento o per colpa propria
# AccidentType_en                   Accident with skidding or self-accident
# AccidentSeverityCategory                                              as4
# AccidentSeverityCategory_de                        Unfall mit Sachschaden
# AccidentSeverityCategory_fr              accident avec dommages matériels
# AccidentSeverityCategory_it                 Incidente con danni materiali
# AccidentSeverityCategory_en                 Accident with property damage
# AccidentInvolvingPedestrian                                         False
# AccidentInvolvingBicycle                                            False
# AccidentInvolvingMotorcycle                                         False
# RoadType                                                            rt433
# RoadType_de                                                  Nebenstrasse
# RoadType_fr                                              route secondaire
# RoadType_it                                             Strada secondaria
# RoadType_en                                                    Minor road
# AccidentLocation_CHLV95_E                                         2696755
# AccidentLocation_CHLV95_N                                         1245383
# CantonCode                                                             ZH
# MunicipalityCode                                                      198
# AccidentYear                                                         2012
# AccidentMonth                                                           9
# AccidentMonth_de                                                September
# AccidentMonth_fr                                                septembre
# AccidentMonth_it                                                Settembre
# AccidentMonth_en                                                September
# AccidentWeekDay                                                     aw402
# AccidentWeekDay_de                                               Dienstag
# AccidentWeekDay_fr                                                  mardi
# AccidentWeekDay_it                                                Martedì
# AccidentWeekDay_en                                                Tuesday
# AccidentHour                                                          NaN
# AccidentHour_text                                                      ?h

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                              AccidentUID AccidentType  \
# count                             163695       163695
# unique                            163695           11
# top     A70191D0D45E00B0E0430A83942700B0          at0
# freq                                   1        54658
#
#                      AccidentType_de                AccidentType_fr  \
# count                         163695                         163695
# unique                            11                             11
# top     Schleuder- oder Selbstunfall  dérapage ou perte de maîtrise
# freq                           54658                          54658
#
#                                      AccidentType_it  \
# count                                         163695
# unique                                            11
# top     Incidente di sbandamento o per colpa propria
# freq                                           54658
#
#                                 AccidentType_en AccidentSeverityCategory  \
# count                                    163695                   163695
# unique                                       11                        4
# top     Accident with skidding or self-accident                      as4
# freq                                      54658                   128185
#
#        AccidentSeverityCategory_de       AccidentSeverityCategory_fr  \
# count                       163695                            163695
# unique                           4                                 4
# top         Unfall mit Sachschaden  accident avec dommages matériels
# freq                        128185                            128185
#
#           AccidentSeverityCategory_it  ... AccidentMonth_de AccidentMonth_fr  \
# count                          163695  ...           163695           163695
# unique                              4  ...               12               12
# top     Incidente con danni materiali  ...             Juni             juin
# freq                           128185  ...            15252            15252
#
#        AccidentMonth_it AccidentMonth_en AccidentWeekDay AccidentWeekDay_de  \
# count            163695           163695          163695             163695
# unique               12               12               7                  7
# top              Giugno             June           aw405            Freitag
# freq              15252            15252           27215              27215
#
#        AccidentWeekDay_fr AccidentWeekDay_it AccidentWeekDay_en  \
# count              163695             163695             163695
# unique                  7                  7                  7
# top              vendredi            Venerdì             Friday
# freq                27215              27215              27215
#
#        AccidentHour_text
# count             163695
# unique                25
# top              17h-18h
# freq               14862
#
# [4 rows x 30 columns]

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        AccidentLocation_CHLV95_E  AccidentLocation_CHLV95_N  MunicipalityCode  \
# count                 163,695.00                 163,695.00        163,695.00
# mean                2,687,092.30               1,250,376.06            191.92
# std                     8,466.72                   8,890.67             82.49
# min                 2,669,862.00               1,224,684.00              1.00
# 25%                 2,681,712.00               1,246,181.00            118.00
# 50%                 2,684,623.00               1,249,928.00            230.00
# 75%                 2,693,840.00               1,254,915.50            261.00
# max                 2,715,506.00               1,283,321.00            298.00
#
#        AccidentYear  AccidentMonth  AccidentHour
# count    163,695.00     163,695.00    161,839.00
# mean       2,016.23           6.65         13.24
# std            3.11           3.38          5.13
# min        2,011.00           1.00          0.00
# 25%        2,014.00           4.00         10.00
# 50%        2,016.00           7.00         14.00
# 75%        2,019.00          10.00         17.00
# max        2,021.00          12.00         23.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Kantonspolizei des Kantons Zürich | Verkehrstechnische Abteilung | verkehrstechnik@kapo.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung [Pers.]

# %% [markdown]
# ### **Description**: Einwohnerbestand Ende Jahr nach zivilrechtlichem Wohnsitz (ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **204@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:05`
# - **Startdate** `1962-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'bevoelkerungsstatistik', 'einwohner', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 167
# Title                    : Bevölkerung [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_133.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_133.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 11,940 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11940 entries, 0 to 11939
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           11940 non-null  int64
#  1   GEBIET_NAME      11940 non-null  object
#  2   THEMA_NAME       11940 non-null  object
#  3   SET_NAME         11940 non-null  object
#  4   SUBSET_NAME      11940 non-null  object
#  5   INDIKATOR_ID     11940 non-null  int64
#  6   INDIKATOR_NAME   11940 non-null  object
#  7   INDIKATOR_JAHR   11940 non-null  int64
#  8   INDIKATOR_VALUE  11940 non-null  int64
#  9   EINHEIT_KURZ     11940 non-null  object
#  10  EINHEIT_LANG     11940 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 8.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
#
#         INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  Bevölkerung [Pers.]            1962              710        Pers.
# 1  Bevölkerung [Pers.]            1963              720        Pers.
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               7306  \
# BFS_NR                                         177
# GEBIET_NAME                              Pfäffikon
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   133
# INDIKATOR_NAME                 Bevölkerung [Pers.]
# INDIKATOR_JAHR                                1993
# INDIKATOR_VALUE                               8834
# EINHEIT_KURZ                                 Pers.
# EINHEIT_LANG                              Personen
#
#                                               2771  \
# BFS_NR                                          59
# GEBIET_NAME                             Hochfelden
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count         11940                     11940
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             60                     11940
#
#                                  SET_NAME          SUBSET_NAME  \
# count                               11940                11940
# unique                                  1                    1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsbestand
# freq                                11940                11940
#
#              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                 11940        11940        11940
# unique                    1            1            1
# top     Bevölkerung [Pers.]        Pers.     Personen
# freq                  11940        11940        11940

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 11,940.00     11,940.00       11,940.00        11,940.00
# mean     110.74        133.00        1,991.36        24,681.33
# std       86.81          0.00           17.25        99,925.83
# min        0.00        133.00        1,962.00           173.00
# 25%       32.00        133.00        1,976.00         1,234.00
# 50%       96.00        133.00        1,991.00         3,408.50
# 75%      181.00        133.00        2,006.00        10,103.00
# max      298.00        133.00        2,021.00     1,562,345.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

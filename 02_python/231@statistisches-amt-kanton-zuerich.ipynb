# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: EFH-Bestand [Whg.]

# %% [markdown]
# ### **Description**: Anzahl Einfamilienhäuser gemäss GWS. EFH-Bestand bis 2009 aus Fortschreibung des Wohnungsbestandes der GWZ aufgrund der WBT.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **231@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T12:59:40`
# - **Startdate** `1980-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'einfamilienhaus', 'gemeinden', 'immobilien', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 193
# Title                    : EFH-Bestand [Whg.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T12:59:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_379.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_379.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 8,190 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           8190 non-null   int64
#  1   GEBIET_NAME      8190 non-null   object
#  2   THEMA_NAME       8190 non-null   object
#  3   SET_NAME         8190 non-null   object
#  4   SUBSET_NAME      8190 non-null   object
#  5   INDIKATOR_ID     8190 non-null   int64
#  6   INDIKATOR_NAME   8190 non-null   object
#  7   INDIKATOR_JAHR   8190 non-null   int64
#  8   INDIKATOR_VALUE  8190 non-null   int64
#  9   EINHEIT_KURZ     8190 non-null   object
#  10  EINHEIT_LANG     8190 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID      INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Wohnungsbestand           379  EFH-Bestand [Whg.]            1980
# 1  Wohnungsbestand           379  EFH-Bestand [Whg.]            1981
# 2  Wohnungsbestand           379  EFH-Bestand [Whg.]            1982
# 3  Wohnungsbestand           379  EFH-Bestand [Whg.]            1983
# 4  Wohnungsbestand           379  EFH-Bestand [Whg.]            1984
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              145         Whg.    Wohnungen
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         3601                         2785  \
# BFS_NR                                   114                           87
# GEBIET_NAME                      Fischenthal                     Hüttikon
# THEMA_NAME                Bau und Immobilien           Bau und Immobilien
# SET_NAME         Wohnungen, Wohnbautätigkeit  Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                  Wohnungsbestand              Wohnungsbestand
# INDIKATOR_ID                             379                          379
# INDIKATOR_NAME            EFH-Bestand [Whg.]           EFH-Bestand [Whg.]
# INDIKATOR_JAHR                          2020                         2002
# INDIKATOR_VALUE                          517                          117
# EINHEIT_KURZ                            Whg.                         Whg.
# EINHEIT_LANG                       Wohnungen                    Wohnungen
#
#                                         3948
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          8190                8190                         8190
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             42                8190                         8190
#
#             SUBSET_NAME      INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count              8190                8190         8190         8190
# unique                1                   1            1            1
# top     Wohnungsbestand  EFH-Bestand [Whg.]         Whg.    Wohnungen
# freq               8190                8190         8190         8190

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 8,190.00      8,190.00        8,190.00         8,190.00
# mean    107.30        379.00        2,000.40         2,061.61
# std      84.01          0.00           12.08         7,769.51
# min       0.00        379.00        1,980.00             9.00
# 25%      31.00        379.00        1,990.00           225.00
# 50%      94.00        379.00        2,000.00           477.00
# 75%     178.00        379.00        2,011.00           963.00
# max     298.00        379.00        2,021.00       118,612.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

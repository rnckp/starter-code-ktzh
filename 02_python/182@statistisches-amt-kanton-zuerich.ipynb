# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Weg zur nächsten Haltestelle [m]

# %% [markdown]
# ### **Description**: Durchschnittliche Distanz zur nächsten Haltestelle

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **182@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-03-17T07:40:20`
# - **Startdate** `2004-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'bus', 'gemeinden', 'kanton_zuerich', 'oeffentlicher_verkehr', 'verkehrsinfrastruktur', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 146
# Title                    : Weg zur nächsten Haltestelle [m]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-03-17T07:40:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_400.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_400.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,396 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3396 entries, 0 to 3395
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3396 non-null   int64
#  1   GEBIET_NAME      3396 non-null   object
#  2   THEMA_NAME       3396 non-null   object
#  3   SET_NAME         3396 non-null   object
#  4   SUBSET_NAME      3396 non-null   object
#  5   INDIKATOR_ID     3396 non-null   int64
#  6   INDIKATOR_NAME   3396 non-null   object
#  7   INDIKATOR_JAHR   3396 non-null   int64
#  8   INDIKATOR_VALUE  3396 non-null   int64
#  9   EINHEIT_KURZ     3396 non-null   object
#  10  EINHEIT_LANG     3396 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.9 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME    SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           400
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           400
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           400
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           400
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           400
#
#                      INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Weg zur nächsten Haltestelle [m]            2004              253
# 1  Weg zur nächsten Haltestelle [m]            2005              253
# 2  Weg zur nächsten Haltestelle [m]            2006              251
# 3  Weg zur nächsten Haltestelle [m]            2007              248
# 4  Weg zur nächsten Haltestelle [m]            2008              248
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            m        Meter
# 1            m        Meter
# 2            m        Meter
# 3            m        Meter
# 4            m        Meter

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                              2031  \
# BFS_NR                                        160
# GEBIET_NAME                               Zumikon
# THEMA_NAME                        Raum und Umwelt
# SET_NAME                                  Verkehr
# SUBSET_NAME                         Erschliessung
# INDIKATOR_ID                                  400
# INDIKATOR_NAME   Weg zur nächsten Haltestelle [m]
# INDIKATOR_JAHR                               2009
# INDIKATOR_VALUE                               254
# EINHEIT_KURZ                                    m
# EINHEIT_LANG                                Meter
#
#                                              365   \
# BFS_NR                                         27
# GEBIET_NAME                           Feuerthalen
# THEMA_NAME                        Raum und Umwelt
# SET_NAME                                  Verkehr
# SUBSET_NAME                         Erschliessung
# INDIKATOR_ID                                  400
# INDIKATOR_NAME   Weg zur nächsten Haltestelle [m]
# INDIKATOR_JAHR                               2009
# INDIKATOR_VALUE                               167
# EINHEIT_KURZ                                    m
# EINHEIT_LANG                                Meter
#
#                                              771
# BFS_NR                                         56
# GEBIET_NAME                               Embrach
# THEMA_NAME                        Raum und Umwelt
# SET_NAME                                  Verkehr
# SUBSET_NAME                         Erschliessung
# INDIKATOR_ID                                  400
# INDIKATOR_NAME   Weg zur nächsten Haltestelle [m]
# INDIKATOR_JAHR                               2010
# INDIKATOR_VALUE                               204
# EINHEIT_KURZ                                    m
# EINHEIT_LANG                                Meter

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME    SUBSET_NAME  \
# count          3396             3396     3396           3396
# unique          200                1        1              1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung
# freq             18             3396     3396           3396
#
#                           INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                               3396         3396         3396
# unique                                 1            1            1
# top     Weg zur nächsten Haltestelle [m]            m        Meter
# freq                                3396         3396         3396

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,396.00      3,396.00        3,396.00         3,396.00
# mean    109.84        400.00        2,012.28           255.44
# std      83.78          0.00            5.15           110.92
# min       0.00        400.00        2,004.00           122.00
# 25%      34.00        400.00        2,008.00           193.00
# 50%      96.00        400.00        2,012.00           228.00
# 75%     180.00        400.00        2,017.00           284.00
# max     298.00        400.00        2,021.00         1,321.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

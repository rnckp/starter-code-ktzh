# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerertrag von natürlichen Personen [Mio.Fr.]

# %% [markdown]
# ### **Description**: Steuerertrag natürliche Personen (Nettoertrag Rechnungsjahr).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **301@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T09:13:33`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeindefinanzen', 'gemeinden', 'kanton_zuerich', 'natuerliche_personen', 'steuerertrag', 'steuern', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 231
# Title                    : Steuerertrag von natürlichen Personen [Mio.Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T09:13:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_299.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_299.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,340 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6340 entries, 0 to 6339
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6340 non-null   int64
#  1   GEBIET_NAME      6340 non-null   object
#  2   THEMA_NAME       6340 non-null   object
#  3   SET_NAME         6340 non-null   object
#  4   SUBSET_NAME      6340 non-null   object
#  5   INDIKATOR_ID     6340 non-null   int64
#  6   INDIKATOR_NAME   6340 non-null   object
#  7   INDIKATOR_JAHR   6340 non-null   int64
#  8   INDIKATOR_VALUE  6338 non-null   float64
#  9   EINHEIT_KURZ     6340 non-null   object
#  10  EINHEIT_LANG     6340 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME         SET_NAME    SUBSET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
#
#    INDIKATOR_ID                                   INDIKATOR_NAME  \
# 0           299  Steuerertrag von natürlichen Personen [Mio.Fr.]
# 1           299  Steuerertrag von natürlichen Personen [Mio.Fr.]
# 2           299  Steuerertrag von natürlichen Personen [Mio.Fr.]
# 3           299  Steuerertrag von natürlichen Personen [Mio.Fr.]
# 4           299  Steuerertrag von natürlichen Personen [Mio.Fr.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ       EINHEIT_LANG
# 0            1990              4.1      Mio.Fr.  Millionen Franken
# 1            1991              4.3      Mio.Fr.  Millionen Franken
# 2            1992              4.5      Mio.Fr.  Millionen Franken
# 3            1993              5.1      Mio.Fr.  Millionen Franken
# 4            1994              5.0      Mio.Fr.  Millionen Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             3139  \
# BFS_NR                                                       136
# GEBIET_NAME                                         Langnau a.A.
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                        Steuererträge
# INDIKATOR_ID                                                 299
# INDIKATOR_NAME   Steuerertrag von natürlichen Personen [Mio.Fr.]
# INDIKATOR_JAHR                                              2013
# INDIKATOR_VALUE                                             25.9
# EINHEIT_KURZ                                             Mio.Fr.
# EINHEIT_LANG                                   Millionen Franken
#
#                                                             4466  \
# BFS_NR                                                       215
# GEBIET_NAME                                            Dättlikon
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                        Steuererträge
# INDIKATOR_ID                                                 299
# INDIKATOR_NAME   Steuerertrag von natürlichen Personen [Mio.Fr.]
# INDIKATOR_JAHR                                              1996
# INDIKATOR_VALUE                                              1.0
# EINHEIT_KURZ                                             Mio.Fr.
# EINHEIT_LANG                                   Millionen Franken
#
#                                                             273
# BFS_NR                                                         9
# GEBIET_NAME                                       Mettmenstetten
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                        Steuererträge
# INDIKATOR_ID                                                 299
# INDIKATOR_NAME   Steuerertrag von natürlichen Personen [Mio.Fr.]
# INDIKATOR_JAHR                                              2007
# INDIKATOR_VALUE                                             10.9
# EINHEIT_KURZ                                             Mio.Fr.
# EINHEIT_LANG                                   Millionen Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME         SET_NAME    SUBSET_NAME  \
# count          6340                  6340             6340           6340
# unique          200                     1                1              1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuererträge
# freq             32                  6340             6340           6340
#
#                                          INDIKATOR_NAME EINHEIT_KURZ  \
# count                                              6340         6340
# unique                                                1            1
# top     Steuerertrag von natürlichen Personen [Mio.Fr.]      Mio.Fr.
# freq                                               6340         6340
#
#              EINHEIT_LANG
# count                6340
# unique                  1
# top     Millionen Franken
# freq                 6340

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,340.00      6,340.00        6,340.00         6,338.00
# mean    110.56        299.00        2,005.37            85.72
# std      86.89          0.00            9.18           359.22
# min       0.00        299.00        1,990.00             0.30
# 25%      32.00        299.00        1,997.00             4.00
# 50%      96.00        299.00        2,005.00            10.60
# 75%     181.00        299.00        2,013.00            33.60
# max     298.00        299.00        2,021.00         6,122.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

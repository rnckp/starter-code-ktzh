# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]

# %% [markdown]
# ### **Description**: Durchschnittliche Bauinvestitionen der letzten 5 Jahre im Bereich Strassen (Bauinv. für Strassen inkl. Parkplätze, ohne Nationalstrassenbau und ohne Strassenunterhalt), in Franken pro Einwohner.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **154@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:01:18`
# - **Startdate** `1998-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bauinvestitionen', 'bautaetigkeit', 'bezirke', 'gemeinden', 'kanton_zuerich', 'strassen', 'strassenbau', 'verkehrsinfrastruktur', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 119
# Title                    : Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:01:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_176.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_176.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,526 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4526 entries, 0 to 4525
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4526 non-null   int64
#  1   GEBIET_NAME      4526 non-null   object
#  2   THEMA_NAME       4526 non-null   object
#  3   SET_NAME         4526 non-null   object
#  4   SUBSET_NAME      4526 non-null   object
#  5   INDIKATOR_ID     4526 non-null   int64
#  6   INDIKATOR_NAME   4526 non-null   object
#  7   INDIKATOR_JAHR   4526 non-null   int64
#  8   INDIKATOR_VALUE  4526 non-null   int64
#  9   EINHEIT_KURZ     4526 non-null   object
#  10  EINHEIT_LANG     4526 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 1       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 2       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 3       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 4       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
#
#         SUBSET_NAME  INDIKATOR_ID                            INDIKATOR_NAME  \
# 0  Bauinvestitionen           176  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# 1  Bauinvestitionen           176  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# 2  Bauinvestitionen           176  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# 3  Bauinvestitionen           176  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# 4  Bauinvestitionen           176  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
#
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                      4191  \
# BFS_NR                                                  0
# GEBIET_NAME                                  Bezirk Uster
# THEMA_NAME                             Bau und Immobilien
# SET_NAME                 Gebäudevolumen, Bauinvestitionen
# SUBSET_NAME                              Bauinvestitionen
# INDIKATOR_ID                                          176
# INDIKATOR_NAME   Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# INDIKATOR_JAHR                                       2008
# INDIKATOR_VALUE                                       104
# EINHEIT_KURZ                                    Fr./Einw.
# EINHEIT_LANG                        Franken pro Einwohner
#
#                                                      2003  \
# BFS_NR                                                116
# GEBIET_NAME                                     Grüningen
# THEMA_NAME                             Bau und Immobilien
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# count          4526                4526                              4526
# unique          202                   1                                 1
# top     Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# freq             23                4526                              4526
#
#              SUBSET_NAME                            INDIKATOR_NAME  \
# count               4526                                      4526
# unique                 1                                         1
# top     Bauinvestitionen  Bauinv. Strassen, PP 5 Jahre [Fr./Einw.]
# freq                4526                                      4526
#
#        EINHEIT_KURZ           EINHEIT_LANG
# count          4526                   4526
# unique            1                      1
# top       Fr./Einw.  Franken pro Einwohner
# freq           4526                   4526

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,526.00      4,526.00        4,526.00         4,526.00
# mean    108.86        176.00        2,008.93           105.47
# std      85.08          0.00            6.60           149.74
# min       0.00        176.00        1,998.00             0.00
# 25%      32.00        176.00        2,003.00             5.00
# 50%      95.00        176.00        2,009.00            68.00
# 75%     180.00        176.00        2,015.00           147.75
# max     298.00        176.00        2,020.00         2,024.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Oberstufe [Anz.]

# %% [markdown]
# ### **Description**: Anzahl OberstufenschülerInnen (exklusiv LangzeitgymnasiastInnen; nach Wohnort)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **42@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `2001-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'schueler', 'schuelerinnen', 'schulen', 'sekundarschule', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 35
# Title                    : Schül. Oberstufe [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_147.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_147.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,084 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4084 entries, 0 to 4083
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4084 non-null   int64
#  1   GEBIET_NAME      4084 non-null   object
#  2   THEMA_NAME       4084 non-null   object
#  3   SET_NAME         4084 non-null   object
#  4   SUBSET_NAME      4084 non-null   object
#  5   INDIKATOR_ID     4084 non-null   int64
#  6   INDIKATOR_NAME   4084 non-null   object
#  7   INDIKATOR_JAHR   4084 non-null   int64
#  8   INDIKATOR_VALUE  4084 non-null   int64
#  9   EINHEIT_KURZ     4084 non-null   object
#  10  EINHEIT_LANG     4084 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#            SUBSET_NAME  INDIKATOR_ID           INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Schüler Volksschule           147  Schül. Oberstufe [Anz.]            2001
# 1  Schüler Volksschule           147  Schül. Oberstufe [Anz.]            2002
# 2  Schüler Volksschule           147  Schül. Oberstufe [Anz.]            2003
# 3  Schüler Volksschule           147  Schül. Oberstufe [Anz.]            2004
# 4  Schüler Volksschule           147  Schül. Oberstufe [Anz.]            2005
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0               43         Anz.       Anzahl
# 1               49         Anz.       Anzahl
# 2               42         Anz.       Anzahl
# 3               49         Anz.       Anzahl
# 4               49         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      3464                      3059  \
# BFS_NR                                251                       222
# GEBIET_NAME                     Weiningen     Hofstetten (bis 2017)
# THEMA_NAME       Bevölkerung und Soziales  Bevölkerung und Soziales
# SET_NAME                          Bildung                   Bildung
# SUBSET_NAME           Schüler Volksschule       Schüler Volksschule
# INDIKATOR_ID                          147                       147
# INDIKATOR_NAME    Schül. Oberstufe [Anz.]   Schül. Oberstufe [Anz.]
# INDIKATOR_JAHR                       2018                      2008
# INDIKATOR_VALUE                       118                        20
# EINHEIT_KURZ                         Anz.                      Anz.
# EINHEIT_LANG                       Anzahl                    Anzahl
#
#                                      478
# BFS_NR                                 29
# GEBIET_NAME                    Flurlingen
# THEMA_NAME       Bevölkerung und Soziales
# SET_NAME                          Bildung
# SUBSET_NAME           Schüler Volksschule
# INDIKATOR_ID                          147
# INDIKATOR_NAME    Schül. Oberstufe [Anz.]
# INDIKATOR_JAHR                       2017
# INDIKATOR_VALUE                        41
# EINHEIT_KURZ                         Anz.
# EINHEIT_LANG                       Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME          SUBSET_NAME  \
# count          4084                      4084     4084                 4084
# unique          200                         1        1                    1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler Volksschule
# freq             21                      4084     4084                 4084
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                      4084         4084         4084
# unique                        1            1            1
# top     Schül. Oberstufe [Anz.]         Anz.       Anzahl
# freq                       4084         4084         4084

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,084.00      4,084.00        4,084.00         4,084.00
# mean    107.86        147.00        2,010.93           703.37
# std      84.88          0.00            6.03         2,664.65
# min       0.00        147.00        2,001.00             3.00
# 25%      31.00        147.00        2,006.00            54.00
# 50%      94.00        147.00        2,011.00           128.00
# 75%     178.25        147.00        2,016.00           312.00
# max     298.00        147.00        2,021.00        36,385.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

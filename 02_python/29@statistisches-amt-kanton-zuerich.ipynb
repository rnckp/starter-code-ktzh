# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]

# %% [markdown]
# ### **Description**: Durchschnittliches Eigenkapital (ehem. Kapital) steuerpflichtiger juristischer Personen. Hinweis: Sehr hohe Beträge einiger weniger Steuerpflichtigen wirken sich entsprechend stark auf den Mittelwert aus.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **29@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-13T09:49:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'eigenkapital', 'gemeinden', 'juristische_personen', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 26
# Title                    : Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-13T09:49:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_281.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_281.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,339 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6339 entries, 0 to 6338
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6339 non-null   int64
#  1   GEBIET_NAME      6339 non-null   object
#  2   THEMA_NAME       6339 non-null   object
#  3   SET_NAME         6339 non-null   object
#  4   SUBSET_NAME      6339 non-null   object
#  5   INDIKATOR_ID     6339 non-null   int64
#  6   INDIKATOR_NAME   6339 non-null   object
#  7   INDIKATOR_JAHR   6339 non-null   int64
#  8   INDIKATOR_VALUE  6338 non-null   float64
#  9   EINHEIT_KURZ     6339 non-null   object
#  10  EINHEIT_LANG     6339 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME         SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
#
#         SUBSET_NAME  INDIKATOR_ID  \
# 0  Steuergrundlagen           281
# 1  Steuergrundlagen           281
# 2  Steuergrundlagen           281
# 3  Steuergrundlagen           281
# 4  Steuergrundlagen           281
#
#                                     INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]            1990
# 1  Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]            1991
# 2  Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]            1992
# 3  Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]            1993
# 4  Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]            1994
#
#    INDIKATOR_VALUE EINHEIT_KURZ     EINHEIT_LANG
# 0             73.0     1000 Fr.  Tausend Franken
# 1             86.0     1000 Fr.  Tausend Franken
# 2            112.0     1000 Fr.  Tausend Franken
# 3            142.0     1000 Fr.  Tausend Franken
# 4            129.0     1000 Fr.  Tausend Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             2225  \
# BFS_NR                                                        90
# GEBIET_NAME                                          Niederhasli
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                     Steuergrundlagen
# INDIKATOR_ID                                                 281
# INDIKATOR_NAME   Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]
# INDIKATOR_JAHR                                              2017
# INDIKATOR_VALUE                                            747.0
# EINHEIT_KURZ                                            1000 Fr.
# EINHEIT_LANG                                     Tausend Franken
#
#                                                             4788  \
# BFS_NR                                                       225
# GEBIET_NAME                                           Rickenbach
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                     Steuergrundlagen
# INDIKATOR_ID                                                 281
# INDIKATOR_NAME   Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]
# INDIKATOR_JAHR                                              2007
# INDIKATOR_VALUE                                            199.0
# EINHEIT_KURZ                                            1000 Fr.
# EINHEIT_LANG                                     Tausend Franken
#
#                                                             4750
# BFS_NR                                                       224
# GEBIET_NAME                                              Pfungen
# THEMA_NAME                                  Öffentliche Finanzen
# SET_NAME                                         Gemeindesteuern
# SUBSET_NAME                                     Steuergrundlagen
# INDIKATOR_ID                                                 281
# INDIKATOR_NAME   Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]
# INDIKATOR_JAHR                                              2001
# INDIKATOR_VALUE                                           1108.0
# EINHEIT_KURZ                                            1000 Fr.
# EINHEIT_LANG                                     Tausend Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME         SET_NAME       SUBSET_NAME  \
# count          6339                  6339             6339              6339
# unique          200                     1                1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuergrundlagen
# freq             32                  6339             6339              6339
#
#                                          INDIKATOR_NAME EINHEIT_KURZ  \
# count                                              6339         6339
# unique                                                1            1
# top     Ø Eigenkapital steuerpfl. jur. Pers. [1000 Fr.]     1000 Fr.
# freq                                               6339         6339
#
#            EINHEIT_LANG
# count              6339
# unique                1
# top     Tausend Franken
# freq               6339

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,339.00      6,339.00        6,339.00         6,338.00
# mean    110.58        281.00        2,005.37         1,294.30
# std      86.89          0.00            9.18         3,254.45
# min       0.00        281.00        1,990.00             0.00
# 25%      32.00        281.00        1,997.00           303.00
# 50%      96.00        281.00        2,005.00           591.00
# 75%     181.00        281.00        2,013.00         1,129.75
# max     298.00        281.00        2,021.00        66,969.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]

# %% [markdown]
# ### **Description**: Anteil Arbeitslose an der zivilrechtlichen Wohnbevölkerung zwischen 15 und 64 Jahren. Aus Datenschutzgründen dürfen Quoten von Gemeinden mit weniger als 5 Arbeitslosen (Jahresmittel) nicht ausgewiesen werden.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **318@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-04-14T08:44:20`
# - **Startdate** `2011-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Arbeit, Erwerb']`
# - **Keyword** `['arbeitslose', 'arbeitslosenquote', 'arbeitslosigkeit', 'arbeitsmarkt', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 243
# Title                    : Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-04-14T08:44:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_380.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_380.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,108 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2108 entries, 0 to 2107
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2108 non-null   int64
#  1   GEBIET_NAME      2108 non-null   object
#  2   THEMA_NAME       2108 non-null   object
#  3   SET_NAME         2108 non-null   object
#  4   SUBSET_NAME      2108 non-null   object
#  5   INDIKATOR_ID     2108 non-null   int64
#  6   INDIKATOR_NAME   2108 non-null   object
#  7   INDIKATOR_JAHR   2108 non-null   int64
#  8   INDIKATOR_VALUE  1981 non-null   float64
#  9   EINHEIT_KURZ     2108 non-null   object
#  10  EINHEIT_LANG     2108 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
#
#         SUBSET_NAME  INDIKATOR_ID  \
# 0  Arbeitslosigkeit           380
# 1  Arbeitslosigkeit           380
# 2  Arbeitslosigkeit           380
# 3  Arbeitslosigkeit           380
# 4  Arbeitslosigkeit           380
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2011
# 1  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2012
# 2  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2013
# 3  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2014
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               1698  \
# BFS_NR                                                         244
# GEBIET_NAME                                             Geroldswil
# THEMA_NAME                                  Arbeit und Unternehmen
# SET_NAME                                          Arbeitslosigkeit
# SUBSET_NAME                                       Arbeitslosigkeit
# INDIKATOR_ID                                                   380
# INDIKATOR_NAME   Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# INDIKATOR_JAHR                                                2011
# INDIKATOR_VALUE                                                2.6
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent
#
#                                                               913   \
# BFS_NR                                                         112
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME          SET_NAME  \
# count          2108                    2108              2108
# unique          200                       1                 1
# top     Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# freq             11                    2108              2108
#
#              SUBSET_NAME                                     INDIKATOR_NAME  \
# count               2108                                               2108
# unique                 1                                                  1
# top     Arbeitslosigkeit  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# freq                2108                                               2108
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          2108         2108
# unique            1            1
# top               %      Prozent
# freq           2108         2108

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,108.00      2,108.00        2,108.00         1,981.00
# mean    107.17        380.00        2,015.94             2.07
# std      85.07          0.00            3.16             0.68
# min       0.00        380.00        2,011.00             0.60
# 25%      30.00        380.00        2,013.00             1.60
# 50%      93.00        380.00        2,016.00             2.00
# 75%     178.25        380.00        2,019.00             2.50
# max     298.00        380.00        2,021.00             4.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

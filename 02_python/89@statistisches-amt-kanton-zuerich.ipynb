# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungszunahme 5 Jahre [%]

# %% [markdown]
# ### **Description**: Veränderung der Einwohnerzahl (zivilrechtlicher Wohnsitz) innerhalb von 5 Jahren in Prozent. Wert für 1970 aus der Volkszählung (wirtschaftl. Wohnsitz), da keine kant. Erhebung stattgefunden hat.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **89@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:16:54`
# - **Startdate** `1962-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungswachstum', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 72
# Title                    : Bevölkerungszunahme 5 Jahre [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:16:54
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_203.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_203.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 11,154 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11154 entries, 0 to 11153
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           11154 non-null  int64
#  1   GEBIET_NAME      11154 non-null  object
#  2   THEMA_NAME       11154 non-null  object
#  3   SET_NAME         11154 non-null  object
#  4   SUBSET_NAME      11154 non-null  object
#  5   INDIKATOR_ID     11154 non-null  int64
#  6   INDIKATOR_NAME   11154 non-null  object
#  7   INDIKATOR_JAHR   11154 non-null  int64
#  8   INDIKATOR_VALUE  11134 non-null  float64
#  9   EINHEIT_KURZ     11154 non-null  object
#  10  EINHEIT_LANG     11154 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 8.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME              SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           203
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           203
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           203
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           203
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung           203
#
#                     INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerungszunahme 5 Jahre [%]            1965              4.5
# 1  Bevölkerungszunahme 5 Jahre [%]            1967             -0.8
# 2  Bevölkerungszunahme 5 Jahre [%]            1968             -5.8
# 3  Bevölkerungszunahme 5 Jahre [%]            1969              3.0
# 4  Bevölkerungszunahme 5 Jahre [%]            1970              0.7
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               9119  \
# BFS_NR                                         247
# GEBIET_NAME                              Schlieren
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   203
# INDIKATOR_NAME     Bevölkerungszunahme 5 Jahre [%]
# INDIKATOR_JAHR                                2017
# INDIKATOR_VALUE                                8.7
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               3332  \
# BFS_NR                                          72
# GEBIET_NAME                                 Winkel
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   203
# INDIKATOR_NAME     Bevölkerungszunahme 5 Jahre [%]
# INDIKATOR_JAHR                                2003
# INDIKATOR_VALUE                               12.7
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               6752
# BFS_NR                                         176
# GEBIET_NAME                                 Lindau
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                Bevölkerungsentwicklung
# INDIKATOR_ID                                   203
# INDIKATOR_NAME     Bevölkerungszunahme 5 Jahre [%]
# INDIKATOR_JAHR                                1987
# INDIKATOR_VALUE                                4.9
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GEBIET_NAME                THEMA_NAME  \
# count        11154                     11154
# unique         200                         1
# top         Horgen  Bevölkerung und Soziales
# freq            60                     11154
#
#                                  SET_NAME              SUBSET_NAME  \
# count                               11154                    11154
# unique                                  1                        1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsentwicklung
# freq                                11154                    11154
#
#                          INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                             11154        11154        11154
# unique                                1            1            1
# top     Bevölkerungszunahme 5 Jahre [%]            %      Prozent
# freq                              11154        11154        11154

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 11,154.00     11,154.00       11,154.00        11,134.00
# mean     110.95        203.00        1,993.31             7.95
# std       87.00          0.00           16.15            15.67
# min        0.00        203.00        1,962.00           -49.10
# 25%       32.00        203.00        1,979.00             2.00
# 50%       96.00        203.00        1,993.00             5.70
# 75%      181.00        203.00        2,007.00            10.30
# max      298.00        203.00        2,021.00           760.50

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

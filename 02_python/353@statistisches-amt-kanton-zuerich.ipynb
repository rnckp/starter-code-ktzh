# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wohnungen: Anteil Eigentumsobjekte [%]

# %% [markdown]
# ### **Description**: Anteil Wohneigentumsobjekte gemessen am Wohnungsbestand des Erhebungsjahres. Der Anteil Eigentums-Objekte bezieht sich auf Wohnungen in Gebäuden, die als Eigentumsobjekte (Einfamilienhäuser und Eigentumswohnungen) vorgesehen sind. Der Wert ist nicht vergleichbar mit der Wohneigentumsquote aus früheren Volkszählungen, denn weitervermietete EFH und weitervermietetes Stockwerkeigentum können in den Registerdaten nicht ausgewiesen werden. Der Anteil Eigentums-Objekte ist somit etwas grösser als die eigentliche Wohneigentumsquote.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **353@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T12:59:40`
# - **Startdate** `2006-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'wohneigentum', 'wohneigentumsquote', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 274
# Title                    : Wohnungen: Anteil Eigentumsobjekte [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T12:59:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_461.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_461.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,912 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2912 entries, 0 to 2911
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2912 non-null   int64
#  1   GEBIET_NAME      2912 non-null   object
#  2   THEMA_NAME       2912 non-null   object
#  3   SET_NAME         2912 non-null   object
#  4   SUBSET_NAME      2912 non-null   object
#  5   INDIKATOR_ID     2912 non-null   int64
#  6   INDIKATOR_NAME   2912 non-null   object
#  7   INDIKATOR_JAHR   2912 non-null   int64
#  8   INDIKATOR_VALUE  2912 non-null   float64
#  9   EINHEIT_KURZ     2912 non-null   object
#  10  EINHEIT_LANG     2912 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID                          INDIKATOR_NAME  \
# 0  Wohnungsbestand           461  Wohnungen: Anteil Eigentumsobjekte [%]
# 1  Wohnungsbestand           461  Wohnungen: Anteil Eigentumsobjekte [%]
# 2  Wohnungsbestand           461  Wohnungen: Anteil Eigentumsobjekte [%]
# 3  Wohnungsbestand           461  Wohnungen: Anteil Eigentumsobjekte [%]
# 4  Wohnungsbestand           461  Wohnungen: Anteil Eigentumsobjekte [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2006             57.9            %      Prozent
# 1            2007             57.7            %      Prozent
# 2            2008             58.3            %      Prozent
# 3            2009             57.1            %      Prozent
# 4            2010             62.1            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                    1753  \
# BFS_NR                                              173
# GEBIET_NAME                                     Hittnau
# THEMA_NAME                           Bau und Immobilien
# SET_NAME                    Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                             Wohnungsbestand
# INDIKATOR_ID                                        461
# INDIKATOR_NAME   Wohnungen: Anteil Eigentumsobjekte [%]
# INDIKATOR_JAHR                                     2013
# INDIKATOR_VALUE                                    63.6
# EINHEIT_KURZ                                          %
# EINHEIT_LANG                                    Prozent
#
#                                                    2895  \
# BFS_NR                                                0
# GEBIET_NAME                               Region Zürich
# THEMA_NAME                           Bau und Immobilien
# SET_NAME                    Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                             Wohnungsbestand
# INDIKATOR_ID                                        461
# INDIKATOR_NAME   Wohnungen: Anteil Eigentumsobjekte [%]
# INDIKATOR_JAHR                                     2020
# INDIKATOR_VALUE                                    14.7
# EINHEIT_KURZ                                          %
# EINHEIT_LANG                                    Prozent
#
#                                                    160
# BFS_NR                                               11
# GEBIET_NAME                                   Ottenbach
# THEMA_NAME                           Bau und Immobilien
# SET_NAME                    Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                             Wohnungsbestand
# INDIKATOR_ID                                        461
# INDIKATOR_NAME   Wohnungen: Anteil Eigentumsobjekte [%]
# INDIKATOR_JAHR                                     2016
# INDIKATOR_VALUE                                    66.6
# EINHEIT_KURZ                                          %
# EINHEIT_LANG                                    Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          2912                2912                         2912
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             15                2912                         2912
#
#             SUBSET_NAME                          INDIKATOR_NAME EINHEIT_KURZ  \
# count              2912                                    2912         2912
# unique                1                                       1            1
# top     Wohnungsbestand  Wohnungen: Anteil Eigentumsobjekte [%]            %
# freq               2912                                    2912         2912
#
#        EINHEIT_LANG
# count          2912
# unique            1
# top         Prozent
# freq           2912

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,912.00      2,912.00        2,912.00         2,912.00
# mean    107.63        461.00        2,013.07            46.71
# std      84.79          0.00            4.51            12.79
# min       0.00        461.00        2,006.00            11.60
# 25%      31.00        461.00        2,009.00            38.30
# 50%      94.00        461.00        2,013.00            48.00
# 75%     178.00        461.00        2,017.00            56.40
# max     298.00        461.00        2,021.00            74.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

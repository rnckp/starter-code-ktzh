# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wohnungsbestand und Anzahl Neubauwohnungen in der Stadt Winterthur ab 1981

# %% [markdown]
# ### **Description**: Zeitreihe des Wohnungsbestandes und der Anzahl Neubauwohnungen in der Stadt Winterthur ab 1981.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1601@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T17:24:49`
# - **Modified** `2022-09-21T10:13:15`
# - **Startdate** `1981-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['gemeinden', 'neubauten', 'wohnungen', 'wohnungsbau', 'wohnungsbestand', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/bauen-und-wohnen`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3061
# Title                    : Anzahl Wohnungen insgesamt und neu gebaut nach Jahr
# Description              : Variablen: 'Wohnungsbestand' = Gesamtanzahl Wohnungen per Ende Jahr; 'Neuwohnungen' = Neu gebaute Wohnungen im entsprechenden Jahr.
# Issued                   : 2022-09-20T17:24:49
# Modified                 : 2022-09-20T17:24:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001601_00003061.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001601_00003061.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 41 rows (observations) and 3 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Jahr             41 non-null     int64
#  1   Wohnungsbestand  41 non-null     int64
#  2   Neuwohnungen     41 non-null     int64
# dtypes: int64(3)
# memory usage: 1.1 KB

# %%
df.head()
# Out:
#    Jahr  Wohnungsbestand  Neuwohnungen
# 0  2021            57253           660
# 1  2020            56643           849
# 2  2019            55670           431
# 3  2018            55314           952
# 4  2017            54452           363

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                     29     31     15
# Jahr              1992   1990   2006
# Wohnungsbestand  40036  39602  47100
# Neuwohnungen       215    420    654

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(exclude='number'))
    except:
        pass

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  Wohnungsbestand  Neuwohnungen
# count    41.00            41.00         41.00
# mean  2,001.00        45,275.24        532.07
# std      11.98         6,417.15        242.52
# min   1,981.00        36,241.00         55.00
# 25%   1,991.00        39,871.00        363.00
# 50%   2,001.00        44,324.00        454.00
# 75%   2,011.00        51,200.00        668.00
# max   2,021.00        57,253.00      1,086.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

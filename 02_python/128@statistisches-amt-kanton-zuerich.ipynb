# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Leerwohnungszahlen

# %% [markdown]
# ### **Description**: Leerwohnungsdaten der Zürcher Gemeinden

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **128@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-08-20T00:00:00`
# - **Modified** `2021-12-21T14:13:23`
# - **Startdate** `1984-06-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['leerwohnungen', 'leerwohnungsziffer', 'mietwohnungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1977
# Title                    : Variablenliste zu Anzahl Leerwohnungen pro Gemeinde im Kanton Zürich seit 1994
# Description              : Die Variablenliste bezieht sich auf eine alte Datenstruktur und ist nicht mehr aktuell. Die neue Datenstruktur sollte selbsterklärend sein.
# Issued                   : 2021-11-23T11:01:23
# Modified                 : 2021-12-21T14:13:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000128_00001977.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000128_00001977.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1978
# Title                    : Anzahl Leerwohnungen pro Gemeinde im Kanton Zürich seit 1994
# Description              : Stichtag der Erhebung ist der 1. Juni, die Angaben beziehen sich auf den Gemeindestand (Variable bfs) zum Zeitpunkt der Erhebung
# Issued                   : 2021-11-23T11:01:23
# Modified                 : 2022-08-30T09:29:04
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000128_00001978.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000128_00001978.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 240,541 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240541 entries, 0 to 240540
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   stichjahr          240541 non-null  int64
#  1   bfs                240541 non-null  int64
#  2   wohnungstyp        240541 non-null  object
#  3   zimmerzahl         240541 non-null  object
#  4   anz_leerwohnungen  240541 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 38.3 MB

# %%
df.head()
# Out:
#    stichjahr  bfs wohnungstyp zimmerzahl  anz_leerwohnungen
# 0       1994    1  Alle Typen      total                 10
# 1       1994    1  Alle Typen          1                  2
# 2       1994    1  Alle Typen          2                  2
# 3       1994    1  Alle Typen          3                  1
# 4       1994    1  Alle Typen          4                  3

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                           94381               197092      192477
# stichjahr                   2005                2017        2017
# bfs                           58                 133           2
# wohnungstyp        Mietwohnungen  Eigentumswohnungen  Alle Typen
# zimmerzahl                 total               total           5
# anz_leerwohnungen             27                  15           9

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        wohnungstyp zimmerzahl
# count       240541     240541
# unique           7          7
# top     Alle Typen      total
# freq         34363      34363

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        stichjahr        bfs  anz_leerwohnungen
# count 240,541.00 240,541.00         240,541.00
# mean    2,007.88     120.97               4.67
# std         8.33      77.22              19.20
# min     1,994.00       1.00              -2.00
# 25%     2,001.00      55.00               0.00
# 50%     2,008.00     114.00               0.00
# 75%     2,015.00     192.00               3.00
# max     2,022.00     298.00           1,364.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | basil.schlaepfer@statistik.ji.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Betriebe, Beschäftigte, Vollzeitäquivalente in der Stadt Winterthur ab 2019

# %% [markdown]
# ### **Description**: Betriebe, Beschäftigte und Vollzeitäquivalente nach Branchen in der Stadt Winterthur. Die Branchen sind mit NOGA08 codiert (Allgemeine Systematik der Wirtschaftszweige, Nomenclature Générale des Activités économiques, 6 Stellen). Datenquelle: Bundesamt für Statistik, Statistik der Unternehmensstruktur (STATENT).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1522@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T17:22:40`
# - **Modified** `2022-09-21T10:07:07`
# - **Startdate** `2019-01-01`
# - **Enddate** `2020-12-31`
# - **Theme** `['Land- und Forstwirtschaft', 'Industrie, Dienstleistungen', 'Volkswirtschaft', 'Arbeit, Erwerb']`
# - **Keyword** `['beschaeftigte', 'betriebe', 'branchen', 'vollzeitaequivalente', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/wirtschaft`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2900
# Title                    : Betriebe, Beschäftigte, Vollzeitäquivalente nach Branchen in der Stadt Winterthur nach Jahr
# Description              : Variablen: 'Betriebe' = Anzahl Betriebe nach Branche (NOGA-Code); 'Beschaeftigte' = Anzahl Beschäftigte nach Branche (NOGA-Code); 'VZAE' = Anzahl Vollzeitäquivalente nach Branche (NOGA-Code).
# Issued                   : 2022-09-20T17:22:40
# Modified                 : 2022-09-20T17:22:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001522_00002900.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001522_00002900.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 975 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jahr           975 non-null    int64
#  1   NOGA08         975 non-null    int64
#  2   Betriebe       975 non-null    int64
#  3   Beschaeftigte  975 non-null    int64
#  4   VZAE           975 non-null    float64
# dtypes: float64(1), int64(4)
# memory usage: 38.2 KB

# %%
df.head()
# Out:
#    Jahr  NOGA08  Betriebe  Beschaeftigte  VZAE
# 0  2019   11100        13             31  13.0
# 1  2019   11300         2              5   5.0
# 2  2019   11900         1              4   1.0
# 3  2019   14100        14             44  35.0
# 4  2019   14200         2              4   3.0

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                      503       212       579
# Jahr             2020.00    2019.0    2020.0
# NOGA08         110100.00  469000.0  309900.0
# Betriebe            1.00      16.0       1.0
# Beschaeftigte      39.00      33.0       3.0
# VZAE               33.97      21.0       1.4

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(exclude='number'))
    except:
        pass

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr     NOGA08  Betriebe  Beschaeftigte     VZAE
# count   975.00     975.00    975.00         975.00   975.00
# mean  2,019.51 531,063.32     16.76         151.75   115.63
# std       0.50 244,021.48     36.32         401.87   308.07
# min   2,019.00  11,100.00      1.00           1.00     0.00
# 25%   2,019.00 383,200.00      2.00           7.00     5.00
# 50%   2,020.00 476,402.00      5.00          36.00    26.65
# 75%   2,020.00 721,500.00     14.00         121.50    93.00
# max   2,020.00 960,900.00    291.00       7,108.00 4,944.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anteil EFH am Wohnungsbestand [%]

# %% [markdown]
# ### **Description**: Anteil EFH am Wohnungsbestand. Wohnungsbestand gemäss GWS. Wohnungsbestand bis 2009 aus Fortschreibung des Wohnungsbestandes der GWZ aufgrund der WBT.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **358@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T12:59:40`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'einfamilienhaus', 'gemeinden', 'immobilien', 'kanton_zuerich', 'wohnungsbestand', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 279
# Title                    : Anteil EFH am Wohnungsbestand [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T12:59:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_369.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_369.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,230 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6230 entries, 0 to 6229
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6230 non-null   int64
#  1   GEBIET_NAME      6230 non-null   object
#  2   THEMA_NAME       6230 non-null   object
#  3   SET_NAME         6230 non-null   object
#  4   SUBSET_NAME      6230 non-null   object
#  5   INDIKATOR_ID     6230 non-null   int64
#  6   INDIKATOR_NAME   6230 non-null   object
#  7   INDIKATOR_JAHR   6230 non-null   int64
#  8   INDIKATOR_VALUE  6230 non-null   float64
#  9   EINHEIT_KURZ     6230 non-null   object
#  10  EINHEIT_LANG     6230 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID                     INDIKATOR_NAME  \
# 0  Wohnungsbestand           369  Anteil EFH am Wohnungsbestand [%]
# 1  Wohnungsbestand           369  Anteil EFH am Wohnungsbestand [%]
# 2  Wohnungsbestand           369  Anteil EFH am Wohnungsbestand [%]
# 3  Wohnungsbestand           369  Anteil EFH am Wohnungsbestand [%]
# 4  Wohnungsbestand           369  Anteil EFH am Wohnungsbestand [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            1990             44.3            %      Prozent
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               3774  \
# BFS_NR                                         173
# GEBIET_NAME                                Hittnau
# THEMA_NAME                      Bau und Immobilien
# SET_NAME               Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                        Wohnungsbestand
# INDIKATOR_ID                                   369
# INDIKATOR_NAME   Anteil EFH am Wohnungsbestand [%]
# INDIKATOR_JAHR                                2021
# INDIKATOR_VALUE                               36.9
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               5126  \
# BFS_NR                                         246
# GEBIET_NAME                          Oetwil a.d.L.
# THEMA_NAME                      Bau und Immobilien
# SET_NAME               Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                        Wohnungsbestand
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          6230                6230                         6230
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             32                6230                         6230
#
#             SUBSET_NAME                     INDIKATOR_NAME EINHEIT_KURZ  \
# count              6230                               6230         6230
# unique                1                                  1            1
# top     Wohnungsbestand  Anteil EFH am Wohnungsbestand [%]            %
# freq               6230                               6230         6230
#
#        EINHEIT_LANG
# count          6230
# unique            1
# top         Prozent
# freq           6230

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,230.00      6,230.00        6,230.00         6,230.00
# mean    107.33        369.00        2,005.41            31.64
# std      84.16          0.00            9.20            13.36
# min       0.00        369.00        1,990.00             4.10
# 25%      31.00        369.00        1,997.00            20.30
# 50%      94.00        369.00        2,005.00            31.90
# 75%     178.00        369.00        2,013.00            42.50
# max     298.00        369.00        2,021.00            63.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

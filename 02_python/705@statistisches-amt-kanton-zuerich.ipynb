# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungsprognose für den Kanton Zürich

# %% [markdown]
# ### **Description**: Bevölkerung nach Bezirk, Region, Geschlecht und Alter (5-Jahres-Altersklassen), nach zivilrechtlichem Wohnsitz, Daten per Ende Jahr. Dieser Datensatz enthält die aktuellen Prognosedaten. Daten von früheren Prognoseläufen finden Sie in separaten Datensätzen im Datenkatalog. Quellen: Kantonale Bevölkerungserhebung KBE (effektive Bevölkerung), Szenario «Trend ZH 2022» (prognostizierte Bevölkerung), Statistisches Amt des Kantons Zürich.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **705@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-10-14T22:35:00`
# - **Modified** `2022-12-02T11:52:08`
# - **Startdate** `2010-12-31`
# - **Enddate** `2050-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['altersklassen', 'bevoelkerung', 'bevoelkerungsprognosen', 'bevoelkerungswachstum', 'einwohnerzahl', 'geschlecht', 'prognosen', 'raumplanungsregionen', 'bevoelkerungsszenarien', 'bevoelkerungsstatistik', 'einwohner', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/soziales/bevoelkerungszahlen/zukuenftige_entwicklung.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1740
# Title                    : Bevölkerungsprognose Trend ZH 2022, nach Region, Geschlecht und 20 Altersklassen
# Description              : Bevölkerung 2010–2050 nach Region, Geschlecht und Alter, nach zivilrechtlichem Wohnsitz, Daten per Ende Jahr. Maschinenlesbares Format.
# Issued                   : 2020-10-14T23:17:49
# Modified                 : 2022-12-02T10:22:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000705_00001740.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000705_00001740.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1741
# Title                    : Bevölkerungsprognose Trend ZH 2022, nach Bezirk, Geschlecht und 20 Altersklassen
# Description              : Bevölkerung 2010–2050 nach Bezirk, Geschlecht und Alter, nach zivilrechtlichem Wohnsitz, Daten per Ende Jahr. Maschinenlesbares Format.
# Issued                   : 2020-10-14T23:39:00
# Modified                 : 2022-12-02T10:22:12
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000705_00001741.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000705_00001741.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 19,680 rows (observations) and 6 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19680 entries, 0 to 19679
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bezirk      19680 non-null  object
#  1   daten       19680 non-null  object
#  2   jahr        19680 non-null  int64
#  3   geschlecht  19680 non-null  object
#  4   alter       19680 non-null  object
#  5   anzahl      19680 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.6 MB

# %%
df.head()
# Out:
#       bezirk                                     daten  jahr geschlecht  \
# 0  Affoltern  Effektiv_Kantonale_Bevoelkerungserhebung  2010  maennlich
# 1  Affoltern  Effektiv_Kantonale_Bevoelkerungserhebung  2010  maennlich
# 2  Affoltern  Effektiv_Kantonale_Bevoelkerungserhebung  2010  maennlich
# 3  Affoltern  Effektiv_Kantonale_Bevoelkerungserhebung  2010  maennlich
# 4  Affoltern  Effektiv_Kantonale_Bevoelkerungserhebung  2010  maennlich
#
#    alter  anzahl
# 0  00_04  1350.0
# 1  05_09  1359.0
# 2  10_14  1359.0
# 3  15_19  1522.0
# 4  20_24  1380.0

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                              10618                                     5240   \
# bezirk                      Horgen                                 Dielsdorf
# daten       Prognose_Trend_ZH_2022  Effektiv_Kantonale_Bevoelkerungserhebung
# jahr                          2029                                      2018
# geschlecht               maennlich                                 maennlich
# alter                        90_94                                     00_04
# anzahl                     565.887                                    2560.0
#
#                                                118
# bezirk                                     Affoltern
# daten       Effektiv_Kantonale_Bevoelkerungserhebung
# jahr                                            2012
# geschlecht                                  weiblich
# alter                                          90_94
# anzahl                                         110.0

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#            bezirk                   daten geschlecht  alter
# count       19680                   19680      19680  19680
# unique         12                       2          2     20
# top     Affoltern  Prognose_Trend_ZH_2022  maennlich  00_04
# freq         1640                   13920       9840    984

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#            jahr    anzahl
# count 19,680.00 19,680.00
# mean   2,030.00  3,544.50
# std       11.83  3,452.68
# min    2,010.00      4.00
# 25%    2,020.00  1,563.00
# 50%    2,030.00  2,871.86
# 75%    2,040.00  4,330.07
# max    2,050.00 28,521.01

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | sebastian.weingartner@statistik.ji.zh.ch

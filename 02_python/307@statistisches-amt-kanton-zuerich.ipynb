# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Heiraten [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Heiraten. Ein oder beide Partner ist/sind in einer Gemeinde des Kantons Zürich wohnhaft.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **307@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'ehe', 'eheschliessungen', 'gemeinden', 'heiraten', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 237
# Title                    : Heiraten [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_445.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_445.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,245 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6245 entries, 0 to 6244
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6245 non-null   int64
#  1   GEBIET_NAME      6245 non-null   object
#  2   THEMA_NAME       6245 non-null   object
#  3   SET_NAME         6245 non-null   object
#  4   SUBSET_NAME      6245 non-null   object
#  5   INDIKATOR_ID     6245 non-null   int64
#  6   INDIKATOR_NAME   6245 non-null   object
#  7   INDIKATOR_JAHR   6245 non-null   int64
#  8   INDIKATOR_VALUE  6230 non-null   float64
#  9   EINHEIT_KURZ     6245 non-null   object
#  10  EINHEIT_LANG     6245 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID   INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Heiraten und Scheidungen           445  Heiraten [Anz.]            1990
# 1  Heiraten und Scheidungen           445  Heiraten [Anz.]            1991
# 2  Heiraten und Scheidungen           445  Heiraten [Anz.]            1992
# 3  Heiraten und Scheidungen           445  Heiraten [Anz.]            1993
# 4  Heiraten und Scheidungen           445  Heiraten [Anz.]            1994
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      1680                      5696  \
# BFS_NR                                 65                         0
# GEBIET_NAME                   Oberembrach             Bezirk Horgen
# THEMA_NAME       Bevölkerung und Soziales  Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbewegung      Bevölkerungsbewegung
# SUBSET_NAME      Heiraten und Scheidungen  Heiraten und Scheidungen
# INDIKATOR_ID                          445                       445
# INDIKATOR_NAME            Heiraten [Anz.]           Heiraten [Anz.]
# INDIKATOR_JAHR                       2017                      2017
# INDIKATOR_VALUE                      11.0                     606.0
# EINHEIT_KURZ                         Anz.                      Anz.
# EINHEIT_LANG                       Anzahl                    Anzahl
#
#                                      4432
# BFS_NR                                214
# GEBIET_NAME                      Dägerlen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          6245                      6245                  6245
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             32                      6245                  6245
#
#                      SUBSET_NAME   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                       6245             6245         6245         6245
# unique                         1                1            1            1
# top     Heiraten und Scheidungen  Heiraten [Anz.]         Anz.       Anzahl
# freq                        6245             6245         6245         6245

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,245.00      6,245.00        6,245.00         6,230.00
# mean    107.86        445.00        2,005.44           167.57
# std      84.60          0.00            9.20           678.84
# min       0.00        445.00        1,990.00             0.00
# 25%      31.00        445.00        1,997.00             8.00
# 50%      94.00        445.00        2,005.00            22.00
# 75%     178.00        445.00        2,013.00            60.00
# max     298.00        445.00        2,021.00         8,781.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

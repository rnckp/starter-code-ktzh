# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lernende der Volksschule im Kanton Zürich nach Staatsangehörigkeit ab 2000

# %% [markdown]
# ### **Description**: Schüler/innen an öffentlichen Volksschulen im Kanton Zürich, die nach kantonalem Lehrplan unterrichtet werden. Mit Volksschule wird die Schulbildung während der obligatorischen Schulzeit bezeichnet. Die obligatorische Schulzeit umfasst den Kindergarten, sechs Jahre Primarschule und drei Jahre Sekundarstufe I. Nicht mitgezählt sind Lernende der Mittelschulen, Lernende in in Heim-/Sonderschulen, und Lernende in Privatschulen. Es gilt das Schulortprinzip, gezählt werden Schülerinnen und Schüler, welche eine Schule innerhalb des Kantons Zürich besuchen.
#
# Die Daten werden jährlich für den Stichtag 15.9. erhoben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1582@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-10-24T11:15:55`
# - **Modified** `2022-10-25T09:16:24`
# - **Startdate** `2000-09-15`
# - **Enddate** `2021-09-15`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['ausbildung', 'bildung', 'grossregionen', 'lernende', 'nationalitaet', 'schueler', 'schuelerinnen', 'staatsangehoerigkeit', 'volksschule', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3020
# Title                    : Lernende der Volksschule im Kanton Zürich nach Staatsangehörigkeit ab 2000
# Description              : Die Daten sind differenziert nach Jahr und Staatsangehörigkeit. Bei Zellen kleiner 5 wird die Staatsangehörigkeit zuerst auf Ebene Grossregion und, wenn nötig, auf Ebene Kontinent aggregiert. Jahr: Das Jahr ist jeweils das Kalenderjahr der Erhebung, wobei der Stichtag der 15.9. ist. Die Daten für das Jahr 2021 sind somit im Schuljahr 2021/22 erhoben worden und zeigen den Datenstand am 15. September 2021. Staatsangehoerigkeit: Es wird pro Person nur eine Staatsangehörigkeit erhoben. Falls eine Person mehrere Staatsangehörigkeiten hat, und eine davon ist die Schweizerische, so wird diese prioritär erfasst. Bei anderen mehrfachen Staatsangehörigkeiten wir keine Vorgabe zur Priorisierung gemacht. Staatsangehoerigkeit_ISO2_Code: Bei der Aggregation auf Grossregion und Kontinent bleibt der ISO2 Code leer. Anzahl: Anzahl der Schülerinnen und Schüler mit der entsprechenden Merkmalskombination.
# Issued                   : 2022-10-24T11:15:55
# Modified                 : 2022-10-24T11:15:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Staatsangehoerigkeit.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Staatsangehoerigkeit.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,479 rows (observations) and 6 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Stand                           2479 non-null   object
#  1   Kanton                          2479 non-null   object
#  2   Jahr                            2479 non-null   int64
#  3   Staatsangehoerigkeit            2479 non-null   object
#  4   Staatsangehoerigkeit_ISO2_Code  2183 non-null   object
#  5   Anzahl                          2479 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 773.3 KB

# %%
df.head()
# Out:
#         Stand Kanton  Jahr Staatsangehoerigkeit  \
# 0  2022-10-21     zh  2021              Schweiz
# 1  2022-10-21     zh  2021          Deutschland
# 2  2022-10-21     zh  2021              Italien
# 3  2022-10-21     zh  2021             Portugal
# 4  2022-10-21     zh  2021               Kosovo
#
#   Staatsangehoerigkeit_ISO2_Code  Anzahl
# 0                             CH  115223
# 1                             DE    6694
# 2                             IT    4183
# 3                             PT    3183
# 4                             XK    2586

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             362         645         1773
# Stand                                 2022-10-21  2022-10-21  2022-10-21
# Kanton                                        zh          zh          zh
# Jahr                                        2019        2016        2007
# Staatsangehoerigkeit            Restliches Asien    Russland      Kanada
# Staatsangehoerigkeit_ISO2_Code               NaN          RU          CA
# Anzahl                                        11         249          32

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#              Stand Kanton Staatsangehoerigkeit Staatsangehoerigkeit_ISO2_Code  \
# count         2479   2479                 2479                           2183
# unique           1      1                  156                            127
# top     2022-10-21     zh              Schweiz                             MN
# freq          2479   2479                   22                             36
#
#        Anzahl
# count    2479
# unique    652
# top         6
# freq      104

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr
# count 2,479.00
# mean  2,011.26
# std       6.05
# min   2,000.00
# 25%   2,006.00
# 50%   2,012.00
# 75%   2,016.00
# max   2,021.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

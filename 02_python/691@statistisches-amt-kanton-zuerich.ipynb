# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Vom Covid-19-Lockdown besonders betroffene Haushalte

# %% [markdown]
# ### **Description**: Anteil der Privathaushalte in Gemeinden des Kantons Zürich mit Covid-19-Risikopersonen im Pensionsalter oder mit mindestens einem Kind im Alter von 0 bis 12 Jahren und potenziellem Kinderbetreuungsproblem.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **691@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-07-06T15:49:00`
# - **Modified** `2020-07-06T15:59:56`
# - **Startdate** `2019-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Bildung, Wissenschaft', 'Gesundheit', 'Bevölkerung']`
# - **Keyword** `['altersgruppen', 'gemeinden', 'haushalte', 'kanton_zuerich', 'kinderbetreuung', 'covid-19', 'sars-cov-2', 'bevoelkerungsstatistik', 'einwohner', 'covid19', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.web.statistik.zh.ch/covid19_indikatoren_uebersicht/#/50/Alle`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1659
# Title                    : Vom Covid-19-Lockdown besonders betroffene Haushalte
# Description              : Spaltenüberschriften: 'bfs' = GEMEINDE_BFS_NR; 'gmd' = GEMEINDE; 'hh...' = HAUSHALTE
# Issued                   : 2020-07-06T15:59:56
# Modified                 : 2020-07-06T15:59:56
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000691_00001659.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000691_00001659.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 162 rows (observations) and 10 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   bfs                          162 non-null    int64
#  1   gmd                          162 non-null    object
#  2   hh1_risikopersonen           162 non-null    float64
#  3   hh11_alleinstehend           162 non-null    float64
#  4   hh12_paar_beide_alt          162 non-null    float64
#  5   hh13_paar_eine_person_alt    162 non-null    float64
#  6   hh2_kinderbetreuungsproblem  162 non-null    float64
#  7   hh21_alleinerziehend         162 non-null    float64
#  8   hh22_elternpaar              162 non-null    float64
#  9   hh3_andere                   162 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 21.9 KB

# %%
df.head()
# Out:
#    bfs             gmd  hh1_risikopersonen  hh11_alleinstehend  \
# 0    1     Aeugst a.A.           29.599057            9.787736
# 1    2  Affoltern a.A.           28.694836           12.544601
# 2    3      Bonstetten           26.944564            9.840997
# 3    4     Hausen a.A.           30.303030           10.767247
# 4    5        Hedingen           27.938343           10.533076
#
#    hh12_paar_beide_alt  hh13_paar_eine_person_alt  \
# 0            11.674528                   8.136792
# 1            10.985915                   5.164319
# 2            12.075634                   5.027933
# 3            12.185687                   7.350097
# 4            11.753372                   5.651895
#
#    hh2_kinderbetreuungsproblem  hh21_alleinerziehend  hh22_elternpaar  \
# 0                    16.627358              1.415094        15.212264
# 1                    18.403756              1.727700        16.676056
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                    84         40           144
# bfs                                116         56          242
# gmd                           Grningen    Embrach  Birmensdorf
# hh1_risikopersonen           29.392971  27.521761    29.200269
# hh11_alleinstehend           11.757188   9.907834     12.02957
# hh12_paar_beide_alt          10.990415  11.136713    11.995968
# hh13_paar_eine_person_alt     6.645367   6.477215     5.174731
# hh2_kinderbetreuungsproblem  19.361022  19.662058    20.262097
# hh21_alleinerziehend          0.958466   2.022529      1.71371
# hh22_elternpaar              18.402556  17.639529    18.548387
# hh3_andere                   51.246006   52.81618    50.537634

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                 gmd
# count           162
# unique          162
# top     Aeugst a.A.
# freq              1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          bfs  hh1_risikopersonen  hh11_alleinstehend  hh12_paar_beide_alt  \
# count 162.00              162.00              162.00               162.00
# mean  124.97               29.17               10.85                12.04
# std    83.35                3.78                2.17                 2.26
# min     1.00               18.74                5.93                 5.77
# 25%    56.25               26.81                9.41                10.78
# 50%   112.50               29.46               10.75                12.01
# 75%   195.75               31.86               12.26                13.57
# max   298.00               39.40               17.48                19.15
#
#        hh13_paar_eine_person_alt  hh2_kinderbetreuungsproblem  \
# count                     162.00                       162.00
# mean                        6.28                        19.23
# std                         1.18                         2.44
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | sebastian.weingartner@statistik.ji.zh.ch

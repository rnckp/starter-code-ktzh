# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bauzonen überbaut  [%]

# %% [markdown]
# ### **Description**: Anteil überbaute Bauzonenfläche gemessen an der gesamten Bauzonenfläche

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **72@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-03-17T07:40:27`
# - **Startdate** `1996-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bauzonen', 'bezirke', 'gemeinden', 'kanton_zuerich', 'nutzungsreserven', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 62
# Title                    : Bauzonen überbaut  [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-03-17T07:40:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_52.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_52.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,934 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4934 entries, 0 to 4933
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4934 non-null   int64
#  1   GEBIET_NAME      4934 non-null   object
#  2   THEMA_NAME       4934 non-null   object
#  3   SET_NAME         4934 non-null   object
#  4   SUBSET_NAME      4934 non-null   object
#  5   INDIKATOR_ID     4934 non-null   int64
#  6   INDIKATOR_NAME   4934 non-null   object
#  7   INDIKATOR_JAHR   4934 non-null   int64
#  8   INDIKATOR_VALUE  4934 non-null   float64
#  9   EINHEIT_KURZ     4934 non-null   object
#  10  EINHEIT_LANG     4934 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 1       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 2       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 3       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 4       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
#
#   SUBSET_NAME  INDIKATOR_ID          INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0    Bauzonen            52  Bauzonen überbaut  [%]            1996
# 1    Bauzonen            52  Bauzonen überbaut  [%]            1997
# 2    Bauzonen            52  Bauzonen überbaut  [%]            1998
# 3    Bauzonen            52  Bauzonen überbaut  [%]            1999
# 4    Bauzonen            52  Bauzonen überbaut  [%]            2000
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0             74.6            %      Prozent
# 1             76.5            %      Prozent
# 2             78.0            %      Prozent
# 3             78.1            %      Prozent
# 4             78.3            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         1863                         1425  \
# BFS_NR                                    96                           70
# GEBIET_NAME                       Regensdorf                 Wasterkingen
# THEMA_NAME                Bau und Immobilien           Bau und Immobilien
# SET_NAME         Bauzonen, Bauzonenverbrauch  Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                         Bauzonen                     Bauzonen
# INDIKATOR_ID                              52                           52
# INDIKATOR_NAME        Bauzonen überbaut  [%]       Bauzonen überbaut  [%]
# INDIKATOR_JAHR                          1996                         2008
# INDIKATOR_VALUE                         76.7                         83.9
# EINHEIT_KURZ                               %                            %
# EINHEIT_LANG                         Prozent                      Prozent
#
#                                         2919
# BFS_NR                                   173
# GEBIET_NAME                          Hittnau
# THEMA_NAME                Bau und Immobilien
# SET_NAME         Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                         Bauzonen
# INDIKATOR_ID                              52
# INDIKATOR_NAME        Bauzonen überbaut  [%]
# INDIKATOR_JAHR                          2004
# INDIKATOR_VALUE                         89.1
# EINHEIT_KURZ                               %
# EINHEIT_LANG                         Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          4934                4934                         4934
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# freq             25                4934                         4934
#
#        SUBSET_NAME          INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count         4934                    4934         4934         4934
# unique           1                       1            1            1
# top       Bauzonen  Bauzonen überbaut  [%]            %      Prozent
# freq          4934                    4934         4934         4934

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,934.00      4,934.00        4,934.00         4,934.00
# mean    110.49         52.00        2,007.87            85.58
# std      86.98          0.00            7.16             6.47
# min       0.00         52.00        1,996.00            58.20
# 25%      32.00         52.00        2,002.00            81.60
# 50%      96.00         52.00        2,008.00            86.60
# 75%     181.00         52.00        2,014.00            90.40
# max     298.00         52.00        2,020.00            97.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

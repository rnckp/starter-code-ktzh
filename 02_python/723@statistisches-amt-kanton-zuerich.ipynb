# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuererträge nach Einkommens- und Vermögensklassen

# %% [markdown]
# ### **Description**: Steuerertrag nach Einkommens- und Vermögensklassen auf Basis der Bundessteuerdaten des kantonalen Steueramts.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **723@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-05-07T00:00:00`
# - **Modified** `2022-10-24T08:25:18`
# - **Startdate** `2012-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['steuerbares_einkommen', 'steuerertrag', 'einkommensverteilung', 'steuerdaten', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3381
# Title                    : Steuererträge nach Vermögensklassen
# Description              : None
# Issued                   : 2022-10-24T08:24:46
# Modified                 : 2022-10-24T08:24:46
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000723_00003381.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000723_00003381.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3380
# Title                    : Steuererträge nach Einkommensklassen
# Description              : Die Basis für die Berechnung der approximativen Steuererträge bildet das steuerbare Einkommen gemäss Bundessteuer. Das steuerbare Einkommen gemäss Bundesteuer kann aufgrund unterschiedlicher Abzüge von dem für die Staats- und Gemeindesteuer massgebenden Einkommen abweichen. Für die unterschiedlich hohen Kinderabzüge wurde eine Korrektur vorgenommen. Für andere Positionen werden keine Korrektur vorgenommen (z.B. Berufsauslagen).
# Issued                   : 2022-10-24T08:24:38
# Modified                 : 2022-10-24T08:24:38
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000723_00003380.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000723_00003380.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 120 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   steuerjahr                    120 non-null    int64
#  1   einkommensklasse              120 non-null    object
#  2   anzahl_pflichtige             120 non-null    int64
#  3   steuerbares_einkommen_in_mio  120 non-null    float64
#  4   staatssteuer                  120 non-null    float64
#  5   anteil_pflichtige             120 non-null    float64
#  6   anteil_einkommen              120 non-null    float64
#  7   anteil_steuer                 120 non-null    float64
#  8   kumuliert_anteil_pflichtige   120 non-null    float64
#  9   kumuliert_anteil_einkommen    120 non-null    float64
#  10  kumuliert_steuer_anteil       120 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 17.9 KB

# %%
df.head()
# Out:
#    steuerjahr einkommensklasse  anzahl_pflichtige  \
# 0        2012        0  -  999              57399
# 1        2012    1000  -  9999              53516
# 2        2012  10000  -  19999              54099
# 3        2012  20000  -  29999              69091
# 4        2012  30000  -  39999              81316
#
#    steuerbares_einkommen_in_mio  staatssteuer  anteil_pflichtige  \
# 0                        2.2885      0.000000           6.944903
# 1                      280.9511      0.442856           6.475086
# 2                      818.4172     10.232752           6.545625
# 3                     1716.5736     37.655095           8.359559
# 4                     2848.5126     82.066906           9.838704
#
#    anteil_einkommen  anteil_steuer  kumuliert_anteil_pflichtige  \
# 0          0.004221       0.000000                     6.944903
# 1          0.518137       0.014314                    13.419989
# 2          1.509346       0.330753                    19.965614
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                          1                38               47
# steuerjahr                             2012             2014             2015
# einkommensklasse              1000  -  9999  70000  -  79999  10000  -  19999
# anzahl_pflichtige                     53516            57447            55119
# steuerbares_einkommen_in_mio       280.9511        4288.4491         832.7005
# staatssteuer                       0.442856       202.943482        10.461438
# anteil_pflichtige                  6.475086          6.81675         6.471379
# anteil_einkommen                   0.518137          7.56899         1.452059
# anteil_steuer                      0.014314          6.19458         0.315035
# kumuliert_anteil_pflichtige       13.419989        74.643333        19.971822
# kumuliert_anteil_einkommen         0.522358        41.919839          1.94052
# kumuliert_steuer_anteil            0.014314         26.92614         0.328303

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        einkommensklasse
# count               120
# unique               15
# top           0  -  999
# freq                  8

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        steuerjahr  anzahl_pflichtige  steuerbares_einkommen_in_mio  \
# count      120.00             120.00                        120.00
# mean     2,015.50          57,739.06                      3,978.60
# std          2.30          24,901.23                      2,796.37
# min      2,012.00          11,640.00                          2.12
# 25%      2,013.75          37,716.75                      1,734.35
# 50%      2,015.50          58,338.00                      4,156.61
# 75%      2,017.25          78,210.75                      4,897.40
# max      2,019.00         100,160.00                     12,010.58
#
#        staatssteuer  anteil_pflichtige  anteil_einkommen  anteil_steuer  \
# count        120.00             120.00            120.00         120.00
# mean         233.83               6.67              6.67           6.67
# std          250.43               2.87              4.61           6.99
# min            0.00               1.41              0.00           0.00
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

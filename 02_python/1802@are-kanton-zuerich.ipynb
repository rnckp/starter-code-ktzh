# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Geschossflächen im Kanton Zürich

# %% [markdown]
# ### **Description**: Übersicht über den Stand der Geschossflächen im Kanton Zürich. Die Geschossflächendefinition lehnt sich an die Definition der Geschossfläche GF gemäss SIA und der anrechenbare Geschossfläche gemäss Planungs- und Baugesetz (PBG) an. Die Erhebung der Geschossflächen leitet sich indirekt aus gesetzlichen Vorgaben von Bund und Kanton ab. Der Zweck der Erhebung der Geschossflächenreserven ist aufzuzeigen, welches Verdichtungspotential rechnerisch in Form von Geschossflächen in der Bauzone theoretisch vorhanden ist. Demgegenüber soll mit dem Geschossflächenbestand quantifiziert werden, wie viel Geschossfläche innerhalb der Bauzone bereits realisiert worden ist. Ab 2021 wird ein neues Berechnungsmodell verwendet, dadurch sind die Werte nur schwer mit jenen der Vorjahre vergleichbar. Aus technischen Gründen fand für 2020 keine Datenerhebung statt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1802@are-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-12-05T11:47:42`
# - **Modified** `2022-12-09T11:22:20`
# - **Startdate** `2000-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['gemeinden', 'geschossflaeche', 'raum', 'raumplanungsregionen', 'ogd']`
# - **Publisher** `['Amt für Raumentwicklung des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`3` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3323
# Title                    : Geschossflächenreserven Kanton Zürich ab 2000 in 1'000m2
# Description              : Geschossflächenreserven, unterteilt in Wohnzone, Mischzone, Arbeitszone und Zone für öffentliche Bauten sowie zusätzlich in überbaute und nicht überbaute Bauzone. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Ab 2021 wird ein neues Berechnungsmodell verwendet. Aus technischen Gründen fand für 2020 keine Datenerhebung statt.
# Issued                   : 2022-12-05T11:47:42
# Modified                 : 2022-12-07T13:00:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003323.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003323.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3325
# Title                    : Ausbaugrad Kanton Zürich ab 2000 in %
# Description              : Ausbaugrad (gebaute Geschossfläche in % der zulässigen Geschossfläche innerhalb der überbauten Bauzone), unterteilt in Wohnzone, Mischzone, Arbeitszone und Zone für öffentliche Bauten. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Es können keine Totale aus den Werten gerechnet werden. Ab 2021 wird ein neues Berechnungsmodell verwendet. Aus technischen Gründen fand für 2020 keine Datenerhebung statt.
# Issued                   : 2022-12-05T11:47:42
# Modified                 : 2022-12-07T12:59:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003325.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003325.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 3321
# Title                    : Geschossflächenbestand Kanton Zürich ab 2000 in 1'000m2
# Description              : Geschossflächenbestand, unterteilt in Wohnzone, Mischzone, Arbeitszone und Zone für öffentliche Bauten. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Ab 2021 wird ein neues Berechnungsmodell verwendet. Aus technischen Gründen fand für 2020 keine Datenerhebung statt.
# Issued                   : 2022-12-05T11:47:42
# Modified                 : 2022-12-07T13:00:14
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003321.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001802_00003321.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,998 rows (observations) and 9 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   BFS_NR                               3662 non-null   float64
#  1   ARE_NR                               3998 non-null   int64
#  2   GEBIET_NAME                          3998 non-null   object
#  3   JAHR                                 3998 non-null   int64
#  4   Gebaute GFL_Wohnzonen                3998 non-null   float64
#  5   Gebaute_GFL_Mischzonen               3998 non-null   float64
#  6   Gebaute_GFL_Arbeitszonen             3998 non-null   float64
#  7   Gebaute_GFL_Zone_öffentliche_Bauten  3998 non-null   int64
#  8   Einheit                              3998 non-null   object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 736.8 KB

# %%
df.head()
# Out:
#    BFS_NR  ARE_NR GEBIET_NAME  JAHR  Gebaute GFL_Wohnzonen  \
# 0   261.0       1      Zürich  2000                13367.0
# 1   261.0       1      Zürich  2001                14073.5
# 2   261.0       1      Zürich  2002                14100.5
# 3   261.0       1      Zürich  2003                14146.0
# 4   261.0       1      Zürich  2004                14271.6
#
#    Gebaute_GFL_Mischzonen  Gebaute_GFL_Arbeitszonen  \
# 0                 17478.5                    2896.2
# 1                 17393.2                    2894.0
# 2                 17670.9                    2776.6
# 3                 17729.4                    2792.4
# 4                 18016.7                    2573.1
#
#    Gebaute_GFL_Zone_öffentliche_Bauten Einheit
# 0                                    0      ha
# 1                                    0      ha
# 2                                    0      ha
# 3                                    0      ha
# 4                                    0      ha

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         278                 1721   1420
# BFS_NR                                 227.0                 NaN   67.0
# ARE_NR                                   111                 174    161
# GEBIET_NAME                          Seuzach  Region Knonaueramt   Rafz
# JAHR                                    2000                2011   2004
# Gebaute GFL_Wohnzonen                  271.6              1626.6  111.1
# Gebaute_GFL_Mischzonen                 139.2              1887.6  133.4
# Gebaute_GFL_Arbeitszonen                47.4               378.5   53.0
# Gebaute_GFL_Zone_öffentliche_Bauten        0                   0      0
# Einheit                                   ha                  ha     ha

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GEBIET_NAME Einheit
# count         3998    3998
# unique         188       1
# top      Wädenswil      ha
# freq            39    3998

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR   ARE_NR     JAHR  Gebaute GFL_Wohnzonen  \
# count 3,662.00 3,998.00 3,998.00               3,998.00
# mean    126.34   143.02 2,009.90                 881.14
# std      81.91   259.48     6.09               4,110.25
# min       1.00     1.00 2,000.00                   0.00
# 25%      57.00    49.00 2,005.00                  44.32
# 50%     116.00    98.00 2,010.00                 144.55
# 75%     196.00   147.00 2,015.00                 373.78
# max     298.00 1,802.00 2,021.00              58,148.90
#
#        Gebaute_GFL_Mischzonen  Gebaute_GFL_Arbeitszonen  \
# count                3,998.00                  3,998.00
# mean                   850.24                    378.50
# std                  4,144.56                  1,703.50
# min                     11.60                      0.00
# 25%                     67.62                      5.40
# 50%                    115.15                     42.25
# 75%                    244.65                    167.40
# max                 56,917.80                 24,042.50
#
#        Gebaute_GFL_Zone_öffentliche_Bauten
# count                             3,998.00
# mean                                  0.00
# std                                   0.00
# min                                   0.00
# 25%                                   0.00
# 50%                                   0.00
# 75%                                   0.00
# max                                   0.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Raumentwicklung des Kantons Zürich | Raumplanung | raumbeobachtung@bd.zh.ch

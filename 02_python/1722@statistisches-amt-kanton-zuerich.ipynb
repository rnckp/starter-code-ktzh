# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anteil Gemeinnützige Wohnungen in Gemeinden des Kantons Zürich [%]

# %% [markdown]
# ### **Description**: Anteil Wohnungen (am Gesamtwohnungsbestand) in Gebäuden, die dem gemeinnützigen Sektor zuzuordnen sind. Das Bundesamt für Wohnungswesen (BWO), das die Daten erhebt, schätzt, dass rund 90 Prozent aller sich im Besitz des gemeinnützigen Sektors befindlichen Wohnungen erfasst werden. Nicht erfasst werden Wohnungen in Gebäuden in direktem kommunalen Besitz (in der Stadt Zürich zum Beispiel die städtischen Wohnungen). Es ist nicht zulässig, die jährliche Veränderung des Indikators als reale Zu- bzw. Abnahme des gemeinnützigen Wohnungsbestandes zu interpretieren, weil die Datengrundlage nur alle fünf Jahre systematisch aktualisiert wird. Insbesondere grosse Veränderungen sind in der Regel der nachträglichen Erfassung von Gebäuden geschuldet.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1722@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-19T16:51:19`
# - **Modified** `2022-09-19T16:58:20`
# - **Startdate** `2016-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen', 'Soziale Sicherheit']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'mietwohnungen', 'wohnungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3220
# Title                    : Anteil Gemeinnützige Wohnungen [%]
# Description              : None
# Issued                   : 2022-09-19T16:51:19
# Modified                 : 2022-09-19T16:51:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_841.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_841.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 956 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           956 non-null    int64
#  1   GEBIET_NAME      956 non-null    object
#  2   THEMA_NAME       956 non-null    object
#  3   SET_NAME         956 non-null    object
#  4   SUBSET_NAME      956 non-null    object
#  5   INDIKATOR_ID     956 non-null    int64
#  6   INDIKATOR_NAME   956 non-null    object
#  7   INDIKATOR_JAHR   956 non-null    int64
#  8   INDIKATOR_VALUE  956 non-null    float64
#  9   EINHEIT_KURZ     956 non-null    object
#  10  EINHEIT_LANG     956 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 619.1 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID                      INDIKATOR_NAME  \
# 0  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 1  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 2  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 3  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 4  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2016              0.0            %      Prozent
# 1            2017              0.0            %      Prozent
# 2            2018              0.0            %      Prozent
# 3            2019              0.0            %      Prozent
# 4            2020              0.0            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 84   \
# BFS_NR                                           23
# GEBIET_NAME                               Berg a.I.
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2020
# INDIKATOR_VALUE                                 0.0
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                 452  \
# BFS_NR                                          120
# GEBIET_NAME                                    Wald
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2019
# INDIKATOR_VALUE                                 2.3
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                 355
# BFS_NR                                           93
# GEBIET_NAME                            Oberweningen
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2017
# INDIKATOR_VALUE                                 0.0
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count           956                 956                          956
# unique          196                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq              5                 956                          956
#
#             SUBSET_NAME                      INDIKATOR_NAME EINHEIT_KURZ  \
# count               956                                 956          956
# unique                1                                   1            1
# top     Wohnungsbestand  Anteil Gemeinnützige Wohnungen [%]            %
# freq                956                                 956          956
#
#        EINHEIT_LANG
# count           956
# unique            1
# top         Prozent
# freq            956

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  956.00        956.00          956.00           956.00
# mean   109.04        841.00        2,017.97             3.22
# std     87.58          0.00            1.41             3.92
# min      0.00        841.00        2,016.00             0.00
# 25%     30.00        841.00        2,017.00             0.00
# 50%     93.00        841.00        2,018.00             2.05
# 75%    181.25        841.00        2,019.00             5.20
# max    298.00        841.00        2,020.00            19.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

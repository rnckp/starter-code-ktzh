# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bauinvestitionen [Mio.Fr.]

# %% [markdown]
# ### **Description**: Bauinvestitionen von Bautätigkeiten mit Investitionscharakter, die einer behördlichen Bewilligung bedürfen

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **185@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:01:18`
# - **Startdate** `1994-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bauinvestitionen', 'bautaetigkeit', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 149
# Title                    : Bauinvestitionen [Mio.Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:01:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_182.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_182.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,322 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322 entries, 0 to 5321
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5322 non-null   int64
#  1   GEBIET_NAME      5322 non-null   object
#  2   THEMA_NAME       5322 non-null   object
#  3   SET_NAME         5322 non-null   object
#  4   SUBSET_NAME      5322 non-null   object
#  5   INDIKATOR_ID     5322 non-null   int64
#  6   INDIKATOR_NAME   5322 non-null   object
#  7   INDIKATOR_JAHR   5322 non-null   int64
#  8   INDIKATOR_VALUE  5322 non-null   int64
#  9   EINHEIT_KURZ     5322 non-null   object
#  10  EINHEIT_LANG     5322 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 1       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 2       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 3       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 4       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
#
#         SUBSET_NAME  INDIKATOR_ID              INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Bauinvestitionen           182  Bauinvestitionen [Mio.Fr.]            1994
# 1  Bauinvestitionen           182  Bauinvestitionen [Mio.Fr.]            1995
# 2  Bauinvestitionen           182  Bauinvestitionen [Mio.Fr.]            1996
# 3  Bauinvestitionen           182  Bauinvestitionen [Mio.Fr.]            1997
# 4  Bauinvestitionen           182  Bauinvestitionen [Mio.Fr.]            1998
#
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                              3673  \
# BFS_NR                                        200
# GEBIET_NAME                   Wangen-Brüttisellen
# THEMA_NAME                     Bau und Immobilien
# SET_NAME         Gebäudevolumen, Bauinvestitionen
# SUBSET_NAME                      Bauinvestitionen
# INDIKATOR_ID                                  182
# INDIKATOR_NAME         Bauinvestitionen [Mio.Fr.]
# INDIKATOR_JAHR                               2008
# INDIKATOR_VALUE                                40
# EINHEIT_KURZ                              Mio.Fr.
# EINHEIT_LANG                    Millionen Franken
#
#                                              1012  \
# BFS_NR                                         44
# GEBIET_NAME                Waltalingen (bis 2018)
# THEMA_NAME                     Bau und Immobilien
# SET_NAME         Gebäudevolumen, Bauinvestitionen
# SUBSET_NAME                      Bauinvestitionen
# INDIKATOR_ID                                  182
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# count          5322                5322                              5322
# unique          202                   1                                 1
# top     Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# freq             27                5322                              5322
#
#              SUBSET_NAME              INDIKATOR_NAME EINHEIT_KURZ  \
# count               5322                        5322         5322
# unique                 1                           1            1
# top     Bauinvestitionen  Bauinvestitionen [Mio.Fr.]      Mio.Fr.
# freq                5322                        5322         5322
#
#              EINHEIT_LANG
# count                5322
# unique                  1
# top     Millionen Franken
# freq                 5322

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,322.00      5,322.00        5,322.00         5,322.00
# mean    108.92        182.00        2,006.93           173.50
# std      85.02          0.00            7.75           755.42
# min       0.00        182.00        1,994.00             0.00
# 25%      32.00        182.00        2,000.00             6.00
# 50%      95.00        182.00        2,007.00            18.00
# 75%     180.00        182.00        2,014.00            58.00
# max     298.00        182.00        2,020.00        10,815.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anteil ohne GK [%]

# %% [markdown]
# ### **Description**: Anteil Einwohner ohne ÖV-Güteklasse: Die ÖV-Güteklassen geben lagesscharf Aufschluss über die Erschliessungsqualität einer Gemeinde mit dem ÖV. In einem ersten Schritt werden Haltestellenkategorien definiert, in Abhängigkeit von einem an der Haltestelle verfügbaren ÖV-Verkehrsmittel und dem Kursintervall.  Danach wird in Abhängigkeit von Haltestellenkategorie und Luftliniendistanz die ÖV-Güteklasse ermittelt. Für jede Gemeinde werden die Einwohner pro Güteklasse in Prozent berechnet. (http://www.afv.zh.ch/internet/volkswirtschaftsdirektion/afv/de/verkehrsgrundlagen/verkehrsangebot/erreichbarkeit_und_erschliessung/_jcr_content/contentPar/downloadlist/downloaditems/infoblatt_v_g_teklas.spooler.download.1436273189233.pdf/KTZH_AFV_Broschuere_OeV-Gueteklassen.pdf)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **392@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-09-22T00:00:00`
# - **Modified** `2022-11-22T16:30:30`
# - **Startdate** `2013-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['kanton_zuerich', 'oeffentlicher_verkehr', 'verkehr', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 501
# Title                    : Anteil ohne GK [%]
# Description              : None
# Issued                   : 2016-09-22T10:10:00
# Modified                 : 2022-11-22T16:30:30
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_827.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_827.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,860 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860 entries, 0 to 1859
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1860 non-null   int64
#  1   GEBIET_NAME      1860 non-null   object
#  2   THEMA_NAME       1860 non-null   object
#  3   SET_NAME         1860 non-null   object
#  4   SUBSET_NAME      1860 non-null   object
#  5   INDIKATOR_ID     1860 non-null   int64
#  6   INDIKATOR_NAME   1860 non-null   object
#  7   INDIKATOR_JAHR   1860 non-null   int64
#  8   INDIKATOR_VALUE  1860 non-null   float64
#  9   EINHEIT_KURZ     1860 non-null   object
#  10  EINHEIT_LANG     1860 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr
#
#                     SUBSET_NAME  INDIKATOR_ID      INDIKATOR_NAME  \
# 0  ÖV-Güteklassen Erschliessung           827  Anteil ohne GK [%]
# 1  ÖV-Güteklassen Erschliessung           827  Anteil ohne GK [%]
# 2  ÖV-Güteklassen Erschliessung           827  Anteil ohne GK [%]
# 3  ÖV-Güteklassen Erschliessung           827  Anteil ohne GK [%]
# 4  ÖV-Güteklassen Erschliessung           827  Anteil ohne GK [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2013              3.0            %      Prozent
# 1            2014              2.8            %      Prozent
# 2            2015              2.8            %      Prozent
# 3            2016              5.0            %      Prozent
# 4            2017              5.2            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                           979                           929  \
# BFS_NR                                    151                           136
# GEBIET_NAME                         Erlenbach                  Langnau a.A.
# THEMA_NAME                    Raum und Umwelt               Raum und Umwelt
# SET_NAME                              Verkehr                       Verkehr
# SUBSET_NAME      ÖV-Güteklassen Erschliessung  ÖV-Güteklassen Erschliessung
# INDIKATOR_ID                              827                           827
# INDIKATOR_NAME             Anteil ohne GK [%]            Anteil ohne GK [%]
# INDIKATOR_JAHR                           2022                          2022
# INDIKATOR_VALUE                           0.0                           1.5
# EINHEIT_KURZ                                %                             %
# EINHEIT_LANG                          Prozent                       Prozent
#
#                                           564
# BFS_NR                                     72
# GEBIET_NAME                            Winkel
# THEMA_NAME                    Raum und Umwelt
# SET_NAME                              Verkehr
# SUBSET_NAME      ÖV-Güteklassen Erschliessung
# INDIKATOR_ID                              827
# INDIKATOR_NAME             Anteil ohne GK [%]
# INDIKATOR_JAHR                           2017
# INDIKATOR_VALUE                           3.7
# EINHEIT_KURZ                                %
# EINHEIT_LANG                          Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME                   SUBSET_NAME  \
# count          1860             1860     1860                          1860
# unique          186                1        1                             1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  ÖV-Güteklassen Erschliessung
# freq             10             1860     1860                          1860
#
#             INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                 1860         1860         1860
# unique                   1            1            1
# top     Anteil ohne GK [%]            %      Prozent
# freq                  1860         1860         1860

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,860.00      1,860.00        1,860.00         1,860.00
# mean    108.84        827.00        2,017.50             5.61
# std      88.16          0.00            2.87             6.92
# min       0.00        827.00        2,013.00             0.00
# 25%      29.00        827.00        2,015.00             1.30
# 50%      92.50        827.00        2,017.50             3.20
# 75%     182.00        827.00        2,020.00             7.70
# max     298.00        827.00        2,022.00            71.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung: Heimat Ausland [Pers.]

# %% [markdown]
# ### **Description**: Einwohnerbestand Ende Jahr Heimat Ausland nach zivilrechtlichem Wohnsitz (ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **298@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:05`
# - **Startdate** `1978-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['auslaender', 'bevoelkerung', 'bezirke', 'gemeinden', 'heimat', 'kanton_zuerich', 'nationalitaet', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 228
# Title                    : Bevölkerung: Heimat Ausland [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_204.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_204.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 8,668 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8668 entries, 0 to 8667
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           8668 non-null   int64
#  1   GEBIET_NAME      8668 non-null   object
#  2   THEMA_NAME       8668 non-null   object
#  3   SET_NAME         8668 non-null   object
#  4   SUBSET_NAME      8668 non-null   object
#  5   INDIKATOR_ID     8668 non-null   int64
#  6   INDIKATOR_NAME   8668 non-null   object
#  7   INDIKATOR_JAHR   8668 non-null   int64
#  8   INDIKATOR_VALUE  8668 non-null   int64
#  9   EINHEIT_KURZ     8668 non-null   object
#  10  EINHEIT_LANG     8668 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 6.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           204
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           204
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           204
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           204
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           204
#
#                         INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerung: Heimat Ausland [Pers.]            1978               26
# 1  Bevölkerung: Heimat Ausland [Pers.]            1979               30
# 2  Bevölkerung: Heimat Ausland [Pers.]            1980               34
# 3  Bevölkerung: Heimat Ausland [Pers.]            1981               30
# 4  Bevölkerung: Heimat Ausland [Pers.]            1982               35
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0        Pers.     Personen
# 1        Pers.     Personen
# 2        Pers.     Personen
# 3        Pers.     Personen
# 4        Pers.     Personen

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 840   \
# BFS_NR                                            26
# GEBIET_NAME                                     Dorf
# THEMA_NAME                  Bevölkerung und Soziales
# SET_NAME           Bevölkerungsbestand und Haushalte
# SUBSET_NAME                      Bevölkerungsbestand
# INDIKATOR_ID                                     204
# INDIKATOR_NAME   Bevölkerung: Heimat Ausland [Pers.]
# INDIKATOR_JAHR                                  1982
# INDIKATOR_VALUE                                   14
# EINHEIT_KURZ                                   Pers.
# EINHEIT_LANG                                Personen
#
#                                                 6119  \
# BFS_NR                                           214
# GEBIET_NAME                                 Dägerlen
# THEMA_NAME                  Bevölkerung und Soziales
# SET_NAME           Bevölkerungsbestand und Haushalte
# SUBSET_NAME                      Bevölkerungsbestand
# INDIKATOR_ID                                     204
# INDIKATOR_NAME   Bevölkerung: Heimat Ausland [Pers.]
# INDIKATOR_JAHR                                  1989
# INDIKATOR_VALUE                                   27
# EINHEIT_KURZ                                   Pers.
# EINHEIT_LANG                                Personen
#
#                                                 4814
# BFS_NR                                           156
# GEBIET_NAME                                   Meilen
# THEMA_NAME                  Bevölkerung und Soziales
# SET_NAME           Bevölkerungsbestand und Haushalte
# SUBSET_NAME                      Bevölkerungsbestand
# INDIKATOR_ID                                     204
# INDIKATOR_NAME   Bevölkerung: Heimat Ausland [Pers.]
# INDIKATOR_JAHR                                  1978
# INDIKATOR_VALUE                                 1363
# EINHEIT_KURZ                                   Pers.
# EINHEIT_LANG                                Personen

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          8668                      8668
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             44                      8668
#
#                                  SET_NAME          SUBSET_NAME  \
# count                                8668                 8668
# unique                                  1                    1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsbestand
# freq                                 8668                 8668
#
#                              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                  8668         8668         8668
# unique                                    1            1            1
# top     Bevölkerung: Heimat Ausland [Pers.]        Pers.     Personen
# freq                                   8668         8668         8668

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 8,668.00      8,668.00        8,668.00         8,668.00
# mean    109.15        204.00        1,999.47         5,625.06
# std      85.58          0.00           12.63        24,054.59
# min       0.00        204.00        1,978.00             0.00
# 25%      32.00        204.00        1,989.00           129.00
# 50%      95.00        204.00        2,000.00           554.00
# 75%     179.00        204.00        2,010.00         2,010.25
# max     298.00        204.00        2,021.00       425,921.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

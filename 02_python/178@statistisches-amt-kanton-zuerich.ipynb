# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Landwirtschaftliche Nutzfläche [ha]

# %% [markdown]
# ### **Description**: Landwirtschaftliche Nutzfläche gemäss landwirtschaftlicher Betriebszählung

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **178@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T08:41:09`
# - **Startdate** `1985-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Land- und Forstwirtschaft']`
# - **Keyword** `['bezirke', 'flaeche', 'gemeinden', 'kanton_zuerich', 'landwirtschaft', 'nutzflaeche', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 142
# Title                    : Landwirtschaftliche Nutzfläche [ha]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-11T08:41:09
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_267.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_267.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,870 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3870 non-null   int64
#  1   GEBIET_NAME      3870 non-null   object
#  2   THEMA_NAME       3870 non-null   object
#  3   SET_NAME         3870 non-null   object
#  4   SUBSET_NAME      3870 non-null   object
#  5   INDIKATOR_ID     3870 non-null   int64
#  6   INDIKATOR_NAME   3870 non-null   object
#  7   INDIKATOR_JAHR   3870 non-null   int64
#  8   INDIKATOR_VALUE  3870 non-null   int64
#  9   EINHEIT_KURZ     3870 non-null   object
#  10  EINHEIT_LANG     3870 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME        SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
#
#                SUBSET_NAME  INDIKATOR_ID                       INDIKATOR_NAME  \
# 0  Betriebe Landwirtschaft           267  Landwirtschaftliche Nutzfläche [ha]
# 1  Betriebe Landwirtschaft           267  Landwirtschaftliche Nutzfläche [ha]
# 2  Betriebe Landwirtschaft           267  Landwirtschaftliche Nutzfläche [ha]
# 3  Betriebe Landwirtschaft           267  Landwirtschaftliche Nutzfläche [ha]
# 4  Betriebe Landwirtschaft           267  Landwirtschaftliche Nutzfläche [ha]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 1881  \
# BFS_NR                                           132
# GEBIET_NAME                        Hirzel (bis 2017)
# THEMA_NAME                    Arbeit und Unternehmen
# SET_NAME                              Landwirtschaft
# SUBSET_NAME                  Betriebe Landwirtschaft
# INDIKATOR_ID                                     267
# INDIKATOR_NAME   Landwirtschaftliche Nutzfläche [ha]
# INDIKATOR_JAHR                                  2015
# INDIKATOR_VALUE                                  830
# EINHEIT_KURZ                                      ha
# EINHEIT_LANG                                Hektaren
#
#                                                 851   \
# BFS_NR                                            56
# GEBIET_NAME                                  Embrach
# THEMA_NAME                    Arbeit und Unternehmen
# SET_NAME                              Landwirtschaft
# SUBSET_NAME                  Betriebe Landwirtschaft
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME        SET_NAME  \
# count          3870                    3870            3870
# unique          200                       1               1
# top     Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# freq             20                    3870            3870
#
#                     SUBSET_NAME                       INDIKATOR_NAME  \
# count                      3870                                 3870
# unique                        1                                    1
# top     Betriebe Landwirtschaft  Landwirtschaftliche Nutzfläche [ha]
# freq                       3870                                 3870
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          3870         3870
# unique            1            1
# top              ha     Hektaren
# freq           3870         3870

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,870.00      3,870.00        3,870.00         3,870.00
# mean    107.59        267.00        2,009.18         1,541.64
# std      84.84          0.00            9.63         5,749.01
# min       0.00        267.00        1,985.00             0.00
# 25%      31.00        267.00        2,005.00           214.25
# 50%      94.00        267.00        2,011.00           439.00
# 75%     178.00        267.00        2,016.00           761.50
# max     298.00        267.00        2,021.00        76,487.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

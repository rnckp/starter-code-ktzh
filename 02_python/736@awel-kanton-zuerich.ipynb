# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ## Dataset: **Kiesstatistik des Kantons Zürich ab 1990**

# %% [markdown]
# ## Description
#
# Jährlich erhobener kantonaler Kiesabbau und Aushub-Einbau mit Restkubatur Kiesabbau, Bahntransportanteil und offenen Flächen.
#
# **[Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.zhweb-noredirect.zhweb-cache.html?keywords=ogd#/datasets/736@awel-kanton-zuerich)**

# %% [markdown]
# *Autogenerated Python starter code for data set with identifier* **736@awel-kanton-zuerich**

# %% [markdown]
# ## Metadata
# - **Issued** `2021-09-27T11:53:00`
# - **Modified** `2022-04-27T15:59:30`
# - **Startdate** `1990-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen', 'Raum, Umwelt']`
# - **Keyword** `['abfallverwertung', 'bahn', 'umwelt', 'raumplanungsregionen', 'aushub', 'kies', 'bahntransport', 'rohstoffe', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for properly reading datasets
def get_dataset(url):
    data = pd.read_csv(url, on_bad_lines='warn', encoding_errors='ignore')
    # if dataframe only has one column or less the "," separator was wrong, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore')
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1881
# Title                    : Kiesstatistik des Kantons Zürich ab 1990
# Description              : Variabeln: 'thema' = thematischer Aspekt, 'indikator' = erhobene Variable , 'einheit' = Masseinheit, 'region' = räumliche Einheit, 'jahr' = Jahr, 'wert' = Wert.
# Issued                   : 2021-09-16T10:05:28
# Modified                 : 2022-07-08T11:42:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000736_00001881.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 172 rows (observations) and 6 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   thema      172 non-null    object
#  1   indikator  172 non-null    object
#  2   einheit    172 non-null    object
#  3   region     172 non-null    object
#  4   jahr       172 non-null    int64
#  5   wert       172 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 57.9 KB

# %%
df.head()
# Out:
#        thema  indikator  einheit         region  jahr       wert
# 0  Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich  1989  3894517.0
# 1  Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich  1990  3110416.0
# 2  Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich  1991  3380652.0
# 3  Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich  1992  2786205.0
# 4  Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich  1993  2397000.0

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                       2           70             52
# thema          Kiesabbau    Regionen      Kiesabbau
# indikator      Kiesabbau   Kiesabbau   Aushubeinbau
# einheit          m³ fest     m³ fest        m³ fest
# region     Kanton Zürich  Zimmerberg  Kanton Zürich
# jahr                1991        2021           2008
# wert           3380652.0         0.0      2709184.0

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")
# Out:
#             thema  indikator  einheit         region
# count         172        172      172            172
# unique          6         10        5             12
# top     Kiesabbau  Kiesabbau  m³ fest  Kanton Zürich
# freq           66         44       88            150

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
#           jahr         wert
# count   172.00       172.00
# mean  2,012.03 1,147,294.68
# std       8.93 1,444,944.07
# min   1,989.00         0.00
# 25%   2,007.00        19.55
# 50%   2,015.00       397.00
# 75%   2,019.00 2,660,770.00
# max   2,021.00 4,298,472.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Abfallwirtschaft und Betriebe - Sektion Abfallwirtschaft | info.aw@bd.zh.ch

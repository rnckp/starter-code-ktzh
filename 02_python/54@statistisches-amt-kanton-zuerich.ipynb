# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Privathaushalte Total [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Privathaushalte (ohne Kollektivhaushalte)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **54@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T10:04:17`
# - **Startdate** `1970-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'haushalte', 'kanton_zuerich', 'privathaushalte', 'bevoelkerungsstatistik', 'einwohner', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 47
# Title                    : Privathaushalte Total [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T10:04:17
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_455.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_455.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,732 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2732 entries, 0 to 2731
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2732 non-null   int64
#  1   GEBIET_NAME      2732 non-null   object
#  2   THEMA_NAME       2732 non-null   object
#  3   SET_NAME         2732 non-null   object
#  4   SUBSET_NAME      2732 non-null   object
#  5   INDIKATOR_ID     2732 non-null   int64
#  6   INDIKATOR_NAME   2732 non-null   object
#  7   INDIKATOR_JAHR   2732 non-null   int64
#  8   INDIKATOR_VALUE  2732 non-null   int64
#  9   EINHEIT_KURZ     2732 non-null   object
#  10  EINHEIT_LANG     2732 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte   Haushalte           455
# 1  Bevölkerungsbestand und Haushalte   Haushalte           455
# 2  Bevölkerungsbestand und Haushalte   Haushalte           455
# 3  Bevölkerungsbestand und Haushalte   Haushalte           455
# 4  Bevölkerungsbestand und Haushalte   Haushalte           455
#
#                  INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  Privathaushalte Total [Anz.]            1970              199         Anz.
# 1  Privathaushalte Total [Anz.]            1980              277         Anz.
# 2  Privathaushalte Total [Anz.]            1990              453         Anz.
# 3  Privathaushalte Total [Anz.]            2000              607         Anz.
# 4  Privathaushalte Total [Anz.]            2012              797         Anz.
#
#   EINHEIT_LANG
# 0       Anzahl
# 1       Anzahl
# 2       Anzahl
# 3       Anzahl
# 4       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               1990  \
# BFS_NR                                         220
# GEBIET_NAME                              Hagenbuch
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                              Haushalte
# INDIKATOR_ID                                   455
# INDIKATOR_NAME        Privathaushalte Total [Anz.]
# INDIKATOR_JAHR                                1990
# INDIKATOR_VALUE                                239
# EINHEIT_KURZ                                  Anz.
# EINHEIT_LANG                                Anzahl
#
#                                               2544  \
# BFS_NR                                           0
# GEBIET_NAME                      Bezirk Winterthur
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                              Haushalte
# INDIKATOR_ID                                   455
# INDIKATOR_NAME        Privathaushalte Total [Anz.]
# INDIKATOR_JAHR                                2016
# INDIKATOR_VALUE                              73017
# EINHEIT_KURZ                                  Anz.
# EINHEIT_LANG                                Anzahl
#
#                                               2482
# BFS_NR                                           0
# GEBIET_NAME                          Bezirk Horgen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                              Haushalte
# INDIKATOR_ID                                   455
# INDIKATOR_NAME        Privathaushalte Total [Anz.]
# INDIKATOR_JAHR                                1990
# INDIKATOR_VALUE                              44654
# EINHEIT_KURZ                                  Anz.
# EINHEIT_LANG                                Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          2732                      2732
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             14                      2732
#
#                                  SET_NAME SUBSET_NAME  \
# count                                2732        2732
# unique                                  1           1
# top     Bevölkerungsbestand und Haushalte   Haushalte
# freq                                 2732        2732
#
#                       INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                           2732         2732         2732
# unique                             1            1            1
# top     Privathaushalte Total [Anz.]         Anz.       Anzahl
# freq                            2732         2732         2732

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,732.00      2,732.00        2,732.00         2,732.00
# mean    109.55        455.00        2,007.39        12,728.02
# std      86.69          0.00           15.61        51,428.80
# min       0.00        455.00        1,970.00            48.00
# 25%      31.00        455.00        2,000.00           623.75
# 50%      95.00        455.00        2,014.00         1,804.00
# 75%     181.00        455.00        2,018.00         4,990.50
# max     298.00        455.00        2,021.00       708,512.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

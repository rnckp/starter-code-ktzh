# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: COVID_19 Einreisequarantäne Kanton Zürich ab 06.07.2020 bis 15.08.2021

# %% [markdown]
# ### **Description**: Anzahl Personen, die pro Kalenderwoche aus einem Gebiet mit erhöhtem Infektionsrisiko ('Risikoland') einreisen und - abhängig von den geltenden Bestimmungen - in Quarantäne müssen. Familien und Gruppen müssen für jede Person eine Meldung erstellen. Die Daten werden jeweils montags aktualisiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **699@gesundheitsdirektion-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-09-15T17:57:00`
# - **Modified** `2022-03-01T16:48:34`
# - **Startdate** `2020-07-06`
# - **Enddate** `2021-08-15`
# - **Theme** `['Gesundheit', 'Mobilität und Verkehr']`
# - **Keyword** `['gesundheit', 'krankheiten', 'corona', 'covid-19', 'sars-cov-2', 'covid19', 'ogd']`
# - **Publisher** `['Gesundheitsdirektion des Kantons Zürich']`
# - **Landingpage** `https://github.com/openZH/covid_19/tree/master/fallzahlen_kanton_zh`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1722
# Title                    : COVID_19 Einreisequarantäne Kanton Zürich - Einreisen aus Risikoländern nach Kalenderwoche
# Description              : Länder mit weniger als 10 Einreisenden pro Kalenderwoche (KW) werden in der Kategorie 'andere' zusammengefasst. In den KW 52, 53 und 1/2021 ist teils alleine die Kategorie 'andere' vorhanden, in der die Einreisenden aus *allen* Ländern insgesamt zusammengefasst sind. Grund: Vom 22.12.2020 bis zum 05.01.2021 konnten die Einreisenden das Land nicht eingeben, aus dem sie einreisten.
# Issued                   : 2020-09-15T18:16:33
# Modified                 : 2021-07-05T14:34:16
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19/master/fallzahlen_kanton_zh/COVID19_Einreisequarantaene_pro_KW.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19/master/fallzahlen_kanton_zh/COVID19_Einreisequarantaene_pro_KW.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,004 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Kalenderwoche       1004 non-null   int64
#  1   Einreiseland        1004 non-null   object
#  2   Anzahl_Einreisende  1004 non-null   int64
#  3   woche_von           1004 non-null   object
#  4   woche_bis           1004 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 217.4 KB

# %%
df.head()
# Out:
#    Kalenderwoche             Einreiseland  Anzahl_Einreisende   woche_von  \
# 0             28                   andere                  29  2020-07-13
# 1             28  Dominikanische Republik                  13  2020-07-13
# 2             28                   Kosovo                  64  2020-07-13
# 3             28           Nordmazedonien                  24  2020-07-13
# 4             28                 Schweden                  43  2020-07-13
#
#     woche_bis
# 0  2020-07-19
# 1  2020-07-19
# 2  2020-07-19
# 3  2020-07-19
# 4  2020-07-19

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                            934         18          78
# Kalenderwoche               22          29          32
# Einreiseland         Malediven         USA      andere
# Anzahl_Einreisende          21         156          42
# woche_von           2021-05-31  2020-07-13  2020-08-03
# woche_bis           2021-06-06  2020-07-19  2020-08-09

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        Einreiseland   woche_von   woche_bis
# count          1004        1004        1004
# unique           59          57          57
# top          andere  2020-10-12  2020-10-18
# freq            112          50          50

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Kalenderwoche  Anzahl_Einreisende
# count       1,004.00            1,004.00
# mean           26.86               61.53
# std            13.09              108.08
# min             1.00                1.00
# 25%            16.00               17.00
# 50%            30.00               31.00
# 75%            39.00               62.00
# max            53.00            1,825.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Gesundheitsdirektion des Kantons Zürich | Coronavirus-Hotline | gdstab@gd.zh.ch

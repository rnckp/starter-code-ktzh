# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Gemeindebeitrag an ZVV [1000 Fr.]

# %% [markdown]
# ### **Description**: Der Beitrag errechnet sich aus dem auf die Gemeinden entfallenden Defizit und wird anteilsmässig nach Angebot (Anzahl Abfahrten, Ant. 80%) und der absoluten, berichtigten Steuerkraft (Ant. 20%) verteilt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **27@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-18T10:41:01`
# - **Startdate** `1994-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'oeffentliche_finanzen', 'oeffentlicher_verkehr', 'zvv', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 24
# Title                    : Gemeindebeitrag an ZVV [1000 Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-18T10:41:01
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_391.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_391.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,449 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5449 entries, 0 to 5448
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5449 non-null   int64
#  1   GEBIET_NAME      5449 non-null   object
#  2   THEMA_NAME       5449 non-null   object
#  3   SET_NAME         5449 non-null   object
#  4   SUBSET_NAME      5449 non-null   object
#  5   INDIKATOR_ID     5449 non-null   int64
#  6   INDIKATOR_NAME   5449 non-null   object
#  7   INDIKATOR_JAHR   5449 non-null   int64
#  8   INDIKATOR_VALUE  5449 non-null   int64
#  9   EINHEIT_KURZ     5449 non-null   object
#  10  EINHEIT_LANG     5449 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME    SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           391
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           391
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           391
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           391
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung           391
#
#                       INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Gemeindebeitrag an ZVV [1000 Fr.]            1994               92
# 1  Gemeindebeitrag an ZVV [1000 Fr.]            1995               92
# 2  Gemeindebeitrag an ZVV [1000 Fr.]            1996              109
# 3  Gemeindebeitrag an ZVV [1000 Fr.]            1997              109
# 4  Gemeindebeitrag an ZVV [1000 Fr.]            1998              103
#
#   EINHEIT_KURZ     EINHEIT_LANG
# 0     1000 Fr.  Tausend Franken
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               1031  \
# BFS_NR                                          44
# GEBIET_NAME                 Waltalingen (bis 2018)
# THEMA_NAME                         Raum und Umwelt
# SET_NAME                                   Verkehr
# SUBSET_NAME                          Erschliessung
# INDIKATOR_ID                                   391
# INDIKATOR_NAME   Gemeindebeitrag an ZVV [1000 Fr.]
# INDIKATOR_JAHR                                1995
# INDIKATOR_VALUE                                 22
# EINHEIT_KURZ                              1000 Fr.
# EINHEIT_LANG                       Tausend Franken
#
#                                               1949  \
# BFS_NR                                          90
# GEBIET_NAME                            Niederhasli
# THEMA_NAME                         Raum und Umwelt
# SET_NAME                                   Verkehr
# SUBSET_NAME                          Erschliessung
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME    SUBSET_NAME  \
# count          5449             5449     5449           5449
# unique          200                1        1              1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  Erschliessung
# freq             28             5449     5449           5449
#
#                            INDIKATOR_NAME EINHEIT_KURZ     EINHEIT_LANG
# count                                5449         5449             5449
# unique                                  1            1                1
# top     Gemeindebeitrag an ZVV [1000 Fr.]     1000 Fr.  Tausend Franken
# freq                                 5449         5449             5449

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,449.00      5,449.00        5,449.00         5,449.00
# mean    107.39        391.00        2,007.42         3,278.38
# std      84.24          0.00            8.05        16,003.38
# min       0.00        391.00        1,994.00             7.00
# 25%      31.00        391.00        2,000.00            76.00
# 50%      94.00        391.00        2,007.00           212.00
# 75%     178.00        391.00        2,014.00           755.00
# max     298.00        391.00        2,021.00       225,197.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Verpackungsglasmengen [Tonnen]

# %% [markdown]
# ### **Description**: Verpackungsglasmengen aus kommunaler Sammlung von Industrie und Privathaushalten.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **226@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-21T00:00:00`
# - **Modified** `2022-11-11T08:41:23`
# - **Startdate** `1996-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['altglas', 'bezirke', 'gemeinden', 'kanton_zuerich', 'recycling', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 189
# Title                    : Verpackungsglasmengen [Tonnen]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-11T08:41:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_138.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_138.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,101 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5101 entries, 0 to 5100
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5101 non-null   int64
#  1   GEBIET_NAME      5101 non-null   object
#  2   THEMA_NAME       5101 non-null   object
#  3   SET_NAME         5101 non-null   object
#  4   SUBSET_NAME      5101 non-null   object
#  5   INDIKATOR_ID     5101 non-null   int64
#  6   INDIKATOR_NAME   5101 non-null   object
#  7   INDIKATOR_JAHR   5101 non-null   int64
#  8   INDIKATOR_VALUE  5083 non-null   float64
#  9   EINHEIT_KURZ     5101 non-null   object
#  10  EINHEIT_LANG     5101 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall           138
# 1       1  Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall           138
# 2       1  Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall           138
# 3       1  Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall           138
# 4       1  Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall           138
#
#                    INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Verpackungsglasmengen [Tonnen]            1996             24.0
# 1  Verpackungsglasmengen [Tonnen]            1997             35.0
# 2  Verpackungsglasmengen [Tonnen]            1998             36.0
# 3  Verpackungsglasmengen [Tonnen]            1999             37.0
# 4  Verpackungsglasmengen [Tonnen]            2000             45.0
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0       Tonnen       Tonnen
# 1       Tonnen       Tonnen
# 2       Tonnen       Tonnen
# 3       Tonnen       Tonnen
# 4       Tonnen       Tonnen

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                            2419  \
# BFS_NR                                      131
# GEBIET_NAME                            Adliswil
# THEMA_NAME                      Raum und Umwelt
# SET_NAME                                 Umwelt
# SUBSET_NAME                              Abfall
# INDIKATOR_ID                                138
# INDIKATOR_NAME   Verpackungsglasmengen [Tonnen]
# INDIKATOR_JAHR                             2009
# INDIKATOR_VALUE                           472.0
# EINHEIT_KURZ                             Tonnen
# EINHEIT_LANG                             Tonnen
#
#                                            3355  \
# BFS_NR                                      194
# GEBIET_NAME                          Greifensee
# THEMA_NAME                      Raum und Umwelt
# SET_NAME                                 Umwelt
# SUBSET_NAME                              Abfall
# INDIKATOR_ID                                138
# INDIKATOR_NAME   Verpackungsglasmengen [Tonnen]
# INDIKATOR_JAHR                             2005
# INDIKATOR_VALUE                           143.0
# EINHEIT_KURZ                             Tonnen
# EINHEIT_LANG                             Tonnen
#
#                                            3917
# BFS_NR                                      227
# GEBIET_NAME                             Seuzach
# THEMA_NAME                      Raum und Umwelt
# SET_NAME                                 Umwelt
# SUBSET_NAME                              Abfall
# INDIKATOR_ID                                138
# INDIKATOR_NAME   Verpackungsglasmengen [Tonnen]
# INDIKATOR_JAHR                             2005
# INDIKATOR_VALUE                           134.0
# EINHEIT_KURZ                             Tonnen
# EINHEIT_LANG                             Tonnen

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  \
# count          5101             5101     5101        5101
# unique          200                1        1           1
# top     Aeugst a.A.  Raum und Umwelt   Umwelt      Abfall
# freq             26             5101     5101        5101
#
#                         INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                             5101         5101         5101
# unique                               1            1            1
# top     Verpackungsglasmengen [Tonnen]       Tonnen       Tonnen
# freq                              5101         5101         5101

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,101.00      5,101.00        5,101.00         5,083.00
# mean    109.40        138.00        2,008.39           815.61
# std      86.08          0.00            7.45         3,221.20
# min       0.00        138.00        1,996.00             0.00
# 25%      32.00        138.00        2,002.00            45.00
# 50%      95.00        138.00        2,008.00           119.00
# 75%     180.00        138.00        2,015.00           354.00
# max     298.00        138.00        2,021.00        51,007.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

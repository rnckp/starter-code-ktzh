# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Archiv Wahlresultate Regierungsratswahlen

# %% [markdown]
# ### **Description**: Ergebnisse der Erneuerungs- und Ersatzwahlen der Mitglieder des Regierungsrates

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **694@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-07-07T16:39:00`
# - **Modified** `2022-04-08T09:35:56`
# - **Startdate** `2007-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['kanton_zuerich', 'politik', 'politische_parteien', 'regierungsrat', 'regierungsratswahlen', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/kantons-regierungsratswahlen.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`10` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1737
# Title                    : Resultate 1. Wahlgang Ersatzwahl Regierungsrat 2009
# Description              : None
# Issued                   : 2020-10-09T11:38:54
# Modified                 : 2021-06-01T13:37:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001737.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001737.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1828
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2011
# Description              : None
# Issued                   : 2021-06-01T13:38:41
# Modified                 : 2021-06-01T13:38:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001828.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001828.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 1826
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2007
# Description              : None
# Issued                   : 2021-06-01T13:36:34
# Modified                 : 2021-06-01T13:36:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001826.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001826.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 1827
# Title                    : Kandidierende 1. Wahlgang Ersatzwahl Regierungsrat 2009
# Description              : None
# Issued                   : 2021-06-01T13:37:41
# Modified                 : 2021-06-01T13:37:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001827.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001827.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 4
# Ktzhdistid               : 1829
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2015
# Description              : None
# Issued                   : 2021-06-01T13:43:00
# Modified                 : 2021-06-01T13:43:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001829.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001829.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 5
# Ktzhdistid               : 1687
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2007
# Description              : None
# Issued                   : 2020-07-07T16:44:16
# Modified                 : 2021-06-01T13:36:03
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001687.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001687.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 6
# Ktzhdistid               : 1688
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2011
# Description              : None
# Issued                   : 2020-07-07T16:45:23
# Modified                 : 2021-06-01T13:38:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001688.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001688.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 7
# Ktzhdistid               : 1689
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2015
# Description              : None
# Issued                   : 2020-07-07T16:46:18
# Modified                 : 2021-06-01T13:42:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001689.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001689.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 8
# Ktzhdistid               : 1690
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2019
# Description              : None
# Issued                   : 2020-07-07T16:46:50
# Modified                 : 2021-06-01T13:46:56
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001690.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001690.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 9
# Ktzhdistid               : 1830
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2019
# Description              : None
# Issued                   : 2021-06-01T13:47:09
# Modified                 : 2021-06-01T13:47:09
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001830.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001830.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 15 rows (observations) and 14 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geschaeft             15 non-null     object
#  1   Kand_ID               15 non-null     int64
#  2   Kand_Nachname         15 non-null     object
#  3   Kand_Vorname          14 non-null     object
#  4   Kand_Beruf_mit_Titel  14 non-null     object
#  5   Kand_Ort              14 non-null     object
#  6   Kand_Jahrgang         14 non-null     float64
#  7   Kand_Geschlecht       14 non-null     object
#  8   Kand_Partei           14 non-null     object
#  9   Kand_Bisher           15 non-null     int64
#  10  Kand_Gewaehlt         15 non-null     int64
#  11  Kand_Stimmenproz      15 non-null     float64
#  12  Kand_Stimmentotal     15 non-null     int64
#  13  Wahl_Absolutesmehr    15 non-null     int64
# dtypes: float64(2), int64(5), object(7)
# ...

# %%
df.head()
# Out:
#                                        Geschaeft  Kand_ID Kand_Nachname  \
# 0  Erneuerungswahl des Regierungsrates 2019–2023        1         Angst
# 1  Erneuerungswahl des Regierungsrates 2019–2023        2          Egli
# 2  Erneuerungswahl des Regierungsrates 2019–2023        3          Fehr
# 3  Erneuerungswahl des Regierungsrates 2019–2023        4          Fehr
# 4  Erneuerungswahl des Regierungsrates 2019–2023        5   Hugentobler
#
#   Kand_Vorname                               Kand_Beruf_mit_Titel  \
# 0       Walter                 Leiter Kommunikation Mieterverband
# 1         Hans                                           Landwirt
# 2   Jacqueline  Regierungsrätin und Vorsteherin der Direktion ...
# 3        Mario                           Jurist und Regierungsrat
# 4    Hanspeter  Geschäftsführer ERF Medien, Schulpräsident, Ka...
#
#        Kand_Ort  Kand_Jahrgang Kand_Geschlecht Kand_Partei  Kand_Bisher  \
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                      13  \
# Geschaeft                 Erneuerungswahl des Regierungsrates 2019–2023
# Kand_ID                                                              14
# Kand_Nachname                                               Walker Späh
# Kand_Vorname                                                     Carmen
# Kand_Beruf_mit_Titel  Rechtsanwältin, Regierungsrätin, Vorsteherin V...
# Kand_Ort                                                         Zürich
# Kand_Jahrgang                                                    1958.0
# Kand_Geschlecht                                                       W
# Kand_Partei                                                         FDP
# Kand_Bisher                                                           1
# Kand_Gewaehlt                                                         1
# Kand_Stimmenproz                                                   44.5
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                                             Geschaeft Kand_Nachname  \
# count                                              15            15
# unique                                              1            14
# top     Erneuerungswahl des Regierungsrates 2019–2023          Fehr
# freq                                               15             2
#
#        Kand_Vorname                Kand_Beruf_mit_Titel Kand_Ort  \
# count            14                                  14       14
# unique           14                                  14       10
# top          Walter  Leiter Kommunikation Mieterverband   Zürich
# freq              1                                   1        3
#
#        Kand_Geschlecht Kand_Partei
# count               14          14
# unique               2          11
# top                  M          SP
# freq                 9           2

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Kand_ID  Kand_Jahrgang  Kand_Bisher  Kand_Gewaehlt  Kand_Stimmenproz  \
# count    15.00          14.00        15.00          15.00             15.00
# mean     73.60       1,967.29         0.33           0.47             34.01
# std     256.04          11.26         0.49           0.52             17.16
# min       1.00       1,955.00         0.00           0.00              2.56
# 25%       4.50       1,958.00         0.00           0.00             22.23
# 50%       8.00       1,964.00         0.00           0.00             38.65
# 75%      11.50       1,974.25         1.00           1.00             46.13
# max     999.00       1,991.00         1.00           1.00             61.07
#
#        Kand_Stimmentotal  Wahl_Absolutesmehr
# count              15.00               15.00
# mean           96,466.40          103,357.00
# std            48,666.21                0.00
# min             7,265.00          103,357.00
# 25%            63,047.00          103,357.00
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

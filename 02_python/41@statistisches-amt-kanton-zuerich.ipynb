# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Mittelschule [Anz.]

# %% [markdown]
# ### **Description**: Anzahl MittelschülerInnen inkl. LangzeitgymnasiastInnen und SchülerInnen privater Mittelschulen (nach Wohnort).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **41@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1992-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'mittelschulen', 'schueler', 'schuelerinnen', 'schulen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 34
# Title                    : Schül. Mittelschule [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_145.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_145.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,847 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5847 entries, 0 to 5846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5847 non-null   int64
#  1   GEBIET_NAME      5847 non-null   object
#  2   THEMA_NAME       5847 non-null   object
#  3   SET_NAME         5847 non-null   object
#  4   SUBSET_NAME      5847 non-null   object
#  5   INDIKATOR_ID     5847 non-null   int64
#  6   INDIKATOR_NAME   5847 non-null   object
#  7   INDIKATOR_JAHR   5847 non-null   int64
#  8   INDIKATOR_VALUE  5846 non-null   float64
#  9   EINHEIT_KURZ     5847 non-null   object
#  10  EINHEIT_LANG     5847 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#                               SUBSET_NAME  INDIKATOR_ID  \
# 0  Schüler Mittelschule und Berufsbildung           145
# 1  Schüler Mittelschule und Berufsbildung           145
# 2  Schüler Mittelschule und Berufsbildung           145
# 3  Schüler Mittelschule und Berufsbildung           145
# 4  Schüler Mittelschule und Berufsbildung           145
#
#                INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  Schül. Mittelschule [Anz.]            1992             23.0         Anz.
# 1  Schül. Mittelschule [Anz.]            1993             22.0         Anz.
# 2  Schül. Mittelschule [Anz.]            1994             16.0         Anz.
# 3  Schül. Mittelschule [Anz.]            1995             16.0         Anz.
# 4  Schül. Mittelschule [Anz.]            1996             22.0         Anz.
#
#   EINHEIT_LANG
# 0       Anzahl
# 1       Anzahl
# 2       Anzahl
# 3       Anzahl
# 4       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                    1614  \
# BFS_NR                                               67
# GEBIET_NAME                                        Rafz
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        145
# INDIKATOR_NAME               Schül. Mittelschule [Anz.]
# INDIKATOR_JAHR                                     1996
# INDIKATOR_VALUE                                    33.0
# EINHEIT_KURZ                                       Anz.
# EINHEIT_LANG                                     Anzahl
#
#                                                    1555  \
# BFS_NR                                               65
# GEBIET_NAME                                 Oberembrach
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        145
# INDIKATOR_NAME               Schül. Mittelschule [Anz.]
# INDIKATOR_JAHR                                     1997
# INDIKATOR_VALUE                                    19.0
# EINHEIT_KURZ                                       Anz.
# EINHEIT_LANG                                     Anzahl
#
#                                                    5034
# BFS_NR                                              295
# GEBIET_NAME                                      Horgen
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        145
# INDIKATOR_NAME               Schül. Mittelschule [Anz.]
# INDIKATOR_JAHR                                     2019
# INDIKATOR_VALUE                                   301.0
# EINHEIT_KURZ                                       Anz.
# EINHEIT_LANG                                     Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME  \
# count          5847                      5847     5847
# unique          200                         1        1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung
# freq             30                      5847     5847
#
#                                    SUBSET_NAME              INDIKATOR_NAME  \
# count                                     5847                        5847
# unique                                       1                           1
# top     Schüler Mittelschule und Berufsbildung  Schül. Mittelschule [Anz.]
# freq                                      5847                        5847
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          5847         5847
# unique            1            1
# top            Anz.       Anzahl
# freq           5847         5847

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,847.00      5,847.00        5,847.00         5,846.00
# mean    107.67        145.00        2,006.43           322.69
# std      84.48          0.00            8.62         1,259.90
# min       0.00        145.00        1,992.00             0.00
# 25%      31.00        145.00        1,999.00            18.00
# 50%      94.00        145.00        2,006.00            51.00
# 75%     178.00        145.00        2,014.00           133.00
# max     298.00        145.00        2,021.00        19,600.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Statistik der Jugendstrafrechtspflege des Kantons Zürich

# %% [markdown]
# ### **Description**: Begehen Jugendliche zwischen dem 10. und 18. Lebensjahr ein Delikt, gilt für sie das Jugendstrafrecht. Die Jugendanwaltschaften des Kantons Zürich untersuchen und beurteilen sämtliche Straftaten von Jugendlichen, die im Kanton Zürich wohnhaft sind. Ausserdem sind sie für den Vollzug jugendstrafrechtlicher Schutzmassnahmen und Strafen verantwortlich.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **544@oberjugendanwaltschaft-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-11-28T00:00:00`
# - **Modified** `2022-04-21T10:51:14`
# - **Startdate** `2007-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Kriminalität, Strafrecht']`
# - **Keyword** `['kanton_zuerich', 'strafdelikte', 'verurteilungen', 'jugendkriminalitaet', 'ogd']`
# - **Publisher** `['Oberjugendanwaltschaft des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`9` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1038
# Title                    : Finanzieller Aufwand für Schutzmassnahmen
# Description              : None
# Issued                   : 2019-11-28T17:24:03
# Modified                 : 2022-10-17T15:54:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001038.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001038.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1031
# Title                    : Anzahl Verurteilungen nach Geschlecht
# Description              : None
# Issued                   : 2019-11-28T16:29:40
# Modified                 : 2022-10-17T15:55:10
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001031.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001031.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 1029
# Title                    : Anzahl Delikte bei den Verurteilungen 
# Description              : Spaltenüberschriften: 'uebrige StGB'=übrige Delikte gemäss Schweizerischem Strafgesetzbuch; 'SVG'=Strassenverkehrsgesetz; 'BetmG'=Betäubungsmittelgesetz
# Issued                   : 2019-11-28T16:22:21
# Modified                 : 2022-10-17T15:55:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001029.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001029.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 1030
# Title                    : Alter bei Eröffnung der Strafuntersuchung
# Description              : None
# Issued                   : 2019-11-28T16:25:55
# Modified                 : 2022-10-17T15:55:59
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001030.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001030.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 4
# Ktzhdistid               : 1034
# Title                    : Art der Sanktion 
# Description              : None
# Issued                   : 2019-11-28T16:48:32
# Modified                 : 2022-10-17T15:56:39
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001034.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001034.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 5
# Ktzhdistid               : 1035
# Title                    :  Anzahl Personen mit mindestens einer Untersuchungshaft 
# Description              : None
# Issued                   : 2019-11-28T16:51:04
# Modified                 : 2022-10-17T15:57:02
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001035.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001035.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 6
# Ktzhdistid               : 1032
# Title                    : Schweizer-/Ausländeranteil bei Verurteilungen
# Description              : None
# Issued                   : 2019-11-28T16:31:31
# Modified                 : 2022-10-17T15:57:32
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001032.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001032.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 7
# Ktzhdistid               : 1037
# Title                    :  Anzahl Jugendliche in einer Massnahme per Jahresende 
# Description              : 'per Jahresende' bedeutet am 31. Dezember des entsprechenden Jahres
# Issued                   : 2019-11-28T17:01:07
# Modified                 : 2022-10-17T15:57:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001037.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001037.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 8
# Ktzhdistid               : 1657
# Title                    : Anzahl verzeigte Jugendliche
# Description              : Anzahl verzeigte Jugendliche insgesamt und wegen Gewaltdelikten seit 2008.
# Issued                   : 2020-06-09T08:10:15
# Modified                 : 2022-10-17T15:58:13
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001657.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000544_00001657.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 14 rows (observations) and 4 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Jahr                                       14 non-null     int64
#  1   Anzahl_verzeigte_Jugendliche               14 non-null     int64
#  2   Anzahl_verzeigte_Jugendliche_Gewaltdelikt  14 non-null     int64
#  3   Anzahl_einwohner_10_17_jaehrig             14 non-null     int64
# dtypes: int64(4)
# memory usage: 576.0 bytes

# %%
df.head()
# Out:
#    Jahr  Anzahl_verzeigte_Jugendliche  \
# 0  2008                          4844
# 1  2009                          5101
# 2  2010                          4170
# 3  2011                          4288
# 4  2012                          3732
#
#    Anzahl_verzeigte_Jugendliche_Gewaltdelikt  Anzahl_einwohner_10_17_jaehrig
# 0                                        951                          104875
# 1                                       1151                          105118
# 2                                        881                          105753
# 3                                        713                          105523
# 4                                        630                          105754

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                13      7       2
# Jahr                                         2021    2015    2010
# Anzahl_verzeigte_Jugendliche                 5961    4674    4170
# Anzahl_verzeigte_Jugendliche_Gewaltdelikt    1014     499     881
# Anzahl_einwohner_10_17_jaehrig             118389  107042  105753

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(exclude='number'))
    except:
        pass

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  Anzahl_verzeigte_Jugendliche  \
# count    14.00                         14.00
# mean  2,014.50                      4,716.71
# std       4.18                        535.14
# min   2,008.00                      3,732.00
# 25%   2,011.25                      4,353.75
# 50%   2,014.50                      4,711.50
# 75%   2,017.75                      4,981.25
# max   2,021.00                      5,961.00
#
#        Anzahl_verzeigte_Jugendliche_Gewaltdelikt  \
# count                                      14.00
# mean                                      750.93
# std                                       206.93
# min                                       499.00
# 25%                                       587.25
# 50%                                       672.50
# 75%                                       905.75
# max                                     1,151.00
#
#        Anzahl_einwohner_10_17_jaehrig
# count                           14.00
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Oberjugendanwaltschaft des Kantons Zürich |  | sarah.reimann@ji.zh.ch

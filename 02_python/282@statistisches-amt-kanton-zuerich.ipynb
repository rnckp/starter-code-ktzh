# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wahlbeteiligung Nationalrat [%]

# %% [markdown]
# ### **Description**: Gültig eingelegte Listen (Wahlzettel) dividiert durch Anzahl Wahlberechtigte

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **282@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-10-21T10:29:47`
# - **Startdate** `2003-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'nationalratswahlen', 'politik', 'wahlbeteiligung', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 212
# Title                    : Wahlbeteiligung Nationalrat [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-10-21T10:29:47
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_804.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_804.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 957 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           957 non-null    int64
#  1   GEBIET_NAME      957 non-null    object
#  2   THEMA_NAME       957 non-null    object
#  3   SET_NAME         957 non-null    object
#  4   SUBSET_NAME      957 non-null    object
#  5   INDIKATOR_ID     957 non-null    int64
#  6   INDIKATOR_NAME   957 non-null    object
#  7   INDIKATOR_JAHR   957 non-null    int64
#  8   INDIKATOR_VALUE  957 non-null    float64
#  9   EINHEIT_KURZ     957 non-null    object
#  10  EINHEIT_LANG     957 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 503.2 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME         SET_NAME  \
# 0       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 1       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 2       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 3       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 4       1  Aeugst a.A.    Politik  Wahlbeteiligung
#
#                      SUBSET_NAME  INDIKATOR_ID  \
# 0  Wahlbeteiligung Proporzwahlen           804
# 1  Wahlbeteiligung Proporzwahlen           804
# 2  Wahlbeteiligung Proporzwahlen           804
# 3  Wahlbeteiligung Proporzwahlen           804
# 4  Wahlbeteiligung Proporzwahlen           804
#
#                     INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Wahlbeteiligung Nationalrat [%]            2003             53.1
# 1  Wahlbeteiligung Nationalrat [%]            2007             57.5
# 2  Wahlbeteiligung Nationalrat [%]            2011             56.3
# 3  Wahlbeteiligung Nationalrat [%]            2015             54.1
# 4  Wahlbeteiligung Nationalrat [%]            2019             55.4
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                              73   \
# BFS_NR                                        21
# GEBIET_NAME                              Adlikon
# THEMA_NAME                               Politik
# SET_NAME                         Wahlbeteiligung
# SUBSET_NAME        Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                 804
# INDIKATOR_NAME   Wahlbeteiligung Nationalrat [%]
# INDIKATOR_JAHR                              2015
# INDIKATOR_VALUE                             56.8
# EINHEIT_KURZ                                   %
# EINHEIT_LANG                             Prozent
#
#                                              124  \
# BFS_NR                                        31
# GEBIET_NAME                             Henggart
# THEMA_NAME                               Politik
# SET_NAME                         Wahlbeteiligung
# SUBSET_NAME        Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                 804
# INDIKATOR_NAME   Wahlbeteiligung Nationalrat [%]
# INDIKATOR_JAHR                              2019
# INDIKATOR_VALUE                             51.6
# EINHEIT_KURZ                                   %
# EINHEIT_LANG                             Prozent
#
#                                              580
# BFS_NR                                       173
# GEBIET_NAME                              Hittnau
# THEMA_NAME                               Politik
# SET_NAME                         Wahlbeteiligung
# SUBSET_NAME        Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                 804
# INDIKATOR_NAME   Wahlbeteiligung Nationalrat [%]
# INDIKATOR_JAHR                              2003
# INDIKATOR_VALUE                             46.8
# EINHEIT_KURZ                                   %
# EINHEIT_LANG                             Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME         SET_NAME  \
# count           957        957              957
# unique          200          1                1
# top     Aeugst a.A.    Politik  Wahlbeteiligung
# freq              5        957              957
#
#                           SUBSET_NAME                   INDIKATOR_NAME  \
# count                             957                              957
# unique                              1                                1
# top     Wahlbeteiligung Proporzwahlen  Wahlbeteiligung Nationalrat [%]
# freq                              957                              957
#
#        EINHEIT_KURZ EINHEIT_LANG
# count           957          957
# unique            1            1
# top               %      Prozent
# freq            957          957

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  957.00        957.00          957.00           957.00
# mean   108.61        804.00        2,010.82            49.00
# std     84.20          0.00            5.60             6.81
# min      0.00        804.00        2,003.00            27.10
# 25%     33.00        804.00        2,007.00            44.40
# 50%     95.00        804.00        2,011.00            49.10
# 75%    179.00        804.00        2,015.00            54.00
# max    298.00        804.00        2,019.00            69.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

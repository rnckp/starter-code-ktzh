# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: 15-Jahresverbrauch  [%]

# %% [markdown]
# ### **Description**: Verbrauchte Bauzonenfläche der letzten 15 Jahre gemessen an der gesamten Bauzonenfläche.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **70@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-21T00:00:00`
# - **Modified** `2022-11-25T10:45:02`
# - **Startdate** `1996-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bauzonen', 'bezirke', 'gemeinden', 'kanton_zuerich', 'nutzungsreserven', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 60
# Title                    : 15-Jahresverbrauch  [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-03-17T07:40:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_46.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_46.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,928 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4928 entries, 0 to 4927
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4928 non-null   int64
#  1   GEBIET_NAME      4928 non-null   object
#  2   THEMA_NAME       4928 non-null   object
#  3   SET_NAME         4928 non-null   object
#  4   SUBSET_NAME      4928 non-null   object
#  5   INDIKATOR_ID     4928 non-null   int64
#  6   INDIKATOR_NAME   4928 non-null   object
#  7   INDIKATOR_JAHR   4928 non-null   int64
#  8   INDIKATOR_VALUE  4928 non-null   float64
#  9   EINHEIT_KURZ     4928 non-null   object
#  10  EINHEIT_LANG     4928 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 1       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 2       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 3       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# 4       1  Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
#
#          SUBSET_NAME  INDIKATOR_ID           INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Bauzonenverbrauch            46  15-Jahresverbrauch  [%]            1996
# 1  Bauzonenverbrauch            46  15-Jahresverbrauch  [%]            1997
# 2  Bauzonenverbrauch            46  15-Jahresverbrauch  [%]            1998
# 3  Bauzonenverbrauch            46  15-Jahresverbrauch  [%]            1999
# 4  Bauzonenverbrauch            46  15-Jahresverbrauch  [%]            2000
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0             13.0            %      Prozent
# 1             14.7            %      Prozent
# 2             14.9            %      Prozent
# 3             14.0            %      Prozent
# 4             14.2            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         2101                         1094  \
# BFS_NR                                   113                           57
# GEBIET_NAME                          Dürnten           Freienstein-Teufen
# THEMA_NAME                Bau und Immobilien           Bau und Immobilien
# SET_NAME         Bauzonen, Bauzonenverbrauch  Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                Bauzonenverbrauch            Bauzonenverbrauch
# INDIKATOR_ID                              46                           46
# INDIKATOR_NAME       15-Jahresverbrauch  [%]      15-Jahresverbrauch  [%]
# INDIKATOR_JAHR                          2009                         2002
# INDIKATOR_VALUE                         12.2                         12.1
# EINHEIT_KURZ                               %                            %
# EINHEIT_LANG                         Prozent                      Prozent
#
#                                         1738
# BFS_NR                                    91
# GEBIET_NAME                   Niederweningen
# THEMA_NAME                Bau und Immobilien
# SET_NAME         Bauzonen, Bauzonenverbrauch
# SUBSET_NAME                Bauzonenverbrauch
# INDIKATOR_ID                              46
# INDIKATOR_NAME       15-Jahresverbrauch  [%]
# INDIKATOR_JAHR                          1996
# INDIKATOR_VALUE                          9.1
# EINHEIT_KURZ                               %
# EINHEIT_LANG                         Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          4928                4928                         4928
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Bauzonen, Bauzonenverbrauch
# freq             25                4928                         4928
#
#               SUBSET_NAME           INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                4928                     4928         4928         4928
# unique                  1                        1            1            1
# top     Bauzonenverbrauch  15-Jahresverbrauch  [%]            %      Prozent
# freq                 4928                     4928         4928         4928

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,928.00      4,928.00        4,928.00         4,928.00
# mean    110.41         46.00        2,007.88             9.34
# std      87.00          0.00            7.16             3.95
# min       0.00         46.00        1,996.00            -1.00
# 25%      32.00         46.00        2,002.00             6.80
# 50%      96.00         46.00        2,008.00             9.00
# 75%     181.00         46.00        2,014.00            11.40
# max     298.00         46.00        2,020.00            28.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerkraft pro Kopf [Fr.]

# %% [markdown]
# ### **Description**: Steuerkraft pro Einwohner (Nettosteuerertrag zu 100% pro Einwohner; = relative Steuerkraft).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **134@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T09:13:50`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeindefinanzen', 'gemeinden', 'kanton_zuerich', 'steuerkraft', 'steuern', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 100
# Title                    : Steuerkraft pro Kopf [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T09:13:50
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_378.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_378.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,333 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6333 entries, 0 to 6332
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6333 non-null   int64
#  1   GEBIET_NAME      6333 non-null   object
#  2   THEMA_NAME       6333 non-null   object
#  3   SET_NAME         6333 non-null   object
#  4   SUBSET_NAME      6333 non-null   object
#  5   INDIKATOR_ID     6333 non-null   int64
#  6   INDIKATOR_NAME   6333 non-null   object
#  7   INDIKATOR_JAHR   6333 non-null   int64
#  8   INDIKATOR_VALUE  6333 non-null   int64
#  9   EINHEIT_KURZ     6333 non-null   object
#  10  EINHEIT_LANG     6333 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME         SET_NAME  SUBSET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
#
#    INDIKATOR_ID              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           378  Steuerkraft pro Kopf [Fr.]            1990             2530
# 1           378  Steuerkraft pro Kopf [Fr.]            1991             2678
# 2           378  Steuerkraft pro Kopf [Fr.]            1992             2659
# 3           378  Steuerkraft pro Kopf [Fr.]            1993             3033
# 4           378  Steuerkraft pro Kopf [Fr.]            1994             2846
#
#   EINHEIT_KURZ           EINHEIT_LANG
# 0    Fr./Einw.  Franken pro Einwohner
# 1    Fr./Einw.  Franken pro Einwohner
# 2    Fr./Einw.  Franken pro Einwohner
# 3    Fr./Einw.  Franken pro Einwohner
# 4    Fr./Einw.  Franken pro Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                        5211                        3370  \
# BFS_NR                                  248                         152
# GEBIET_NAME                         Uitikon                  Herrliberg
# THEMA_NAME             Öffentliche Finanzen        Öffentliche Finanzen
# SET_NAME                    Gemeindesteuern             Gemeindesteuern
# SUBSET_NAME                     Steuerkraft                 Steuerkraft
# INDIKATOR_ID                            378                         378
# INDIKATOR_NAME   Steuerkraft pro Kopf [Fr.]  Steuerkraft pro Kopf [Fr.]
# INDIKATOR_JAHR                         2013                        1994
# INDIKATOR_VALUE                        9393                        4974
# EINHEIT_KURZ                      Fr./Einw.                   Fr./Einw.
# EINHEIT_LANG          Franken pro Einwohner       Franken pro Einwohner
#
#                                        3803
# BFS_NR                                  175
# GEBIET_NAME               Kyburg (bis 2015)
# THEMA_NAME             Öffentliche Finanzen
# SET_NAME                    Gemeindesteuern
# SUBSET_NAME                     Steuerkraft
# INDIKATOR_ID                            378
# INDIKATOR_NAME   Steuerkraft pro Kopf [Fr.]
# INDIKATOR_JAHR                         1992
# INDIKATOR_VALUE                        2527
# EINHEIT_KURZ                      Fr./Einw.
# EINHEIT_LANG          Franken pro Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME         SET_NAME  SUBSET_NAME  \
# count          6333                  6333             6333         6333
# unique          200                     1                1            1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuerkraft
# freq             32                  6333             6333         6333
#
#                     INDIKATOR_NAME EINHEIT_KURZ           EINHEIT_LANG
# count                         6333         6333                   6333
# unique                           1            1                      1
# top     Steuerkraft pro Kopf [Fr.]    Fr./Einw.  Franken pro Einwohner
# freq                          6333         6333                   6333

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,333.00      6,333.00        6,333.00         6,333.00
# mean    110.36        378.00        2,005.38         2,753.02
# std      86.72          0.00            9.17         1,831.12
# min       0.00        378.00        1,990.00           559.00
# 25%      32.00        378.00        1,997.00         1,804.00
# 50%      96.00        378.00        2,005.00         2,325.00
# 75%     181.00        378.00        2,013.00         3,021.00
# max     298.00        378.00        2,021.00        48,366.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

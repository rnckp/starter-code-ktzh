# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung: Durchschnittsalter [Jahre]

# %% [markdown]
# ### **Description**: Durchschnittsalter Ende Jahr (zivilrechtlicher Wohnsitz; ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **289@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:16:16`
# - **Startdate** `2009-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['alter', 'altersstruktur', 'bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'bevoelkerungsstatistik', 'einwohner', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 219
# Title                    : Bevölkerung: Durchschnittsalter [Jahre]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:16:16
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_809.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_809.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,533 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2533 entries, 0 to 2532
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2533 non-null   int64
#  1   GEBIET_NAME      2533 non-null   object
#  2   THEMA_NAME       2533 non-null   object
#  3   SET_NAME         2533 non-null   object
#  4   SUBSET_NAME      2533 non-null   object
#  5   INDIKATOR_ID     2533 non-null   int64
#  6   INDIKATOR_NAME   2533 non-null   object
#  7   INDIKATOR_JAHR   2533 non-null   int64
#  8   INDIKATOR_VALUE  2533 non-null   float64
#  9   EINHEIT_KURZ     2533 non-null   object
#  10  EINHEIT_LANG     2533 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME     SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Altersstruktur           809
# 1  Bevölkerungsbestand und Haushalte  Altersstruktur           809
# 2  Bevölkerungsbestand und Haushalte  Altersstruktur           809
# 3  Bevölkerungsbestand und Haushalte  Altersstruktur           809
# 4  Bevölkerungsbestand und Haushalte  Altersstruktur           809
#
#                             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerung: Durchschnittsalter [Jahre]            2009             41.9
# 1  Bevölkerung: Durchschnittsalter [Jahre]            2010             42.2
# 2  Bevölkerung: Durchschnittsalter [Jahre]            2011             41.8
# 3  Bevölkerung: Durchschnittsalter [Jahre]            2012             41.9
# 4  Bevölkerung: Durchschnittsalter [Jahre]            2013             42.2
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0        Jahre        Jahre
# 1        Jahre        Jahre
# 2        Jahre        Jahre
# 3        Jahre        Jahre
# 4        Jahre        Jahre

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                      641  \
# BFS_NR                                                63
# GEBIET_NAME                                     Lufingen
# THEMA_NAME                      Bevölkerung und Soziales
# SET_NAME               Bevölkerungsbestand und Haushalte
# SUBSET_NAME                               Altersstruktur
# INDIKATOR_ID                                         809
# INDIKATOR_NAME   Bevölkerung: Durchschnittsalter [Jahre]
# INDIKATOR_JAHR                                      2009
# INDIKATOR_VALUE                                     38.6
# EINHEIT_KURZ                                       Jahre
# EINHEIT_LANG                                       Jahre
#
#                                                      210  \
# BFS_NR                                                23
# GEBIET_NAME                                    Berg a.I.
# THEMA_NAME                      Bevölkerung und Soziales
# SET_NAME               Bevölkerungsbestand und Haushalte
# SUBSET_NAME                               Altersstruktur
# INDIKATOR_ID                                         809
# INDIKATOR_NAME   Bevölkerung: Durchschnittsalter [Jahre]
# INDIKATOR_JAHR                                      2011
# INDIKATOR_VALUE                                     43.9
# EINHEIT_KURZ                                       Jahre
# EINHEIT_LANG                                       Jahre
#
#                                                      762
# BFS_NR                                                72
# GEBIET_NAME                                       Winkel
# THEMA_NAME                      Bevölkerung und Soziales
# SET_NAME               Bevölkerungsbestand und Haushalte
# SUBSET_NAME                               Altersstruktur
# INDIKATOR_ID                                         809
# INDIKATOR_NAME   Bevölkerung: Durchschnittsalter [Jahre]
# INDIKATOR_JAHR                                      2013
# INDIKATOR_VALUE                                     43.0
# EINHEIT_KURZ                                       Jahre
# EINHEIT_LANG                                       Jahre

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          2533                      2533
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             13                      2533
#
#                                  SET_NAME     SUBSET_NAME  \
# count                                2533            2533
# unique                                  1               1
# top     Bevölkerungsbestand und Haushalte  Altersstruktur
# freq                                 2533            2533
#
#                                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                      2533         2533         2533
# unique                                        1            1            1
# top     Bevölkerung: Durchschnittsalter [Jahre]        Jahre        Jahre
# freq                                       2533         2533         2533

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,533.00      2,533.00        2,533.00         2,533.00
# mean    109.51        809.00        2,014.92            41.76
# std      86.74          0.00            3.72             1.75
# min       0.00        809.00        2,009.00            36.80
# 25%      31.00        809.00        2,012.00            40.60
# 50%      95.00        809.00        2,015.00            41.70
# 75%     181.00        809.00        2,018.00            42.80
# max     298.00        809.00        2,021.00            48.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

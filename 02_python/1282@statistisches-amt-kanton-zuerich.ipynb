# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Archiv Wahlresultate Gemeindeparlamentswahlen im Kanton Zürich

# %% [markdown]
# ### **Description**: Ergebnisse der Erneuerungswahlen der Zürcher Gemeindeparlamente

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1282@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-03-24T10:22:23`
# - **Modified** `2023-01-04T13:53:37`
# - **Startdate** `2022-02-13`
# - **Enddate** `None`
# - **Theme** `['Politik']`
# - **Keyword** `['gemeinden', 'gemeindewahlen', 'kanton_zuerich', 'politik', 'politische_gemeinden', 'politische_parteien', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/gemeindewahlen.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`3` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2438
# Title                    : Ergebnisse der kommunalen Parlamentswahlen 2022
# Description              : Ergebnisse der Erneuerungswahlen der Zürcher Gemeindeparlamente. Abgebildet sind sämtliche über die den Gemeinden vom Kanton Zürich zur Verfügung gestellte Wahl- und Abstimmungssoftware abgewickelten Gemeindeparlamentswahlen 2022. Gemeinden sind nicht verpflichtet, die Wahlen mit besagter Software abzuwickeln. Ausserdem ist es möglich, dass gewählte Personen die Wahl ablehnen. Der rechtskräftig gewordene Ausgang einer Wahl wird lediglich von der entsprechenden Gemeinde publiziert.
# Issued                   : 2022-04-12T12:27:37
# Modified                 : 2022-06-29T16:14:51
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002438.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002438.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 2418
# Title                    : Ergebnisse der kommunalen Parlamentswahlen 2022 auf Ebene Kandidierende
# Description              : Ergebnisse der Erneuerungswahlen der Zürcher Gemeindeparlamente. Abgebildet sind sämtliche über die den Gemeinden vom Kanton Zürich zur Verfügung gestellte Wahl- und Abstimmungssoftware abgewickelten Gemeindeparlamentswahlen 2022. Gemeinden sind nicht verpflichtet, die Wahlen mit besagter Software abzuwickeln. Ausserdem ist es möglich, dass gewählte Personen die Wahl ablehnen. Der rechtskräftig gewordene Ausgang einer Wahl wird lediglich von der entsprechenden Gemeinde publiziert.
# Issued                   : 2022-03-24T10:22:23
# Modified                 : 2022-06-29T16:14:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002418.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002418.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 2420
# Title                    : Ergebnisse der kommunalen Parlamentswahlen 2022 auf Ebene Listen
# Description              : Ergebnisse der Erneuerungswahlen der Zürcher Gemeindeparlamente. Abgebildet sind sämtliche über die den Gemeinden vom Kanton Zürich zur Verfügung gestellte Wahl- und Abstimmungssoftware abgewickelten Gemeindeparlamentswahlen 2022. Gemeinden sind nicht verpflichtet, die Wahlen mit besagter Software abzuwickeln. Ausserdem ist es möglich, dass gewählte Personen die Wahl ablehnen. Der rechtskräftig gewordene Ausgang einer Wahl wird lediglich von der entsprechenden Gemeinde publiziert.
# Issued                   : 2022-03-24T10:22:23
# Modified                 : 2022-06-29T16:14:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002420.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001282_00002420.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 248 rows (observations) and 15 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SortGemeinde            248 non-null    int64
#  1   SortGemeindeSub         248 non-null    int64
#  2   ListNr                  248 non-null    int64
#  3   StimmenTotalAuszKreis   248 non-null    int64
#  4   StimmenZusatzAuszKreis  248 non-null    int64
#  5   BfsNrGemeinde           248 non-null    int64
#  6   GeArt                   248 non-null    object
#  7   GeLfNr                  248 non-null    int64
#  8   GeVerbNr                90 non-null     float64
#  9   SortGeschaeft           248 non-null    int64
#  10  ListCode                248 non-null    object
#  11  ListBez                 248 non-null    object
#  12  StimmenTotalWahlKreis   248 non-null    int64
#  13  StimmenZusatzWahlKreis  248 non-null    int64
#  14  Sitze                   248 non-null    int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 79.6 KB

# %%
df.head()
# Out:
#    SortGemeinde  SortGemeindeSub  ListNr  StimmenTotalAuszKreis  \
# 0           230                1       1                 118144
# 1           230                1       2                  31190
# 2           230                1       3                  55590
# 3           230                1       4                  58702
# 4           230                1       5                  53127
#
#    StimmenZusatzAuszKreis  BfsNrGemeinde GeArt      GeLfNr  GeVerbNr  \
# 0                     891            230   Gde  1245456007       NaN
# 1                     332            230   Gde  1245456007       NaN
# 2                     862            230   Gde  1245456007       NaN
# 3                     378            230   Gde  1245456007       NaN
# 4                     323            230   Gde  1245456007       NaN
#
#    SortGeschaeft ListCode                                            ListBez  \
# 0              1       SP  Sozialdemokratische Partei (SP), Gewerkschafte...
# 1              1      SVP                     Schweizerische Volkspartei SVP
# 2              1      FDP                                  FDP.Die Liberalen
# 3              1      GLP                                Grünliberale Partei
# 4              1    Grüne                       Grüne und junge Grüne Partei
#
#    StimmenTotalWahlKreis  StimmenZusatzWahlKreis  Sitze
# 0                 384922                    2718     15
# 1                 231661                    2696      9
# 2                 214475                    3704      9
# 3                 209642                    1412      8
# 4                 187121                    1389      8

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                189  \
# SortGemeinde                                    66
# SortGemeindeSub                                 66
# ListNr                                           3
# StimmenTotalAuszKreis                        10791
# StimmenZusatzAuszKreis                        1269
# BfsNrGemeinde                                   66
# GeArt                                          Gde
# GeLfNr                                  1245520114
# GeVerbNr                                       NaN
# SortGeschaeft                                    1
# ListCode                                        SP
# ListBez                 Sozialdemokratische Partei
# StimmenTotalWahlKreis                        10791
# StimmenZusatzWahlKreis                        1269
# Sitze                                            6
#
#                                                      216  \
# SortGemeinde                                         293
# SortGemeindeSub                                      293
# ListNr                                                 3
# StimmenTotalAuszKreis                              41562
# StimmenZusatzAuszKreis                              2256
# BfsNrGemeinde                                        293
# GeArt                                                Gde
# GeLfNr                                        1247049024
# GeVerbNr                                             NaN
# SortGeschaeft                                          1
# ListCode                                             SVP
# ListBez                 Schweizerische Volkspartei (SVP)
# StimmenTotalWahlKreis                              41562
# StimmenZusatzWahlKreis                              2256
# Sitze                                                  8
#
#                                                    63
# SortGemeinde                                       243
# SortGemeindeSub                                    243
# ListNr                                               1
# StimmenTotalAuszKreis                            33741
# StimmenZusatzAuszKreis                            1763
# BfsNrGemeinde                                      243
# GeArt                                              Gde
# GeLfNr                                      1245443176
# GeVerbNr                                           NaN
# SortGeschaeft                                        1
# ListCode                                           SVP
# ListBez                 SVP Schweizerische Volkspartei
# StimmenTotalWahlKreis                            33741
# StimmenZusatzWahlKreis                            1763
# Sitze                                                9

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GeArt ListCode    ListBez
# count    248      248        248
# unique     1       29         71
# top      Gde       SP  Die Mitte
# freq     248       27         22

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        SortGemeinde  SortGemeindeSub  ListNr  StimmenTotalAuszKreis  \
# count        248.00           248.00  248.00                 248.00
# mean         219.00            68.70    6.37              17,735.47
# std           66.14            97.44   10.68              16,564.62
# min           53.00             1.00    1.00                   0.00
# 25%          230.00             4.00    3.00               5,700.00
# 50%          236.50             7.00    5.00              12,783.00
# 75%          261.00           121.00    7.00              24,279.25
# max          296.00           296.00   99.00             118,144.00
#
#        StimmenZusatzAuszKreis  BfsNrGemeinde           GeLfNr  \
# count                  248.00         248.00           248.00
# mean                   587.78         219.00 1,245,591,097.88
# std                    963.36          66.14       494,802.44
# min                      0.00          53.00 1,245,358,847.00
# 25%                    120.25         230.00 1,245,358,940.00
# 50%                    243.00         236.50 1,245,456,007.00
# 75%                    607.00         261.00 1,245,498,395.00
# max                  8,376.00         296.00 1,247,074,503.00
#
#               GeVerbNr  SortGeschaeft  StimmenTotalWahlKreis  \
# count            90.00         248.00                 248.00
# mean  1,245,358,845.00           2.46              54,305.95
# std               0.00           2.49              85,698.01
# min   1,245,358,845.00           1.00                   0.00
# 25%   1,245,358,845.00           1.00               7,126.75
# 50%   1,245,358,845.00           1.00              18,067.00
# 75%   1,245,358,845.00           3.00              55,392.75
# max   1,245,358,845.00           9.00             384,922.00
#
#        StimmenZusatzWahlKreis  Sitze
# count                  248.00 248.00
# mean                 1,283.69   3.76
# std                  2,479.88   3.41
# min                      0.00   0.00
# 25%                    157.75   1.00
# 50%                    388.00   3.00
# 75%                  1,389.00   6.00
# max                 14,220.00  15.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

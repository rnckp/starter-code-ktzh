# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]

# %% [markdown]
# ### **Description**: Das ÖV-Verkehrsaufkommen ist die Summe aller ÖV-Personenwege im Quell-, Ziel- und Binnenverkehr an einem durchschnittlichen Werktag (DWV). Mit Prognosezustand. Anzahl Wege pro Gemeinde, pro Planungsregion und ganzer Kanton.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **366@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T07:34:30`
# - **Startdate** `2013-12-31`
# - **Enddate** `2018-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'oeffentlicher_verkehr', 'verkehrsmittelwahl', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 287
# Title                    : ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2020-09-22T14:44:38
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_492.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_492.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 538 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538 entries, 0 to 537
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           538 non-null    int64
#  1   GEBIET_NAME      538 non-null    object
#  2   THEMA_NAME       538 non-null    object
#  3   SET_NAME         538 non-null    object
#  4   SUBSET_NAME      538 non-null    object
#  5   INDIKATOR_ID     538 non-null    int64
#  6   INDIKATOR_NAME   538 non-null    object
#  7   INDIKATOR_JAHR   538 non-null    int64
#  8   INDIKATOR_VALUE  538 non-null    int64
#  9   EINHEIT_KURZ     538 non-null    object
#  10  EINHEIT_LANG     538 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 323.1 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME       THEMA_NAME SET_NAME        SUBSET_NAME  \
# 0       1     Aeugst a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
# 1       1     Aeugst a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
# 2       1     Aeugst a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
# 3       2  Affoltern a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
# 4       2  Affoltern a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
#
#    INDIKATOR_ID                                  INDIKATOR_NAME  \
# 0           492  ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# 1           492  ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# 2           492  ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# 3           492  ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# 4           492  ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2013              970         Anz.       Anzahl
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             168  \
# BFS_NR                                                       70
# GEBIET_NAME                                        Wasterkingen
# THEMA_NAME                                      Raum und Umwelt
# SET_NAME                                                Verkehr
# SUBSET_NAME                                   Verkehrsaufkommen
# INDIKATOR_ID                                                492
# INDIKATOR_NAME   ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]
# INDIKATOR_JAHR                                             2013
# INDIKATOR_VALUE                                             250
# EINHEIT_KURZ                                               Anz.
# EINHEIT_LANG                                             Anzahl
#
#                                                             43   \
# BFS_NR                                                       21
# GEBIET_NAME                                             Adlikon
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME        SUBSET_NAME  \
# count           538              538      538                538
# unique          188                1        1                  1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  Verkehrsaufkommen
# freq              3              538      538                538
#
#                                         INDIKATOR_NAME EINHEIT_KURZ  \
# count                                              538          538
# unique                                               1            1
# top     ÖV-Wege Quell-, Ziel- und Binnenverkehr [Anz.]         Anz.
# freq                                               538          538
#
#        EINHEIT_LANG
# count           538
# unique            1
# top          Anzahl
# freq            538

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  538.00        538.00          538.00           538.00
# mean   114.44        492.00        2,015.62        26,270.60
# std     83.23          0.00            2.06       138,214.71
# min      0.00        492.00        2,013.00            50.00
# 25%     40.00        492.00        2,013.00           661.25
# 50%     99.00        492.00        2,016.00         1,938.50
# 75%    182.00        492.00        2,018.00         5,825.75
# max    298.00        492.00        2,018.00     1,316,696.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

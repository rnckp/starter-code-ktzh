# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Mittelschule [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Anzahl MittelschülerInnen inkl. LangzeitgymnasiastenInnen und SchülerInnen privater Mittelschulen gemessen an der zivilrechtlichen Bevölkerung Ende Vorjahr.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **216@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1992-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'mittelschulen', 'schueler', 'schuelerinnen', 'schulen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 179
# Title                    : Schül. Mittelschule [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_146.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_146.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,848 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5848 entries, 0 to 5847
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5848 non-null   int64
#  1   GEBIET_NAME      5848 non-null   object
#  2   THEMA_NAME       5848 non-null   object
#  3   SET_NAME         5848 non-null   object
#  4   SUBSET_NAME      5848 non-null   object
#  5   INDIKATOR_ID     5848 non-null   int64
#  6   INDIKATOR_NAME   5848 non-null   object
#  7   INDIKATOR_JAHR   5848 non-null   int64
#  8   INDIKATOR_VALUE  5847 non-null   float64
#  9   EINHEIT_KURZ     5848 non-null   object
#  10  EINHEIT_LANG     5848 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#                               SUBSET_NAME  INDIKATOR_ID  \
# 0  Schüler Mittelschule und Berufsbildung           146
# 1  Schüler Mittelschule und Berufsbildung           146
# 2  Schüler Mittelschule und Berufsbildung           146
# 3  Schüler Mittelschule und Berufsbildung           146
# 4  Schüler Mittelschule und Berufsbildung           146
#
#                          INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Schül. Mittelschule [pro 1000 Einw.]            1992             18.6
# 1  Schül. Mittelschule [pro 1000 Einw.]            1993             17.0
# 2  Schül. Mittelschule [pro 1000 Einw.]            1994             12.2
# 3  Schül. Mittelschule [pro 1000 Einw.]            1995             11.8
# 4  Schül. Mittelschule [pro 1000 Einw.]            1996             15.9
#
#      EINHEIT_KURZ           EINHEIT_LANG
# 0  pro 1000 Einw.  pro Tausend Einwohner
# 1  pro 1000 Einw.  pro Tausend Einwohner
# 2  pro 1000 Einw.  pro Tausend Einwohner
# 3  pro 1000 Einw.  pro Tausend Einwohner
# 4  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                     624  \
# BFS_NR                                               27
# GEBIET_NAME                                 Feuerthalen
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        146
# INDIKATOR_NAME     Schül. Mittelschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     2016
# INDIKATOR_VALUE                                     2.0
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner
#
#                                                     125  \
# BFS_NR                                                5
# GEBIET_NAME                                    Hedingen
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        146
# INDIKATOR_NAME     Schül. Mittelschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     1997
# INDIKATOR_VALUE                                    20.7
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner
#
#                                                     299
# BFS_NR                                               10
# GEBIET_NAME                                    Obfelden
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        146
# INDIKATOR_NAME     Schül. Mittelschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     2021
# INDIKATOR_VALUE                                    12.6
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME  \
# count          5848                      5848     5848
# unique          200                         1        1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung
# freq             30                      5848     5848
#
#                                    SUBSET_NAME  \
# count                                     5848
# unique                                       1
# top     Schüler Mittelschule und Berufsbildung
# freq                                      5848
#
#                               INDIKATOR_NAME    EINHEIT_KURZ  \
# count                                   5848            5848
# unique                                     1               1
# top     Schül. Mittelschule [pro 1000 Einw.]  pro 1000 Einw.
# freq                                    5848            5848
#
#                  EINHEIT_LANG
# count                    5848
# unique                      1
# top     pro Tausend Einwohner
# freq                     5848

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,848.00      5,848.00        5,848.00         5,847.00
# mean    107.66        146.00        2,006.43            12.83
# std      84.48          0.00            8.62             5.82
# min       0.00        146.00        1,992.00             0.00
# 25%      31.00        146.00        1,999.00             9.20
# 50%      94.00        146.00        2,006.00            11.90
# 75%     178.00        146.00        2,014.00            15.40
# max     298.00        146.00        2,021.00            53.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

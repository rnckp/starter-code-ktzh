# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Ausländeranteil [%]

# %% [markdown]
# ### **Description**: Ausländeranteil in Prozent der Gesamtbevölkerung (zivilrechtlicher Wohnsitz; ab 2010 inkl. vorläufig Aufgenommene, die über einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **68@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:05`
# - **Startdate** `1978-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['auslaender', 'bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'bevoelkerungsstatistik', 'einwohner', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 58
# Title                    : Ausländeranteil [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_205.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_205.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 8,668 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8668 entries, 0 to 8667
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           8668 non-null   int64
#  1   GEBIET_NAME      8668 non-null   object
#  2   THEMA_NAME       8668 non-null   object
#  3   SET_NAME         8668 non-null   object
#  4   SUBSET_NAME      8668 non-null   object
#  5   INDIKATOR_ID     8668 non-null   int64
#  6   INDIKATOR_NAME   8668 non-null   object
#  7   INDIKATOR_JAHR   8668 non-null   int64
#  8   INDIKATOR_VALUE  8668 non-null   float64
#  9   EINHEIT_KURZ     8668 non-null   object
#  10  EINHEIT_LANG     8668 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 6.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           205
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           205
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           205
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           205
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           205
#
#         INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  Ausländeranteil [%]            1978              3.1            %
# 1  Ausländeranteil [%]            1979              3.5            %
# 2  Ausländeranteil [%]            1980              3.8            %
# 3  Ausländeranteil [%]            1981              3.3            %
# 4  Ausländeranteil [%]            1982              3.6            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               534   \
# BFS_NR                                          13
# GEBIET_NAME                              Stallikon
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   205
# INDIKATOR_NAME                 Ausländeranteil [%]
# INDIKATOR_JAHR                                1984
# INDIKATOR_VALUE                                8.6
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               6164  \
# BFS_NR                                         215
# GEBIET_NAME                              Dättlikon
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   205
# INDIKATOR_NAME                 Ausländeranteil [%]
# INDIKATOR_JAHR                                1990
# INDIKATOR_VALUE                                2.7
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               6244
# BFS_NR                                         217
# GEBIET_NAME                        Elgg (bis 2017)
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   205
# INDIKATOR_NAME                 Ausländeranteil [%]
# INDIKATOR_JAHR                                1982
# INDIKATOR_VALUE                               14.0
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          8668                      8668
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             44                      8668
#
#                                  SET_NAME          SUBSET_NAME  \
# count                                8668                 8668
# unique                                  1                    1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsbestand
# freq                                 8668                 8668
#
#              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                  8668         8668         8668
# unique                    1            1            1
# top     Ausländeranteil [%]            %      Prozent
# freq                   8668         8668         8668

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 8,668.00      8,668.00        8,668.00         8,668.00
# mean    109.15        205.00        1,999.47            14.66
# std      85.58          0.00           12.63             7.95
# min       0.00        205.00        1,978.00             0.00
# 25%      32.00        205.00        1,989.00             8.40
# 50%      95.00        205.00        2,000.00            14.10
# 75%     179.00        205.00        2,010.00            19.70
# max     298.00        205.00        2,021.00            47.20

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

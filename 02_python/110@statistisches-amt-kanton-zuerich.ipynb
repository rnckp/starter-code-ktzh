# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Leerwohnungsquote [%]

# %% [markdown]
# ### **Description**: Leerstehende Wohnungen am 1. Juni des Erhebungsjahres, gemessen am Wohnungsbestand

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **110@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-30T07:55:20`
# - **Startdate** `1984-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'leerwohnungen', 'wohnungen', 'wohnungsbestand', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 90
# Title                    : Leerwohnungsquote [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-30T07:55:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_373.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_373.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 7,495 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7495 entries, 0 to 7494
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           7495 non-null   int64
#  1   GEBIET_NAME      7495 non-null   object
#  2   THEMA_NAME       7495 non-null   object
#  3   SET_NAME         7495 non-null   object
#  4   SUBSET_NAME      7495 non-null   object
#  5   INDIKATOR_ID     7495 non-null   int64
#  6   INDIKATOR_NAME   7495 non-null   object
#  7   INDIKATOR_JAHR   7495 non-null   int64
#  8   INDIKATOR_VALUE  7495 non-null   float64
#  9   EINHEIT_KURZ     7495 non-null   object
#  10  EINHEIT_LANG     7495 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID         INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Wohnungsbestand           373  Leerwohnungsquote [%]            1984
# 1  Wohnungsbestand           373  Leerwohnungsquote [%]            1985
# 2  Wohnungsbestand           373  Leerwohnungsquote [%]            1986
# 3  Wohnungsbestand           373  Leerwohnungsquote [%]            1987
# 4  Wohnungsbestand           373  Leerwohnungsquote [%]            1988
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0             0.64            %      Prozent
# 1             0.32            %      Prozent
# 2             0.31            %      Prozent
# 3             0.00            %      Prozent
# 4             0.30            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         4931                         2571  \
# BFS_NR                                   191                           87
# GEBIET_NAME                        Dübendorf                     Hüttikon
# THEMA_NAME                Bau und Immobilien           Bau und Immobilien
# SET_NAME         Wohnungen, Wohnbautätigkeit  Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                  Wohnungsbestand              Wohnungsbestand
# INDIKATOR_ID                             373                          373
# INDIKATOR_NAME         Leerwohnungsquote [%]        Leerwohnungsquote [%]
# INDIKATOR_JAHR                          1987                         1993
# INDIKATOR_VALUE                         0.27                         1.28
# EINHEIT_KURZ                               %                            %
# EINHEIT_LANG                         Prozent                      Prozent
#
#                                         741
# BFS_NR                                    26
# GEBIET_NAME                             Dorf
# THEMA_NAME                Bau und Immobilien
# SET_NAME         Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                  Wohnungsbestand
# INDIKATOR_ID                             373
# INDIKATOR_NAME         Leerwohnungsquote [%]
# INDIKATOR_JAHR                          1984
# INDIKATOR_VALUE                         0.81
# EINHEIT_KURZ                               %
# EINHEIT_LANG                         Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          7495                7495                         7495
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             39                7495                         7495
#
#             SUBSET_NAME         INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count              7495                   7495         7495         7495
# unique                1                      1            1            1
# top     Wohnungsbestand  Leerwohnungsquote [%]            %      Prozent
# freq               7495                   7495         7495         7495

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 7,495.00      7,495.00        7,495.00         7,495.00
# mean    104.90        373.00        2,002.93             0.91
# std      81.88          0.00           11.22             0.92
# min       0.00        373.00        1,984.00             0.00
# 25%      31.00        373.00        1,993.00             0.29
# 50%      93.00        373.00        2,003.00             0.70
# 75%     176.00        373.00        2,013.00             1.24
# max     298.00        373.00        2,022.00            13.81

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Sterberate [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Sterbefälle in Bezug auf die Einwohnerzahl (gemäss Kantonaler Erhebung) Ende des vorhergehenden Jahres. Beispiel: Die "Sterbefälle [pro 1000 Einw.] 2003" beziehen sich auf die Einwohnerzahl von Ende 2002.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **220@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungsbewegungen', 'bezirke', 'gemeinden', 'kanton_zuerich', 'sterbefaelle', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 183
# Title                    : Sterberate [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_102.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_102.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,247 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6247 entries, 0 to 6246
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6247 non-null   int64
#  1   GEBIET_NAME      6247 non-null   object
#  2   THEMA_NAME       6247 non-null   object
#  3   SET_NAME         6247 non-null   object
#  4   SUBSET_NAME      6247 non-null   object
#  5   INDIKATOR_ID     6247 non-null   int64
#  6   INDIKATOR_NAME   6247 non-null   object
#  7   INDIKATOR_JAHR   6247 non-null   int64
#  8   INDIKATOR_VALUE  6247 non-null   float64
#  9   EINHEIT_KURZ     6247 non-null   object
#  10  EINHEIT_LANG     6247 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID               INDIKATOR_NAME  \
# 0  Geburten und Sterbefälle           102  Sterberate [pro 1000 Einw.]
# 1  Geburten und Sterbefälle           102  Sterberate [pro 1000 Einw.]
# 2  Geburten und Sterbefälle           102  Sterberate [pro 1000 Einw.]
# 3  Geburten und Sterbefälle           102  Sterberate [pro 1000 Einw.]
# 4  Geburten und Sterbefälle           102  Sterberate [pro 1000 Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE    EINHEIT_KURZ           EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         1642                         1379  \
# BFS_NR                                    64                           56
# GEBIET_NAME                       Nürensdorf                      Embrach
# THEMA_NAME          Bevölkerung und Soziales     Bevölkerung und Soziales
# SET_NAME                Bevölkerungsbewegung         Bevölkerungsbewegung
# SUBSET_NAME         Geburten und Sterbefälle     Geburten und Sterbefälle
# INDIKATOR_ID                             102                          102
# INDIKATOR_NAME   Sterberate [pro 1000 Einw.]  Sterberate [pro 1000 Einw.]
# INDIKATOR_JAHR                          2009                         2002
# INDIKATOR_VALUE                          3.6                          4.5
# EINHEIT_KURZ                  pro 1000 Einw.               pro 1000 Einw.
# EINHEIT_LANG           pro Tausend Einwohner        pro Tausend Einwohner
#
#                                         3749
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          6247                      6247                  6247
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             32                      6247                  6247
#
#                      SUBSET_NAME               INDIKATOR_NAME    EINHEIT_KURZ  \
# count                       6247                         6247            6247
# unique                         1                            1               1
# top     Geburten und Sterbefälle  Sterberate [pro 1000 Einw.]  pro 1000 Einw.
# freq                        6247                         6247            6247
#
#                  EINHEIT_LANG
# count                    6247
# unique                      1
# top     pro Tausend Einwohner
# freq                     6247

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,247.00      6,247.00        6,247.00         6,247.00
# mean    107.84        102.00        2,005.44             6.76
# std      84.60          0.00            9.20             2.36
# min       0.00        102.00        1,990.00             0.00
# 25%      31.00        102.00        1,997.00             5.20
# 50%      94.00        102.00        2,005.00             6.70
# 75%     178.00        102.00        2,013.00             8.00
# max     298.00        102.00        2,021.00            22.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

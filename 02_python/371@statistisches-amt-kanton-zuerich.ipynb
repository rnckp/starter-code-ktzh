# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Durchschnittliche Haushaltsgrösse [Pers.]

# %% [markdown]
# ### **Description**: Durchschnittliche Haushaltsgrösse von Privathaushalten der ständigen Wohnbevölkerung.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **371@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T10:04:17`
# - **Startdate** `2010-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'haushalte', 'haushaltsgroesse', 'haushalt-typ', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 292
# Title                    : Durchschnittliche Haushaltsgrösse [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T10:04:17
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_449.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_449.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,752 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1752 non-null   int64
#  1   GEBIET_NAME      1752 non-null   object
#  2   THEMA_NAME       1752 non-null   object
#  3   SET_NAME         1752 non-null   object
#  4   SUBSET_NAME      1752 non-null   object
#  5   INDIKATOR_ID     1752 non-null   int64
#  6   INDIKATOR_NAME   1752 non-null   object
#  7   INDIKATOR_JAHR   1752 non-null   int64
#  8   INDIKATOR_VALUE  1752 non-null   float64
#  9   EINHEIT_KURZ     1752 non-null   object
#  10  EINHEIT_LANG     1752 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte   Haushalte           449
# 1  Bevölkerungsbestand und Haushalte   Haushalte           449
# 2  Bevölkerungsbestand und Haushalte   Haushalte           449
# 3  Bevölkerungsbestand und Haushalte   Haushalte           449
# 4  Bevölkerungsbestand und Haushalte   Haushalte           449
#
#                               INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Durchschnittliche Haushaltsgrösse [Pers.]            2013             2.43
# 1  Durchschnittliche Haushaltsgrösse [Pers.]            2014             2.44
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                       850   \
# BFS_NR                                                 134
# GEBIET_NAME                              Hütten (bis 2018)
# THEMA_NAME                        Bevölkerung und Soziales
# SET_NAME                 Bevölkerungsbestand und Haushalte
# SUBSET_NAME                                      Haushalte
# INDIKATOR_ID                                           449
# INDIKATOR_NAME   Durchschnittliche Haushaltsgrösse [Pers.]
# INDIKATOR_JAHR                                        2016
# INDIKATOR_VALUE                                       2.61
# EINHEIT_KURZ                                         Pers.
# EINHEIT_LANG                                      Personen
#
#                                                       1297  \
# BFS_NR                                                 224
# GEBIET_NAME                                        Pfungen
# THEMA_NAME                        Bevölkerung und Soziales
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GEBIET_NAME                THEMA_NAME  \
# count         1752                      1752
# unique         200                         1
# top         Horgen  Bevölkerung und Soziales
# freq            12                      1752
#
#                                  SET_NAME SUBSET_NAME  \
# count                                1752        1752
# unique                                  1           1
# top     Bevölkerungsbestand und Haushalte   Haushalte
# freq                                 1752        1752
#
#                                    INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                        1752         1752         1752
# unique                                          1            1            1
# top     Durchschnittliche Haushaltsgrösse [Pers.]        Pers.     Personen
# freq                                         1752         1752         1752

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,752.00      1,752.00        1,752.00         1,752.00
# mean    110.86        449.00        2,016.89             2.34
# std      88.38          0.00            2.62             0.13
# min       0.00        449.00        2,010.00             1.97
# 25%      31.00        449.00        2,015.00             2.25
# 50%      95.00        449.00        2,017.00             2.33
# 75%     182.00        449.00        2,019.00             2.42
# max     298.00        449.00        2,021.00             2.79

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

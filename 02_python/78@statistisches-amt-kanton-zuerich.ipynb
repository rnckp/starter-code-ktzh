# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: KRW Wähleranteil CVP [%]

# %% [markdown]
# ### **Description**: Wähleranteil CVP bei Kantonsratswahlen

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **78@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-03-25T10:44:00`
# - **Startdate** `1995-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kantonsratswahlen', 'kanton_zuerich', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 64
# Title                    : KRW Wähleranteil CVP [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-03-25T10:44:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_114.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_114.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,331 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1331 entries, 0 to 1330
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1331 non-null   int64
#  1   GEBIET_NAME      1331 non-null   object
#  2   THEMA_NAME       1331 non-null   object
#  3   SET_NAME         1331 non-null   object
#  4   SUBSET_NAME      1331 non-null   object
#  5   INDIKATOR_ID     1331 non-null   int64
#  6   INDIKATOR_NAME   1331 non-null   object
#  7   INDIKATOR_JAHR   1331 non-null   int64
#  8   INDIKATOR_VALUE  1331 non-null   float64
#  9   EINHEIT_KURZ     1331 non-null   object
#  10  EINHEIT_LANG     1331 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 779.1 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           114
# 1       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           114
# 2       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           114
# 3       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           114
# 4       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           114
#
#              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  KRW Wähleranteil CVP [%]            1995              1.2            %
# 1  KRW Wähleranteil CVP [%]            1999              2.1            %
# 2  KRW Wähleranteil CVP [%]            2003              4.4            %
# 3  KRW Wähleranteil CVP [%]            2007              5.4            %
# 4  KRW Wähleranteil CVP [%]            2011              1.3            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      682                       744   \
# BFS_NR                                136                       153
# GEBIET_NAME                  Langnau a.A.             Hombrechtikon
# THEMA_NAME                        Politik                   Politik
# SET_NAME                    Wähleranteile             Wähleranteile
# SUBSET_NAME                    Kantonsrat                Kantonsrat
# INDIKATOR_ID                          114                       114
# INDIKATOR_NAME   KRW Wähleranteil CVP [%]  KRW Wähleranteil CVP [%]
# INDIKATOR_JAHR                       2003                      2007
# INDIKATOR_VALUE                      11.7                       6.5
# EINHEIT_KURZ                            %                         %
# EINHEIT_LANG                      Prozent                   Prozent
#
#                                      1228
# BFS_NR                                  0
# GEBIET_NAME                 Bezirk Meilen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  \
# count          1331       1331           1331        1331
# unique          200          1              1           1
# top     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat
# freq              7       1331           1331        1331
#
#                   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                       1331         1331         1331
# unique                         1            1            1
# top     KRW Wähleranteil CVP [%]            %      Prozent
# freq                        1331         1331         1331

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,331.00      1,331.00        1,331.00         1,331.00
# mean    108.33        114.00        2,006.74             4.64
# std      82.99          0.00            7.86             3.01
# min       0.00        114.00        1,995.00             0.00
# 25%      33.00        114.00        1,999.00             2.30
# 50%      95.00        114.00        2,007.00             4.10
# 75%     178.00        114.00        2,015.00             6.50
# max     298.00        114.00        2,019.00            19.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

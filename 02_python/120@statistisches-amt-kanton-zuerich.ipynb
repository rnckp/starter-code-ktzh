# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Quartalsbericht Wohnbautätigkeit

# %% [markdown]
# ### **Description**: Der Quartalsbericht umfasst die aktuellsten Zahlen zur Wohnbautätigkeit im Kanton Zürich.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **120@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-02-27T00:00:00`
# - **Modified** `2020-02-01T00:00:00`
# - **Startdate** `2000-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bautaetigkeit', 'neubauten']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1220
# Title                    : Jahresentwicklung Wohnbautätigkeit (Daten)
# Description              : Daten zur Jahresentwicklung der Wohnbautätigkeit ab 2000
# Issued                   : 2020-02-01T00:00:00
# Modified                 : 2020-02-01T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000120_00001220.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000120_00001220.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1225
# Title                    : Quartalsentwicklung Wohnbautätigkeit (Daten)
# Description              : Daten zur Quartalsentwicklung der Wohnbautätigkeit ab 2014
# Issued                   : 2020-02-01T00:00:00
# Modified                 : 2020-02-01T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000120_00001225.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000120_00001225.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 37 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    37 non-null     int64
#  1   STICHTAG_neu  37 non-null     object
#  2   Q             37 non-null     int64
#  3   zeitraum      37 non-null     object
#  4   NWHG          37 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 5.5 KB

# %%
df.head()
# Out:
#    Unnamed: 0 STICHTAG_neu  Q zeitraum  NWHG
# 0           1   2014-03-31  1        0  1784
# 1           2   2014-06-30  2        0  1980
# 2           3   2014-09-30  3        0  2811
# 3           4   2014-12-31  4        0  1995
# 4           5   2015-03-31  1        0  2990

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                       34          15          5
# Unnamed: 0            35          16           6
# STICHTAG_neu  2022-04-01  2017-12-31  2015-06-30
# Q                      2           4           2
# zeitraum             24+           0           0
# NWHG                 952        2619        2191

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        STICHTAG_neu zeitraum
# count            37       37
# unique           34        4
# top      2022-04-01        0
# freq              4       25

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Unnamed: 0     Q     NWHG
# count       37.00 37.00    37.00
# mean        19.00  2.46 2,130.35
# std         10.82  1.14   634.15
# min          1.00  1.00   749.00
# 25%         10.00  1.00 1,784.00
# 50%         19.00  2.00 2,137.00
# 75%         28.00  3.00 2,619.00
# max         37.00  4.00 3,334.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | katharina.kaelin@statistik.ji.zh.ch

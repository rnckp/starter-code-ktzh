# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungswachstum der Stadt Winterthur ab 1985

# %% [markdown]
# ### **Description**: Zeitreihe des Bevölkerungsbestands und -wachstums (total sowie Schweizer:innen und Ausländer:innen) in der Stadt Winterthur ab 1985.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1481@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T17:00:21`
# - **Modified** `2022-09-21T10:08:33`
# - **Startdate** `1985-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungswachstum', 'gemeinden', 'nationalitaet', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/bevoelkerung`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2898
# Title                    : Bevölkerungsbestand und -wachstum total und Schweizer:innen und Ausländer:innen nach Jahr
# Description              : Variablen: 'Gesamt' = Gesamtzahl der Einwohner:innen; 'Wachstum' = Bevölkerungswachstum zum Vorjahr absolut; 'Schweiz' = Anzahl Schweizer:innen; 'Ausland' = Anzahl Ausländer:innen.
# Issued                   : 2022-09-20T17:00:21
# Modified                 : 2022-09-20T17:00:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001481_00002898.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001481_00002898.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 37 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Jahr      37 non-null     object
#  1   Gesamt    37 non-null     int64
#  2   Wachstum  36 non-null     float64
#  3   Schweiz   37 non-null     int64
#  4   Ausland   37 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 3.5 KB

# %%
df.head()
# Out:
#    Jahr  Gesamt  Wachstum  Schweiz  Ausland
# 0  2021  117289     885.0    87957    29269
# 1  2020  116404     912.0    87492    28849
# 2  2019  115492    1308.0    87061    28371
# 3  2018  114184    1007.0    86311    27873
# 4  2017  113177    1056.0    85687    27490

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#              24      10      14
# Jahr       1997    2011    2007
# Gesamt    89850  105086   99304
# Wachstum  -57.0  1827.0  1572.0
# Schweiz   68877   80572   75769
# Ausland   20973   24514   23535

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         Jahr
# count     37
# unique    37
# top     2021
# freq       1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Gesamt  Wachstum   Schweiz   Ausland
# count      37.00     36.00     37.00     37.00
# mean   97,776.70    898.42 75,311.62 22,459.81
# std    10,330.45    570.27  6,828.58  3,729.82
# min    84,946.00   -284.00 68,877.00 15,639.00
# 25%    89,850.00    429.00 69,534.00 20,174.00
# 50%    94,003.00    898.50 71,651.00 22,352.00
# 75%   106,542.00  1,461.75 81,562.00 24,980.00
# max   117,289.00  1,827.00 87,957.00 29,269.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

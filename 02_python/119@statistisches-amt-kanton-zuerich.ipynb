# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Quartalsbericht Immobilienmarkt

# %% [markdown]
# ### **Description**: Der Quartalsbericht umfasst die aktuellsten Zahlen zu Preisentwicklung und Handelsvolumen auf dem Zürcher Immobilienmarkt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **119@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2018-05-27T00:00:00`
# - **Modified** `2022-05-16T15:35:56`
# - **Startdate** `2012-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['bodenpreise', 'einfamilienhaus', 'immobilienpreise', 'kanton_zuerich', 'mehrfamilienhaus', 'stockwerkeigentum', 'wohnbauland', 'immobilienhandel']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1212
# Title                    :  Daten für interaktive Grafiken: Quartalsbericht Handänderungsstatistik 
# Description              : Daten zum aktuellsten Quartalsbericht Handänderungsstatistik zur Preisentwicklung von Wohnbauland, Stockwerkeigentum, Ein- und Mehrfamilienhäusern.
# Issued                   : 2019-11-27T00:00:00
# Modified                 : 2022-11-25T09:35:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000119_00001212.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000119_00001212.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 172 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   s_j_erhjahr  172 non-null    int64
#  1   quartal      172 non-null    int64
#  2   typ          172 non-null    object
#  3   anz_i        172 non-null    float64
#  4   med_preis_i  172 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 17.6 KB

# %%
df.head()
# Out:
#    s_j_erhjahr  quartal                typ     anz_i  med_preis_i
# 0         2012        1        Wohnbauland  1.000000     1.000000
# 1         2012        1    Einfamilienhaus  1.000000     1.000000
# 2         2012        1  Stockwerkeigentum  1.000000     1.000000
# 3         2012        1   Mehrfamilienhaus  1.000000     1.000000
# 4         2012        2        Wohnbauland  0.885327     1.045121

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                            78               61                 138
# s_j_erhjahr               2016             2015               2020
# quartal                      4                4                  3
# typ          Stockwerkeigentum  Einfamilienhaus  Stockwerkeigentum
# anz_i                 1.021235          0.92837           0.953846
# med_preis_i           1.204506         1.169669           1.318544

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                 typ
# count           172
# unique            4
# top     Wohnbauland
# freq             43

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        s_j_erhjahr  quartal  anz_i  med_preis_i
# count       172.00   172.00 172.00       172.00
# mean      2,016.88     2.47   0.82         1.29
# std           3.11     1.11   0.17         0.24
# min       2,012.00     1.00   0.27         0.91
# 25%       2,014.00     1.00   0.75         1.12
# 50%       2,017.00     2.00   0.89         1.25
# 75%       2,020.00     3.00   0.93         1.40
# max       2,022.00     4.00   1.04         1.94

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | basil.schlaepfer@statistik.ji.zh.ch

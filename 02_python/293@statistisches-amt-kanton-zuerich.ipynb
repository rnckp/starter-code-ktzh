# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]

# %% [markdown]
# ### **Description**: Steuerbares Vermögen natürlicher Personen des Kantonalen Steueramts. (Durchschnitt).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **293@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-06T11:26:44`
# - **Startdate** `2003-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'natuerliche_personen', 'steuerbares_vermoegen', 'vermoegen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 223
# Title                    : Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-06T11:26:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_321.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_321.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,320 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3320 entries, 0 to 3319
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3320 non-null   int64
#  1   GEBIET_NAME      3320 non-null   object
#  2   THEMA_NAME       3320 non-null   object
#  3   SET_NAME         3320 non-null   object
#  4   SUBSET_NAME      3320 non-null   object
#  5   INDIKATOR_ID     3320 non-null   int64
#  6   INDIKATOR_NAME   3320 non-null   object
#  7   INDIKATOR_JAHR   3320 non-null   int64
#  8   INDIKATOR_VALUE  3320 non-null   int64
#  9   EINHEIT_KURZ     3320 non-null   object
#  10  EINHEIT_LANG     3320 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME                SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
#
#             SUBSET_NAME  INDIKATOR_ID  \
# 0  Steuerbares Vermögen           321
# 1  Steuerbares Vermögen           321
# 2  Steuerbares Vermögen           321
# 3  Steuerbares Vermögen           321
# 4  Steuerbares Vermögen           321
#
#                                      INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]            2003
# 1  Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]            2004
# 2  Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]            2005
# 3  Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]            2006
# 4  Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]            2007
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0           687000          Fr.      Franken
# 1           659000          Fr.      Franken
# 2           727000          Fr.      Franken
# 3           781000          Fr.      Franken
# 4           731000          Fr.      Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                              1638  \
# BFS_NR                                                        134
# GEBIET_NAME                                     Hütten (bis 2018)
# THEMA_NAME                               Bevölkerung und Soziales
# SET_NAME                                   Einkommen und Vermögen
# SUBSET_NAME                                  Steuerbares Vermögen
# INDIKATOR_ID                                                  321
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]
# INDIKATOR_JAHR                                               2016
# INDIKATOR_VALUE                                            283000
# EINHEIT_KURZ                                                  Fr.
# EINHEIT_LANG                                              Franken
#
#                                                              2385  \
# BFS_NR                                                        215
# GEBIET_NAME                                             Dättlikon
# THEMA_NAME                               Bevölkerung und Soziales
# SET_NAME                                   Einkommen und Vermögen
# SUBSET_NAME                                  Steuerbares Vermögen
# INDIKATOR_ID                                                  321
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]
# INDIKATOR_JAHR                                               2019
# INDIKATOR_VALUE                                            821000
# EINHEIT_KURZ                                                  Fr.
# EINHEIT_LANG                                              Franken
#
#                                                              2599
# BFS_NR                                                        228
# GEBIET_NAME                                            Turbenthal
# THEMA_NAME                               Bevölkerung und Soziales
# SET_NAME                                   Einkommen und Vermögen
# SUBSET_NAME                                  Steuerbares Vermögen
# INDIKATOR_ID                                                  321
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]
# INDIKATOR_JAHR                                               2016
# INDIKATOR_VALUE                                            280000
# EINHEIT_KURZ                                                  Fr.
# EINHEIT_LANG                                              Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME                SET_NAME  \
# count          3320                      3320                    3320
# unique          200                         1                       1
# top     Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# freq             17                      3320                    3320
#
#                  SUBSET_NAME  \
# count                   3320
# unique                     1
# top     Steuerbares Vermögen
# freq                    3320
#
#                                           INDIKATOR_NAME EINHEIT_KURZ  \
# count                                               3320         3320
# unique                                                 1            1
# top     Steuerb. Vermögen natürl. Pers. Durchschn. [Fr.]          Fr.
# freq                                                3320         3320
#
#        EINHEIT_LANG
# count          3320
# unique            1
# top         Franken
# freq           3320

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,320.00      3,320.00        3,320.00         3,320.00
# mean    107.83        321.00        2,010.97       449,386.75
# std      84.66          0.00            4.88       388,856.49
# min       0.00        321.00        2,003.00       133,000.00
# 25%      31.00        321.00        2,007.00       285,000.00
# 50%      94.00        321.00        2,011.00       347,000.00
# 75%     178.00        321.00        2,015.00       440,000.00
# max     298.00        321.00        2,019.00     4,413,000.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

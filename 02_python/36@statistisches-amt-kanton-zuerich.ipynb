# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Arbeitslose [Anz.]

# %% [markdown]
# ### **Description**: Jahresmittel der beim kantonalen Arbeitsamt eingeschriebenen Arbeitslosen. Aus Datenschutzgründen dürfen Werte von Gemeinden mit weniger als 6 Arbeitslosen (Jahresmittel) nicht ausgewiesen werden.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **36@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-04-14T08:44:20`
# - **Startdate** `1991-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Arbeit, Erwerb']`
# - **Keyword** `['arbeitslose', 'arbeitslosigkeit', 'arbeitsmarkt', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 31
# Title                    : Arbeitslose [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-04-14T08:44:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_107.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_107.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,028 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6028 non-null   int64
#  1   GEBIET_NAME      6028 non-null   object
#  2   THEMA_NAME       6028 non-null   object
#  3   SET_NAME         6028 non-null   object
#  4   SUBSET_NAME      6028 non-null   object
#  5   INDIKATOR_ID     6028 non-null   int64
#  6   INDIKATOR_NAME   6028 non-null   object
#  7   INDIKATOR_JAHR   6028 non-null   int64
#  8   INDIKATOR_VALUE  5901 non-null   float64
#  9   EINHEIT_KURZ     6028 non-null   object
#  10  EINHEIT_LANG     6028 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
#
#         SUBSET_NAME  INDIKATOR_ID      INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Arbeitslosigkeit           107  Arbeitslose [Anz.]            1991
# 1  Arbeitslosigkeit           107  Arbeitslose [Anz.]            1992
# 2  Arbeitslosigkeit           107  Arbeitslose [Anz.]            1993
# 3  Arbeitslosigkeit           107  Arbeitslose [Anz.]            1994
# 4  Arbeitslosigkeit           107  Arbeitslose [Anz.]            1995
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              1.8         Anz.       Anzahl
# 1              3.4         Anz.       Anzahl
# 2             11.3         Anz.       Anzahl
# 3             11.1         Anz.       Anzahl
# 4             14.3         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                    267                     448   \
# BFS_NR                                9                      21
# GEBIET_NAME              Mettmenstetten                 Adlikon
# THEMA_NAME       Arbeit und Unternehmen  Arbeit und Unternehmen
# SET_NAME               Arbeitslosigkeit        Arbeitslosigkeit
# SUBSET_NAME            Arbeitslosigkeit        Arbeitslosigkeit
# INDIKATOR_ID                        107                     107
# INDIKATOR_NAME       Arbeitslose [Anz.]      Arbeitslose [Anz.]
# INDIKATOR_JAHR                     2010                    2005
# INDIKATOR_VALUE                    52.0                     9.0
# EINHEIT_KURZ                       Anz.                    Anz.
# EINHEIT_LANG                     Anzahl                  Anzahl
#
#                                    1971
# BFS_NR                               84
# GEBIET_NAME                    Dällikon
# THEMA_NAME       Arbeit und Unternehmen
# SET_NAME               Arbeitslosigkeit
# SUBSET_NAME            Arbeitslosigkeit
# INDIKATOR_ID                        107
# INDIKATOR_NAME       Arbeitslose [Anz.]
# INDIKATOR_JAHR                     2018
# INDIKATOR_VALUE                    60.8
# EINHEIT_KURZ                       Anz.
# EINHEIT_LANG                     Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME          SET_NAME  \
# count          6028                    6028              6028
# unique          200                       1                 1
# top     Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# freq             31                    6028              6028
#
#              SUBSET_NAME      INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count               6028                6028         6028         6028
# unique                 1                   1            1            1
# top     Arbeitslosigkeit  Arbeitslose [Anz.]         Anz.       Anzahl
# freq                6028                6028         6028         6028

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,028.00      6,028.00        6,028.00         5,901.00
# mean    107.19        107.00        2,005.90           506.38
# std      84.07          0.00            8.91         2,152.08
# min       0.00        107.00        1,991.00             0.00
# 25%      31.00        107.00        1,998.00            14.90
# 50%      94.00        107.00        2,006.00            53.50
# 75%     178.00        107.00        2,014.00           167.00
# max     298.00        107.00        2,021.00        34,306.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Hauptberufliche Landwirtschaftsbetriebe [Anz.]

# %% [markdown]
# ### **Description**: Anzahl hauptberuflicher Betriebe gemäss landwirtschaftlicher Betriebszählung

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **51@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T08:35:24`
# - **Startdate** `1985-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Land- und Forstwirtschaft', 'Bau- und Wohnungswesen', 'Arbeit, Erwerb']`
# - **Keyword** `['betriebe', 'bezirke', 'gemeinden', 'kanton_zuerich', 'landwirtschaft', 'landwirtschaftsbetriebe', 'wirtschaftssektor', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 44
# Title                    : Hauptberufliche Landwirtschaftsbetriebe [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2021-05-28T11:35:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_271.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_271.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,684 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3684 entries, 0 to 3683
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3684 non-null   int64
#  1   GEBIET_NAME      3684 non-null   object
#  2   THEMA_NAME       3684 non-null   object
#  3   SET_NAME         3684 non-null   object
#  4   SUBSET_NAME      3684 non-null   object
#  5   INDIKATOR_ID     3684 non-null   int64
#  6   INDIKATOR_NAME   3684 non-null   object
#  7   INDIKATOR_JAHR   3684 non-null   int64
#  8   INDIKATOR_VALUE  3684 non-null   int64
#  9   EINHEIT_KURZ     3684 non-null   object
#  10  EINHEIT_LANG     3684 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME        SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
#
#                SUBSET_NAME  INDIKATOR_ID  \
# 0  Betriebe Landwirtschaft           271
# 1  Betriebe Landwirtschaft           271
# 2  Betriebe Landwirtschaft           271
# 3  Betriebe Landwirtschaft           271
# 4  Betriebe Landwirtschaft           271
#
#                                    INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Hauptberufliche Landwirtschaftsbetriebe [Anz.]            1985
# 1  Hauptberufliche Landwirtschaftsbetriebe [Anz.]            1990
# 2  Hauptberufliche Landwirtschaftsbetriebe [Anz.]            1996
# 3  Hauptberufliche Landwirtschaftsbetriebe [Anz.]            2000
# 4  Hauptberufliche Landwirtschaftsbetriebe [Anz.]            2005
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0               30         Anz.       Anzahl
# 1               24         Anz.       Anzahl
# 2               18         Anz.       Anzahl
# 3               18         Anz.       Anzahl
# 4               15         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                            2121  \
# BFS_NR                                                      159
# GEBIET_NAME                                        Uetikon a.S.
# THEMA_NAME                               Arbeit und Unternehmen
# SET_NAME                                         Landwirtschaft
# SUBSET_NAME                             Betriebe Landwirtschaft
# INDIKATOR_ID                                                271
# INDIKATOR_NAME   Hauptberufliche Landwirtschaftsbetriebe [Anz.]
# INDIKATOR_JAHR                                             1985
# INDIKATOR_VALUE                                              16
# EINHEIT_KURZ                                               Anz.
# EINHEIT_LANG                                             Anzahl
#
#                                                            2820  \
# BFS_NR                                                      225
# GEBIET_NAME                                          Rickenbach
# THEMA_NAME                               Arbeit und Unternehmen
# SET_NAME                                         Landwirtschaft
# SUBSET_NAME                             Betriebe Landwirtschaft
# INDIKATOR_ID                                                271
# INDIKATOR_NAME   Hauptberufliche Landwirtschaftsbetriebe [Anz.]
# INDIKATOR_JAHR                                             2013
# INDIKATOR_VALUE                                              18
# EINHEIT_KURZ                                               Anz.
# EINHEIT_LANG                                             Anzahl
#
#                                                            3503
# BFS_NR                                                        0
# GEBIET_NAME                                  Region Knonaueramt
# THEMA_NAME                               Arbeit und Unternehmen
# SET_NAME                                         Landwirtschaft
# SUBSET_NAME                             Betriebe Landwirtschaft
# INDIKATOR_ID                                                271
# INDIKATOR_NAME   Hauptberufliche Landwirtschaftsbetriebe [Anz.]
# INDIKATOR_JAHR                                             2011
# INDIKATOR_VALUE                                             195
# EINHEIT_KURZ                                               Anz.
# EINHEIT_LANG                                             Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME        SET_NAME  \
# count          3684                    3684            3684
# unique          200                       1               1
# top     Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft
# freq             19                    3684            3684
#
#                     SUBSET_NAME  \
# count                      3684
# unique                        1
# top     Betriebe Landwirtschaft
# freq                       3684
#
#                                         INDIKATOR_NAME EINHEIT_KURZ  \
# count                                             3684         3684
# unique                                               1            1
# top     Hauptberufliche Landwirtschaftsbetriebe [Anz.]         Anz.
# freq                                              3684         3684
#
#        EINHEIT_LANG
# count          3684
# unique            1
# top          Anzahl
# freq           3684

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,684.00      3,684.00        3,684.00         3,684.00
# mean    107.53        271.00        2,008.58            59.14
# std      84.67          0.00            9.49           227.97
# min       0.00        271.00        1,985.00             0.00
# 25%      31.00        271.00        2,005.00             8.00
# 50%      94.00        271.00        2,011.00            16.00
# 75%     178.00        271.00        2,016.00            29.00
# max     298.00        271.00        2,020.00         4,915.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001660.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 16,883 rows (observations) and 32 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16883 entries, 0 to 16882
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Geschaeft                 16883 non-null  object
#  1   Einheit_Code              16883 non-null  object
#  2   Einheit_Name              16883 non-null  object
#  3   Einheit_BFS               16883 non-null  int64
#  4   Einheit_BFSSub            16883 non-null  int64
#  5   Kand_Nachname             16883 non-null  object
#  6   Kand_Vorname              16883 non-null  object
#  7   Kand_Ort                  16883 non-null  object
#  8   Kand_ID                   16883 non-null  int64
#  9   Liste_KandID              16883 non-null  int64
#  10  Liste_ID                  16883 non-null  int64
#  11  Liste_Code                16883 non-null  object
#  12  Liste_Bez                 16883 non-null  object
# ...

# %%
df.head()
# Out:
#                                  Geschaeft Einheit_Code  \
# 0  KR 2007 - Wahlkreis I, Stadt Zürich 1+2       ZHZP01
# 1  KR 2007 - Wahlkreis I, Stadt Zürich 1+2       ZHZP01
# 2  KR 2007 - Wahlkreis I, Stadt Zürich 1+2       ZHZP01
# 3  KR 2007 - Wahlkreis I, Stadt Zürich 1+2       ZHZP01
# 4  KR 2007 - Wahlkreis I, Stadt Zürich 1+2       ZHZP01
#
#               Einheit_Name  Einheit_BFS  Einheit_BFSSub Kand_Nachname  \
# 0  Stadt Zürich, Kreis 1+2          261               1      Bachmann
# 1  Stadt Zürich, Kreis 1+2          261               1         Combe
# 2  Stadt Zürich, Kreis 1+2          261               1     Schlatter
# 3  Stadt Zürich, Kreis 1+2          261               1        Schmid
# 4  Stadt Zürich, Kreis 1+2          261               1          Grob
#
#   Kand_Vorname Kand_Ort  Kand_ID  Liste_KandID  ...  02.SP 03.FDP 04.GRÜNE  \
# 0        Ernst   Zürich        1           101  ...     23    118        1
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                       2327   \
# Geschaeft                 KR 2007 - Wahlkreis VII, Dietikon
# Einheit_Code                                          ZH241
# Einheit_Name                                          Aesch
# Einheit_BFS                                             241
# Einheit_BFSSub                                          241
# Kand_Nachname                                      Zirngast
# Kand_Vorname                                         Marcel
# Kand_Ort                                             Urdorf
# Kand_ID                                                   2
# Liste_KandID                                            602
# Liste_ID                                                  6
# Liste_Code                                              EVP
# Liste_Bez                    Evangelische Volkspartei (EVP)
# Liste_WZUnveraendert                                      4
# Liste_WZVeraendert                                        4
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                                Geschaeft Einheit_Code Einheit_Name  \
# count                              16883        16883        16883
# unique                                18          185          185
# top     KR 2007 - Wahlkreis XVII, Bülach        ZH191    Dübendorf
# freq                                3190          150          150
#
#        Kand_Nachname Kand_Vorname Kand_Ort Liste_Code  \
# count          16883        16883    16883      16883
# unique          1233          594      200         11
# top           Schmid        Peter   Zürich        SVP
# freq             234          464     1270       1897
#
#                                Liste_Bez
# count                              16883
# unique                                11
# top     Schweizerische Volkspartei (SVP)
# freq                                1897

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Einheit_BFS  Einheit_BFSSub   Kand_ID  Liste_KandID  Liste_ID  \
# count    16,883.00       16,883.00 16,883.00     16,883.00 16,883.00
# mean        137.12          113.56      6.19        521.94      5.16
# std          74.18           74.21      4.07        284.11      2.84
# min           1.00            1.00      1.00        101.00      1.00
# 25%          69.00           57.00      3.00        303.00      3.00
# 50%         135.00          111.00      5.00        506.00      5.00
# 75%         199.00          176.00      9.00        709.00      7.00
# max         261.00          251.00     17.00      1,101.00     11.00
#
#        Liste_WZUnveraendert  Liste_WZVeraendert  Kand_StimmenPanaschiert  \
# count             16,883.00           16,883.00                16,883.00
# mean                 103.74               81.45                    13.91
# std                  196.82              126.20                    36.76
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

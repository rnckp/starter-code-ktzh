# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: COVID_19 Gesellschaftsmonitoring des Kantons Zürich

# %% [markdown]
# ### **Description**: Datenreihen zu verschiedenen Indikatoren – die meisten auf Tagesbasis – können dabei helfen, besser zu verstehen, wie die Bevölkerung auf die COVID-19-Pandemie und die behördlichen Massnahmen zu ihrer Bewältigung reagiert hat. Verzeichnis aller Indikatoren und Spezifikation der Datenstruktur im Readme unter "Weiterführende Informationen".

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **740@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-10-04T00:00:00`
# - **Modified** `2021-10-25T11:18:00`
# - **Startdate** `2018-01-01`
# - **Enddate** `None`
# - **Theme** `['Bildung, Wissenschaft', 'Energie', 'Gesundheit', 'Industrie, Dienstleistungen', 'Mobilität und Verkehr', 'Volkswirtschaft', 'Soziale Sicherheit', 'Raum, Umwelt', 'Arbeit, Erwerb', 'Volkswirtschaft']`
# - **Keyword** `['arbeitslose', 'ausbildung', 'bahn', 'berufslehre', 'bildung', 'bus', 'energie', 'familienberatung', 'flugbewegungen', 'flughafen', 'flugverkehr', 'gesundheit', 'gesundheitszustand', 'handelsregister', 'internetnutzung', 'jugendberatung', 'kinder', 'kinderbetreuung', 'kindergarten', 'kinderkrippen', 'kleinkinderbetreuung', 'konkurse', 'konsum', 'langsamverkehr', 'lehrlinge', 'luftverkehr', 'medien', 'oeffentlicher_verkehr', 'oeffentliche_schulen', 'primarschule', 'psychosozial', 's-bahn', 'soziales', 'stellensuchende', 'strassenverkehr', 'strassenverkehrszaehlung', 'suchtprobleme', 'todesfaelle', 'verkehr', 'verkehrsfrequenz', 'verkehrsmittelwahl', 'volkswirtschaft', 'vorschulstufe', 'wirtschaft', 'corona', 'covid-19', 'sars-cov-2', 'mobilitaet', 'covid19', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://github.com/statistikZH/covid19monitoring`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1886
# Title                    : Daten aller Indikatoren im COVID_19 Gesellschaftsmonitoring des Kantons Zürich
# Description              : Variabeln: 'date' = Datum der Erhebung; 'value' = erhobener Wert; 'topic' = thematische Kategorie des Indikators (Liste aller Indikatoren siehe Readme unter "Weiterführende Informationen"); 'variable_short' = Kurzbezeichnung des Indikators (kein String); 'variable_long' = längere Bezeichnung des Indikators (String); 'location' = räumlicher Bezug der Erhebung, 'unit' = Masseinheit des erhobenen Werts; 'source' = Quelle der erhobenen Daten, 'update' = Aktualisierungsfrequenz, 'public' = Status der Veröffentlichung (ja/nein), 'description' = URL mit Beschreibung zur Grundlage der jeweiligen Datenerhebung, Hinweisen zur Methodik sowie Weiteren Informationen.
# Issued                   : 2021-10-04T17:04:16
# Modified                 : 2021-10-25T11:18:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/covid19monitoring/master/covid19socialmonitoring.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/covid19monitoring/master/covid19socialmonitoring.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1887
# Title                    : Metadaten aller Indikatoren im COVID_19 Gesellschaftsmonitoring des Kantons Zürich
# Description              : Variabeln: 'id' = Kombination von 'variable_short' und 'location' ergibt eindeutigen Identifkator; 'topic' = thematische Kategorie des Indikators; 'variable_short' = Kurzbezeichnung des Indikators (kein String); 'variable_long' = längere Bezeichnung des Indikators (String); 'location' = räumlicher Bezug der Erhebung, 'unit' = Masseinheit des erhobenen Werts; 'source' = Quelle der erhobenen Daten, 'update' = Aktualisierungsfrequenz, 'public' = Status der Veröffentlichung (ja/nein), 'description' = URL mit Beschreibung zur Grundlage der jeweiligen Datenerhebung, Hinweisen zur Methodik sowie Weiteren Informationen; 'last_modified' = Datum der letzten Aktualisierung; 'date_first_obs' = Startdatum der Zeitreihe (d.i. die erste erhobene Beobachtung); 'date_last_obs' = Enddatum der Zeitreihe (d.i. die letzte erhobene Beobachtung); 'sort' = alphabetische Sortierungsvariable nach 'topic' und 'variable_long'.
# Issued                   : 2021-10-04T17:38:30
# Modified                 : 2021-10-25T11:18:07
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/covid19monitoring/master/Metadata.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/statistikZH/covid19monitoring/master/Metadata.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 625 rows (observations) and 14 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              625 non-null    object
#  1   topic           625 non-null    object
#  2   variable_short  625 non-null    object
#  3   variable_long   625 non-null    object
#  4   location        625 non-null    object
#  5   unit            625 non-null    object
#  6   source          625 non-null    object
#  7   update          625 non-null    object
#  8   public          625 non-null    object
#  9   description     625 non-null    object
#  10  last_modified   625 non-null    object
#  11  date_first_obs  625 non-null    object
#  12  date_last_obs   625 non-null    object
#  13  sort            625 non-null    float64
# dtypes: float64(1), object(13)
# memory usage: 740.4 KB

# %%
df.head()
# Out:
#                                               id      topic  \
# 0                    tages_distanz_mittelwert_CH  Mobilität
# 1               tages_distanz_mittelwert_CH-Land  Mobilität
# 2              tages_distanz_mittelwert_CH-Urban  Mobilität
# 3        tages_distanz_mittelwert_Deutschschweiz  Mobilität
# 4  tages_distanz_mittelwert_italienische_Schweiz  Mobilität
#
#              variable_short                    variable_long  \
# 0  tages_distanz_mittelwert   durchschnittliche Tagesdistanz
# 1  tages_distanz_mittelwert   durchschnittliche Tagesdistanz
# 2  tages_distanz_mittelwert   durchschnittliche Tagesdistanz
# 3  tages_distanz_mittelwert   durchschnittliche Tagesdistanz
# 4  tages_distanz_mittelwert   durchschnittliche Tagesdistanz
#
#                location unit                     source   update public  \
# 0                    CH   km  intervista Tracking-panel  täglich     ja
# 1               CH-Land   km  intervista Tracking-panel  täglich     ja
# 2              CH-Urban   km  intervista Tracking-panel  täglich     ja
# 3        Deutschschweiz   km  intervista Tracking-panel  täglich     ja
# 4  italienische Schweiz   km  intervista Tracking-panel  täglich     ja
#
#                                          description last_modified  \
# 0  https://github.com/statistikZH/covid19monitori...    2022-05-12
# 1  https://github.com/statistikZH/covid19monitori...    2022-05-12
# 2  https://github.com/statistikZH/covid19monitori...    2022-05-12
# 3  https://github.com/statistikZH/covid19monitori...    2022-05-12
# 4  https://github.com/statistikZH/covid19monitori...    2022-05-12
#
#   date_first_obs date_last_obs   sort
# 0     2020-01-01    2021-07-04  1.001
# 1     2020-01-01    2021-07-04  1.002
# 2     2020-01-01    2021-07-04  1.003
# 3     2020-01-01    2021-07-04  1.004
# 4     2020-01-01    2021-07-04  1.005

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               157  \
# id                                          konk_eroeff_noga_M_AG
# topic                                                  Wirtschaft
# variable_short                                 konk_eroeff_noga_M
# variable_long   Anzahl Eröffnungen erstmaliger Konkursverfahre...
# location                                                       AG
# unit                                                       Anzahl
# source                                    SHAB via Moneyhouse API
# update                                                wöchentlich
# public                                                         ja
# description     https://github.com/statistikZH/covid19monitori...
# last_modified                                          2022-05-12
# date_first_obs                                         2017-01-03
# date_last_obs                                          2022-05-02
# sort                                                         2.07
#
#                                                               101  \
# id                                          konk_eroeff_noga_F_JU
# topic                                                  Wirtschaft
# variable_short                                 konk_eroeff_noga_F
# variable_long   Anzahl Eröffnungen erstmaliger Konkursverfahre...
# location                                                       JU
# unit                                                       Anzahl
# source                                    SHAB via Moneyhouse API
# update                                                wöchentlich
# public                                                         ja
# description     https://github.com/statistikZH/covid19monitori...
# last_modified                                          2022-05-12
# date_first_obs                                         2017-01-03
# date_last_obs                                          2022-05-02
# sort                                                        2.014
#
#                                                               281
# id                                          konk_eroeff_noga_Q_AI
# topic                                                  Wirtschaft
# variable_short                                 konk_eroeff_noga_Q
# variable_long   Anzahl Eröffnungen erstmaliger Konkursverfahre...
# location                                                       AI
# unit                                                       Anzahl
# source                                    SHAB via Moneyhouse API
# update                                                wöchentlich
# public                                                         ja
# description     https://github.com/statistikZH/covid19monitori...
# last_modified                                          2022-05-12
# date_first_obs                                         2017-01-03
# date_last_obs                                          2022-05-02
# sort                                                        2.194

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                                  id       topic      variable_short  \
# count                           625         625                 625
# unique                          625           6                 187
# top     tages_distanz_mittelwert_CH  Wirtschaft  konk_eroeff_noga_F
# freq                              1         463                  26
#
#                                             variable_long location    unit  \
# count                                                 625      625     625
# unique                                                187       44      24
# top     Anzahl Eröffnungen erstmaliger Konkursverfahre...       CH  Anzahl
# freq                                                   26       92     498
#
#                          source       update public  \
# count                       625          625    625
# unique                       22            3      3
# top     SHAB via Moneyhouse API  wöchentlich     ja
# freq                        433          457    601
#
#                                               description last_modified  \
# count                                                 625           625
# unique                                                 21             1
# top     https://github.com/statistikZH/covid19monitori...    2022-05-12
# freq                                                  433           625
#
#        date_first_obs date_last_obs
# count             625           625
# unique             14            23
# top        2017-01-03    2022-05-02
# freq              433           433

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         sort
# count 625.00
# mean    2.26
# std     0.81
# min     1.00
# 25%     2.07
# 50%     2.23
# 75%     2.38
# max     6.01

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Analysen & Studien | peter.moser@statistik.ji.zh.ch

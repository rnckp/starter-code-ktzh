# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung der Stadt Winterthur nach Alter, Geschlecht und Herkunft ab 2021

# %% [markdown]
# ### **Description**: Bestand der wirtschaftlichen Wohnbevölkerung nach Alter (5-Jahres-Altersgruppen), Geschlecht und Herkunft (Schweiz / Ausland) per Ende Jahr.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1521@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T16:55:57`
# - **Modified** `2022-09-21T10:07:56`
# - **Startdate** `2021-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['alter', 'altersgruppen', 'altersklassen', 'altersstruktur', 'bevoelkerung', 'bevoelkerungswachstum', 'gemeinden', 'nationalitaet', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/bevoelkerung`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2899
# Title                    : Alter, Geschlecht, Herkunft der Einwohner:innen der Stadt Winterthur nach Jahr
# Description              : Variablen: 'AK' = 5-Jahres-Altersklassen; 'TotalMann' = Gesamtzahl Männer; 'TotalFrau' = Gesamtzahl Frauen; 'SchweizMann' = Anzahl männliche Schweizer Staatsbürger; 'SchweizFrau' = Anzahl weibliche Schweizer Staatsbürger; 'AuslandMann' = Anzahl männliche Ausländer; 'AuslandFrau' = Anzahl weibliche Ausländerinnen.
# Issued                   : 2022-09-20T16:55:57
# Modified                 : 2022-09-20T16:55:57
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001521_00002899.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001521_00002899.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 20 rows (observations) and 8 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Jahr         20 non-null     int64
#  1   AK           20 non-null     object
#  2   TotalMann    20 non-null     int64
#  3   TotalFrau    20 non-null     int64
#  4   SchweizMann  20 non-null     int64
#  5   SchweizFrau  20 non-null     int64
#  6   AuslandMann  20 non-null     int64
#  7   AuslandFrau  20 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.4 KB

# %%
df.head()
# Out:
#    Jahr    AK  TotalMann  TotalFrau  SchweizMann  SchweizFrau  AuslandMann  \
# 0  2021    04       3246       3012         2434         2237          812
# 1  2021    59       3025       2944         2206         2126          819
# 2  2021  1014       2951       2739         2215         2074          736
# 3  2021  1519       2817       2610         2208         2134          609
# 4  2021  2024       3599       3726         2742         3030          857
#
#    AuslandFrau
# 0          775
# 1          818
# 2          665
# 3          476
# 4          696

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                11    8     9
# Jahr         2021  2021  2021
# AK           5559  4044  4549
# TotalMann    3853  4336  3734
# TotalFrau    3881  4106  3695
# SchweizMann  2907  2748  2455
# SchweizFrau  3080  2703  2582
# AuslandMann   946  1588  1279
# AuslandFrau   801  1403  1113

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         AK
# count   20
# unique  20
# top     04
# freq     1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  TotalMann  TotalFrau  SchweizMann  SchweizFrau  AuslandMann  \
# count    20.00      20.00      20.00        20.00        20.00        20.00
# mean  2,021.00   2,897.05   2,967.40     2,128.35     2,269.50       768.70
# std       0.00   1,543.28   1,365.74     1,037.71       925.49       544.42
# min   2,021.00      51.00     192.00        47.00       182.00         4.00
# 25%   2,021.00   1,847.25   2,362.75     1,564.25     2,048.50       283.00
# 50%   2,021.00   3,027.50   2,978.00     2,295.00     2,226.00       774.00
# 75%   2,021.00   3,814.75   3,784.25     2,743.50     2,868.50     1,138.00
# max   2,021.00   5,467.00   5,168.00     3,790.00     3,830.00     1,740.00
#
#        AuslandFrau
# count        20.00
# mean        697.90
# std         500.95
# min          10.00
# 25%         286.50
# 50%         680.50
# 75%         978.00
# max       1,628.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

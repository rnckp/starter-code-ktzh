# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich ab 2015

# %% [markdown]
# ### **Description**: Die Abteilung «Data Shop» des Statistischen Amts ist die Anlaufstelle für alle Fragen zu statistischen Informationen. Das Team bewirtschaftet das statistische Grundangebot des Kanton Zürich und bietet Nutzenden kostenlose Auskunft und Beratung zu Anfragen per Telefon oder E-Mail. Seit 2015 werden Anfragen mit Metadaten erfasst und in einer Anfragenstatistik archiviert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **698@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-08-24T00:00:00`
# - **Modified** `2023-01-01T04:28:08`
# - **Startdate** `2015-01-05`
# - **Enddate** `2022-12-23`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3668
# Title                    : Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich ab 2015
# Description              : NA
# Issued                   : 2022-12-02T12:18:50
# Modified                 : 2023-01-01T05:28:14
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003668.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003668.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3669
# Title                    : Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich - kontrollierte Vokabulare
# Description              : NA
# Issued                   : 2022-12-19T13:20:10
# Modified                 : 2023-01-01T05:28:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003669.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003669.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 71 rows (observations) and 2 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   variable   71 non-null     object
#  1   kategorie  71 non-null     object
# dtypes: object(2)
# memory usage: 9.6 KB

# %%
df.head()
# Out:
#      variable              kategorie
# 0  anfragetyp                Anderes
# 1  anfragetyp     Datenverfügbarkeit
# 2  anfragetyp      Einzeldaten (DSV)
# 3  anfragetyp                    GIS
# 4  anfragetyp  Interne Weiterleitung

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                           16           44       22
# variable           nutzertyp  mitarbeiter    thema
# kategorie  Politische Partei          M01  Bildung

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#            variable kategorie
# count            71        71
# unique            5        71
# top     mitarbeiter   Anderes
# freq             27         1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(include='number'))
    except:
        print("No numerical data in this distribution")
# Out:
# No numerical data in this distribution

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, layout=(-1, 5), edgecolor='black');
except:
    print("No numerical data in this distribution.")
# Out:
# No numerical data in this distribution.

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich ab 2015

# %% [markdown]
# ### **Description**: Die Abteilung «Data Shop» des Statistischen Amts ist die Anlaufstelle für alle Fragen zu statistischen Informationen. Das Team bewirtschaftet das statistische Grundangebot des Kanton Zürich und bietet Nutzenden kostenlose Auskunft und Beratung zu Anfragen per Telefon oder E-Mail. Seit 2015 werden Anfragen mit Metadaten erfasst und in einer Anfragenstatistik archiviert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **698@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-08-24T00:00:00`
# - **Modified** `2023-01-01T04:28:08`
# - **Startdate** `2015-01-05`
# - **Enddate** `2022-12-23`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3669
# Title                    : Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich - kontrollierte Vokabulare
# Description              : NA
# Issued                   : 2022-12-19T13:20:10
# Modified                 : 2023-01-01T05:28:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003669.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003669.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3668
# Title                    : Anfragestatistik des Data Shop im Statistischen Amt des Kantons Zürich ab 2015
# Description              : NA
# Issued                   : 2022-12-02T12:18:50
# Modified                 : 2023-01-01T05:28:14
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003668.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000698_00003668.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 9,173 rows (observations) and 7 columns (variables).
# There seem to be 1 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9173 entries, 0 to 9172
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   erfassung    9173 non-null   object
#  1   nutzertyp    9173 non-null   object
#  2   anfragetyp   9173 non-null   object
#  3   thema        9173 non-null   object
#  4   kanal        9173 non-null   object
#  5   zeitaufwand  4991 non-null   float64
#  6   mitarbeiter  9173 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 4.3 MB

# %%
df.head()
# Out:
#              erfassung                                  nutzertyp  \
# 0  2022-12-23 11:09:08  Verwaltung (kommunal, kantonal, national)
# 1  2022-12-22 14:00:37                          Politische Partei
# 2  2022-12-22 08:13:49                                      Firma
# 3  2022-12-22 08:08:13  Verwaltung (kommunal, kantonal, national)
# 4  2022-12-22 08:05:01                                     Medien
#
#                anfragetyp                          thema            kanal  \
# 0      Datenverfügbarkeit                   Raumstruktur            Email
# 1   Interne Weiterleitung  Wahlen, Abstimmungen, Politik          Telefon
# 2      Datenverfügbarkeit                    Bevölkerung            Email
# 3      Datenverfügbarkeit                    Bevölkerung  Kontaktformular
# 4  Weiterleitung, Verweis                        Verkehr            Email
#
#    zeitaufwand mitarbeiter
# 0         20.0         M01
# 1          2.0         M02
# 2         10.0         M03
# 3          5.0         M02
# 4          5.0         M03

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                             1587                                       6538  \
# erfassung    2021-05-21 16:25:14                        2017-01-19 10:11:19
# nutzertyp                 Medien  Verwaltung (kommunal, kantonal, national)
# anfragetyp         Verifizierung                         Datenverfügbarkeit
# thema                    Verkehr                                Bevölkerung
# kanal                    Telefon                                      Email
# zeitaufwand                 60.0                                        NaN
# mitarbeiter                  M15                                        M25
#
#                                 6054
# erfassung        2017-06-13 10:59:05
# nutzertyp               Privatperson
# anfragetyp        Datenverfügbarkeit
# thema        Boden-/Immobilienpreise
# kanal                        Telefon
# zeitaufwand                      NaN
# mitarbeiter                      M16

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                   erfassung     nutzertyp          anfragetyp        thema  \
# count                  9173          9173                9173         9173
# unique                 9171            10                  10           21
# top     2015-11-20 10:09:35  Privatperson  Datenverfügbarkeit  Bevölkerung
# freq                      2          2562                6197         1826
#
#           kanal mitarbeiter
# count      9173        9173
# unique        3          27
# top     Telefon         M16
# freq       5265        2281

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        zeitaufwand
# count     4,991.00
# mean         25.85
# std          95.08
# min           0.00
# 25%           5.00
# 50%          15.00
# 75%          20.00
# max       5,280.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

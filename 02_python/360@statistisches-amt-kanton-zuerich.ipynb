# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anteil Gewässerfläche [%]

# %% [markdown]
# ### **Description**: Anteil stehender und fliessender Gewässer an der Gesamtfläche ohne Zürichsee (5976 ha auf Kantonsgebiet) und Greifensee (829 ha; jeweils Punktfläche). Die Arealstatistiken werden ca. alle 10 Jahre erhoben. Die letzten vier fanden zwischen 1979-1985, 1992-1997, 2004-2009 und 2013-2018 statt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **360@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-08-20T16:05:49`
# - **Startdate** `1983-12-31`
# - **Enddate** `2018-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['bezirke', 'flaeche', 'gemeinden', 'geographie', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 281
# Title                    : Anteil Gewässerfläche [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-08-20T16:05:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_185.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_185.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 792 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           792 non-null    int64
#  1   GEBIET_NAME      792 non-null    object
#  2   THEMA_NAME       792 non-null    object
#  3   SET_NAME         792 non-null    object
#  4   SUBSET_NAME      792 non-null    object
#  5   INDIKATOR_ID     792 non-null    int64
#  6   INDIKATOR_NAME   792 non-null    object
#  7   INDIKATOR_JAHR   792 non-null    int64
#  8   INDIKATOR_VALUE  792 non-null    float64
#  9   EINHEIT_KURZ     792 non-null    object
#  10  EINHEIT_LANG     792 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 504.7 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME       THEMA_NAME             SET_NAME SUBSET_NAME  \
# 0       1     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
# 1       1     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
# 2       1     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
# 3       1     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
# 4       2  Affoltern a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
#
#    INDIKATOR_ID             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           185  Anteil Gewässerfläche [%]            1985              3.8
# 1           185  Anteil Gewässerfläche [%]            1997              3.8
# 2           185  Anteil Gewässerfläche [%]            2009              3.8
# 3           185  Anteil Gewässerfläche [%]            2018              3.8
# 4           185  Anteil Gewässerfläche [%]            1985              0.0
#
#   EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                        324                        360  \
# BFS_NR                                 102                        119
# GEBIET_NAME                         Weiach                  Seegräben
# THEMA_NAME                 Raum und Umwelt            Raum und Umwelt
# SET_NAME               Geographie, Flächen        Geographie, Flächen
# SUBSET_NAME                        Flächen                    Flächen
# INDIKATOR_ID                           185                        185
# INDIKATOR_NAME   Anteil Gewässerfläche [%]  Anteil Gewässerfläche [%]
# INDIKATOR_JAHR                        1985                       1985
# INDIKATOR_VALUE                        2.2                       10.8
# EINHEIT_KURZ                             %                          %
# EINHEIT_LANG                       Prozent                    Prozent
#
#                                        347
# BFS_NR                                 115
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME             SET_NAME SUBSET_NAME  \
# count           792              792                  792         792
# unique          200                1                    1           1
# top     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen     Flächen
# freq              4              792                  792         792
#
#                    INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                         792          792          792
# unique                          1            1            1
# top     Anteil Gewässerfläche [%]            %      Prozent
# freq                          792          792          792

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  792.00        792.00          792.00           792.00
# mean   110.28        185.00        2,002.04             1.22
# std     86.90          0.00           12.43             1.69
# min      0.00        185.00        1,983.00             0.00
# 25%     32.00        185.00        1,985.00             0.30
# 50%     95.50        185.00        1,997.00             0.60
# 75%    180.25        185.00        2,009.00             1.50
# max    298.00        185.00        2,018.00            11.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

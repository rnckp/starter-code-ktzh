# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lernende der Volksschule im Kanton Zürich nach Staatsangehörigkeit auf Ebene Schulgemeinde ab 2000

# %% [markdown]
# ### **Description**: Schüler/innen an öffentlichen Volksschulen im Kanton Zürich, die nach kantonalem Lehrplan unterrichtet werden. Mit Volksschule wird die Schulbildung während der obligatorischen Schulzeit bezeichnet. Die obligatorische Schulzeit umfasst den Kindergarten, sechs Jahre Primarschule und drei Jahre Sekundarstufe I. Nicht mitgezählt sind Lernende der Mittelschulen, Lernende in in Heim-/Sonderschulen, und Lernende in Privatschulen. Es gilt das Schulortprinzip, gezählt werden Schülerinnen und Schüler, welche eine Schule innerhalb des Kantons Zürich besuchen.
#
# Die Daten werden jährlich für den Stichtag 15.9. erhoben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **525@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-12-02T13:12:00`
# - **Modified** `2022-10-21T15:11:34`
# - **Startdate** `2000-09-15`
# - **Enddate** `2021-09-15`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['ausbildung', 'bildung', 'kindergarten', 'lernende', 'nationalitaet', 'primarschule', 'schueler', 'schuelerinnen', 'schulgemeinden', 'sekundarstufe', 'staatsangehoerigkeit', 'volksschule', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3018
# Title                    : Lernende der Volksschule im Kanton Zürich nach Staatsangehörigkeit auf Ebene Schulgemeinde ab 2000
# Description              : Die Daten sind differenziert nach Jahr, zuständiger Schulgemeinde und Staatsangehörigkeit. Bei Zellen kleiner 5 wird die Staatsangehörigkeit zuerst auf Ebene Grossregion und, wenn nötig, auf Ebene Kontinent aggregiert. Jahr: Das Jahr ist jeweils das Kalenderjahr der Erhebung, wobei der Stichtag der 15.9. ist. Die Daten für das Jahr 2021 sind somit im Schuljahr 2021/22 erhoben worden und zeigen den Datenstand am 15. September 2021. Schulgemeinde: Es wird die zuständige Schulgemeinde dargestellt. Das ist üblicherweise die Schulgemeinde des Wohnort. Es entspricht aber nicht in jedem Fall der Schulgemeinde des Schulstandorts der effektiv besucht wird. Staatsangehoerigkeit: Es wird pro Person nur eine Staatsangehörigkeit erhoben. Falls eine Person mehrere Staatsangehörigkeiten hat, und eine davon ist die Schweizerische, so wird diese prioritär erfasst. Bei anderen mehrfachen Staatsangehörigkeiten wir keine Vorgabe zur Priorisierung gemacht. Staatsangehoerigkeit_ISO2_Code: Bei der Aggregation auf Grossregion und Kontinent bleibt der ISO2 Code leer. Anzahl: Anzahl der Schülerinnen und Schüler mit der entsprechenden Merkmalskombination.
# Issued                   : 2022-10-03T12:38:04
# Modified                 : 2022-10-21T15:11:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Regional_Staatsangehoerigkeit.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Regional_Staatsangehoerigkeit.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 51,503 rows (observations) and 7 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51503 entries, 0 to 51502
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Stand                           51503 non-null  object
#  1   Kanton                          51503 non-null  object
#  2   Jahr                            51503 non-null  int64
#  3   Schulgemeinde                   51503 non-null  object
#  4   Staatsangehoerigkeit            51503 non-null  object
#  5   Staatsangehoerigkeit_ISO2_Code  28043 non-null  object
#  6   Anzahl                          51503 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 19.5 MB

# %%
df.head()
# Out:
#         Stand Kanton  Jahr Schulgemeinde   Staatsangehoerigkeit  \
# 0  2022-10-21     zh  2021       Adlikon                Schweiz
# 1  2022-10-21     zh  2021       Adlikon  Restliches Westeuropa
# 2  2022-10-21     zh  2021       Adlikon       Restliches Asien
# 3  2022-10-21     zh  2021       Adlikon      Restliches Europa
# 4  2022-10-21     zh  2021      Adliswil                Schweiz
#
#   Staatsangehoerigkeit_ISO2_Code   Anzahl
# 0                             CH       44
# 1                            NaN        7
# 2                            NaN  1 bis 5
# 3                            NaN  1 bis 5
# 4                             CH     1068

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             37590       26026  \
# Stand                                  2022-10-21  2022-10-21
# Kanton                                         zh          zh
# Jahr                                         2006        2011
# Schulgemeinde                             Opfikon      Lindau
# Staatsangehoerigkeit            Restliches Europa      Kosovo
# Staatsangehoerigkeit_ISO2_Code                NaN          XK
# Anzahl                                         10           9
#
#                                                     4928
# Stand                                          2022-10-21
# Kanton                                                 zh
# Jahr                                                 2020
# Schulgemeinde                   Winterthur-Oberwinterthur
# Staatsangehoerigkeit                Restliches Westafrika
# Staatsangehoerigkeit_ISO2_Code                        NaN
# Anzahl                                                  9

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#              Stand Kanton   Schulgemeinde Staatsangehoerigkeit  \
# count        51503  51503           51503                51503
# unique           1      1             227                  120
# top     2022-10-21     zh  Zürich-Glattal              Schweiz
# freq         51503  51503            1216                 4085
#
#        Staatsangehoerigkeit_ISO2_Code   Anzahl
# count                           28043    51503
# unique                             80     1361
# top                                CH  1 bis 5
# freq                             4085     8975

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#            Jahr
# count 51,503.00
# mean   2,011.02
# std        6.35
# min    2,000.00
# 25%    2,006.00
# 50%    2,011.00
# 75%    2,017.00
# max    2,021.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

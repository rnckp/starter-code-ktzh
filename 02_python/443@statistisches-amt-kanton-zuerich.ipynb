# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Abstimmungsempfehlungen von Kantonsrat und Regierungsrat des Kantons Zürich

# %% [markdown]
# ### **Description**: Abstimmungsempfehlungen des Zürcher Regierungs- und Kantonsrats zu kantonalen Abstimmungen und des Bundes-, des National- und des Ständerates zu eidgenössischen Abstimmungen. Es besteht kein Anspruch auf Vollständigkeit. Bitte senden Sie Ergänzungen zum Datensatz an die unter Kontakt angegebene E-Mail-Adresse.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **443@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-07-02T00:00:00`
# - **Modified** `2022-08-26T13:33:22`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Politik']`
# - **Keyword** `['abstimmungen', 'eidgenoessische_volksabstimmungen', 'kantonale_volksabstimmungen', 'kantonsrat', 'politik', 'regierungsrat', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 748
# Title                    : Abstimmungsempfehlungen von Kantonsrat und Regierungsrat des Kantons Zürich
# Description              : None
# Issued                   : 2019-07-02T15:41:05
# Modified                 : 2022-11-30T07:53:48
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsempfehlungen.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsempfehlungen.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,068 rows (observations) and 16 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068 entries, 0 to 2067
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ABSTIMMTAG          2068 non-null   object
#  1   STAT_VORLAGE_ID     2068 non-null   int64
#  2   BFS_VORLAGE_ID      1213 non-null   float64
#  3   VORLAGE_KURZBEZ     2068 non-null   object
#  4   VORLAGE_LANGBEZ     2068 non-null   object
#  5   VORLAGENART_ID      2068 non-null   int64
#  6   VORLAGENART_BEZ     2068 non-null   object
#  7   THEMA_ID            2031 non-null   object
#  8   THEMA               2031 non-null   object
#  9   ABSTIMMUNGSART_ID   2068 non-null   int64
#  10  ABSTIMMUNGSART_BEZ  2068 non-null   object
#  11  RAT_ID              2068 non-null   int64
#  12  RAT_BEZEICHNUNG     2068 non-null   object
#  13  STUFE               2068 non-null   object
#  14  PAROLE_ID           2068 non-null   int64
# ...

# %%
df.head()
# Out:
#              ABSTIMMTAG  STAT_VORLAGE_ID  BFS_VORLAGE_ID  \
# 0  1981-04-05T00:00:00Z              713           305.0
# 1  1981-04-05T00:00:00Z              713           305.0
# 2  1981-04-05T00:00:00Z              713           305.0
# 3  1981-04-05T00:00:00Z             1708             NaN
# 4  1981-04-05T00:00:00Z             1708             NaN
#
#                                      VORLAGE_KURZBEZ  \
# 0  Volksinitiative «Mitenand-Initiative für eine ...
# 1  Volksinitiative «Mitenand-Initiative für eine ...
# 2  Volksinitiative «Mitenand-Initiative für eine ...
# 3  Gesetz über die Organisation und die Geschäfts...
# 4  Gesetz über die Organisation und die Geschäfts...
#
#                                      VORLAGE_LANGBEZ  VORLAGENART_ID  \
# 0  Volksinitiative «Mitenand-Initiative für eine ...               3
# 1  Volksinitiative «Mitenand-Initiative für eine ...               3
# 2  Volksinitiative «Mitenand-Initiative für eine ...               3
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                  1411  \
# ABSTIMMTAG                                       2011-05-15T00:00:00Z
# STAT_VORLAGE_ID                                                   333
# BFS_VORLAGE_ID                                                    NaN
# VORLAGE_KURZBEZ                                Finanzausgleichsgesetz
# VORLAGE_LANGBEZ     Beschluss des Regierungsrates vom 19. Januar 2...
# VORLAGENART_ID                                                     10
# VORLAGENART_BEZ                Konstruktives Referendum: Hauptvorlage
# THEMA_ID                                                            6
# THEMA                                            Öffentliche Finanzen
# ABSTIMMUNGSART_ID                                                   1
# ABSTIMMUNGSART_BEZ                                           kantonal
# RAT_ID                                                              4
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                   ABSTIMMTAG VORLAGE_KURZBEZ VORLAGE_LANGBEZ  \
# count                   2068            2068            2068
# unique                   159             766             775
# top     2021-06-13T00:00:00Z      Asylgesetz      Asylgesetz
# freq                      40               9               6
#
#                    VORLAGENART_BEZ THEMA_ID                           THEMA  \
# count                         2068     2031                            2031
# unique                          10       72                              72
# top     Obligatorisches Referendum       10  Soziale Fragen – Sozialpolitik
# freq                           730      307                             307
#
#        ABSTIMMUNGSART_BEZ RAT_BEZEICHNUNG STUFE PAROLENAME
# count                2068            2068  2068       1921
# unique                  2               5     2          5
# top         eidgenössisch   Regierungsrat  EIDG         Ja
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        STAT_VORLAGE_ID  BFS_VORLAGE_ID  VORLAGENART_ID  ABSTIMMUNGSART_ID  \
# count         2,068.00        1,213.00        2,068.00           2,068.00
# mean          1,213.35       16,276.13            2.33               1.55
# std           1,019.52       54,808.64            1.78               0.50
# min               1.00          305.00            1.00               1.00
# 25%             181.00          404.00            1.00               1.00
# 50%           1,728.00          507.00            2.00               2.00
# 75%           2,398.25          610.00            3.00               2.00
# max           2,562.00      237,561.00           13.00               2.00
#
#         RAT_ID  PAROLE_ID
# count 2,068.00   2,068.00
# mean      3.12       8.37
# std       1.42      25.09
# min       1.00       1.00
# 25%       2.00       1.00
# 50%       3.00       1.00
# 75%       4.00       2.00
# max       5.00      99.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

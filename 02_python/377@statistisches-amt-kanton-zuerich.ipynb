# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: NRW Wähleranteil CVP [%]

# %% [markdown]
# ### **Description**: Wähleranteil CVP bei Nationalratswahlen. Hinweis: 2015 werden alle Auslandschweizer zur Stadt Zürich gezählt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **377@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-10-21T10:29:00`
# - **Startdate** `1991-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'nationalratswahlen', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 296
# Title                    : NRW Wähleranteil CVP [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-10-21T10:29:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_120.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_120.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,536 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1536 non-null   int64
#  1   GEBIET_NAME      1536 non-null   object
#  2   THEMA_NAME       1536 non-null   object
#  3   SET_NAME         1536 non-null   object
#  4   SUBSET_NAME      1536 non-null   object
#  5   INDIKATOR_ID     1536 non-null   int64
#  6   INDIKATOR_NAME   1536 non-null   object
#  7   INDIKATOR_JAHR   1536 non-null   int64
#  8   INDIKATOR_VALUE  1536 non-null   float64
#  9   EINHEIT_KURZ     1536 non-null   object
#  10  EINHEIT_LANG     1536 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 900.7 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           120
# 1       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           120
# 2       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           120
# 3       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           120
# 4       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           120
#
#              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  NRW Wähleranteil CVP [%]            1991              2.5            %
# 1  NRW Wähleranteil CVP [%]            1995              1.8            %
# 2  NRW Wähleranteil CVP [%]            1999              2.6            %
# 3  NRW Wähleranteil CVP [%]            2003              4.3            %
# 4  NRW Wähleranteil CVP [%]            2007              3.3            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      1158                      1174  \
# BFS_NR                                220                       222
# GEBIET_NAME                     Hagenbuch     Hofstetten (bis 2017)
# THEMA_NAME                        Politik                   Politik
# SET_NAME                    Wähleranteile             Wähleranteile
# SUBSET_NAME                   Nationalrat               Nationalrat
# INDIKATOR_ID                          120                       120
# INDIKATOR_NAME   NRW Wähleranteil CVP [%]  NRW Wähleranteil CVP [%]
# INDIKATOR_JAHR                       2011                      2011
# INDIKATOR_VALUE                       2.9                       2.0
# EINHEIT_KURZ                            %                         %
# EINHEIT_LANG                      Prozent                   Prozent
#
#                                      820
# BFS_NR                                141
# GEBIET_NAME                       Thalwil
# THEMA_NAME                        Politik
# SET_NAME                    Wähleranteile
# SUBSET_NAME                   Nationalrat
# INDIKATOR_ID                          120
# INDIKATOR_NAME   NRW Wähleranteil CVP [%]
# INDIKATOR_JAHR                       2003
# INDIKATOR_VALUE                       6.6
# EINHEIT_KURZ                            %
# EINHEIT_LANG                      Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  \
# count          1536       1536           1536         1536
# unique          200          1              1            1
# top     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# freq              8       1536           1536         1536
#
#                   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                       1536         1536         1536
# unique                         1            1            1
# top     NRW Wähleranteil CVP [%]            %      Prozent
# freq                        1536         1536         1536

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,536.00      1,536.00        1,536.00         1,536.00
# mean    106.97        120.00        2,004.85             4.45
# std      82.94          0.00            9.07             2.30
# min       0.00        120.00        1,991.00             0.00
# 25%      32.00        120.00        1,995.00             2.80
# 50%      94.00        120.00        2,003.00             4.20
# 75%     177.00        120.00        2,011.00             5.70
# max     298.00        120.00        2,019.00            14.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Baulandpreis Modell (Median) [Fr./m2]

# %% [markdown]
# ### **Description**: Bodenpreismodell: Median der Modellpreise von unbebautem Land der Wohn- und Mischzone inkl. Abbruchliegenschaften. Die Modellpreise werden jährlich für den gesamten ausgewiesenen Zeitraum neu berechnet und aktualisiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **332@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2023-01-06T14:55:15`
# - **Startdate** `1974-12-31`
# - **Enddate** `None`
# - **Theme** `['Preise']`
# - **Keyword** `['bauland', 'bezirke', 'bodenpreise', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 255
# Title                    : Baulandpreis Modell (Median) [Fr./m2]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-17T15:56:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_477.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_477.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 7,776 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7776 entries, 0 to 7775
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           7776 non-null   int64
#  1   GEBIET_NAME      7776 non-null   object
#  2   THEMA_NAME       7776 non-null   object
#  3   SET_NAME         7776 non-null   object
#  4   SUBSET_NAME      7776 non-null   object
#  5   INDIKATOR_ID     7776 non-null   int64
#  6   INDIKATOR_NAME   7776 non-null   object
#  7   INDIKATOR_JAHR   7776 non-null   int64
#  8   INDIKATOR_VALUE  7776 non-null   int64
#  9   EINHEIT_KURZ     7776 non-null   object
#  10  EINHEIT_LANG     7776 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 1       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 2       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 3       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 4       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
#
#    INDIKATOR_ID                         INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           477  Baulandpreis Modell (Median) [Fr./m2]            1974
# 1           477  Baulandpreis Modell (Median) [Fr./m2]            1975
# 2           477  Baulandpreis Modell (Median) [Fr./m2]            1976
# 3           477  Baulandpreis Modell (Median) [Fr./m2]            1977
# 4           477  Baulandpreis Modell (Median) [Fr./m2]            1978
#
#    INDIKATOR_VALUE EINHEIT_KURZ              EINHEIT_LANG
# 0              151       Fr./m2  Franken pro Quadratmeter
# 1              148       Fr./m2  Franken pro Quadratmeter
# 2              146       Fr./m2  Franken pro Quadratmeter
# 3              146       Fr./m2  Franken pro Quadratmeter
# 4              149       Fr./m2  Franken pro Quadratmeter

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                   6730  \
# BFS_NR                                             228
# GEBIET_NAME                                 Turbenthal
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                              Immobilienhandel
# SUBSET_NAME                               Baulandpreis
# INDIKATOR_ID                                       477
# INDIKATOR_NAME   Baulandpreis Modell (Median) [Fr./m2]
# INDIKATOR_JAHR                                    1984
# INDIKATOR_VALUE                                    131
# EINHEIT_KURZ                                    Fr./m2
# EINHEIT_LANG                  Franken pro Quadratmeter
#
#                                                   7092  \
# BFS_NR                                             245
# GEBIET_NAME                            Oberengstringen
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                              Immobilienhandel
# SUBSET_NAME                               Baulandpreis
# INDIKATOR_ID                                       477
# INDIKATOR_NAME   Baulandpreis Modell (Median) [Fr./m2]
# INDIKATOR_JAHR                                    2010
# INDIKATOR_VALUE                                   1002
# EINHEIT_KURZ                                    Fr./m2
# EINHEIT_LANG                  Franken pro Quadratmeter
#
#                                                   437
# BFS_NR                                              10
# GEBIET_NAME                                   Obfelden
# THEMA_NAME                          Bau und Immobilien
# SET_NAME                              Immobilienhandel
# SUBSET_NAME                               Baulandpreis
# INDIKATOR_ID                                       477
# INDIKATOR_NAME   Baulandpreis Modell (Median) [Fr./m2]
# INDIKATOR_JAHR                                    1979
# INDIKATOR_VALUE                                    113
# EINHEIT_KURZ                                    Fr./m2
# EINHEIT_LANG                  Franken pro Quadratmeter

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# count          7776                7776              7776          7776
# unique          162                   1                 1             1
# top     Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# freq             48                7776              7776          7776
#
#                                INDIKATOR_NAME EINHEIT_KURZ  \
# count                                    7776         7776
# unique                                      1            1
# top     Baulandpreis Modell (Median) [Fr./m2]       Fr./m2
# freq                                     7776         7776
#
#                     EINHEIT_LANG
# count                       7776
# unique                         1
# top     Franken pro Quadratmeter
# freq                        7776

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 7,776.00      7,776.00        7,776.00         7,776.00
# mean    124.97        477.00        1,997.50           543.34
# std      83.09          0.00           13.85           403.82
# min       1.00        477.00        1,974.00            34.00
# 25%      56.00        477.00        1,985.75           256.75
# 50%     112.50        477.00        1,997.50           476.00
# 75%     196.00        477.00        2,009.25           692.00
# max     298.00        477.00        2,021.00         3,071.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

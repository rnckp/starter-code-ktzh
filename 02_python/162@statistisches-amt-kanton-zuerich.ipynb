# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Nettoaufwand soziale Sicherheit [Fr./Einw.]

# %% [markdown]
# ### **Description**: Bruttoaufwand - Bruttoertrag (der Laufenden Rechnung). Aussage: Durch Steuern zu finanzierender Anteil des betreffenden Hauptaufgabenbereichs. Grundlage ist die Konsolidierte Gemeinde. Der Haushalt der Schulgemeinde wird dabei anteilsmässig in den Haushalt der poltischen Gemeinden umgelegt. Umstellung des Rechnungsmodells von HRM1 auf HRM2 ab Rechnungsjahr 2019.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **162@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-03T12:45:06`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeindefinanzen', 'gemeinden', 'kanton_zuerich', 'nettoaufwendungen', 'oeffentliche_finanzen', 'soziale_wohlfahrt', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 127
# Title                    : Nettoaufwand soziale Sicherheit [Fr./Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-03T12:45:06
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_426.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_426.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,388 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6388 entries, 0 to 6387
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6388 non-null   int64
#  1   GEBIET_NAME      6388 non-null   object
#  2   THEMA_NAME       6388 non-null   object
#  3   SET_NAME         6388 non-null   object
#  4   SUBSET_NAME      6388 non-null   object
#  5   INDIKATOR_ID     6388 non-null   int64
#  6   INDIKATOR_NAME   6388 non-null   object
#  7   INDIKATOR_JAHR   6388 non-null   int64
#  8   INDIKATOR_VALUE  6388 non-null   int64
#  9   EINHEIT_KURZ     6388 non-null   object
#  10  EINHEIT_LANG     6388 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
#
#              SUBSET_NAME  INDIKATOR_ID  \
# 0  Gemeinde Nettoaufwand           426
# 1  Gemeinde Nettoaufwand           426
# 2  Gemeinde Nettoaufwand           426
# 3  Gemeinde Nettoaufwand           426
# 4  Gemeinde Nettoaufwand           426
#
#                                 INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Nettoaufwand soziale Sicherheit [Fr./Einw.]            1990
# 1  Nettoaufwand soziale Sicherheit [Fr./Einw.]            1991
# 2  Nettoaufwand soziale Sicherheit [Fr./Einw.]            1992
# 3  Nettoaufwand soziale Sicherheit [Fr./Einw.]            1993
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                         4822  \
# BFS_NR                                                   225
# GEBIET_NAME                                       Rickenbach
# THEMA_NAME                              Öffentliche Finanzen
# SET_NAME                                    Gemeindefinanzen
# SUBSET_NAME                            Gemeinde Nettoaufwand
# INDIKATOR_ID                                             426
# INDIKATOR_NAME   Nettoaufwand soziale Sicherheit [Fr./Einw.]
# INDIKATOR_JAHR                                          2016
# INDIKATOR_VALUE                                          454
# EINHEIT_KURZ                                       Fr./Einw.
# EINHEIT_LANG                           Franken pro Einwohner
#
#                                                         3960  \
# BFS_NR                                                   180
# GEBIET_NAME                                      Weisslingen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME          SET_NAME  \
# count          6388                  6388              6388
# unique          202                     1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# freq             32                  6388              6388
#
#                   SUBSET_NAME                               INDIKATOR_NAME  \
# count                    6388                                         6388
# unique                      1                                            1
# top     Gemeinde Nettoaufwand  Nettoaufwand soziale Sicherheit [Fr./Einw.]
# freq                     6388                                         6388
#
#        EINHEIT_KURZ           EINHEIT_LANG
# count          6388                   6388
# unique            1                      1
# top       Fr./Einw.  Franken pro Einwohner
# freq           6388                   6388

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,388.00      6,388.00        6,388.00         6,388.00
# mean    111.39        426.00        2,005.34           412.07
# std      87.09          0.00            9.17           281.34
# min       0.00        426.00        1,990.00          -225.00
# 25%      32.00        426.00        1,997.00           212.00
# 50%      97.00        426.00        2,005.00           355.00
# 75%     182.00        426.00        2,013.00           548.00
# max     298.00        426.00        2,021.00         1,998.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

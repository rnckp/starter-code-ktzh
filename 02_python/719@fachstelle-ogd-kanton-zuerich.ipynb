# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Corona-Hilfen im Kulturbereich im Kanton Zürich

# %% [markdown]
# ### **Description**: Um die wirtschaftlichen Auswirkungen der Massnahmen zur Pandemiebekämpfung abzufedern und die kulturelle Vielfalt zu erhalten, können Kulturschaffende, nicht-gewinnorientierte sowie gewinnorientierte Kulturunternehmen finanzielle Unterstützung anfordern. Bei den Ausfallentschädigungen handelt es sich um nicht-rückzahlbare Beiträge für im Rahmen der COVID-19-Pandemie abgesagte Veranstaltungen oder Projekte und Betriebsschliessungen. Die Daten werden von der Direktion der Justiz und des Innern des Kantons Zürich, Fachstelle Kultur, ab dem 04.03.2021 in unregelmässiger Frequenz aktualisiert, sofern weitere Ausfallentschädigungsgesuche bewilligt werden können. Nachgefragte wie beschlossene Beträge sind gerundet auf 100 CHF; antragstellende natürliche oder juristische Personen sind anonymisiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **719@fachstelle-ogd-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-03-04T09:27:00`
# - **Modified** `2022-02-10T10:49:37`
# - **Startdate** `2020-04-06`
# - **Enddate** `2021-02-19`
# - **Theme** `['Kultur, Medien, Informationsgesellschaft, Sport']`
# - **Keyword** `['kultur', 'kulturfinanzierung', 'corona', 'covid-19', 'covid19', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1790
# Title                    : Corona-Hilfen im Kulturbereich im Kanton Zürich
# Description              : Die Direktion der Justiz und des Innern des Kantons Zürich, Fachstelle Kultur, veröffentlicht ab dem 04.03.2021 anonymisierte Daten zu den nachgefragten, beschlossenen und ausbezahlten Ausfallentschädigungen. Die Zeitreihe beginnt am 06.04.2020 mit dem ersten eingegangenen Gesuch. Spaltenüberschriften: 'Kategorie' = Antragstellende Kategorie ('Kulturschaffende', 'Kulturunternehmen gemeinnützig' oder 'Kulturunternehmen gewinnorientiert'); 'Sparte' = Kultursparte ('Bereichsübergreifend', 'Bildende Kunst', 'Design', 'Film', 'Kino', 'Klubs und Konzertlokale', 'Literatur', 'Museen', 'Musik' oder 'Tanz/Theater'); 'Nachgefragt' = Nachgefragter Betrag in CHF (gerundet auf 100 CHF); 'Beschluss' = Beschlossener Betrag in CHF (gerundet auf 100 CHF, 'NA' bei Ablehnung); 'Status' = Status des Antrags ('Ablehnung', 'Ausbezahlt' oder 'Saldo offen'); 'Eingangsdatum' = Datum des Eingangs des Gesuchs; 'Beschlussdatum' = Datum des Beschlusses über das Gesuch; 'ID' = anonymisierter Identifikator der antragstellenden natürlichen oder juristischen Person.
# Issued                   : 2021-02-15T17:28:56
# Modified                 : 2021-03-04T10:54:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000719_00001790.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000719_00001790.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,611 rows (observations) and 8 columns (variables).
# There seem to be 1 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Kategorie       1611 non-null   object
#  1   Sparte          1611 non-null   object
#  2   Nachgefragt     1611 non-null   int64
#  3   Beschluss       1302 non-null   float64
#  4   Status          1611 non-null   object
#  5   Eingangsdatum   1611 non-null   object
#  6   Beschlussdatum  1611 non-null   object
#  7   ID              1611 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 689.7 KB

# %%
df.head()
# Out:
#                         Kategorie        Sparte  Nachgefragt  Beschluss  \
# 0  Kulturunternehmen gemeinnützig     Literatur        32900    24600.0
# 1                Kulturschaffende         Musik         3900        0.0
# 2                Kulturschaffende  Tanz/Theater        11800        NaN
# 3                Kulturschaffende         Musik         1900      900.0
# 4                Kulturschaffende  Tanz/Theater          500        0.0
#
#        Status Eingangsdatum Beschlussdatum        ID
# 0  Ausbezahlt    2020-04-27     2020-09-03  9fd67c46
# 1  Ausbezahlt    2020-04-27     2020-06-29  5bff21c9
# 2   Ablehnung    2020-04-27     2020-06-23  0b159cfe
# 3  Ausbezahlt    2020-04-27     2020-07-10  bce1e0d0
# 4  Ausbezahlt    2020-04-27     2020-09-09  bb2605fa

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               606               1161  \
# Kategorie       Kulturunternehmen gewinnorientiert  Kulturschaffende
# Sparte                                      Museen             Musik
# Nachgefragt                                  17800              1500
# Beschluss                                      NaN               0.0
# Status                                   Ablehnung        Ausbezahlt
# Eingangsdatum                           2020-09-19        2020-06-10
# Beschlussdatum                          2021-01-08        2020-09-21
# ID                                        6ed5e616          a27f636b
#
#                                               1499
# Kategorie       Kulturunternehmen gewinnorientiert
# Sparte                                       Musik
# Nachgefragt                                 104100
# Beschluss                                  81900.0
# Status                                  Ausbezahlt
# Eingangsdatum                           2020-05-14
# Beschlussdatum                          2020-09-03
# ID                                        ae568635

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                Kategorie Sparte      Status Eingangsdatum Beschlussdatum  \
# count               1611   1611        1611          1611           1611
# unique                 3     10           3           143             74
# top     Kulturschaffende  Musik  Ausbezahlt    2020-09-20     2020-12-02
# freq                1027    771        1298           156            101
#
#               ID
# count       1611
# unique      1239
# top     bb2605fa
# freq          14

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         Nachgefragt    Beschluss
# count      1,611.00     1,302.00
# mean      96,668.40    46,436.64
# std      379,465.56   171,376.67
# min            0.00         0.00
# 25%        5,800.00     1,600.00
# 50%       14,700.00     6,400.00
# 75%       49,450.00    23,600.00
# max   10,749,500.00 2,718,700.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Direktion der Justiz und des Innern | Fachstelle Kultur | fachstellekultur@ji.zh.ch

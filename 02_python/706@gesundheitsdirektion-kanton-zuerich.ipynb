# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: COVID_19 Belegung Intensivpflege Kanton Zürich ab 29.10.2020

# %% [markdown]
# ### **Description**: Anzahl zertifizierte Intensivpflege-Betten und deren aktuelle Belegung auf Spitalebene im Kanton Zürich (Stand jeweils am Mittwoch). Die Daten werden einmal wöchentlich (jeweils am Mittwoch) aktualisiert. Variabeln: 'Name des Spitals', 'Anzahl Covid-19-PatientInnen auf der Intensivpflegestation, an deren Behandlung sich das Spital derzeit beteiligen müsste (die Sollwerte werden von der Gesundheitsdirektion zusammen mit den Spitälern definiert)', 'Anzahl Covid-19-PatientInnen auf der Intensivpflegestation', 'Anzahl andere PatientInnen auf der Intensivpflegestation' und (seit 2021-12-10) 'Anzahl zertifizierte Intensivpflege-Betten, die aktuell mit dem verfügbaren Pflegepersonal betrieben werden können'.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **706@gesundheitsdirektion-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-11-06T00:00:00`
# - **Modified** `2022-03-15T13:38:36`
# - **Startdate** `2020-10-29`
# - **Enddate** `None`
# - **Theme** `['Gesundheit']`
# - **Keyword** `['kanton_zuerich', 'spitaeler', 'spitalpatient', 'spitalpatientinnen', 'corona', 'covid-19', 'covid19', 'ogd']`
# - **Publisher** `['Gesundheitsdirektion des Kantons Zürich']`
# - **Landingpage** `https://github.com/openZH/covid_19/tree/master/fallzahlen_kanton_zh`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1744
# Title                    : COVID_19 Belegung Intensivpflege Kanton Zürich ab 29.10.2020
# Description              : Variabeln: 'hospital_name' = Name des Spitals; 'current_icu_service_certified' = Anzahl zertifizierte Intensivpflege-Betten; 'current_icu_target_covid' = Anzahl Covid-19-PatientInnen auf der Intensivpflegestation, an deren Behandlung sich das Spital derzeit beteiligen müsste (die Sollwerte werden von der Gesundheitsdirektion zusammen mit den Spitälern definiert); 'current_icu_covid' = Anzahl Covid-19-PatientInnen auf der Intensivpflegestation; 'current_icu_not_covid' = Anzahl andere PatientInnen auf der Intensivpflegestation; 'current_icu_service_certified_operated' (seit 2021-12-10) = Anzahl zertifizierte Intensivpflege-Betten, die aktuell mit dem verfügbaren Pflegepersonal betrieben werden können.
# Issued                   : 2020-11-06T16:07:21
# Modified                 : 2021-12-16T17:28:51
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19/master/fallzahlen_kanton_zh/COVID19_Belegung_Intensivpflege.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19/master/fallzahlen_kanton_zh/COVID19_Belegung_Intensivpflege.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 11,955 rows (observations) and 9 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11955 entries, 0 to 11954
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    11955 non-null  object
#  1   time                                    11955 non-null  object
#  2   abbreviation_canton_and_fl              11955 non-null  object
#  3   hospital_name                           11955 non-null  object
#  4   current_icu_service_certified           11955 non-null  int64
#  5   current_icu_covid                       11955 non-null  int64
#  6   current_icu_not_covid                   11955 non-null  int64
#  7   current_icu_service_certified_operated  5835 non-null   float64
#  8   source                                  11955 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.1 MB

# %%
df.head()
# Out:
#          date   time abbreviation_canton_and_fl                 hospital_name  \
# 0  2020-10-29  14:30                         ZH           GZO Spital Wetzikon
# 1  2020-10-29  14:30                         ZH  Hirslanden Klinik Hirslanden
# 2  2020-10-29  14:30                         ZH     Hirslanden Klinik im Park
# 3  2020-10-29  14:30                         ZH      Kantonsspital Winterthur
# 4  2020-10-29  14:30                         ZH           Kinderspital Zürich
#
#    current_icu_service_certified  current_icu_covid  current_icu_not_covid  \
# 0                              7                  1                      5
# 1                             22                  2                     15
# 2                              6                  0                      5
# 3                             18                  3                      9
# 4                             25                  0                     21
#
#    current_icu_service_certified_operated  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                               source
# 0  https://gd.zh.ch/internet/gesundheitsdirektion...
# 1  https://gd.zh.ch/internet/gesundheitsdirektion...
# 2  https://gd.zh.ch/internet/gesundheitsdirektion...
# 3  https://gd.zh.ch/internet/gesundheitsdirektion...
# 4  https://gd.zh.ch/internet/gesundheitsdirektion...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                                      5965  \
# date                                                                           2021-11-30
# time                                                                                14:30
# abbreviation_canton_and_fl                                                             ZH
# hospital_name                                                            Spital Männedorf
# current_icu_service_certified                                                           7
# current_icu_covid                                                                       1
# current_icu_not_covid                                                                   4
# current_icu_service_certified_operated                                                NaN
# source                                  https://gd.zh.ch/internet/gesundheitsdirektion...
#
#                                                                                      2898  \
# date                                                                           2021-05-10
# time                                                                                14:30
# abbreviation_canton_and_fl                                                             ZH
# hospital_name                                                         Stadtspital Triemli
# current_icu_service_certified                                                          18
# current_icu_covid                                                                       3
# current_icu_not_covid                                                                  12
# current_icu_service_certified_operated                                                NaN
# source                                  https://gd.zh.ch/internet/gesundheitsdirektion...
#
#                                                                                      8896
# date                                                                           2022-06-14
# time                                                                                14:30
# abbreviation_canton_and_fl                                                             ZH
# hospital_name                                                    Kantonsspital Winterthur
# current_icu_service_certified                                                          18
# current_icu_covid                                                                       1
# current_icu_not_covid                                                                   7
# current_icu_service_certified_operated                                               12.0
# source                                  https://gd.zh.ch/internet/gesundheitsdirektion...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#               date   time abbreviation_canton_and_fl        hospital_name  \
# count        11955  11955                      11955                11955
# unique         797      1                          1                   15
# top     2020-10-29  14:30                         ZH  GZO Spital Wetzikon
# freq            15  11955                      11955                  797
#
#                                                    source
# count                                               11955
# unique                                                  1
# top     https://gd.zh.ch/internet/gesundheitsdirektion...
# freq                                                11955

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        current_icu_service_certified  current_icu_covid  \
# count                      11,955.00          11,955.00
# mean                           14.87               2.24
# std                            16.52               3.93
# min                             6.00               0.00
# 25%                             6.00               0.00
# 50%                             7.00               1.00
# 75%                            18.00               3.00
# max                            72.00              40.00
#
#        current_icu_not_covid  current_icu_service_certified_operated
# count              11,955.00                                5,835.00
# mean                    9.29                                   12.74
# std                    11.40                                   13.57
# min                     0.00                                    3.00
# 25%                     3.00                                    6.00
# 50%                     5.00                                    7.00
# 75%                    10.00                                   16.00
# max                    62.00                                   65.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Gesundheitsdirektion des Kantons Zürich | Coronavirus-Hotline | gdstab@gd.zh.ch

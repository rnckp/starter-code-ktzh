# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungsbefragung im Kanton Zürich zur Zufriedenheit mit der Wohngemeinde

# %% [markdown]
# ### **Description**: Informationen zur Befindlichkeit der Bevölkerung bezüglich der eigenen Wohngemeinde. Die Befragten konnten sich dazu äussern, ob sie sich in ihren Wohngemeinden wohl fühlen, wie zufrieden sie mit den Leistungen der Gemeinden sind und wie sie deren finanzielle Situation einschätzen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1341@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-07-07T13:45:15`
# - **Modified** `2023-01-03T16:08:59`
# - **Startdate** `2019-09-01`
# - **Enddate** `2019-09-30`
# - **Theme** `['Bevölkerung', 'Volkswirtschaft']`
# - **Keyword** `['gemeindefinanzen', 'gemeinden', 'gemeindesteuerfuesse', 'gemeindesteuern', 'kanton_zuerich', 'staatsausgaben', 'steuerfuss', 'steuern', 'wohnbevoelkerung', 'lebenszufriedenheit', 'nachbargemeinden', 'gemeindeleistungen', 'wohngemeinde', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2918
# Title                    : Codebook Bevölkerungsbefragung 2019
# Description              : Im Codebook sind die erhobenen Variablen mit den möglichen Ausprägungen beschrieben. 
# Issued                   : 2022-07-07T13:45:15
# Modified                 : 2022-07-07T13:45:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001341_00002918.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001341_00002918.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 2759
# Title                    : Antworten der Bevölkerungsbefragung in den Zürcher Gemeinden 2019
# Description              : Antworten zu vier Themenblöcken (1-4): (1) Identifikation mit Wohnort und Zufriedenheit in der Wohngemeinde; (2) Gemeindeleistungen, Wichtigkeit dieser Aspekte und Zufriedenheit mit der Umsetzung durch Gemeinden; (3) Beurteilung Höhe der Steuern, kommunaler Steuerfuss und Bandbreite der kommunalen Steuerfüsse, in welche Themen sollen Steuergelder zukünftig investiert werden?; (4) Bereitschaft Dienstleistungen der Wohngemeinde in einer Nachbargemeinde zu beziehen, beziehungsweise welche Massnahmen zu ergreifen sind, wenn zentrale Dienstleistungen nicht mehr selbstständig von der Wohngemeinde erfüllt werden können.
# Issued                   : 2022-07-07T13:45:15
# Modified                 : 2022-07-07T13:45:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001341_00002759.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001341_00002759.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,337 rows (observations) and 84 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 84 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1337 non-null   int64
#  1   Frage1m           1218 non-null   float64
#  2   Frage2_SQ001      1313 non-null   float64
#  3   Frage3_SQ001      1289 non-null   float64
#  4   Frage3_SQ002      1233 non-null   float64
#  5   Frage3_SQ003      1199 non-null   float64
#  6   Frage3_SQ004      1249 non-null   float64
#  7   Frage3_SQ005      1286 non-null   float64
#  8   Frage3_SQ006      1266 non-null   float64
#  9   Frage3_SQ007      1289 non-null   float64
#  10  Frage3_SQ008      1244 non-null   float64
#  11  Frage3_SQ009      1228 non-null   float64
#  12  Frage3_SQ010      1200 non-null   float64
#  13  Frage3_SQ011      1288 non-null   float64
#  14  Frage3_SQ012      1272 non-null   float64
#  15  Frage3_SQ013      1284 non-null   float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Frage1m  Frage2_SQ001  Frage3_SQ001  Frage3_SQ002  \
# 0           1      8.0           4.0           6.0           4.0
# 1           2      2.0           4.0           6.0           6.0
# 2           3      3.0           4.0           5.0           4.0
# 3           4      NaN           3.0           5.0           1.0
# 4           5      2.0           3.0           1.0           1.0
#
#    Frage3_SQ003  Frage3_SQ004  Frage3_SQ005  Frage3_SQ006  Frage3_SQ007  ...  \
# 0           6.0           5.0           7.0           5.0           5.0  ...
# 1           6.0           6.0           NaN           4.0           6.0  ...
# 2           5.0           4.0           7.0           4.0           5.0  ...
# 3           7.0           6.0           7.0           7.0           7.0  ...
# 4           5.0           3.0           6.0           3.0           1.0  ...
#
#    Frage12_SQ006  Frage12_SQ007  Frage12_SQ008  methode  geschlecht  \
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                              618             949             392
# Unnamed: 0                   619             950             393
# Frage1m                      4.0             1.0             2.0
# Frage2_SQ001                 4.0             4.0             4.0
# Frage3_SQ001                 6.0             7.0             7.0
# Frage3_SQ002                 2.0             5.0             7.0
# ...                          ...             ...             ...
# alter_koh              55 bis 59       65 bis 69       60 bis 64
# aufenthaltsdauer  Alteingesessen  Alteingesessen  Alteingesessen
# gemeinde_groesse         >100000   2001 bis 5000         >100000
# bezirk_code                  110             104             110
# bezirk_name_kurz      Winterthur       Dielsdorf      Winterthur
#
# [84 rows x 3 columns]

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        methode  alter_koh aufenthaltsdauer gemeinde_groesse bezirk_name_kurz
# count     1337       1337             1337             1337             1337
# unique       2         13                2                7               12
# top     online  55 bis 59   Alteingesessen          >100000       Winterthur
# freq      1081        148             1107              318              254

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Unnamed: 0  Frage1m  Frage2_SQ001  Frage3_SQ001  Frage3_SQ002  \
# count    1,337.00 1,218.00      1,313.00      1,289.00      1,233.00
# mean       669.00     3.80          3.63          5.65          3.91
# std        386.10     2.18          0.57          1.51          1.80
# min          1.00     1.00          1.00          1.00          1.00
# 25%        335.00     2.00          3.00          5.00          2.00
# 50%        669.00     3.00          4.00          6.00          4.00
# 75%      1,003.00     6.00          4.00          7.00          5.00
# max      1,337.00     8.00          4.00          7.00          7.00
#
#        Frage3_SQ003  Frage3_SQ004  Frage3_SQ005  Frage3_SQ006  Frage3_SQ007  \
# count      1,199.00      1,249.00      1,286.00      1,266.00      1,289.00
# mean           5.37          5.53          6.16          5.07          5.53
# std            1.91          1.35          1.11          1.60          1.44
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Befragungen und Sozialhilfestatistik | umfragen@statistik.ji.zh.ch

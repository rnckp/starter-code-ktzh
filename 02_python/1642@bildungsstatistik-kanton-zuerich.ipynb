# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lernende der Berufsbildung im Kanton Zürich ab 2000

# %% [markdown]
# ### **Description**: Ausgewertet sind alle Lernenden, die eine Schule im Bereich Berufsbildung mit Standort im Kanton Zürich besuchen. Dazu gehören alle Berufsfachschulen und Berufsmaturitätsschulen. Die Daten werden jährlich für den Stichtag 15.9. erhoben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1642@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-10-24T11:55:49`
# - **Modified** `2022-10-25T09:15:32`
# - **Startdate** `2000-09-15`
# - **Enddate** `2021-09-15`
# - **Theme** `['Bildung, Wissenschaft', 'Arbeit, Erwerb']`
# - **Keyword** `['ausbildung', 'berufsausbildung', 'berufsbildung', 'berufsgruppen', 'berufslehre', 'berufsmaturitaetsschule', 'berufsschule', 'bildung', 'bildungsstufe', 'lernende', 'schueler', 'schuelerinnen', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3078
# Title                    : Lernende der Berufsbildung im Kanton Zürich ab 2000
# Description              : Die Daten sind differenziert nach Jahr, Bildungsfeld und Berufsmaturitätstyp. Jahr: Das Jahr ist jeweils das Kalenderjahr der Erhebung, wobei der Stichtag der 15.9. ist. Die Daten für das Jahr 2021 sind somit im Schuljahr 2021/22 erhoben worden und zeigen den Datenstand am 15. September 2021. Bildungsfeld: Das Bildungsfeld ist eine Kategorisierung der Berufsbildung nach ISCED2013-F. Es gibt acht Kategorien. Berufsmaturitaetstyp: Beim Berufsmaturitätstyp wird unterschieden zwischen "Berufsfachschule (ohne BM)", "BM1" (gleichzeitig mit der Lehre) oder "BM2" (nach der Lehre). Anzahl: Anzahl der Schülerinnen und Schüler mit der entsprechenden Merkmalskombination
# Issued                   : 2022-10-24T11:55:49
# Modified                 : 2022-10-24T11:55:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Berufsbildung_Bildungsfeld.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Berufsbildung_Bildungsfeld.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')
# Out:
# Skipping line 6: expected 6 fields, saw 7
# Skipping line 7: expected 6 fields, saw 7
# Skipping line 8: expected 6 fields, saw 7
# Skipping line 9: expected 6 fields, saw 7
# Skipping line 10: expected 6 fields, saw 7
# Skipping line 11: expected 6 fields, saw 7
# Skipping line 12: expected 6 fields, saw 7
# Skipping line 16: expected 6 fields, saw 7
# Skipping line 17: expected 6 fields, saw 7
# Skipping line 18: expected 6 fields, saw 7
# Skipping line 19: expected 6 fields, saw 7
# Skipping line 20: expected 6 fields, saw 8
# Skipping line 21: expected 6 fields, saw 8
# Skipping line 22: expected 6 fields, saw 8
# Skipping line 23: expected 6 fields, saw 8
# Skipping line 40: expected 6 fields, saw 7
# Skipping line 41: expected 6 fields, saw 7
# Skipping line 42: expected 6 fields, saw 7
# Skipping line 43: expected 6 fields, saw 7
# Skipping line 44: expected 6 fields, saw 7
# Skipping line 45: expected 6 fields, saw 7
# Skipping line 46: expected 6 fields, saw 7
# ...

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 236 rows (observations) and 6 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Stand                 236 non-null    object
#  1   Kanton                236 non-null    object
#  2   Jahr                  236 non-null    int64
#  3   Bildungsfeld          236 non-null    object
#  4   Berufsmaturitaetstyp  236 non-null    object
#  5   Anzahl                236 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 68.2 KB

# %%
df.head()
# Out:
#         Stand Kanton  Jahr                              Bildungsfeld  \
# 0  2022-10-21     zh  2021          Geisteswissenschaften und Künste
# 1  2022-10-21     zh  2021          Geisteswissenschaften und Künste
# 2  2022-10-21     zh  2021          Geisteswissenschaften und Künste
# 3  2022-10-21     zh  2021          Geisteswissenschaften und Künste
# 4  2022-10-21     zh  2021  Informatik und Kommunikationstechnologie
#
#          Berufsmaturitaetstyp  Anzahl
# 0  Berufsfachschule (ohne BM)    1579
# 1                         BM1     234
# 2                         BM2     228
# 3                       Total    2041
# 4  Berufsfachschule (ohne BM)    1602

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                    76                177  \
# Stand                                       2022-10-21        2022-10-21
# Kanton                                              zh                zh
# Jahr                                              2017              2011
# Bildungsfeld          Geisteswissenschaften und Künste  nicht zugeordnet
# Berufsmaturitaetstyp        Berufsfachschule (ohne BM)               BM1
# Anzahl                                            1520              4991
#
#                                    194
# Stand                       2022-10-21
# Kanton                              zh
# Jahr                              2008
# Bildungsfeld          nicht zugeordnet
# Berufsmaturitaetstyp             Total
# Anzahl                           44919

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#              Stand Kanton      Bildungsfeld Berufsmaturitaetstyp
# count          236    236               236                  236
# unique           1      1                 7                    4
# top     2022-10-21     zh  nicht zugeordnet                Total
# freq           236    236                70                   89

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr    Anzahl
# count   236.00    236.00
# mean  2,013.97 10,223.11
# std       5.74 16,434.74
# min   2,000.00     34.00
# 25%   2,011.00    432.25
# 50%   2,015.00  1,736.00
# 75%   2,018.00  7,046.25
# max   2,021.00 47,094.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

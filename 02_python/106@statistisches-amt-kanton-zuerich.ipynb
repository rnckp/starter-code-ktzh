# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung: Anteil 65-79-Jährige [%]

# %% [markdown]
# ### **Description**: Anteil 65-79-Jähriger an der Gesamtbevölkerung nach zivilrechtlichem Wohnsitz(ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **106@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:55`
# - **Startdate** `1998-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['alter', 'altersstruktur', 'bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 87
# Title                    : Bevölkerung: Anteil 65-79-Jährige [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_89.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_89.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,692 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4692 entries, 0 to 4691
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4692 non-null   int64
#  1   GEBIET_NAME      4692 non-null   object
#  2   THEMA_NAME       4692 non-null   object
#  3   SET_NAME         4692 non-null   object
#  4   SUBSET_NAME      4692 non-null   object
#  5   INDIKATOR_ID     4692 non-null   int64
#  6   INDIKATOR_NAME   4692 non-null   object
#  7   INDIKATOR_JAHR   4692 non-null   int64
#  8   INDIKATOR_VALUE  4692 non-null   float64
#  9   EINHEIT_KURZ     4692 non-null   object
#  10  EINHEIT_LANG     4692 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME     SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Altersstruktur            89
# 1  Bevölkerungsbestand und Haushalte  Altersstruktur            89
# 2  Bevölkerungsbestand und Haushalte  Altersstruktur            89
# 3  Bevölkerungsbestand und Haushalte  Altersstruktur            89
# 4  Bevölkerungsbestand und Haushalte  Altersstruktur            89
#
#                           INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerung: Anteil 65-79-Jährige [%]            1998              8.6
# 1  Bevölkerung: Anteil 65-79-Jährige [%]            1999              8.5
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                   4450  \
# BFS_NR                                               0
# GEBIET_NAME                             Region Glattal
# THEMA_NAME                    Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbestand und Haushalte
# SUBSET_NAME                             Altersstruktur
# INDIKATOR_ID                                        89
# INDIKATOR_NAME   Bevölkerung: Anteil 65-79-Jährige [%]
# INDIKATOR_JAHR                                    2020
# INDIKATOR_VALUE                                   11.7
# EINHEIT_KURZ                                         %
# EINHEIT_LANG                                   Prozent
#
#                                                   1012  \
# BFS_NR                                              55
# GEBIET_NAME                                    Eglisau
# THEMA_NAME                    Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbestand und Haushalte
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          4692                      4692
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             24                      4692
#
#                                  SET_NAME     SUBSET_NAME  \
# count                                4692            4692
# unique                                  1               1
# top     Bevölkerungsbestand und Haushalte  Altersstruktur
# freq                                 4692            4692
#
#                                INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                    4692         4692         4692
# unique                                      1            1            1
# top     Bevölkerung: Anteil 65-79-Jährige [%]            %      Prozent
# freq                                     4692         4692         4692

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,692.00      4,692.00        4,692.00         4,692.00
# mean    108.57         89.00        2,009.44            11.64
# std      85.39          0.00            6.88             2.49
# min       0.00         89.00        1,998.00             4.40
# 25%      31.00         89.00        2,003.00             9.90
# 50%      95.00         89.00        2,009.00            11.60
# 75%     179.00         89.00        2,015.00            13.40
# max     298.00         89.00        2,021.00            21.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

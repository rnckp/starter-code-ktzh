# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Tertiärstufe [Pers. pro 1000 Einw.]

# %% [markdown]
# ### **Description**: inkl. Universität Zürich, aber ohne ETH; gemessen an der zivilrechtlichen Bevölkerung Ende Vorjahr

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **279@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1999-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'schueler', 'schuelerinnen', 'studierende', 'tertiaerstufe', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 209
# Title                    : Schül. Tertiärstufe [Pers. pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_466.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_466.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,280 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4280 entries, 0 to 4279
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4280 non-null   int64
#  1   GEBIET_NAME      4280 non-null   object
#  2   THEMA_NAME       4280 non-null   object
#  3   SET_NAME         4280 non-null   object
#  4   SUBSET_NAME      4280 non-null   object
#  5   INDIKATOR_ID     4280 non-null   int64
#  6   INDIKATOR_NAME   4280 non-null   object
#  7   INDIKATOR_JAHR   4280 non-null   int64
#  8   INDIKATOR_VALUE  4280 non-null   float64
#  9   EINHEIT_KURZ     4280 non-null   object
#  10  EINHEIT_LANG     4280 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME         SUBSET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
#
#    INDIKATOR_ID                              INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           466  Schül. Tertiärstufe [Pers. pro 1000 Einw.]            1999
# 1           466  Schül. Tertiärstufe [Pers. pro 1000 Einw.]            2000
# 2           466  Schül. Tertiärstufe [Pers. pro 1000 Einw.]            2001
# 3           466  Schül. Tertiärstufe [Pers. pro 1000 Einw.]            2002
# 4           466  Schül. Tertiärstufe [Pers. pro 1000 Einw.]            2003
#
#    INDIKATOR_VALUE          EINHEIT_KURZ                    EINHEIT_LANG
# 0             20.0  Pers. pro 1000 Einw.  Personen pro Tausend Einwohner
# 1             16.7  Pers. pro 1000 Einw.  Personen pro Tausend Einwohner
# 2             21.7  Pers. pro 1000 Einw.  Personen pro Tausend Einwohner
# 3             16.6  Pers. pro 1000 Einw.  Personen pro Tausend Einwohner
# 4             16.1  Pers. pro 1000 Einw.  Personen pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                        2307  \
# BFS_NR                                                  152
# GEBIET_NAME                                      Herrliberg
# THEMA_NAME                         Bevölkerung und Soziales
# SET_NAME                                            Bildung
# SUBSET_NAME                              Schüler nach ISCED
# INDIKATOR_ID                                            466
# INDIKATOR_NAME   Schül. Tertiärstufe [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                         2000
# INDIKATOR_VALUE                                        22.4
# EINHEIT_KURZ                           Pers. pro 1000 Einw.
# EINHEIT_LANG                 Personen pro Tausend Einwohner
#
#                                                        484   \
# BFS_NR                                                   29
# GEBIET_NAME                                      Flurlingen
# THEMA_NAME                         Bevölkerung und Soziales
# SET_NAME                                            Bildung
# SUBSET_NAME                              Schüler nach ISCED
# INDIKATOR_ID                                            466
# INDIKATOR_NAME   Schül. Tertiärstufe [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                         1999
# INDIKATOR_VALUE                                        15.9
# EINHEIT_KURZ                           Pers. pro 1000 Einw.
# EINHEIT_LANG                 Personen pro Tausend Einwohner
#
#                                                        722
# BFS_NR                                                   39
# GEBIET_NAME                                Thalheim a.d.Th.
# THEMA_NAME                         Bevölkerung und Soziales
# SET_NAME                                            Bildung
# SUBSET_NAME                              Schüler nach ISCED
# INDIKATOR_ID                                            466
# INDIKATOR_NAME   Schül. Tertiärstufe [Pers. pro 1000 Einw.]
# INDIKATOR_JAHR                                         2021
# INDIKATOR_VALUE                                         4.2
# EINHEIT_KURZ                           Pers. pro 1000 Einw.
# EINHEIT_LANG                 Personen pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME         SUBSET_NAME  \
# count          4280                      4280     4280                4280
# unique          200                         1        1                   1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler nach ISCED
# freq             22                      4280     4280                4280
#
#                                     INDIKATOR_NAME          EINHEIT_KURZ  \
# count                                         4280                  4280
# unique                                           1                     1
# top     Schül. Tertiärstufe [Pers. pro 1000 Einw.]  Pers. pro 1000 Einw.
# freq                                          4280                  4280
#
#                           EINHEIT_LANG
# count                             4280
# unique                               1
# top     Personen pro Tausend Einwohner
# freq                              4280

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,280.00      4,280.00        4,280.00         4,280.00
# mean    107.83        466.00        2,009.74            16.69
# std      84.82          0.00            6.69             6.99
# min       0.00        466.00        1,999.00             0.00
# 25%      31.00        466.00        2,004.00            11.20
# 50%      94.00        466.00        2,009.00            17.20
# 75%     178.00        466.00        2,016.00            21.30
# max     298.00        466.00        2,021.00            62.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

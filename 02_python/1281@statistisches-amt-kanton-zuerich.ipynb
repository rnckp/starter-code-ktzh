# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Archiv Wahlresultate Gemeindebehördenwahlen im Kanton Zürich

# %% [markdown]
# ### **Description**: Ergebnisse der Erneuerungswahlen der Zürcher Gemeindebehörden

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1281@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-03-24T10:21:34`
# - **Modified** `2023-01-04T13:53:02`
# - **Startdate** `2022-02-13`
# - **Enddate** `None`
# - **Theme** `['Politik']`
# - **Keyword** `['gemeinden', 'gemeindewahlen', 'kanton_zuerich', 'politik', 'politische_gemeinden', 'politische_parteien', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/gemeindewahlen.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2419
# Title                    : Ergebnisse der kommunalen Behördenwahlen 2022
# Description              : Ergebnisse der Erneuerungswahlen der Zürcher Gemeindebehörden. Abgebildet sind sämtliche über die den Gemeinden vom Kanton Zürich zur Verfügung gestellte Wahl- und Abstimmungssoftware abgewickelten Gesamterneuerungswahlen von Gemeindebehörden 2022, sowie sämtliche gemeldete in Stiller Wahl gewählte Personen für Behörden mit Amtsantritt 2022. Gemeinden sind gesetzlich nicht verpflichtet, die Behördenwahlen mit besagter Software abzuwickeln oder Stille Wahlen zu melden. Ausserdem ist es möglich, dass an der Urne gewählte Personen die Wahl ablehnen. Der rechtskräftig gewordene Ausgang einer Wahl wird lediglich von der entsprechenden Gemeinde publiziert.
# Issued                   : 2022-03-24T10:21:34
# Modified                 : 2022-10-10T18:33:36
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001281_00002419.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001281_00002419.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,111 rows (observations) and 78 columns (variables).
# There seem to be 10 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6111 entries, 0 to 6110
# Data columns (total 78 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SortGemeinde             5972 non-null   float64
#  1   SortGemeindeSub          5797 non-null   float64
#  2   KNR                      5797 non-null   float64
#  3   StimmenAuszKreis         5797 non-null   float64
#  4   StimmenNWAuszKreis       5797 non-null   float64
#  5   BfsNrGemeinde            5972 non-null   float64
#  6   EinheitCode              5776 non-null   object
#  7   StimmenNW2AuszKreis      5797 non-null   float64
#  8   GeArt                    5972 non-null   object
#  9   GeLfNr                   5797 non-null   float64
#  10  Nachname                 6111 non-null   object
#  11  Vorname                  5291 non-null   object
#  12  Partei                   4107 non-null   object
#  13  Beruf                    4401 non-null   object
#  14  Titel                    207 non-null    object
#  15  Wohnort                  4063 non-null   object
#  16  Jahrgang                 4932 non-null   float64
#  17  Bisher                   6111 non-null   int64
#  18  Gewaehlt                 6111 non-null   int64
#  19  StimmenWahlkreis         5797 non-null   float64
#  20  AbsolutesMehr            5797 non-null   float64
#  21  KandidatHwNw             5797 non-null   float64
#  22  BisherNW                 5797 non-null   float64
#  23  GewaehltNW               5797 non-null   float64
#  24  StimmenNWWahlkreis       5797 non-null   float64
#  25  AbsolutesMehrNW          5797 non-null   float64
#  26  BisherNW2                5797 non-null   float64
#  27  GewaehltNW2              5797 non-null   float64
#  28  StimmenNW2Wahlkreis      5797 non-null   float64
#  29  AbsolutesMehrNW2         5797 non-null   float64
#  30  Geschlecht               6111 non-null   object
#  31  SortWahlkreis            5797 non-null   float64
#  32  SortGeschaeft            5797 non-null   float64
#  33  Gemeinde                 6111 non-null   object
#  34  Stimmberechtigte         5777 non-null   float64
#  35  WKreisRegionNr           1448 non-null   float64
#  36  WKreisRegionBez          1448 non-null   object
#  37  StmAbgegeben             5797 non-null   float64
#  38  StmEingelegtUngueltig    5722 non-null   float64
#  39  StmEingelegtGueltig      5722 non-null   float64
#  40  StmUngueltig             5797 non-null   float64
#  41  StmLeer                  5797 non-null   float64
#  42  StmGueltig               5797 non-null   float64
#  43  StimmenUngueltig         5797 non-null   float64
#  44  StimmenLeer              5797 non-null   float64
#  45  StimmenUngueltigNW       5797 non-null   float64
#  46  StimmenLeerNW            5797 non-null   float64
#  47  StimmenUngueltigNW2      5797 non-null   float64
#  48  StimmenLeerNW2           5797 non-null   float64
#  49  StiAusweiseUrne          5716 non-null   float64
#  50  StiAusweiseVorzeitig     5716 non-null   float64
#  51  StiAusweiseBriefGueltig  5716 non-null   float64
#  52  StiAusweiseBriefNiUz     5716 non-null   float64
#  53  AntwkOhneStiAusweis      5716 non-null   float64
#  54  GeBezKurz                6111 non-null   object
#  55  GeBezOffiziell           6111 non-null   object
#  56  Sonntag                  5797 non-null   object
#  57  Kanton                   5972 non-null   object
#  58  Mandate                  5797 non-null   float64
#  59  MassgebStimmen           5797 non-null   float64
#  60  EinfacheStimmen          5797 non-null   float64
#  61  WahlkreisBez             5797 non-null   object
#  62  WahlkreisChef            5797 non-null   object
#  63  BfsNrWKreisChef          5797 non-null   float64
#  64  GeBezKurzNW              4221 non-null   object
#  65  GeBezOffiziellNW         4218 non-null   object
#  66  MandateNW                4214 non-null   float64
#  67  MassgebStimmenNW         5797 non-null   float64
#  68  EinfacheStimmenNW        5797 non-null   float64
#  69  GeBezKurzNW2             143 non-null    object
#  70  GeBezOffiziellNW2        143 non-null    object
#  71  MandateNW2               122 non-null    float64
#  72  MassgebStimmenNW2        5797 non-null   float64
#  73  EinfacheStimmenNW2       5797 non-null   float64
#  74  GeTyp                    5797 non-null   object
#  75  AmtsdauerVon             6111 non-null   int64
#  76  StilleWahl               6111 non-null   int64
#  77  GeCode                   6032 non-null   float64
# dtypes: float64(52), int64(4), object(22)
# memory usage: 12.1 MB

# %%
df.head()
# Out:
#    SortGemeinde  SortGemeindeSub  KNR  StimmenAuszKreis  StimmenNWAuszKreis  \
# 0         243.0            243.0  1.0            2399.0              2118.0
# 1         243.0            243.0  2.0             351.0                22.0
# 2         243.0            243.0  3.0            1386.0                91.0
# 3         243.0            243.0  4.0            1058.0                18.0
# 4         243.0            243.0  5.0            1265.0                27.0
#
#    BfsNrGemeinde EinheitCode  StimmenNW2AuszKreis GeArt        GeLfNr  ...  \
# 0          243.0       ZH243                  0.0   Gde  1.245443e+09  ...
# 1          243.0       ZH243                  0.0   Gde  1.245443e+09  ...
# 2          243.0       ZH243                  0.0   Gde  1.245443e+09  ...
# 3          243.0       ZH243                  0.0   Gde  1.245443e+09  ...
# 4          243.0       ZH243                  0.0   Gde  1.245443e+09  ...
#
#   EinfacheStimmenNW GeBezKurzNW2 GeBezOffiziellNW2 MandateNW2  \
# 0            1652.5          NaN               NaN        NaN
# 1            1652.5          NaN               NaN        NaN
# 2            1652.5          NaN               NaN        NaN
# 3            1652.5          NaN               NaN        NaN
# 4            1652.5          NaN               NaN        NaN
#
#   MassgebStimmenNW2 EinfacheStimmenNW2  GeTyp  AmtsdauerVon  StilleWahl  \
# 0               0.0                0.0   MWNW          2022           0
# 1               0.0                0.0   MWNW          2022           0
# 2               0.0                0.0   MWNW          2022           0
# 3               0.0                0.0   MWNW          2022           0
# 4               0.0                0.0   MWNW          2022           0
#
#    GeCode
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
#
# [5 rows x 78 columns]

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                      1886   1704   2543
# SortGemeinde        231.0  245.0   24.0
# SortGemeindeSub     231.0  245.0   24.0
# KNR                   2.0    1.0    1.0
# StimmenAuszKreis    651.0  581.0  174.0
# StimmenNWAuszKreis    9.0    0.0    6.0
# ...                   ...    ...    ...
# EinfacheStimmenNW2    0.0    0.0    0.0
# GeTyp                MWNW   MWNW   MWNW
# AmtsdauerVon         2022   2022   2022
# StilleWahl              0      0      0
# GeCode                5.0    5.0    3.0
#
# [78 rows x 3 columns]

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        EinheitCode GeArt     Nachname Vorname     Partei        Beruf Titel  \
# count         5776  5972         6111    5291       4107         4401   207
# unique         273     1         2532    1080        116         2149    33
# top          ZH038   Gde  Vereinzelte  Thomas  parteilos  Unternehmer  Herr
# freq           117  5972          820     147       1081           67    29
#
#        Wohnort Geschlecht Gemeinde  ...  \
# count     4063       6111     6111  ...
# unique     241          2      277  ...
# top     Zürich          M   Zürich  ...
# freq       404       3947      122  ...
#
#                                            GeBezOffiziell     Sonntag Kanton  \
# count                                                6111        5797   5972
# unique                                                603           4      1
# top     Erneuerungswahl der 9 Mitglieder des Stadtrats...  2022-03-27     ZH
# freq                                                  234        3854   5972
#
#         WahlkreisBez WahlkreisChef            GeBezKurzNW  \
# count           5797          5797                   4221
# unique           220           219                    227
# top     Stadt Zürich  Stadt Zürich  Präsidium Gemeinderat
# freq             234           234                    299
#
#                                          GeBezOffiziellNW  \
# count                                                4218
# unique                                                321
# top     Erneuerungswahl des Stadtpräsidiums für die Am...
# freq                                                  234
#
#                                GeBezKurzNW2  \
# count                                   143
# unique                                   11
# top     Erneuerungswahl des Schulpräsidiums
# freq                                     43
#
#                                         GeBezOffiziellNW2 GeTyp
# count                                                 143  5797
# unique                                                 12     3
# top     Erneuerungswahl des Schulpräsidiums für die Am...  MWNW
# freq                                                   24  4092
#
# [4 rows x 22 columns]

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        SortGemeinde  SortGemeindeSub      KNR  StimmenAuszKreis  \
# count      5,972.00         5,797.00 5,797.00          5,797.00
# mean         134.33           118.36   147.08            812.04
# std           90.90            91.00   346.00          1,149.08
# min            1.00             1.00     1.00              0.00
# 25%           55.00            38.00     2.00            149.00
# 50%          118.00            99.00     5.00            464.00
# 75%          223.00           196.00    11.00            993.00
# max          298.00           298.00   999.00          9,927.00
#
#        StimmenNWAuszKreis  BfsNrGemeinde  StimmenNW2AuszKreis  \
# count            5,797.00       5,972.00             5,797.00
# mean                97.79         134.33                 3.47
# std                409.53          90.90                70.71
# min                  0.00           1.00                 0.00
# 25%                  0.00          55.00                 0.00
# 50%                  0.00         118.00                 0.00
# 75%                 20.00         223.00                 0.00
# max              8,492.00         298.00             2,679.00
#
#                 GeLfNr  Jahrgang   Bisher  ...  BfsNrWKreisChef  MandateNW  \
# count         5,797.00  4,932.00 6,111.00  ...         5,797.00   4,214.00
# mean  1,247,007,389.56  1,969.04     0.39  ...           133.99       1.00
# std       1,600,116.57     66.94     0.49  ...            91.10       0.00
# min   1,245,357,408.00     71.00     0.00  ...             1.00       1.00
# 25%   1,245,516,501.00  1,964.00     0.00  ...            55.00       1.00
# 50%   1,247,051,672.00  1,970.00     0.00  ...           118.00       1.00
# 75%   1,247,094,753.00  1,979.00     1.00  ...           224.00       1.00
# max   1,250,446,832.00  2,004.00     1.00  ...           298.00       1.00
#
#        MassgebStimmenNW  EinfacheStimmenNW  MandateNW2  MassgebStimmenNW2  \
# count          5,797.00           5,797.00      122.00           5,797.00
# mean           4,666.14           2,333.07        1.00              44.95
# std           16,040.83           8,020.41        0.00             374.11
# min                0.00               0.00        1.00               0.00
# 25%                0.00               0.00        1.00               0.00
# 50%              663.00             331.50        1.00               0.00
# 75%            1,414.00             707.00        1.00               0.00
# max           80,944.00          40,472.00        1.00           3,918.00
#
#        EinfacheStimmenNW2  AmtsdauerVon  StilleWahl   GeCode
# count            5,797.00      6,111.00    6,111.00 6,032.00
# mean                22.47      2,022.00        0.05     3.36
# std                187.05          0.00        0.22     1.83
# min                  0.00      2,022.00        0.00     1.00
# 25%                  0.00      2,022.00        0.00     1.00
# 50%                  0.00      2,022.00        0.00     3.00
# 75%                  0.00      2,022.00        0.00     5.00
# max              1,959.00      2,022.00        1.00     7.00
#
# [8 rows x 56 columns]

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

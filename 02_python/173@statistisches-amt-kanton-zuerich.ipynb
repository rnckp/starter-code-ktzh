# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Nettovermögen [Fr./Einw.]

# %% [markdown]
# ### **Description**: Nettovermögen pro Einwohner. Finanzvermögen minus Fremdkapital. Das Nettovermögen wird als Gradmesser für die Verschuldung verwendet indem sie den Betrag an Finanzvermögen zeigt, welcher die Schulden übersteigt. Grundlage ist die Konsolidierte Gemeinde. Der Haushalt der Schulgemeinde wird dabei anteilsmässig in den Haushalt der poltischen Gemeinden umgelegt. Umstellung des Rechnungsmodells von HRM1 auf HRM2 ab Rechnungsjahr 2019.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **173@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-03T12:45:14`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'finanzkennzahlen', 'finanzvermoegen', 'gemeindefinanzen', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 137
# Title                    : Nettovermögen [Fr./Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-03T12:45:14
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_431.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_431.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,388 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6388 entries, 0 to 6387
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6388 non-null   int64
#  1   GEBIET_NAME      6388 non-null   object
#  2   THEMA_NAME       6388 non-null   object
#  3   SET_NAME         6388 non-null   object
#  4   SUBSET_NAME      6388 non-null   object
#  5   INDIKATOR_ID     6388 non-null   int64
#  6   INDIKATOR_NAME   6388 non-null   object
#  7   INDIKATOR_JAHR   6388 non-null   int64
#  8   INDIKATOR_VALUE  6388 non-null   int64
#  9   EINHEIT_KURZ     6388 non-null   object
#  10  EINHEIT_LANG     6388 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.0 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
#
#            SUBSET_NAME  INDIKATOR_ID             INDIKATOR_NAME  \
# 0  Gemeindekennziffern           431  Nettovermögen [Fr./Einw.]
# 1  Gemeindekennziffern           431  Nettovermögen [Fr./Einw.]
# 2  Gemeindekennziffern           431  Nettovermögen [Fr./Einw.]
# 3  Gemeindekennziffern           431  Nettovermögen [Fr./Einw.]
# 4  Gemeindekennziffern           431  Nettovermögen [Fr./Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ           EINHEIT_LANG
# 0            1990             1349    Fr./Einw.  Franken pro Einwohner
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                       3937                       1793  \
# BFS_NR                                 179                         69
# GEBIET_NAME         Sternenberg (bis 2014)                Wallisellen
# THEMA_NAME            Öffentliche Finanzen       Öffentliche Finanzen
# SET_NAME                  Gemeindefinanzen           Gemeindefinanzen
# SUBSET_NAME            Gemeindekennziffern        Gemeindekennziffern
# INDIKATOR_ID                           431                        431
# INDIKATOR_NAME   Nettovermögen [Fr./Einw.]  Nettovermögen [Fr./Einw.]
# INDIKATOR_JAHR                        2004                       2000
# INDIKATOR_VALUE                      -7368                       1553
# EINHEIT_KURZ                     Fr./Einw.                  Fr./Einw.
# EINHEIT_LANG         Franken pro Einwohner      Franken pro Einwohner
#
#                                       5731
# BFS_NR                                   0
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME          SET_NAME  \
# count          6388                  6388              6388
# unique          202                     1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindefinanzen
# freq             32                  6388              6388
#
#                 SUBSET_NAME             INDIKATOR_NAME EINHEIT_KURZ  \
# count                  6388                       6388         6388
# unique                    1                          1            1
# top     Gemeindekennziffern  Nettovermögen [Fr./Einw.]    Fr./Einw.
# freq                   6388                       6388         6388
#
#                  EINHEIT_LANG
# count                    6388
# unique                      1
# top     Franken pro Einwohner
# freq                     6388

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,388.00      6,388.00        6,388.00         6,388.00
# mean    111.39        431.00        2,005.34         1,582.80
# std      87.09          0.00            9.17         3,450.11
# min       0.00        431.00        1,990.00       -14,378.00
# 25%      32.00        431.00        1,997.00          -318.00
# 50%      97.00        431.00        2,005.00         1,546.50
# 75%     182.00        431.00        2,013.00         3,494.25
# max     298.00        431.00        2,021.00        15,199.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Statistik der Informationszugangsgesuche nach IDG des Kantons Zürich ab 2013

# %% [markdown]
# ### **Description**: Anzahl und Erledigungsart der schriftlich eingereichten Informationszugangsgesuche in der kantonalen Verwaltung. Nicht enthalten sind die – praxisgemäss viel zahlreicheren – sogenannten formlosen Gesuche. Darunter fallen insbesondere die telefonischen oder per Mail eingereichten Anfragen. Spalten: 'jahr'; 'organisationseinheit'; 'gesuche_haengig_jan' (am 1. Januar des Jahres); 'gesuche_total' (des gesamten Jahres); 'zugang_uneingeschraenkt_gewaehrt'; 'zugang_teilweise_gewaehrt'; 'zugang_vollstaendig_abgelehnt'; 'anderweitige_erledigung' (z.B. Rückzug, Gegenstandslosigkeit); 'gesuche_haengig_dez' (am 31. Dezember des Jahres).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **523@fachstelle-ogd-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-12-05T09:44:00`
# - **Modified** `2021-02-10T09:51:00`
# - **Startdate** `2013-01-01`
# - **Enddate** `2020-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['direktionen', 'kantonale_verwaltung', 'regierungsrat', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/kanton/kantonale-verwaltung/oeffentlichkeitsprinzip.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 968
# Title                    : Statistik der Informationszugangsgesuche nach IDG des Kantons Zürich
# Description              : None
# Issued                   : 2019-11-19T17:55:39
# Modified                 : 2021-02-10T09:51:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000523_00000968.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000523_00000968.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 72 rows (observations) and 9 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   jahr                              72 non-null     int64
#  1   organisationseinheit              72 non-null     object
#  2   gesuche_haengig_jan               46 non-null     float64
#  3   gesuche_total                     65 non-null     float64
#  4   zugang_uneingeschraenkt_gewaehrt  65 non-null     float64
#  5   zugang_teilweise_gewaehrt         45 non-null     float64
#  6   zugang_vollstaendig_abgelehnt     49 non-null     float64
#  7   anderweitige_erledigung           38 non-null     float64
#  8   gesuche_haengig_dez               50 non-null     float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 9.9 KB

# %%
df.head()
# Out:
#    jahr                 organisationseinheit  gesuche_haengig_jan  \
# 0  2013  Direktion der Justiz und des Innern                  1.0
# 1  2013                 Sicherheitsdirektion                  NaN
# 2  2013                      Finanzdirektion                  NaN
# 3  2013            Volkswirtschaftsdirektion                  NaN
# 4  2013                 Gesundheitsdirektion                  1.0
#
#    gesuche_total  zugang_uneingeschraenkt_gewaehrt  zugang_teilweise_gewaehrt  \
# 0           52.0                              45.0                        4.0
# 1           12.0                               4.0                        NaN
# 2           14.0                              14.0                        NaN
# 3            3.0                               2.0                        1.0
# 4           45.0                               8.0                        6.0
#
#    zugang_vollstaendig_abgelehnt  anderweitige_erledigung  gesuche_haengig_dez
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             60               20  \
# jahr                                      2019             2015
# organisationseinheit              Baudirektion  Finanzdirektion
# gesuche_haengig_jan                        4.0              1.0
# gesuche_total                              5.0             23.0
# zugang_uneingeschraenkt_gewaehrt           4.0             19.0
# zugang_teilweise_gewaehrt                  NaN              NaN
# zugang_vollstaendig_abgelehnt              NaN              1.0
# anderweitige_erledigung                    2.0              1.0
# gesuche_haengig_dez                        3.0              3.0
#
#                                                  32
# jahr                                           2016
# organisationseinheit              Bildungsdirektion
# gesuche_haengig_jan                             3.0
# gesuche_total                                  25.0
# zugang_uneingeschraenkt_gewaehrt               15.0
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                        organisationseinheit
# count                                    72
# unique                                    9
# top     Direktion der Justiz und des Innern
# freq                                      8

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           jahr  gesuche_haengig_jan  gesuche_total  \
# count    72.00                46.00          65.00
# mean  2,016.50                 6.70          44.00
# std       2.31                 7.60          54.72
# min   2,013.00                 1.00           1.00
# 25%   2,014.75                 2.00          10.00
# 50%   2,016.50                 3.50          25.00
# 75%   2,018.25                 8.75          45.00
# max   2,020.00                30.00         231.00
#
#        zugang_uneingeschraenkt_gewaehrt  zugang_teilweise_gewaehrt  \
# count                             65.00                      45.00
# mean                              24.46                       4.93
# std                               30.89                       4.95
# min                                1.00                       1.00
# 25%                                6.00                       1.00
# 50%                               13.00                       4.00
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Fachstelle Open Government Data des Kantons Zürich |  | info@open.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Badewasserqualität in öffentlichen Badeanstalten an Flüssen und Seen im Kanton Zürich

# %% [markdown]
# ### **Description**: In den Sommermonaten regelmässig erhobene Proben zur Überprüfung der Badewasserqualität. Daten enthalten: 'Name des Orts', 'Bewertungsstufen der Badewasserqualität', 'Breitengrad' und 'Längengrad des Orts'. Die Untersuchungen und Bewertungen der Wasserproben erfolgen nach den Empfehlungen zur Untersuchung und Beurteilung der Badewasserqualität von See- und Flussbädern des Bundesamtes für Umwelt (siehe "Weitere Informationen").

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **729@gesundheitsdirektion-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-08-03T15:33:00`
# - **Modified** `2022-10-04T10:35:55`
# - **Startdate** `2019-07-03`
# - **Enddate** `2022-09-22`
# - **Theme** `['Kultur, Medien, Informationsgesellschaft, Sport', 'Gesundheit', 'Raum, Umwelt']`
# - **Keyword** `['gesundheit', 'kanton_zuerich', 'seen', 'sport', 'wasser', 'ogd']`
# - **Publisher** `['Gesundheitsdirektion des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3341
# Title                    : Erhebung der Badewasserqualität in öffentlichen Badeanstalten an Flüssen und Seen im Kanton Zürich
# Description              : Variabeln: 'date' = Tag der Entnahme der Probe; 'id' = Identifikator des Orts; 'location' = Ausgeschriebener Name des Orts; 'quality' = Bewertungsstufen der Badewasserqualität; 'remark' = Optionale Anmerkungen zur Probe; 'source' = Organisation, welche die Probe durchführt; 'lat' = Breitengrad des Orts; 'long' = Längengrad des Orts; 'image' = Bild des Orts (wird nicht regelmässig aktualisiert; URL).
# Issued                   : 2022-10-17T16:13:37
# Modified                 : 2022-10-17T16:13:37
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000729_00003341.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000729_00003341.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 698 rows (observations) and 8 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      698 non-null    object
#  1   id        698 non-null    object
#  2   location  698 non-null    object
#  3   quality   698 non-null    object
#  4   source    698 non-null    object
#  5   lat       698 non-null    float64
#  6   long      698 non-null    float64
#  7   image     418 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 400.0 KB

# %%
df.head()
# Out:
#          date      id             location        quality  \
# 0  2019-07-24  999268  Küsnacht / Kusenbad  Ausgezeichnet
# 1  2020-05-26  999268  Küsnacht / Kusenbad  Ausgezeichnet
# 2  2020-07-20  999268  Küsnacht / Kusenbad  Ausgezeichnet
# 3  2021-05-20  999268  Küsnacht / Kusenbad  Ausgezeichnet
# 4  2021-07-15  999268  Küsnacht / Kusenbad  Ausgezeichnet
#
#                     source       lat      long image
# 0  Kantonales Labor Zürich  8.576564  47.32271   NaN
# 1  Kantonales Labor Zürich  8.576564  47.32271   NaN
# 2  Kantonales Labor Zürich  8.576564  47.32271   NaN
# 3  Kantonales Labor Zürich  8.576564  47.32271   NaN
# 4  Kantonales Labor Zürich  8.576564  47.32271   NaN

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                     398  \
# date                         2021-06-17
# id                               999390
# location  Zürich / Strandbad Mythenquai
# quality                   Ausgezeichnet
# source          Kantonales Labor Zürich
# lat                            8.537366
# long                          47.353521
# image                               NaN
#
#                                                         348  \
# date                                             2019-08-29
# id                                                   999372
# location                    Zürich / Flussbad Oberer Letten
# quality                                       Ausgezeichnet
# source                              Kantonales Labor Zürich
# lat                                                8.534637
# long                                              47.385633
# image     https://raw.githubusercontent.com/openZH/bathi...
#
#                               90
# date                   2020-08-17
# id                         999277
# location    Herrliberg / Steinrad
# quality             Ausgezeichnet
# source    Kantonales Labor Zürich
# lat                      8.600435
# long                    47.291393
# image                         NaN

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#               date      id                    location        quality  \
# count          698     698                         698            698
# unique          69      72                          72              3
# top     2022-06-27  999308  Zürich / Flussbad Au-Höngg  Ausgezeichnet
# freq            29      17                          17            628
#
#                          source  \
# count                       698
# unique                        2
# top     Kantonales Labor Zürich
# freq                        680
#
#                                                     image
# count                                                 418
# unique                                                 70
# top     https://raw.githubusercontent.com/openZH/bathi...
# freq                                                   15

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          lat   long
# count 698.00 698.00
# mean    8.62  47.34
# std     0.09   0.09
# min     8.45  47.18
# 25%     8.55  47.28
# 50%     8.62  47.35
# 75%     8.68  47.37
# max     8.83  47.69

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Gesundheitsdirektion des Kantons Zürich | Kantonales Labor | info@kl.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerfüsse der Zürcher Gemeinden für natürliche und juristische Personen

# %% [markdown]
# ### **Description**: Gemeindesteuerfüsse natürlicher und juristischer Personen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **711@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-12-10T00:00:00`
# - **Modified** `2023-01-06T06:48:37`
# - **Startdate** `2012-12-31`
# - **Enddate** `2023-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['gemeindesteuerfuesse', 'gemeindesteuern', 'juristische_personen', 'natuerliche_personen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1775
# Title                    : Zürcher Gemeindesteuerfüsse - aktuell
# Description              : NA
# Issued                   : 2020-12-10T15:35:17
# Modified                 : 2023-01-06T07:48:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/steuerfuesse/kanton_zuerich_stf_aktuell.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/steuerfuesse/kanton_zuerich_stf_aktuell.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1776
# Title                    : Zürcher Gemeindesteuerfüsse - Zeitreihe
# Description              : Gemeindesteuerfüsse seit 2012, ohne aktuelle Erhebung
# Issued                   : 2020-12-10T15:38:07
# Modified                 : 2022-05-13T08:10:10
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/steuerfuesse/kanton_zuerich_stf_timeseries.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/steuerfuesse/kanton_zuerich_stf_timeseries.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,831 rows (observations) and 16 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1831 entries, 0 to 1830
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YEAR           1831 non-null   int64
#  1   BFSNR          1831 non-null   int64
#  2   GDE_NAME       1831 non-null   object
#  3   STF_O_KIRCHE1  1831 non-null   int64
#  4   STF_O_KIRCHE2  1831 non-null   int64
#  5   STF_O_KIRCHE3  1831 non-null   int64
#  6   STF_REF1       1831 non-null   float64
#  7   STF_REF2       1831 non-null   int64
#  8   STF_REF2.1     1831 non-null   int64
#  9   STF_KATH1      1831 non-null   int64
#  10  STF_KATH2      1831 non-null   int64
#  11  STF_KATH3      1831 non-null   int64
#  12  STF_CKRKATH1   1831 non-null   int64
#  13  STF_CKRKATH2   1831 non-null   int64
#  14  STF_CKRKATH3   1831 non-null   int64
#  15  JUR_PERS       1831 non-null   float64
# dtypes: float64(2), int64(13), object(1)
# memory usage: 344.2 KB

# %%
df.head()
# Out:
#    YEAR  BFSNR        GDE_NAME  STF_O_KIRCHE1  STF_O_KIRCHE2  STF_O_KIRCHE3  \
# 0  2022      1     Aeugst a.A.             95              0              0
# 1  2022      2  Affoltern a.A.            124              0              0
# 2  2022      3      Bonstetten            109              0              0
# 3  2022      4     Hausen a.A.            112              0              0
# 4  2022      5        Hedingen            105              0              0
#
#    STF_REF1  STF_REF2  STF_REF2.1  STF_KATH1  STF_KATH2  STF_KATH3  \
# 0     107.0         0           0        108          0          0
# 1     136.0         0           0        137          0          0
# 2     121.0         0           0        120          0          0
# 3     124.0         0           0        126          0          0
# 4     117.0         0           0        118          0          0
#
#    STF_CKRKATH1  STF_CKRKATH2  STF_CKRKATH3  JUR_PERS
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                      488       906     1110
# YEAR                 2019      2017    2016
# BFSNR                   3       121     195
# GDE_NAME       Bonstetten  Wetzikon    Maur
# STF_O_KIRCHE1         109       119      87
# STF_O_KIRCHE2           0         0       0
# STF_O_KIRCHE3           0         0       0
# STF_REF1            122.0     133.0    96.5
# STF_REF2                0         0       0
# STF_REF2.1              0         0       0
# STF_KATH1             120       133      97
# STF_KATH2               0         0       0
# STF_KATH3               0         0       0
# STF_CKRKATH1          123       133     101
# STF_CKRKATH2            0         0       0
# STF_CKRKATH3            0         0       0
# JUR_PERS           121.14     133.0  96.685

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#            GDE_NAME
# count          1831
# unique          172
# top     Aeugst a.A.
# freq             11

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           YEAR    BFSNR  STF_O_KIRCHE1  STF_O_KIRCHE2  STF_O_KIRCHE3  \
# count 1,831.00 1,831.00       1,831.00       1,831.00       1,831.00
# mean  2,016.93   122.18         106.68           4.48           0.81
# std       3.16    79.68          13.15          22.31          10.00
# min   2,012.00     1.00          72.00           0.00           0.00
# 25%   2,014.00    55.00          99.00           0.00           0.00
# 50%   2,017.00   113.00         109.00           0.00           0.00
# 75%   2,020.00   193.00         116.00           0.00           0.00
# max   2,022.00   298.00         135.00         131.00         130.00
#
#        STF_REF1  STF_REF2  STF_REF2.1  STF_KATH1  STF_KATH2  STF_KATH3  \
# count  1,831.00  1,831.00    1,831.00   1,831.00   1,831.00   1,831.00
# mean     118.71      7.31        0.90     118.93       6.68       0.90
# std       14.27     29.39       11.08      14.29      28.11      11.11
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Management | daniel.cahn@statistik.ji.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Abfallmengen und Abfallgebühren in den Gemeinden im Kanton Zürich ab 2000

# %% [markdown]
# ### **Description**: Jährlich aktualisierte Zeitreihen der kommunalen Abfallmengen nach Abfallarten und der Abfallgebühren nach Gemeinden. Mehr Info in den Beschreibungen der Ressourcen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1803@awel-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-11-07T13:23:18`
# - **Modified** `2022-11-07T13:23:18`
# - **Startdate** `2000-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['abfall', 'abfallentsorgung', 'altglas', 'karton', 'kehricht', 'papier', 'recycling', 'siedlungsabfaelle', 'sperrgut', 'kunststoff', 'textilien', 'strassenabfall', 'abfallgebuehren', 'altoel', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gesetze-beschluesse/gesetzessammlung/zhlex-ls/erlass-712_1-1994_09_25-2001_01_01-085.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3460
# Title                    : Abfallmengen nach Abfallarten und Gemeinden
# Description              : Der Datensatz zeigt die Gesamtmenge der Siedlungsabfälle aus Haushalten und Betrieben, die bei der kommunalen Sammlung gesammelt wurden. Direkte Anlieferungen an Kehrichtverbrennungsanlagen und private Entsorgungslösungen, die nicht den kommunalen Weg nutzen, sind nicht enthalten. Die Siedlungsabfälle werden unterteilt in die Abfallarten Kehricht (einschliesslich Sperrgut), zum Recycling bestimmte Abfälle wie Altglas, Papier und Karton, Kunststoffe, Metalle, Altöl, biogene Abfälle sowie Textilien. Zudem werden mineralische Abfälle (Grubengut) erfasst. Seit 2007 werden auch Strassenabfälle aus Strassenwischern und Strassensammlerschlämme erfasst. Werte unter 500 kg werden auf 0 Tonnen abgerundet. Einige Gemeinden stellen nicht für alle Abfallarten Daten zur Verfügung, insbesondere für Kunststoffe und Textilien. Einträge mit (‘NA’) bedeuten, dass diese Abfallart in der Gemeinde nicht gesammelt wird oder keine Mengenangabe erfolgte.
# Issued                   : 2022-11-07T13:23:18
# Modified                 : 2022-11-07T13:23:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001803_00003460.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001803_00003460.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3461
# Title                    : Abfallgebühren nach Gemeinden
# Description              : Die Abfallgebühren sind in CHF inkl. MWST angegeben und werden als Abfallgrundgebühr (‘Grundgebuehr’) und Preis pro 35-Liter-Gebührensack (‘35-L-Sack’) ausgewiesen. Die Gebühren gelten für Privathaushalte. Die ‘Grundgebuehr’ gilt pro Kalenderjahr und wird zur Vergleichbarkeit von den Gemeinden auf eine Gebühr für eine 4-Zimmer-Wohnung umgerechnet. Es gibt Ausnahmen, bei denen eine solche Umrechnung nicht vorgenommen wird. Diese Fälle werden mit ‘0’ erfasst. Ebenso mit ‘0’ erfasst sind Gemeinden, wo keine Grundgebühr erhoben wird.
# Issued                   : 2022-11-07T13:23:18
# Modified                 : 2022-11-07T13:23:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001803_00003461.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001803_00003461.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 7,452 rows (observations) and 6 columns (variables).
# There seem to be 19 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7452 entries, 0 to 7451
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jahr           7452 non-null   int64
#  1   Gemeinde_Nr    7452 non-null   int64
#  2   Gemeinde       7452 non-null   object
#  3   Messkategorie  7407 non-null   object
#  4   Wert           7407 non-null   float64
#  5   Einheit        7452 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#    Jahr  Gemeinde_Nr     Gemeinde Messkategorie    Wert Einheit
# 0  2022            1  Aeugst a.A.  Grundgebuehr  204.63     CHF
# 1  2021            1  Aeugst a.A.  Grundgebuehr  204.63     CHF
# 2  2020            1  Aeugst a.A.  Grundgebuehr  204.63     CHF
# 3  2019            1  Aeugst a.A.  Grundgebuehr  204.63     CHF
# 4  2018            1  Aeugst a.A.  Grundgebuehr  205.20     CHF

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                        6815          887        2973
# Jahr                   2015          2009       2016
# Gemeinde_Nr             246            26         88
# Gemeinde       Oetwil a.d.L          Dorf    Neerach
# Messkategorie  Grundgebuehr  Grundgebuehr  35-L-Sack
# Wert                  129.6         100.0        1.8
# Einheit                 CHF           CHF        CHF

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#            Gemeinde Messkategorie Einheit
# count          7452          7407    7452
# unique          162             2       1
# top     Aeugst a.A.     35-L-Sack     CHF
# freq             46          3798    7452

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  Gemeinde_Nr     Wert
# count 7,452.00     7,452.00 7,407.00
# mean  2,011.00       124.97    55.30
# std       6.63        83.09    62.14
# min   2,000.00         1.00     0.00
# 25%   2,005.00        56.00     1.80
# 50%   2,011.00       112.50     2.50
# 75%   2,017.00       196.00   105.00
# max   2,022.00       298.00   290.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Abfallwirtschaft und Betriebe - Sektion Abfallwirtschaft | info.aw@bd.zh.ch

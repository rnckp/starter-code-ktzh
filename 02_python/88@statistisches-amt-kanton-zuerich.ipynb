# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Gesamtsteuerfuss (ohne Kirchen) [%]

# %% [markdown]
# ### **Description**: Bezogener Gesamtsteuerfuss ohne Kirchen in Prozent der einfachen Staatssteuer, gewichtet mit der Steuerkraft des jeweiligen Jahres. Zeitreihe ab 2012 (neues Finanzausgleichsgesetz). Details zu angewendeten Steuerfüssen sind direkt bei den jeweiligen Gemeinden einzuholen. Die Daten des aktuellsten Jahr sind provisorisch.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **88@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T07:31:42`
# - **Startdate** `2012-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'gemeindesteuerfuesse', 'gemeindesteuern', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 71
# Title                    : Gesamtsteuerfuss (ohne Kirchen) [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T09:13:50
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_65.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_65.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,909 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1909 entries, 0 to 1908
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1909 non-null   int64
#  1   GEBIET_NAME      1909 non-null   object
#  2   THEMA_NAME       1909 non-null   object
#  3   SET_NAME         1909 non-null   object
#  4   SUBSET_NAME      1909 non-null   object
#  5   INDIKATOR_ID     1909 non-null   int64
#  6   INDIKATOR_NAME   1909 non-null   object
#  7   INDIKATOR_JAHR   1909 non-null   int64
#  8   INDIKATOR_VALUE  1909 non-null   float64
#  9   EINHEIT_KURZ     1909 non-null   object
#  10  EINHEIT_LANG     1909 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME     SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
#
#            SUBSET_NAME  INDIKATOR_ID                       INDIKATOR_NAME  \
# 0  natürliche Personen            65  Gesamtsteuerfuss (ohne Kirchen) [%]
# 1  natürliche Personen            65  Gesamtsteuerfuss (ohne Kirchen) [%]
# 2  natürliche Personen            65  Gesamtsteuerfuss (ohne Kirchen) [%]
# 3  natürliche Personen            65  Gesamtsteuerfuss (ohne Kirchen) [%]
# 4  natürliche Personen            65  Gesamtsteuerfuss (ohne Kirchen) [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2012             96.0            %      Prozent
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 1120  \
# BFS_NR                                           160
# GEBIET_NAME                                  Zumikon
# THEMA_NAME                      Öffentliche Finanzen
# SET_NAME                                 Steuerfüsse
# SUBSET_NAME                      natürliche Personen
# INDIKATOR_ID                                      65
# INDIKATOR_NAME   Gesamtsteuerfuss (ohne Kirchen) [%]
# INDIKATOR_JAHR                                  2018
# INDIKATOR_VALUE                                 85.0
# EINHEIT_KURZ                                       %
# EINHEIT_LANG                                 Prozent
#
#                                                 1260  \
# BFS_NR                                           194
# GEBIET_NAME                               Greifensee
# THEMA_NAME                      Öffentliche Finanzen
# SET_NAME                                 Steuerfüsse
# SUBSET_NAME                      natürliche Personen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME     SET_NAME          SUBSET_NAME  \
# count          1909                  1909         1909                 1909
# unique          202                     1            1                    1
# top     Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse  natürliche Personen
# freq             10                  1909         1909                 1909
#
#                              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                  1909         1909         1909
# unique                                    1            1            1
# top     Gesamtsteuerfuss (ohne Kirchen) [%]            %      Prozent
# freq                                   1909         1909         1909

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,909.00      1,909.00        1,909.00         1,909.00
# mean    106.58         65.00        2,016.45           106.55
# std      84.48          0.00            2.87            12.86
# min       0.00         65.00        2,012.00            72.00
# 25%      30.00         65.00        2,014.00            99.00
# 50%      93.00         65.00        2,016.00           109.00
# 75%     178.00         65.00        2,019.00           116.00
# max     298.00         65.00        2,021.00           135.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

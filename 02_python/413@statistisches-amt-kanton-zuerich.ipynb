# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerfuss (ohne Kirchen) [%]

# %% [markdown]
# ### **Description**: Steuerfuss inkl. Schulgemeinde. Bei mehreren Primarschul- oder Oberstufenschulgemeinden auf dem Gemeindegebiet, wurde der erste Steuerfuss verwendet. Details zu angewendeten Steuerfüssen sind direkt bei den jeweiligen Gemeinden einzuholen. Zeitreihe ab 2012 (neues Finanzausgleichsgesetz).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **413@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-07-01T20:19:00`
# - **Modified** `2022-11-11T07:31:51`
# - **Startdate** `2012-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['gemeindefinanzen', 'gemeinden', 'gemeindesteuerfuesse', 'gemeindesteuern', 'kanton_zuerich', 'oeffentliche_finanzen', 'steuerfuss', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 729
# Title                    : Steuerfuss (ohne Kirchen) [%]
# Description              : None
# Issued                   : 2019-07-01T20:19:00
# Modified                 : 2022-04-11T09:11:46
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_839.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_839.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,831 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1831 entries, 0 to 1830
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1831 non-null   int64
#  1   GEBIET_NAME      1831 non-null   object
#  2   THEMA_NAME       1831 non-null   object
#  3   SET_NAME         1831 non-null   object
#  4   SUBSET_NAME      1831 non-null   object
#  5   INDIKATOR_ID     1831 non-null   int64
#  6   INDIKATOR_NAME   1831 non-null   object
#  7   INDIKATOR_JAHR   1831 non-null   int64
#  8   INDIKATOR_VALUE  1831 non-null   int64
#  9   EINHEIT_KURZ     1831 non-null   object
#  10  EINHEIT_LANG     1831 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME     SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
#
#            SUBSET_NAME  INDIKATOR_ID                 INDIKATOR_NAME  \
# 0  natürliche Personen           839  Steuerfuss (ohne Kirchen) [%]
# 1  natürliche Personen           839  Steuerfuss (ohne Kirchen) [%]
# 2  natürliche Personen           839  Steuerfuss (ohne Kirchen) [%]
# 3  natürliche Personen           839  Steuerfuss (ohne Kirchen) [%]
# 4  natürliche Personen           839  Steuerfuss (ohne Kirchen) [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2012               96            %      Prozent
# 1            2013               96            %      Prozent
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                           1634                           59    \
# BFS_NR                                     229                              6
# GEBIET_NAME            Wiesendangen (bis 2013)                    Kappel a.A.
# THEMA_NAME                Öffentliche Finanzen           Öffentliche Finanzen
# SET_NAME                           Steuerfüsse                    Steuerfüsse
# SUBSET_NAME                natürliche Personen            natürliche Personen
# INDIKATOR_ID                               839                            839
# INDIKATOR_NAME   Steuerfuss (ohne Kirchen) [%]  Steuerfuss (ohne Kirchen) [%]
# INDIKATOR_JAHR                            2013                           2016
# INDIKATOR_VALUE                             87                            112
# EINHEIT_KURZ                                 %                              %
# EINHEIT_LANG                           Prozent                        Prozent
#
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME     SET_NAME          SUBSET_NAME  \
# count          1831                  1831         1831                 1831
# unique          178                     1            1                    1
# top     Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse  natürliche Personen
# freq             11                  1831         1831                 1831
#
#                        INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                            1831         1831         1831
# unique                              1            1            1
# top     Steuerfuss (ohne Kirchen) [%]            %      Prozent
# freq                             1831         1831         1831

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,831.00      1,831.00        1,831.00         1,831.00
# mean    122.18        839.00        2,016.93           106.68
# std      79.68          0.00            3.16            13.15
# min       1.00        839.00        2,012.00            72.00
# 25%      55.00        839.00        2,014.00            99.00
# 50%     113.00        839.00        2,017.00           109.00
# 75%     193.00        839.00        2,020.00           116.00
# max     298.00        839.00        2,022.00           135.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

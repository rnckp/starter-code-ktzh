# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wanderungsbilanz [Pers.]

# %% [markdown]
# ### **Description**: Zuzüge minus Wegzüge (ohne Umzüge innerhalb der Gemeinden). Inkl. innerkantonaler Wanderungen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **201@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:34:56`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'wanderungen', 'zuzuege-wegzuege', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 164
# Title                    : Wanderungsbilanz [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:34:56
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_104.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_104.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,230 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6230 entries, 0 to 6229
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6230 non-null   int64
#  1   GEBIET_NAME      6230 non-null   object
#  2   THEMA_NAME       6230 non-null   object
#  3   SET_NAME         6230 non-null   object
#  4   SUBSET_NAME      6230 non-null   object
#  5   INDIKATOR_ID     6230 non-null   int64
#  6   INDIKATOR_NAME   6230 non-null   object
#  7   INDIKATOR_JAHR   6230 non-null   int64
#  8   INDIKATOR_VALUE  6230 non-null   int64
#  9   EINHEIT_KURZ     6230 non-null   object
#  10  EINHEIT_LANG     6230 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#           SUBSET_NAME  INDIKATOR_ID            INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Zuzüge und Wegzüge           104  Wanderungsbilanz [Pers.]            1990
# 1  Zuzüge und Wegzüge           104  Wanderungsbilanz [Pers.]            1991
# 2  Zuzüge und Wegzüge           104  Wanderungsbilanz [Pers.]            1992
# 3  Zuzüge und Wegzüge           104  Wanderungsbilanz [Pers.]            1993
# 4  Zuzüge und Wegzüge           104  Wanderungsbilanz [Pers.]            1994
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0               33        Pers.     Personen
# 1               31        Pers.     Personen
# 2               46        Pers.     Personen
# 3               15        Pers.     Personen
# 4               29        Pers.     Personen

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      4192                      4165  \
# BFS_NR                                195                       194
# GEBIET_NAME                          Maur                Greifensee
# THEMA_NAME       Bevölkerung und Soziales  Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbewegung      Bevölkerungsbewegung
# SUBSET_NAME            Zuzüge und Wegzüge        Zuzüge und Wegzüge
# INDIKATOR_ID                          104                       104
# INDIKATOR_NAME   Wanderungsbilanz [Pers.]  Wanderungsbilanz [Pers.]
# INDIKATOR_JAHR                       2010                      2015
# INDIKATOR_VALUE                       171                        17
# EINHEIT_KURZ                        Pers.                     Pers.
# EINHEIT_LANG                     Personen                  Personen
#
#                                      1019
# BFS_NR                                 38
# GEBIET_NAME                       Rheinau
# THEMA_NAME       Bevölkerung und Soziales
# SET_NAME             Bevölkerungsbewegung
# SUBSET_NAME            Zuzüge und Wegzüge
# INDIKATOR_ID                          104
# INDIKATOR_NAME   Wanderungsbilanz [Pers.]
# INDIKATOR_JAHR                       2020
# INDIKATOR_VALUE                       -24
# EINHEIT_KURZ                        Pers.
# EINHEIT_LANG                     Personen

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          6230                      6230                  6230
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             32                      6230                  6230
#
#                SUBSET_NAME            INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                 6230                      6230         6230         6230
# unique                   1                         1            1            1
# top     Zuzüge und Wegzüge  Wanderungsbilanz [Pers.]        Pers.     Personen
# freq                  6230                      6230         6230         6230

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,230.00      6,230.00        6,230.00         6,230.00
# mean    107.33        104.00        2,005.41           200.16
# std      84.16          0.00            9.20           958.97
# min       0.00        104.00        1,990.00        -2,265.00
# 25%      31.00        104.00        1,997.00            -3.00
# 50%      94.00        104.00        2,005.00            23.00
# 75%     178.00        104.00        2,013.00            95.00
# max     298.00        104.00        2,021.00        21,828.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

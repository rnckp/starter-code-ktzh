# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: KRW Wähleranteil BDP [%]

# %% [markdown]
# ### **Description**: Wähleranteil BDP bei Kantonsratswahlen

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **288@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-03-25T10:44:00`
# - **Startdate** `2011-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'nationalratswahlen', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 218
# Title                    : KRW Wähleranteil BDP [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-03-25T10:44:35
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_444.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_444.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 553 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           553 non-null    int64
#  1   GEBIET_NAME      553 non-null    object
#  2   THEMA_NAME       553 non-null    object
#  3   SET_NAME         553 non-null    object
#  4   SUBSET_NAME      553 non-null    object
#  5   INDIKATOR_ID     553 non-null    int64
#  6   INDIKATOR_NAME   553 non-null    object
#  7   INDIKATOR_JAHR   553 non-null    int64
#  8   INDIKATOR_VALUE  553 non-null    float64
#  9   EINHEIT_KURZ     553 non-null    object
#  10  EINHEIT_LANG     553 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 323.6 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           444
# 1       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           444
# 2       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           444
# 3       2  Affoltern a.A.    Politik  Wähleranteile  Kantonsrat           444
# 4       2  Affoltern a.A.    Politik  Wähleranteile  Kantonsrat           444
#
#              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  KRW Wähleranteil BDP [%]            2011              6.6            %
# 1  KRW Wähleranteil BDP [%]            2015              0.0            %
# 2  KRW Wähleranteil BDP [%]            2019              0.7            %
# 3  KRW Wähleranteil BDP [%]            2011              4.8            %
# 4  KRW Wähleranteil BDP [%]            2015              0.0            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                       261                       137  \
# BFS_NR                                117                        59
# GEBIET_NAME                        Hinwil                Hochfelden
# THEMA_NAME                        Politik                   Politik
# SET_NAME                    Wähleranteile             Wähleranteile
# SUBSET_NAME                    Kantonsrat                Kantonsrat
# INDIKATOR_ID                          444                       444
# INDIKATOR_NAME   KRW Wähleranteil BDP [%]  KRW Wähleranteil BDP [%]
# INDIKATOR_JAHR                       2011                      2019
# INDIKATOR_VALUE                       3.8                       2.1
# EINHEIT_KURZ                            %                         %
# EINHEIT_LANG                      Prozent                   Prozent
#
#                                       548
# BFS_NR                                  0
# GEBIET_NAME                 Region Zürich
# THEMA_NAME                        Politik
# SET_NAME                    Wähleranteile
# SUBSET_NAME                    Kantonsrat
# INDIKATOR_ID                          444
# INDIKATOR_NAME   KRW Wähleranteil BDP [%]
# INDIKATOR_JAHR                       2011
# INDIKATOR_VALUE                       1.5
# EINHEIT_KURZ                            %
# EINHEIT_LANG                      Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  \
# count           553        553            553         553
# unique          200          1              1           1
# top     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat
# freq              3        553            553         553
#
#                   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                        553          553          553
# unique                         1            1            1
# top     KRW Wähleranteil BDP [%]            %      Prozent
# freq                         553          553          553

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  553.00        553.00          553.00           553.00
# mean   111.97        444.00        2,014.76             3.42
# std     83.99          0.00            3.22             2.52
# min      0.00        444.00        2,011.00             0.00
# 25%     37.00        444.00        2,011.00             1.70
# 50%     97.00        444.00        2,015.00             3.00
# 75%    181.00        444.00        2,019.00             4.60
# max    298.00        444.00        2,019.00            21.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

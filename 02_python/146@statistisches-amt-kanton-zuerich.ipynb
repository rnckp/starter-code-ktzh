# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Motorräder [Anz.]

# %% [markdown]
# ### **Description**: Am 30. September eingelöste Motorräder. Hinweis: Der Wert für den ganzen Kanton umfasst alle Motorräder mit einem Zürcher Kennzeichen; diese können auch Personen oder Unternehmen gehören, die ihr Domizil nicht im Kanton Zürich haben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **146@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-21T00:00:00`
# - **Modified** `2022-11-03T12:45:40`
# - **Startdate** `2002-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'fahrzeuge', 'gemeinden', 'kanton_zuerich', 'motorfahrzeugbestand', 'motorfahrzeuge', 'motorraeder', 'privatverkehr', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 112
# Title                    : Motorräder [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-03T12:45:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_395.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_395.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,150 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4150 entries, 0 to 4149
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4150 non-null   int64
#  1   GEBIET_NAME      4150 non-null   object
#  2   THEMA_NAME       4150 non-null   object
#  3   SET_NAME         4150 non-null   object
#  4   SUBSET_NAME      4150 non-null   object
#  5   INDIKATOR_ID     4150 non-null   int64
#  6   INDIKATOR_NAME   4150 non-null   object
#  7   INDIKATOR_JAHR   4150 non-null   int64
#  8   INDIKATOR_VALUE  4150 non-null   int64
#  9   EINHEIT_KURZ     4150 non-null   object
#  10  EINHEIT_LANG     4150 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME           SUBSET_NAME  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
#
#    INDIKATOR_ID     INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           395  Motorräder [Anz.]            2002              160
# 1           395  Motorräder [Anz.]            2003              160
# 2           395  Motorräder [Anz.]            2004              166
# 3           395  Motorräder [Anz.]            2005              168
# 4           395  Motorräder [Anz.]            2006              168
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0         Anz.       Anzahl
# 1         Anz.       Anzahl
# 2         Anz.       Anzahl
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                  2686                  11    \
# BFS_NR                            193                     1
# GEBIET_NAME                 Fällanden           Aeugst a.A.
# THEMA_NAME            Raum und Umwelt       Raum und Umwelt
# SET_NAME                      Verkehr               Verkehr
# SUBSET_NAME      Motorfahrzeugbestand  Motorfahrzeugbestand
# INDIKATOR_ID                      395                   395
# INDIKATOR_NAME      Motorräder [Anz.]     Motorräder [Anz.]
# INDIKATOR_JAHR                   2022                  2013
# INDIKATOR_VALUE                   898                   203
# EINHEIT_KURZ                     Anz.                  Anz.
# EINHEIT_LANG                   Anzahl                Anzahl
#
#                                  3092
# BFS_NR                            224
# GEBIET_NAME                   Pfungen
# THEMA_NAME            Raum und Umwelt
# SET_NAME                      Verkehr
# SUBSET_NAME      Motorfahrzeugbestand
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME           SUBSET_NAME  \
# count          4150             4150     4150                  4150
# unique          202                1        1                     1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  Motorfahrzeugbestand
# freq             21             4150     4150                  4150
#
#            INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                4150         4150         4150
# unique                  1            1            1
# top     Motorräder [Anz.]         Anz.       Anzahl
# freq                 4150         4150         4150

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,150.00      4,150.00        4,150.00         4,150.00
# mean    110.91        395.00        2,011.84         1,922.98
# std      87.21          0.00            6.01         7,444.96
# min       0.00        395.00        2,002.00            14.00
# 25%      32.00        395.00        2,007.00           162.00
# 50%      96.00        395.00        2,012.00           362.00
# 75%     182.00        395.00        2,017.00           818.00
# max     298.00        395.00        2,022.00       117,271.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

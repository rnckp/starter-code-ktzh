# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Neu gegründete Unternehmen Total [Anz.]

# %% [markdown]
# ### **Description**: Neu gegründete Unternehmen (2. und 3. Sektor). Die Statistik der Neugründungen erfasst nur tatsächlich - also «ex nihilo» - neu entstandene Unternehmen mit marktwirtschaftlicher Tätigkeit. Aus Fusionen, Übernahmen, Spaltungen oder Restrukturierungen hervorgegangene Unternehmen werden folglich nicht berücksichtigt. Werte < 4 werden nicht ausgewiesen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **396@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2017-05-26T12:00:00`
# - **Modified** `2022-04-11T12:32:42`
# - **Startdate** `2013-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Arbeit, Erwerb']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'unternehmen', 'unternehmensstruktur', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 489
# Title                    : Neu gegründete Unternehmen Total [Anz.]
# Description              : None
# Issued                   : 2017-05-26T12:00:00
# Modified                 : 2022-04-11T12:32:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_353.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_353.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,346 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1346 entries, 0 to 1345
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1346 non-null   int64
#  1   GEBIET_NAME      1346 non-null   object
#  2   THEMA_NAME       1346 non-null   object
#  3   SET_NAME         1346 non-null   object
#  4   SUBSET_NAME      1346 non-null   object
#  5   INDIKATOR_ID     1346 non-null   int64
#  6   INDIKATOR_NAME   1346 non-null   object
#  7   INDIKATOR_JAHR   1346 non-null   int64
#  8   INDIKATOR_VALUE  1184 non-null   float64
#  9   EINHEIT_KURZ     1346 non-null   object
#  10  EINHEIT_LANG     1346 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1010.1 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen
# 1       1  Aeugst a.A.  Arbeit und Unternehmen
# 2       1  Aeugst a.A.  Arbeit und Unternehmen
# 3       1  Aeugst a.A.  Arbeit und Unternehmen
# 4       1  Aeugst a.A.  Arbeit und Unternehmen
#
#                                        SET_NAME             SUBSET_NAME  \
# 0  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
# 1  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
# 2  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
# 3  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
# 4  Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
#
#    INDIKATOR_ID                           INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           353  Neu gegründete Unternehmen Total [Anz.]            2013
# 1           353  Neu gegründete Unternehmen Total [Anz.]            2014
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                          203   \
# BFS_NR                                                     36
# GEBIET_NAME                          Oberstammheim (bis 2018)
# THEMA_NAME                             Arbeit und Unternehmen
# SET_NAME         Betriebe, Beschäftigte (Sektoren 1, 2 und 3)
# SUBSET_NAME                            Unternehmensgründungen
# INDIKATOR_ID                                              353
# INDIKATOR_NAME        Neu gegründete Unternehmen Total [Anz.]
# INDIKATOR_JAHR                                           2016
# INDIKATOR_VALUE                                           NaN
# EINHEIT_KURZ                                             Anz.
# EINHEIT_LANG                                           Anzahl
#
#                                                          680   \
# BFS_NR                                                    139
# GEBIET_NAME                                        Rüschlikon
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME  \
# count          1346                    1346
# unique          202                       1
# top     Aeugst a.A.  Arbeit und Unternehmen
# freq              7                    1346
#
#                                             SET_NAME             SUBSET_NAME  \
# count                                           1346                    1346
# unique                                             1                       1
# top     Betriebe, Beschäftigte (Sektoren 1, 2 und 3)  Unternehmensgründungen
# freq                                            1346                    1346
#
#                                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                      1346         1346         1346
# unique                                        1            1            1
# top     Neu gegründete Unternehmen Total [Anz.]         Anz.       Anzahl
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,346.00      1,346.00        1,346.00         1,184.00
# mean    110.35        353.00        2,015.94           180.89
# std      87.52          0.00            2.00           714.35
# min       0.00        353.00        2,013.00             4.00
# 25%      31.00        353.00        2,014.00            11.00
# 50%      95.00        353.00        2,016.00            23.00
# 75%     181.75        353.00        2,018.00            75.00
# max     298.00        353.00        2,019.00         8,212.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

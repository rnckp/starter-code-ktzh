# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Neuzulassungen  Dieselmotor [%]

# %% [markdown]
# ### **Description**: Anteil der Personenwagen (PW) mit Dieselmotor an allen Personenwagen, die zwischen dem 1. Oktober des Vorjahrs und dem 30. September erstmals in Verkehr gesetzt wurden. Hinweis: Der Wert für den ganzen Kanton umfasst alle Autos mit einem Zürcher Kennzeichen; diese können auch Personen oder Unternehmen gehören, die ihr Domizil nicht im Kanton Zürich haben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **686@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-05-25T00:00:00`
# - **Modified** `2022-11-03T12:45:40`
# - **Startdate** `2002-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'fahrzeuge', 'gemeinden', 'kanton_zuerich', 'motorfahrzeugbestand', 'motorfahrzeuge', 'personenwagen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1646
# Title                    : Neuzulassungen  Dieselmotor [%]
# Description              : None
# Issued                   : 2020-05-25T00:00:00
# Modified                 : 2022-11-03T12:45:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_610.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_610.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,150 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4150 entries, 0 to 4149
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4150 non-null   int64
#  1   GEBIET_NAME      4150 non-null   object
#  2   THEMA_NAME       4150 non-null   object
#  3   SET_NAME         4150 non-null   object
#  4   SUBSET_NAME      4150 non-null   object
#  5   INDIKATOR_ID     4150 non-null   int64
#  6   INDIKATOR_NAME   4150 non-null   object
#  7   INDIKATOR_JAHR   4150 non-null   int64
#  8   INDIKATOR_VALUE  4150 non-null   float64
#  9   EINHEIT_KURZ     4150 non-null   object
#  10  EINHEIT_LANG     4150 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr
#
#                           SUBSET_NAME  INDIKATOR_ID  \
# 0  PW-Neuzulassungen nach Antriebsart           610
# 1  PW-Neuzulassungen nach Antriebsart           610
# 2  PW-Neuzulassungen nach Antriebsart           610
# 3  PW-Neuzulassungen nach Antriebsart           610
# 4  PW-Neuzulassungen nach Antriebsart           610
#
#                     INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Neuzulassungen  Dieselmotor [%]            2002             10.6
# 1  Neuzulassungen  Dieselmotor [%]            2003             12.5
# 2  Neuzulassungen  Dieselmotor [%]            2004             15.4
# 3  Neuzulassungen  Dieselmotor [%]            2005             28.6
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                2322  \
# BFS_NR                                          158
# GEBIET_NAME                                   Stäfa
# THEMA_NAME                          Raum und Umwelt
# SET_NAME                                    Verkehr
# SUBSET_NAME      PW-Neuzulassungen nach Antriebsart
# INDIKATOR_ID                                    610
# INDIKATOR_NAME      Neuzulassungen  Dieselmotor [%]
# INDIKATOR_JAHR                                 2006
# INDIKATOR_VALUE                                20.0
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                2054  \
# BFS_NR                                          137
# GEBIET_NAME                              Oberrieden
# THEMA_NAME                          Raum und Umwelt
# SET_NAME                                    Verkehr
# SUBSET_NAME      PW-Neuzulassungen nach Antriebsart
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME  \
# count          4150             4150     4150
# unique          202                1        1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr
# freq             21             4150     4150
#
#                                SUBSET_NAME                   INDIKATOR_NAME  \
# count                                 4150                             4150
# unique                                   1                                1
# top     PW-Neuzulassungen nach Antriebsart  Neuzulassungen  Dieselmotor [%]
# freq                                  4150                             4150
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          4150         4150
# unique            1            1
# top               %      Prozent
# freq           4150         4150

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,150.00      4,150.00        4,150.00         4,150.00
# mean    110.91        610.00        2,011.84            27.46
# std      87.21          0.00            6.01            10.06
# min       0.00        610.00        2,002.00             0.00
# 25%      32.00        610.00        2,007.00            20.70
# 50%      96.00        610.00        2,012.00            27.40
# 75%     182.00        610.00        2,017.00            34.50
# max     298.00        610.00        2,022.00            71.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

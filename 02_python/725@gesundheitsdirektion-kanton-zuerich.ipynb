# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: COVID_19 Impfkampagne im Kanton Zürich ab 18.01.2021 bis 12.10.2022

# %% [markdown]
# ### **Description**: Erfolgte Impfungen im Kanton Zürich. Die Daten der ersten Wochen der Impfkampagne im Jahr 2021 wurden mittels Massenimports integriert und daraufhin bereinigt. Seit dem 12. Oktober 2022 werden diese Daten-Ressourcen nicht mehr aktualisiert. Nützliche, weiterhin aktualisierte Daten stellt das Bundesamt für Gesundheit zur Verfügung (siehe Links unter "Weitere Informationen").

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **725@gesundheitsdirektion-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-09-14T14:53:00`
# - **Modified** `2022-10-28T16:34:44`
# - **Startdate** `2021-01-01`
# - **Enddate** `2022-10-12`
# - **Theme** `['Gesundheit']`
# - **Keyword** `['alter', 'altersgruppen', 'altersklassen', 'bezirke', 'geschlecht', 'gesundheit', 'kanton_zuerich', 'krankheiten', 'wohnsitz', 'corona', 'covid-19', 'sars-cov-2', 'covid19', 'ogd']`
# - **Publisher** `['Gesundheitsdirektion des Kantons Zürich']`
# - **Landingpage** `https://github.com/openZH/covid_19_vaccination_campaign_ZH`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1845
# Title                    : Kumulierte Anzahl Impfungen nach 10-Jahres-Altersklassen, Geschlecht pro Tag ab 18.01.2021 bis 12.10.2022
# Description              : Anzahl Personen nach 10-Jahres-Altersklassen ('0-9', '10-19', '20-29', .., '80+') und Geschlecht ('d'=divers, 'f'=weiblich, 'm'=männlich, 'NA'=unbekannt), die insgesamt im Kanton Zürich ab dem 18.01.2021 bis und mit Stichtag eine Coronavirus-Impfung ('atLeastOneDose', 'completedBasicImmu' oder 'booster') erhalten haben. Aus Datenschutzgründen sind die Daten der ersten paar Tage auf den 18.01.2021 aggregiert. Die Daten wurden bis zum 12. Oktober 2022 einmal werktags aktualisiert. Nützliche, weiterhin aktualisierte Daten stellt das Bundesamt für Gesundheit zur Verfügung (siehe Links im Datensatz unter "Weitere Informationen").
# Issued                   : 2021-06-11T09:51:02
# Modified                 : 2022-10-28T16:22:29
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Datum_Altersklasse_Geschlecht_v2.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Datum_Altersklasse_Geschlecht_v2.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1880
# Title                    : Kumulierte Anzahl Impfungen im Kanton Zürich wohnhafter Personen nach 1-Jahres-Altersklassen für die jeweils vergangene Kalenderwoche bis 12.10.2022
# Description              : Anzahl Personen nach 1-Jahres-Altersklassen ('0', '1', '2', .., '100+'), die insgesamt im Kanton Zürich in der jeweils vergangenen Kalenderwoche eine Coronavirus-Impfung ('atLeastOneDose', 'completedBasicImmu' oder 'booster') erhalten haben. Die Daten wurden bis zum 12. Oktober 2022 jeweils Montags für die Vorwoche aktualisiert. Nützliche, weiterhin aktualisierte Daten stellt das Bundesamt für Gesundheit zur Verfügung (siehe Links im Datensatz unter "Weitere Informationen").
# Issued                   : 2021-09-14T14:42:59
# Modified                 : 2022-10-28T16:21:08
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_Alter_in_KTZH_wohnhaft_v2.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_Alter_in_KTZH_wohnhaft_v2.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 1879
# Title                    : Kumulierte Anzahl Impfungen nach Postleitzahl pro Kalenderwoche ab 18.01.2021 bis 12.10.2022
# Description              : Anzahl im Kanton Zürich wohnhafter Personen nach Postleitzahl, die insgesamt im Kanton Zürich ab dem 18.01.2021 bis und mit Stichtag eine Coronavirus-Impfung ('atLeastOneDose', 'completedBasicImmu' oder 'booster') erhalten haben. Aus Datenschutzgründen sind die Daten der ersten paar Wochen auf die Kalenderwoche 3 aggregiert. Die Daten wurden bis zum 12. Oktober 2022 einmal wöchentlich aktualisiert. Nützliche, weiterhin aktualisierte Daten stellt das Bundesamt für Gesundheit zur Verfügung (siehe Links im Datensatz unter "Weitere Informationen").
# Issued                   : 2021-09-14T14:24:16
# Modified                 : 2022-10-28T16:19:54
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_PLZ_v2.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_PLZ_v2.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 1846
# Title                    : Kumulierte Anzahl Impfungen nach Wohnsitz pro Kalenderwoche ab 18.01.2021 bis 12.10.2022
# Description              : Anzahl Personen nach Wohnsitz (Bezirke des Kantons Zürich ('bfsNumber' = BFS-Nummer des Bezirks), 'ZH aber ausserkantonal geimpft' (von Menschen mit Wohnsitz im Kanton ZH, die ausserkantonal geimpft wurden, sind keine Wohnsitzinformationen nach Bezirken vorhanden), 'Nachbarkantone', 'andere Kantone' oder 'unbekannt'), die insgesamt im Kanton Zürich ab dem 18.01.2021 bis und mit Kalenderwoche eine Coronavirus-Impfung ('atLeastOneDose', 'completedBasicImmu' oder 'booster') erhalten haben. Aus Datenschutzgründen sind die Daten der ersten paar Wochen auf die Kalenderwoche 3 aggregiert. Die Daten wurden bis zum 12. Oktober 2022 einmal wöchentlich aktualisiert. Nützliche, weiterhin aktualisierte Daten stellt das Bundesamt für Gesundheit zur Verfügung (siehe Links im Datensatz unter "Weitere Informationen").
# Issued                   : 2021-06-11T10:08:09
# Modified                 : 2022-10-28T16:19:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_Wohnsitz_v2.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_vaccination_campaign_ZH/master/COVID19_Impfungen_pro_Woche_Wohnsitz_v2.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,275 rows (observations) and 7 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4275 entries, 0 to 4274
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   week_from      4275 non-null   object
#  1   week_until     4275 non-null   object
#  2   calendar_week  4275 non-null   int64
#  3   bfsNumber      3204 non-null   float64
#  4   residence      4272 non-null   object
#  5   vacc_status    4275 non-null   object
#  6   nCumul         4275 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.2 MB

# %%
df.head()
# Out:
#     week_from  week_until  calendar_week  bfsNumber           residence  \
# 0  2021-01-01  2021-01-24              3      101.0    Bezirk Affoltern
# 1  2021-01-01  2021-01-24              3      101.0    Bezirk Affoltern
# 2  2021-01-01  2021-01-24              3      101.0    Bezirk Affoltern
# 3  2021-01-01  2021-01-24              3      102.0  Bezirk Andelfingen
# 4  2021-01-01  2021-01-24              3      102.0  Bezirk Andelfingen
#
#           vacc_status  nCumul
# 0      atLeastOneDose     764
# 1  completedBasicImmu       0
# 2             booster       0
# 3      atLeastOneDose     574
# 4  completedBasicImmu       0

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                              577             3249              1355
# week_from              2021-04-12      2022-05-02        2021-08-02
# week_until             2021-04-18      2022-05-08        2021-08-08
# calendar_week                  15              18                31
# bfsNumber                   101.0           112.0             104.0
# residence        Bezirk Affoltern   Bezirk Zurich  Bezirk Dielsdorf
# vacc_status    completedBasicImmu  atLeastOneDose           booster
# nCumul                       3446          316563                 0

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#          week_from  week_until         residence     vacc_status
# count         4275        4275              4272            4275
# unique          89          89                16               3
# top     2022-09-26  2022-10-02  Bezirk Affoltern  atLeastOneDose
# freq            51          51               267            1425

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        calendar_week  bfsNumber     nCumul
# count       4,275.00   3,204.00   4,275.00
# mean           24.22     106.50  43,379.40
# std            13.65       3.45  59,577.77
# min             1.00     101.00       0.00
# 25%            13.00     103.75   3,807.50
# 50%            24.00     106.50  25,972.00
# 75%            35.00     109.25  61,793.00
# max            52.00     112.00 317,070.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Gesundheitsdirektion des Kantons Zürich | Coronavirus-Hotline | gdstab@gd.zh.ch

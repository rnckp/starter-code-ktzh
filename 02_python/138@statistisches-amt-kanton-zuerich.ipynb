# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Ø steuerbares Einkommen natürliche Pers. [Fr.]

# %% [markdown]
# ### **Description**: Durchschnittliches steuerbares Einkommen ordentlich besteuerter natürlichen Personen (exkl. Quellensteuerpflichtige und ausserhalb des Kt. wohnhafte). Hinweis: Sehr hohe Beträge einiger weniger Steuerpflichtigen wirken sich entsprechend stark auf den Mittelwert aus. Bis 1998: Reineinkommen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **138@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-13T09:49:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'natuerliche_personen', 'steuerbares_einkommen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 104
# Title                    : Ø steuerbares Einkommen natürliche Pers. [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-13T09:49:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_282.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_282.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,340 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6340 entries, 0 to 6339
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6340 non-null   int64
#  1   GEBIET_NAME      6340 non-null   object
#  2   THEMA_NAME       6340 non-null   object
#  3   SET_NAME         6340 non-null   object
#  4   SUBSET_NAME      6340 non-null   object
#  5   INDIKATOR_ID     6340 non-null   int64
#  6   INDIKATOR_NAME   6340 non-null   object
#  7   INDIKATOR_JAHR   6340 non-null   int64
#  8   INDIKATOR_VALUE  6340 non-null   int64
#  9   EINHEIT_KURZ     6340 non-null   object
#  10  EINHEIT_LANG     6340 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME         SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
#
#         SUBSET_NAME  INDIKATOR_ID  \
# 0  Steuergrundlagen           282
# 1  Steuergrundlagen           282
# 2  Steuergrundlagen           282
# 3  Steuergrundlagen           282
# 4  Steuergrundlagen           282
#
#                                    INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Ø steuerbares Einkommen natürliche Pers. [Fr.]            1990
# 1  Ø steuerbares Einkommen natürliche Pers. [Fr.]            1991
# 2  Ø steuerbares Einkommen natürliche Pers. [Fr.]            1992
# 3  Ø steuerbares Einkommen natürliche Pers. [Fr.]            1993
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                            933   \
# BFS_NR                                                       36
# GEBIET_NAME                            Oberstammheim (bis 2018)
# THEMA_NAME                                 Öffentliche Finanzen
# SET_NAME                                        Gemeindesteuern
# SUBSET_NAME                                    Steuergrundlagen
# INDIKATOR_ID                                                282
# INDIKATOR_NAME   Ø steuerbares Einkommen natürliche Pers. [Fr.]
# INDIKATOR_JAHR                                             1995
# INDIKATOR_VALUE                                           50009
# EINHEIT_KURZ                                                Fr.
# EINHEIT_LANG                                            Franken
#
#                                                            3693  \
# BFS_NR                                                      171
# GEBIET_NAME                                    Bauma (bis 2014)
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME         SET_NAME       SUBSET_NAME  \
# count          6340                  6340             6340              6340
# unique          200                     1                1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern  Steuergrundlagen
# freq             32                  6340             6340              6340
#
#                                         INDIKATOR_NAME EINHEIT_KURZ  \
# count                                             6340         6340
# unique                                               1            1
# top     Ø steuerbares Einkommen natürliche Pers. [Fr.]          Fr.
# freq                                              6340         6340
#
#        EINHEIT_LANG
# count          6340
# unique            1
# top         Franken
# freq           6340

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,340.00      6,340.00        6,340.00         6,340.00
# mean    110.56        282.00        2,005.37        62,791.89
# std      86.89          0.00            9.18        17,565.29
# min       0.00        282.00        1,990.00        32,234.00
# 25%      32.00        282.00        1,997.00        53,281.00
# 50%      96.00        282.00        2,005.00        59,042.00
# 75%     181.00        282.00        2,013.00        66,630.25
# max     298.00        282.00        2,021.00       581,506.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

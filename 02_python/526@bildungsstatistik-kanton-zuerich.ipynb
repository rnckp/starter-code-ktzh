# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lernende der Mittelschulen im Kanton Zürich ab 2000

# %% [markdown]
# ### **Description**: Zu den Mittelschulen zählen neben den klassischen Gymnasien auch Handels- und Informatikmittelschulen, Fachmittelschulen und Passarellen-Lehrgänge.
#
# Die Mittelschulen schliessen mit der gymnasialen Maturität, der Berufsmaturität, dem Fachmittelschulausweis oder der Fachmaturität ab und öffnen den Zugang zur höheren Berufsbildung, zu Fachhochschulen, Universitäten und Eidgenössisch Technischen Hochschulen.
#
# Die Daten werden jährlich für den Stichtag 15.9. erhoben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **526@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-12-02T13:15:00`
# - **Modified** `2022-10-21T15:11:33`
# - **Startdate** `2000-09-15`
# - **Enddate** `2021-09-15`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['ausbildung', 'bildung', 'bildungsstufe', 'gymnasien', 'handelsschulen', 'lernende', 'mittelschulen', 'schueler', 'schuelerinnen', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1009
# Title                    : Lernende der Mittelschulen im Kanton Zürich ab 2000
# Description              : Die Daten sind differenziert nach Jahr, Stufe, Typ, Profil, Geschlecht, Finanzierung und Staatsangehörigkeit. Jahr: Das Jahr ist jeweils das Kalenderjahr der Erhebung, wobei der Stichtag der 15.9. ist. Die Daten für das Jahr 2021 sind somit im Schuljahr 2021/22 erhoben worden und zeigen den Datenstand am 15. September 2021. Stufe: Die Lernenden der Mittelstufe sind zum Teil auf der Sekundarstufe I und zum Teil auf der Sekundarstufe II. Die Sekundarstufe II beginnt nach dem Ende der obligatorischen Schulzeit. Mittelschultyp: Beim Typ der Mittelschule wird zwischen Gymnasium, Handelsmittelschule, Fachmittelschule und Informatikmittelschule unterschieden. In der Restkategorie "andere" sind enthalten: Passerelle und allgemeinbildende Privatschule mit eigenem Programm. Bildungsart: Bei den Gymnasien vor 2011: Profil, danach Schwerpunktfach. Bei den Fachmittelschulen: Profil und ab 2015 Fachmaturität. Finanzierung: Es wird zwischen öffentlich finanzierten Bildungsinstitutionen (oeff) und privat finanzierten Bildungsinstitutionen (priv) unterscheidet. Staatsangehoerigkeit: Es wird pro Person nur eine Staatsangehörigkeit erhoben. Falls eine Person mehrere Staatsangehörigkeiten hat, und eine davon ist die Schweizerische, so wird diese prioritär erfasst. Bei anderen mehrfachen Staatsangehörigkeiten wir keine Vorgabe zur Priorisierung gemacht. In dieser Auswertung  wird nur zwischen Schweiz und Ausland unterschieden. Anzahl: Anzahl der Schülerinnen und Schüler mit der entsprechenden Merkmalskombination.
# Issued                   : 2019-11-24T15:52:46
# Modified                 : 2022-10-21T15:11:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Mittelschulen.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Mittelschulen.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,828 rows (observations) and 10 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3828 entries, 0 to 3827
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Stand                 3828 non-null   object
#  1   Kanton                3828 non-null   object
#  2   Jahr                  3828 non-null   int64
#  3   Stufe                 3828 non-null   object
#  4   Mittelschultyp        3828 non-null   object
#  5   Bildungsart           3828 non-null   object
#  6   Geschlecht            3828 non-null   object
#  7   Finanzierung          3828 non-null   object
#  8   Staatsangehoerigkeit  3828 non-null   object
#  9   Anzahl                3828 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 2.0 MB

# %%
df.head()
# Out:
#         Stand Kanton  Jahr            Stufe Mittelschultyp  \
# 0  2022-10-21     zh  2021  Sekundarstufe I      Gymnasium
# 1  2022-10-21     zh  2021  Sekundarstufe I      Gymnasium
# 2  2022-10-21     zh  2021  Sekundarstufe I      Gymnasium
# 3  2022-10-21     zh  2021  Sekundarstufe I      Gymnasium
# 4  2022-10-21     zh  2021  Sekundarstufe I      Gymnasium
#
#             Bildungsart Geschlecht Finanzierung Staatsangehoerigkeit  Anzahl
# 0  Gymnasium Unterstufe          F          oef              Schweiz    1912
# 1  Gymnasium Unterstufe          M          oef              Schweiz    1713
# 2  Gymnasium Unterstufe          F          oef              Ausland     310
# 3  Gymnasium Unterstufe          M          oef              Ausland     296
# 4  Gymnasium Unterstufe          M         priv              Schweiz      93

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                           2120                       3332  \
# Stand                               2022-10-21                 2022-10-21
# Kanton                                      zh                         zh
# Jahr                                      2011                       2003
# Stufe                          Sekundarstufe I            Sekundarstufe I
# Mittelschultyp                       Gymnasium        Handelsmittelschule
# Bildungsart           SPF Wirtschaft und Recht  Handelsmittelschule (HMS)
# Geschlecht                                   M                          M
# Finanzierung                               oef                        oef
# Staatsangehoerigkeit                   Ausland                    Ausland
# Anzahl                                      28                          6
#
#                                       224
# Stand                           2022-10-21
# Kanton                                  zh
# Jahr                                  2020
# Stufe                      Sekundarstufe I
# Mittelschultyp                   Gymnasium
# Bildungsart           Gymnasium Unterstufe
# Geschlecht                               M
# Finanzierung                           oef
# Staatsangehoerigkeit               Ausland
# Anzahl                                 306

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#              Stand Kanton             Stufe Mittelschultyp  \
# count         3828   3828              3828           3828
# unique           1      1                 2              7
# top     2022-10-21     zh  Sekundarstufe II      Gymnasium
# freq          3828   3828              2457           2598
#
#                                Bildungsart Geschlecht Finanzierung  \
# count                                 3828       3828         3828
# unique                                  43          2            2
# top     Gymnasium vor Wahl Schwerpunktfach          F          oef
# freq                                   273       1938         2044
#
#        Staatsangehoerigkeit
# count                  3828
# unique                    2
# top                 Schweiz
# freq                   2078

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr   Anzahl
# count 3,828.00 3,828.00
# mean  2,011.65   104.07
# std       6.29   247.35
# min   2,000.00     1.00
# 25%   2,007.00     5.00
# 50%   2,012.00    19.00
# 75%   2,017.00    75.00
# max   2,021.00 1,912.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

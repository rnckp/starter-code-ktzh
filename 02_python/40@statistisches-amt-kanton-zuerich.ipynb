# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Kindergarten [Anz.]

# %% [markdown]
# ### **Description**: Anzahl KindergartenschülerInnen inkl. Grundstufe (nach Wohnort)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **40@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'kindergarten', 'schueler', 'schuelerinnen', 'schulen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 33
# Title                    : Schül. Kindergarten [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_143.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_143.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,236 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6236 non-null   int64
#  1   GEBIET_NAME      6236 non-null   object
#  2   THEMA_NAME       6236 non-null   object
#  3   SET_NAME         6236 non-null   object
#  4   SUBSET_NAME      6236 non-null   object
#  5   INDIKATOR_ID     6236 non-null   int64
#  6   INDIKATOR_NAME   6236 non-null   object
#  7   INDIKATOR_JAHR   6236 non-null   int64
#  8   INDIKATOR_VALUE  6236 non-null   int64
#  9   EINHEIT_KURZ     6236 non-null   object
#  10  EINHEIT_LANG     6236 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#            SUBSET_NAME  INDIKATOR_ID              INDIKATOR_NAME  \
# 0  Schüler Volksschule           143  Schül. Kindergarten [Anz.]
# 1  Schüler Volksschule           143  Schül. Kindergarten [Anz.]
# 2  Schüler Volksschule           143  Schül. Kindergarten [Anz.]
# 3  Schüler Volksschule           143  Schül. Kindergarten [Anz.]
# 4  Schüler Volksschule           143  Schül. Kindergarten [Anz.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            1990               30         Anz.       Anzahl
# 1            1991               28         Anz.       Anzahl
# 2            1992               36         Anz.       Anzahl
# 3            1993               41         Anz.       Anzahl
# 4            1994               34         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                        477                         3232  \
# BFS_NR                                   21                         139
# GEBIET_NAME                         Adlikon                  Rüschlikon
# THEMA_NAME         Bevölkerung und Soziales    Bevölkerung und Soziales
# SET_NAME                            Bildung                     Bildung
# SUBSET_NAME             Schüler Volksschule         Schüler Volksschule
# INDIKATOR_ID                            143                         143
# INDIKATOR_NAME   Schül. Kindergarten [Anz.]  Schül. Kindergarten [Anz.]
# INDIKATOR_JAHR                         2019                        2011
# INDIKATOR_VALUE                          21                          87
# EINHEIT_KURZ                           Anz.                        Anz.
# EINHEIT_LANG                         Anzahl                      Anzahl
#
#                                        3836
# BFS_NR                                  176
# GEBIET_NAME                          Lindau
# THEMA_NAME         Bevölkerung und Soziales
# SET_NAME                            Bildung
# SUBSET_NAME             Schüler Volksschule
# INDIKATOR_ID                            143
# INDIKATOR_NAME   Schül. Kindergarten [Anz.]
# INDIKATOR_JAHR                         2000
# INDIKATOR_VALUE                          99
# EINHEIT_KURZ                           Anz.
# EINHEIT_LANG                         Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME          SUBSET_NAME  \
# count          6236                      6236     6236                 6236
# unique          200                         1        1                    1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung  Schüler Volksschule
# freq             32                      6236     6236                 6236
#
#                     INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                         6236         6236         6236
# unique                           1            1            1
# top     Schül. Kindergarten [Anz.]         Anz.       Anzahl
# freq                          6236         6236         6236

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,236.00      6,236.00        6,236.00         6,236.00
# mean    107.59        143.00        2,005.43           556.31
# std      84.41          0.00            9.20         2,160.98
# min       0.00        143.00        1,990.00             0.00
# 25%      31.00        143.00        1,997.00            38.00
# 50%      94.00        143.00        2,005.00            96.00
# 75%     178.00        143.00        2,013.00           228.00
# max     298.00        143.00        2,021.00        34,334.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Geb.Vol. Infrastruktur: Anteil [%]

# %% [markdown]
# ### **Description**: Approximatives Gebäudevolumen in den Bereichen Unterricht, Gesundheit, Kultur/Sport, Verkehr und Ver-/Entsorgung

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **96@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T09:40:43`
# - **Startdate** `1990-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gebaeude', 'gebaeudeart', 'gemeinden', 'infrastruktur', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 77
# Title                    : Geb.Vol. Infrastruktur: Anteil [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T09:40:43
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_161.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_161.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,453 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4453 entries, 0 to 4452
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4453 non-null   int64
#  1   GEBIET_NAME      4453 non-null   object
#  2   THEMA_NAME       4453 non-null   object
#  3   SET_NAME         4453 non-null   object
#  4   SUBSET_NAME      4453 non-null   object
#  5   INDIKATOR_ID     4453 non-null   int64
#  6   INDIKATOR_NAME   4453 non-null   object
#  7   INDIKATOR_JAHR   4453 non-null   int64
#  8   INDIKATOR_VALUE  4453 non-null   float64
#  9   EINHEIT_KURZ     4453 non-null   object
#  10  EINHEIT_LANG     4453 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 1       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 2       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 3       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# 4       1  Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
#
#       SUBSET_NAME  INDIKATOR_ID                      INDIKATOR_NAME  \
# 0  Gebäudevolumen           161  Geb.Vol. Infrastruktur: Anteil [%]
# 1  Gebäudevolumen           161  Geb.Vol. Infrastruktur: Anteil [%]
# 2  Gebäudevolumen           161  Geb.Vol. Infrastruktur: Anteil [%]
# 3  Gebäudevolumen           161  Geb.Vol. Infrastruktur: Anteil [%]
# 4  Gebäudevolumen           161  Geb.Vol. Infrastruktur: Anteil [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                2247  \
# BFS_NR                                          136
# GEBIET_NAME                            Langnau a.A.
# THEMA_NAME                       Bau und Immobilien
# SET_NAME           Gebäudevolumen, Bauinvestitionen
# SUBSET_NAME                          Gebäudevolumen
# INDIKATOR_ID                                    161
# INDIKATOR_NAME   Geb.Vol. Infrastruktur: Anteil [%]
# INDIKATOR_JAHR                                 2012
# INDIKATOR_VALUE                                 9.4
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                842   \
# BFS_NR                                           43
# GEBIET_NAME                                  Volken
# THEMA_NAME                       Bau und Immobilien
# SET_NAME           Gebäudevolumen, Bauinvestitionen
# SUBSET_NAME                          Gebäudevolumen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                          SET_NAME  \
# count          4453                4453                              4453
# unique          200                   1                                 1
# top     Aeugst a.A.  Bau und Immobilien  Gebäudevolumen, Bauinvestitionen
# freq             23                4453                              4453
#
#            SUBSET_NAME                      INDIKATOR_NAME EINHEIT_KURZ  \
# count             4453                                4453         4453
# unique               1                                   1            1
# top     Gebäudevolumen  Geb.Vol. Infrastruktur: Anteil [%]            %
# freq              4453                                4453         4453
#
#        EINHEIT_LANG
# count          4453
# unique            1
# top         Prozent
# freq           4453

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,453.00      4,453.00        4,453.00         4,453.00
# mean    106.84        161.00        2,009.62             8.10
# std      83.91          0.00            7.57             4.81
# min       0.00        161.00        1,990.00             0.50
# 25%      31.00        161.00        2,004.00             5.70
# 50%      94.00        161.00        2,010.00             7.50
# 75%     178.00        161.00        2,016.00             9.50
# max     298.00        161.00        2,022.00            52.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

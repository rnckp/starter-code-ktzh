# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Höhe [m.ü.M.]

# %% [markdown]
# ### **Description**: Höhe des Hauptsiedlungsgebietes, erhoben bei den Gemeinden 1995 (i.d.R. die Höhe des Dorfzentrums, der reformierten Kirche oder des Gemeindehauses)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **183@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2016-06-15T13:42:12`
# - **Startdate** `1995-12-31`
# - **Enddate** `1995-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['bezirke', 'gemeinden', 'geographie', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 147
# Title                    : Höhe [m.ü.M.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2016-06-15T13:42:12
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_43.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_43.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 174 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           174 non-null    int64
#  1   GEBIET_NAME      174 non-null    object
#  2   THEMA_NAME       174 non-null    object
#  3   SET_NAME         174 non-null    object
#  4   SUBSET_NAME      174 non-null    object
#  5   INDIKATOR_ID     174 non-null    int64
#  6   INDIKATOR_NAME   174 non-null    object
#  7   INDIKATOR_JAHR   174 non-null    int64
#  8   INDIKATOR_VALUE  174 non-null    int64
#  9   EINHEIT_KURZ     174 non-null    object
#  10  EINHEIT_LANG     174 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 120.3 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME       THEMA_NAME             SET_NAME SUBSET_NAME  \
# 0       1     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen        Höhe
# 1       2  Affoltern a.A.  Raum und Umwelt  Geographie, Flächen        Höhe
# 2       3      Bonstetten  Raum und Umwelt  Geographie, Flächen        Höhe
# 3       4     Hausen a.A.  Raum und Umwelt  Geographie, Flächen        Höhe
# 4       5        Hedingen  Raum und Umwelt  Geographie, Flächen        Höhe
#
#    INDIKATOR_ID INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0            43  Höhe [m.ü.M.]            1995              700       m.ü.M.
# 1            43  Höhe [m.ü.M.]            1995              494       m.ü.M.
# 2            43  Höhe [m.ü.M.]            1995              528       m.ü.M.
# 3            43  Höhe [m.ü.M.]            1995              617       m.ü.M.
# 4            43  Höhe [m.ü.M.]            1995              497       m.ü.M.
#
#       EINHEIT_LANG
# 0  Meter über Meer
# 1  Meter über Meer
# 2  Meter über Meer
# 3  Meter über Meer
# 4  Meter über Meer

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                  123                  32                   129
# BFS_NR                           178                   39                  192
# GEBIET_NAME                 Russikon     Thalheim a.d.Th.                  Egg
# THEMA_NAME           Raum und Umwelt      Raum und Umwelt      Raum und Umwelt
# SET_NAME         Geographie, Flächen  Geographie, Flächen  Geographie, Flächen
# SUBSET_NAME                     Höhe                 Höhe                 Höhe
# INDIKATOR_ID                      43                   43                   43
# INDIKATOR_NAME         Höhe [m.ü.M.]        Höhe [m.ü.M.]        Höhe [m.ü.M.]
# INDIKATOR_JAHR                  1995                 1995                 1995
# INDIKATOR_VALUE                  610                  385                  548
# EINHEIT_KURZ                  m.ü.M.               m.ü.M.               m.ü.M.
# EINHEIT_LANG         Meter über Meer      Meter über Meer      Meter über Meer

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME             SET_NAME SUBSET_NAME  \
# count           174              174                  174         174
# unique          174                1                    1           1
# top     Aeugst a.A.  Raum und Umwelt  Geographie, Flächen        Höhe
# freq              1              174                  174         174
#
#        INDIKATOR_NAME EINHEIT_KURZ     EINHEIT_LANG
# count             174          174              174
# unique              1            1                1
# top     Höhe [m.ü.M.]       m.ü.M.  Meter über Meer
# freq              174          174              174

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  174.00        174.00          174.00           174.00
# mean   124.14         43.00        1,995.00           477.39
# std     80.17          0.00            0.00            87.71
# min      1.00         43.00        1,995.00           360.00
# 25%     56.25         43.00        1,995.00           420.00
# 50%    115.50         43.00        1,995.00           443.00
# 75%    192.75         43.00        1,995.00           517.00
# max    298.00         43.00        1,995.00           870.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

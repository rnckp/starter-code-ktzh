# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Verkäufe von unbebautem Land [Anz.]

# %% [markdown]
# ### **Description**: Freihandverkäufe von unbebautem Land der Wohn- und Mischzone (Zentrums-, Kern- und Wohn/Gewerbezonen) inkl. Abbruchliegenschaften. Bis ins Jahr 2011 wurden Verkäufe ab Plan (in der Regel bei Stockwerkeigentum) als unbebaute Liegenschaft erfasst. Die Anzahl Verkäufe ist ab 2011 entsprechend tiefer als zuvor. Die letzten drei Jahre sind provisorisch.
# Weitere Infos: www.zh.ch/bodenpreise

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **116@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-17T15:56:32`
# - **Startdate** `2007-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Preise']`
# - **Keyword** `['bauland', 'bezirke', 'freihandverkaeufe', 'gemeinden', 'handaenderungen', 'kanton_zuerich', 'wohnbauland', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 96
# Title                    : Verkäufe von unbebautem Land [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-17T15:56:32
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_402.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_402.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,790 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2790 entries, 0 to 2789
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2790 non-null   int64
#  1   GEBIET_NAME      2790 non-null   object
#  2   THEMA_NAME       2790 non-null   object
#  3   SET_NAME         2790 non-null   object
#  4   SUBSET_NAME      2790 non-null   object
#  5   INDIKATOR_ID     2790 non-null   int64
#  6   INDIKATOR_NAME   2790 non-null   object
#  7   INDIKATOR_JAHR   2790 non-null   int64
#  8   INDIKATOR_VALUE  2790 non-null   int64
#  9   EINHEIT_KURZ     2790 non-null   object
#  10  EINHEIT_LANG     2790 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 1       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 2       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 3       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 4       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
#
#    INDIKATOR_ID                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           402  Verkäufe von unbebautem Land [Anz.]            2007
# 1           402  Verkäufe von unbebautem Land [Anz.]            2008
# 2           402  Verkäufe von unbebautem Land [Anz.]            2009
# 3           402  Verkäufe von unbebautem Land [Anz.]            2010
# 4           402  Verkäufe von unbebautem Land [Anz.]            2011
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0                2         Anz.       Anzahl
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 1590  \
# BFS_NR                                           160
# GEBIET_NAME                                  Zumikon
# THEMA_NAME                        Bau und Immobilien
# SET_NAME                            Immobilienhandel
# SUBSET_NAME                             Baulandpreis
# INDIKATOR_ID                                     402
# INDIKATOR_NAME   Verkäufe von unbebautem Land [Anz.]
# INDIKATOR_JAHR                                  2007
# INDIKATOR_VALUE                                   17
# EINHEIT_KURZ                                    Anz.
# EINHEIT_LANG                                  Anzahl
#
#                                                 309   \
# BFS_NR                                            27
# GEBIET_NAME                              Feuerthalen
# THEMA_NAME                        Bau und Immobilien
# SET_NAME                            Immobilienhandel
# SUBSET_NAME                             Baulandpreis
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# count          2790                2790              2790          2790
# unique          186                   1                 1             1
# top     Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# freq             15                2790              2790          2790
#
#                              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                  2790         2790         2790
# unique                                    1            1            1
# top     Verkäufe von unbebautem Land [Anz.]         Anz.       Anzahl
# freq                                   2790         2790         2790

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,790.00      2,790.00        2,790.00         2,790.00
# mean    108.84        402.00        2,014.00            17.29
# std      88.15          0.00            4.32            76.96
# min       0.00        402.00        2,007.00             0.00
# 25%      29.00        402.00        2,010.00             1.00
# 50%      92.50        402.00        2,014.00             3.00
# 75%     182.00        402.00        2,018.00             9.00
# max     298.00        402.00        2,021.00         1,688.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wohnungsbestand nach Zimmerzahl und Quartier in der Stadt Winterthur ab 2020

# %% [markdown]
# ### **Description**: Zeitreihe des Wohnungsbestandes in der Stadt Winterthur nach Wohnungsgrösse (Zimmerzahl) und Quartier.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1602@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T17:27:44`
# - **Modified** `2022-09-21T10:09:36`
# - **Startdate** `2020-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['gemeinden', 'wohnungen', 'wohnungsbestand', 'zimmerzahl', 'quartier', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/bauen-und-wohnen`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3060
# Title                    : Anzahl Wohnungen nach Zimmerzahl, Quartier und Jahr
# Description              : Variablen: 'NrQuartier' = offizielle Quartiernummer; 'NameQuartier' = Name des Quartiers; '1_ZWHG' = Anzahl Einzimmerwohnungen; '2_ZWHG' = Anzahl Zweizimmerwohnungen; …; '6_ZWHG' = Anzahl Sechszimmerwohnungen: 'Unbekannt' = Anzahl Wohnungen mit unbekannter Zimmerzahl; 'Gesamt' = Gesamtzahl der Wohnungen.
# Issued                   : 2022-09-20T17:27:44
# Modified                 : 2022-09-20T17:27:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001602_00003060.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001602_00003060.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 86 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Jahr          86 non-null     int64
#  1   NrQuartier    84 non-null     float64
#  2   NameQuartier  86 non-null     object
#  3   1_ZWHG        86 non-null     int64
#  4   2_ZWHG        86 non-null     int64
#  5   3_ZWHG        86 non-null     int64
#  6   4_ZWHG        86 non-null     int64
#  7   5_ZWHG        86 non-null     int64
#  8   6_ZWHG        86 non-null     int64
#  9   Unbekannt     86 non-null     int64
#  10  Gesamt        86 non-null     int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 12.3 KB

# %%
df.head()
# Out:
#    Jahr  NrQuartier NameQuartier  1_ZWHG  2_ZWHG  3_ZWHG  4_ZWHG  5_ZWHG  \
# 0  2020       110.0     Altstadt     313     412     384     245      91
# 1  2020       120.0         Lind     451     390     842     808     330
# 2  2020       130.0   Heiligberg     168     240     380     397     272
# 3  2020       140.0      Tssfeld     247     390     659     519     100
# 4  2020       150.0     Brhlberg     144     165     277     273     107
#
#    6_ZWHG  Unbekannt  Gesamt
# 0      42          2    1489
# 1     332          1    3154
# 2     219          0    1676
# 3      34          1    1950
# 4     111          0    1077

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                  44     15     8
# Jahr           2021   2020   2020
# NrQuartier    120.0  310.0  230.0
# NameQuartier   Lind  Waser   Grze
# 1_ZWHG          450    105     57
# 2_ZWHG          389    428    361
# 3_ZWHG          844    943    608
# 4_ZWHG          807    845    414
# 5_ZWHG          332    268     65
# 6_ZWHG          333     67     18
# Unbekannt         1      1      0
# Gesamt         3156   2657   1523

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        NameQuartier
# count            86
# unique           43
# top        Altstadt
# freq              2

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  NrQuartier   1_ZWHG   2_ZWHG    3_ZWHG    4_ZWHG   5_ZWHG  \
# count    86.00       84.00    86.00    86.00     86.00     86.00    86.00
# mean  2,020.50      394.64   179.74   387.56    837.98    775.42   306.88
# std       0.50      189.32   581.71 1,243.61  2,687.99  2,482.58   983.56
# min   2,020.00      110.00     0.00     4.00      7.00      8.00     3.00
# 25%   2,020.00      250.00     4.50    45.00    106.75    129.75    82.25
# 50%   2,020.50      355.00    55.00   165.00    408.50    420.50   119.50
# 75%   2,021.00      610.00   140.75   389.00    731.00    574.50   251.75
# max   2,021.00      730.00 3,872.00 8,420.00 18,128.00 16,748.00 6,618.00
#
#         6_ZWHG  Unbekannt    Gesamt
# count    86.00      86.00     86.00
# mean    160.42       0.74  2,648.74
# std     516.04       2.47  8,482.43
# min       1.00       0.00     26.00
# 25%      28.25       0.00    517.25
# 50%      61.00       0.00  1,439.00
# 75%     120.25       1.00  2,126.00
# max   3,453.00      18.00 57,253.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

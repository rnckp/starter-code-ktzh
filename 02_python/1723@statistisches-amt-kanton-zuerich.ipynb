# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Gemeinnützige Wohnungen in Gemeinden des Kantons Zürich [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Wohnungen in Gebäuden, die dem gemeinnützigen Sektor zuzuordnen sind. Das Bundesamt für Wohnungswesen (BWO), das die Daten erhebt, schätzt, dass rund 90 Prozent aller sich im Besitz des gemeinnützigen Sektors befindlichen Wohnungen erfasst werden. Nicht erfasst werden Wohnungen in Gebäuden in direktem kommunalen Besitz (in der Stadt Zürich zum Beispiel die städtischen Wohnungen). Es ist nicht zulässig, die jährliche Veränderung des Indikators als reale Zu- bzw. Abnahme des gemeinnützigen Wohnungsbestandes zu interpretieren, weil die Datengrundlage nur alle fünf Jahre systematisch aktualisiert wird. Insbesondere grosse Veränderungen sind in der Regel der nachträglichen Erfassung von Gebäuden geschuldet.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1723@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-19T16:46:33`
# - **Modified** `2022-09-19T16:46:33`
# - **Startdate** `2016-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'mietwohnungen', 'wohnungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3221
# Title                    : Gemeinnützige Wohnungen [Anz.]
# Description              : None
# Issued                   : 2022-09-19T16:46:33
# Modified                 : 2022-09-19T16:46:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_840.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_840.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 956 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           956 non-null    int64
#  1   GEBIET_NAME      956 non-null    object
#  2   THEMA_NAME       956 non-null    object
#  3   SET_NAME         956 non-null    object
#  4   SUBSET_NAME      956 non-null    object
#  5   INDIKATOR_ID     956 non-null    int64
#  6   INDIKATOR_NAME   956 non-null    object
#  7   INDIKATOR_JAHR   956 non-null    int64
#  8   INDIKATOR_VALUE  956 non-null    int64
#  9   EINHEIT_KURZ     956 non-null    object
#  10  EINHEIT_LANG     956 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 613.5 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID                  INDIKATOR_NAME  \
# 0  Wohnungsbestand           840  Gemeinnützige Wohnungen [Anz.]
# 1  Wohnungsbestand           840  Gemeinnützige Wohnungen [Anz.]
# 2  Wohnungsbestand           840  Gemeinnützige Wohnungen [Anz.]
# 3  Wohnungsbestand           840  Gemeinnützige Wohnungen [Anz.]
# 4  Wohnungsbestand           840  Gemeinnützige Wohnungen [Anz.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2016                0         Anz.       Anzahl
# 1            2017                0         Anz.       Anzahl
# 2            2018                0         Anz.       Anzahl
# 3            2019                0         Anz.       Anzahl
# 4            2020                0         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             842  \
# BFS_NR                                        0
# GEBIET_NAME                  Bezirk Andelfingen
# THEMA_NAME                   Bau und Immobilien
# SET_NAME            Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                     Wohnungsbestand
# INDIKATOR_ID                                840
# INDIKATOR_NAME   Gemeinnützige Wohnungen [Anz.]
# INDIKATOR_JAHR                             2017
# INDIKATOR_VALUE                             127
# EINHEIT_KURZ                               Anz.
# EINHEIT_LANG                             Anzahl
#
#                                             311  \
# BFS_NR                                       84
# GEBIET_NAME                            Dällikon
# THEMA_NAME                   Bau und Immobilien
# SET_NAME            Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                     Wohnungsbestand
# INDIKATOR_ID                                840
# INDIKATOR_NAME   Gemeinnützige Wohnungen [Anz.]
# INDIKATOR_JAHR                             2018
# INDIKATOR_VALUE                              21
# EINHEIT_KURZ                               Anz.
# EINHEIT_LANG                             Anzahl
#
#                                             855
# BFS_NR                                        0
# GEBIET_NAME                    Bezirk Dielsdorf
# THEMA_NAME                   Bau und Immobilien
# SET_NAME            Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                     Wohnungsbestand
# INDIKATOR_ID                                840
# INDIKATOR_NAME   Gemeinnützige Wohnungen [Anz.]
# INDIKATOR_JAHR                             2020
# INDIKATOR_VALUE                            1995
# EINHEIT_KURZ                               Anz.
# EINHEIT_LANG                             Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count           956                 956                          956
# unique          196                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq              5                 956                          956
#
#             SUBSET_NAME                  INDIKATOR_NAME EINHEIT_KURZ  \
# count               956                             956          956
# unique                1                               1            1
# top     Wohnungsbestand  Gemeinnützige Wohnungen [Anz.]         Anz.
# freq                956                             956          956
#
#        EINHEIT_LANG
# count           956
# unique            1
# top          Anzahl
# freq            956

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  956.00        956.00          956.00           956.00
# mean   109.04        840.00        2,017.97         1,470.33
# std     87.58          0.00            1.41         7,461.91
# min      0.00        840.00        2,016.00             0.00
# 25%     30.00        840.00        2,017.00             0.00
# 50%     93.00        840.00        2,018.00            50.00
# 75%    181.25        840.00        2,019.00           291.00
# max    298.00        840.00        2,020.00        73,686.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

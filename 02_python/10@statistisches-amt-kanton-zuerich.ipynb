# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: KRW Wähleranteil SD [%]

# %% [markdown]
# ### **Description**: Wähleranteil SD bei Kantonsratswahlen

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **10@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2016-06-24T11:38:30`
# - **Startdate** `1999-12-31`
# - **Enddate** `2015-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kantonsratswahlen', 'kanton_zuerich', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 9
# Title                    : KRW Wähleranteil SD [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2016-06-24T11:38:30
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_439.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_439.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 973 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           973 non-null    int64
#  1   GEBIET_NAME      973 non-null    object
#  2   THEMA_NAME       973 non-null    object
#  3   SET_NAME         973 non-null    object
#  4   SUBSET_NAME      973 non-null    object
#  5   INDIKATOR_ID     973 non-null    int64
#  6   INDIKATOR_NAME   973 non-null    object
#  7   INDIKATOR_JAHR   973 non-null    int64
#  8   INDIKATOR_VALUE  973 non-null    float64
#  9   EINHEIT_KURZ     973 non-null    object
#  10  EINHEIT_LANG     973 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 567.9 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           439
# 1       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           439
# 2       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           439
# 3       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           439
# 4       1  Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           439
#
#             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  KRW Wähleranteil SD [%]            1999              0.0            %
# 1  KRW Wähleranteil SD [%]            2003              0.0            %
# 2  KRW Wähleranteil SD [%]            2007              0.5            %
# 3  KRW Wähleranteil SD [%]            2011              0.4            %
# 4  KRW Wähleranteil SD [%]            2015              0.0            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      58                       91   \
# BFS_NR                                12                       25
# GEBIET_NAME                   Rifferswil                  Dachsen
# THEMA_NAME                       Politik                  Politik
# SET_NAME                   Wähleranteile            Wähleranteile
# SUBSET_NAME                   Kantonsrat               Kantonsrat
# INDIKATOR_ID                         439                      439
# INDIKATOR_NAME   KRW Wähleranteil SD [%]  KRW Wähleranteil SD [%]
# INDIKATOR_JAHR                      2011                     2003
# INDIKATOR_VALUE                      0.0                      0.0
# EINHEIT_KURZ                           %                        %
# EINHEIT_LANG                     Prozent                  Prozent
#
#                                      415
# BFS_NR                               112
# GEBIET_NAME                      Bubikon
# THEMA_NAME                       Politik
# SET_NAME                   Wähleranteile
# SUBSET_NAME                   Kantonsrat
# INDIKATOR_ID                         439
# INDIKATOR_NAME   KRW Wähleranteil SD [%]
# INDIKATOR_JAHR                      1999
# INDIKATOR_VALUE                      3.0
# EINHEIT_KURZ                           %
# EINHEIT_LANG                     Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  \
# count           973        973            973         973
# unique          196          1              1           1
# top     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat
# freq              5        973            973         973
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                       973          973          973
# unique                        1            1            1
# top     KRW Wähleranteil SD [%]            %      Prozent
# freq                        973          973          973

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  973.00        973.00          973.00           973.00
# mean   106.09        439.00        2,007.02             0.78
# std     82.70          0.00            5.65             1.24
# min      0.00        439.00        1,999.00             0.00
# 25%     31.00        439.00        2,003.00             0.00
# 50%     94.00        439.00        2,007.00             0.10
# 75%    177.00        439.00        2,011.00             1.10
# max    298.00        439.00        2,015.00             9.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

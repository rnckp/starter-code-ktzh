# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wasserverbrauch pro Tag und Kopf [Liter]

# %% [markdown]
# ### **Description**: Mittlerer Tagesverbrauch: Die Pro-Kopf-Werte müssen unter Vorbehalt betrachtet werden, da sie auch den Verbrauch von Industrie und Gewerbe mit einschliessen und deshalb nicht als haushaltstypisch angesehen werden können.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **181@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-30T16:55:49`
# - **Startdate** `2006-12-31`
# - **Enddate** `None`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'trinkwasser', 'wasser', 'wasserverbrauch', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 145
# Title                    : Wasserverbrauch pro Tag und Kopf [Liter]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-30T16:55:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_469.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_469.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,918 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2918 entries, 0 to 2917
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2918 non-null   int64
#  1   GEBIET_NAME      2918 non-null   object
#  2   THEMA_NAME       2918 non-null   object
#  3   SET_NAME         2918 non-null   object
#  4   SUBSET_NAME      2918 non-null   object
#  5   INDIKATOR_ID     2918 non-null   int64
#  6   INDIKATOR_NAME   2918 non-null   object
#  7   INDIKATOR_JAHR   2918 non-null   int64
#  8   INDIKATOR_VALUE  2874 non-null   float64
#  9   EINHEIT_KURZ     2918 non-null   object
#  10  EINHEIT_LANG     2918 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch           469
# 1       1  Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch           469
# 2       1  Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch           469
# 3       1  Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch           469
# 4       1  Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch           469
#
#                              INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Wasserverbrauch pro Tag und Kopf [Liter]            2006            248.0
# 1  Wasserverbrauch pro Tag und Kopf [Liter]            2007            231.0
# 2  Wasserverbrauch pro Tag und Kopf [Liter]            2008            235.0
# 3  Wasserverbrauch pro Tag und Kopf [Liter]            2009            228.0
# 4  Wasserverbrauch pro Tag und Kopf [Liter]            2010            209.0
#
#               EINHEIT_KURZ                 EINHEIT_LANG
# 0  Liter pro Tag und Einw.  Liter pro Tag und Einwohner
# 1  Liter pro Tag und Einw.  Liter pro Tag und Einwohner
# 2  Liter pro Tag und Einw.  Liter pro Tag und Einwohner
# 3  Liter pro Tag und Einw.  Liter pro Tag und Einwohner
# 4  Liter pro Tag und Einw.  Liter pro Tag und Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                      1402  \
# BFS_NR                                                131
# GEBIET_NAME                                      Adliswil
# THEMA_NAME                                Raum und Umwelt
# SET_NAME                                           Umwelt
# SUBSET_NAME                                     Verbrauch
# INDIKATOR_ID                                          469
# INDIKATOR_NAME   Wasserverbrauch pro Tag und Kopf [Liter]
# INDIKATOR_JAHR                                       2019
# INDIKATOR_VALUE                                     189.0
# EINHEIT_KURZ                      Liter pro Tag und Einw.
# EINHEIT_LANG                  Liter pro Tag und Einwohner
#
#                                                      882   \
# BFS_NR                                                 72
# GEBIET_NAME                                        Winkel
# THEMA_NAME                                Raum und Umwelt
# SET_NAME                                           Umwelt
# SUBSET_NAME                                     Verbrauch
# INDIKATOR_ID                                          469
# INDIKATOR_NAME   Wasserverbrauch pro Tag und Kopf [Liter]
# INDIKATOR_JAHR                                       2009
# INDIKATOR_VALUE                                     248.0
# EINHEIT_KURZ                      Liter pro Tag und Einw.
# EINHEIT_LANG                  Liter pro Tag und Einwohner
#
#                                                      136
# BFS_NR                                                 10
# GEBIET_NAME                                      Obfelden
# THEMA_NAME                                Raum und Umwelt
# SET_NAME                                           Umwelt
# SUBSET_NAME                                     Verbrauch
# INDIKATOR_ID                                          469
# INDIKATOR_NAME   Wasserverbrauch pro Tag und Kopf [Liter]
# INDIKATOR_JAHR                                       2007
# INDIKATOR_VALUE                                     237.0
# EINHEIT_KURZ                      Liter pro Tag und Einw.
# EINHEIT_LANG                  Liter pro Tag und Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME SUBSET_NAME  \
# count          2918             2918     2918        2918
# unique          202                1        1           1
# top     Aeugst a.A.  Raum und Umwelt   Umwelt   Verbrauch
# freq             15             2918     2918        2918
#
#                                   INDIKATOR_NAME             EINHEIT_KURZ  \
# count                                       2918                     2918
# unique                                         1                        1
# top     Wasserverbrauch pro Tag und Kopf [Liter]  Liter pro Tag und Einw.
# freq                                        2918                     2918
#
#                        EINHEIT_LANG
# count                          2918
# unique                            1
# top     Liter pro Tag und Einwohner
# freq                           2918

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,918.00      2,918.00        2,918.00         2,874.00
# mean    107.97        469.00        2,012.94           260.43
# std      85.04          0.00            4.30            62.38
# min       0.00        469.00        2,006.00           108.00
# 25%      31.00        469.00        2,009.00           218.00
# 50%      94.00        469.00        2,013.00           249.00
# 75%     179.00        469.00        2,017.00           287.00
# max     298.00        469.00        2,020.00         1,036.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

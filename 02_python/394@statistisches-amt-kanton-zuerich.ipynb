# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerfuss juristische Personen [%]

# %% [markdown]
# ### **Description**: Steuerfuss für juristische Personen. Details zu angewendeten Steuerfüssen sind direkt bei den jeweiligen Gemeinden einzuholen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **394@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-11-18T15:15:00`
# - **Modified** `2022-11-11T07:31:29`
# - **Startdate** `1990-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['gemeinden', 'gemeindesteuerfuesse', 'gemeindesteuern', 'kanton_zuerich', 'steuerfuss', 'steuern', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 488
# Title                    : Steuerfuss juristische Personen [%]
# Description              : None
# Issued                   : 2016-11-18T15:15:00
# Modified                 : 2022-04-11T09:11:39
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_68.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_68.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,593 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5593 entries, 0 to 5592
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5593 non-null   int64
#  1   GEBIET_NAME      5593 non-null   object
#  2   THEMA_NAME       5593 non-null   object
#  3   SET_NAME         5593 non-null   object
#  4   SUBSET_NAME      5593 non-null   object
#  5   INDIKATOR_ID     5593 non-null   int64
#  6   INDIKATOR_NAME   5593 non-null   object
#  7   INDIKATOR_JAHR   5593 non-null   int64
#  8   INDIKATOR_VALUE  5593 non-null   float64
#  9   EINHEIT_KURZ     5593 non-null   object
#  10  EINHEIT_LANG     5593 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME     SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse
#
#             SUBSET_NAME  INDIKATOR_ID                       INDIKATOR_NAME  \
# 0  juristische Personen            68  Steuerfuss juristische Personen [%]
# 1  juristische Personen            68  Steuerfuss juristische Personen [%]
# 2  juristische Personen            68  Steuerfuss juristische Personen [%]
# 3  juristische Personen            68  Steuerfuss juristische Personen [%]
# 4  juristische Personen            68  Steuerfuss juristische Personen [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            1990           136.12            %      Prozent
# 1            1991           132.90            %      Prozent
# 2            1992           132.90            %      Prozent
# 3            1993           133.16            %      Prozent
# 4            1994           133.16            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 4575  \
# BFS_NR                                           213
# GEBIET_NAME                                  Brütten
# THEMA_NAME                      Öffentliche Finanzen
# SET_NAME                                 Steuerfüsse
# SUBSET_NAME                     juristische Personen
# INDIKATOR_ID                                      68
# INDIKATOR_NAME   Steuerfuss juristische Personen [%]
# INDIKATOR_JAHR                                  2018
# INDIKATOR_VALUE                                102.0
# EINHEIT_KURZ                                       %
# EINHEIT_LANG                                 Prozent
#
#                                                 4710  \
# BFS_NR                                           218
# GEBIET_NAME                          Ellikon a.d.Th.
# THEMA_NAME                      Öffentliche Finanzen
# SET_NAME                                 Steuerfüsse
# SUBSET_NAME                     juristische Personen
# INDIKATOR_ID                                      68
# INDIKATOR_NAME   Steuerfuss juristische Personen [%]
# INDIKATOR_JAHR                                  1993
# INDIKATOR_VALUE                               130.54
# EINHEIT_KURZ                                       %
# EINHEIT_LANG                                 Prozent
#
#                                                 4929
# BFS_NR                                           224
# GEBIET_NAME                                  Pfungen
# THEMA_NAME                      Öffentliche Finanzen
# SET_NAME                                 Steuerfüsse
# SUBSET_NAME                     juristische Personen
# INDIKATOR_ID                                      68
# INDIKATOR_NAME   Steuerfuss juristische Personen [%]
# INDIKATOR_JAHR                                  2019
# INDIKATOR_VALUE                               128.76
# EINHEIT_KURZ                                       %
# EINHEIT_LANG                                 Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME     SET_NAME           SUBSET_NAME  \
# count          5593                  5593         5593                  5593
# unique          178                     1            1                     1
# top     Aeugst a.A.  Öffentliche Finanzen  Steuerfüsse  juristische Personen
# freq             33                  5593         5593                  5593
#
#                              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                                  5593         5593         5593
# unique                                    1            1            1
# top     Steuerfuss juristische Personen [%]            %      Prozent
# freq                                   5593         5593         5593

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,593.00      5,593.00        5,593.00         5,593.00
# mean    120.88         68.00        2,005.88           123.39
# std      77.04          0.00            9.48            15.12
# min       1.00         68.00        1,990.00            76.72
# 25%      55.00         68.00        1,998.00           114.38
# 50%     114.00         68.00        2,006.00           126.79
# 75%     192.00         68.00        2,014.00           134.95
# max     298.00         68.00        2,022.00           149.47

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

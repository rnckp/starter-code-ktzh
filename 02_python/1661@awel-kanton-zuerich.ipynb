# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wärme-, Strom- und Treibstoffverbrauch im Kanton Zürich ab 2010

# %% [markdown]
# ### **Description**: Die Stromdaten stammen von der Eidgenössischen Elektrizitätskommission (ElCom), die Treibstoffdaten aus der schweizerischen Gesamtenergiestatistik des Bundesamts für Energie (BFE) und die Wärmedaten aus der kantonalen Statistik des Amts für Abfall, Wasser, Energie und Luft (AWEL). Die Erhebung der Daten dient dem AWEL dazu, den Energieverbrauch nach unterschiedlichen Energiesektoren für den Kanton Zürich aufzuzeichnen und beobachten zu können.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1661@awel-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-08-25T09:41:16`
# - **Modified** `2022-08-25T10:03:41`
# - **Startdate** `2010-01-01`
# - **Enddate** `2020-12-31`
# - **Theme** `['Energie', 'Mobilität und Verkehr', 'Raum, Umwelt', None]`
# - **Keyword** `['elektrizitaet', 'energie', 'strom', 'stromverbrauch', 'treibstoffverbrauch', 'waerme', 'energieverbrauch', 'waermeverbrauch', 'treibstoff', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3118
# Title                    : Wärme-, Strom- und Treibstoffverbrauch im Kanton Zürich
# Description              : Der Energieverbrauch wird in Gigawattstunden (GWh) ausgewiesen. Dabei wird unterschieden zwischen den Energiesektoren Wärme, Strom und Treibstoff.
# Issued                   : 2022-08-25T09:41:16
# Modified                 : 2022-12-13T15:43:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001661_00003118.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001661_00003118.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 33 rows (observations) and 4 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jahr           33 non-null     int64
#  1   Energiesektor  33 non-null     object
#  2   Wert           33 non-null     int64
#  3   Einheit        33 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 4.6 KB

# %%
df.head()
# Out:
#    Jahr Energiesektor   Wert Einheit
# 0  2010         Strom   9000     GWh
# 1  2010    Treibstoff  14400     GWh
# 2  2010        Waerme  17202     GWh
# 3  2011         Strom   9300     GWh
# 4  2011    Treibstoff  14500     GWh

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                    2       14      26
# Jahr             2010    2014    2018
# Energiesektor  Waerme  Waerme  Waerme
# Wert            17202   14237   14099
# Einheit           GWh     GWh     GWh

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        Energiesektor Einheit
# count             33      33
# unique             3       1
# top            Strom     GWh
# freq              11      33

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr      Wert
# count    33.00     33.00
# mean  2,015.00 12,748.76
# std       3.21  2,868.62
# min   2,010.00  8,800.00
# 25%   2,012.00  9,100.00
# 50%   2,015.00 14,251.00
# 75%   2,018.00 14,600.00
# max   2,020.00 17,202.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Energie | mirjam.baumann@bd.zh.ch

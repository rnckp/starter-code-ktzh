# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Geburtenrate (5-J.-mittel) [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Durchschnittliche Zahl von Geburten im Fünfjahresmittel pro 1000 Einw. Beispiel: Die Zahl von 2003 entspricht dem Mittelwert der Geburten von 1999-2003 in Bezug auf die Einwohnerzahl von 1998

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **212@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1994-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungsbewegungen', 'bezirke', 'geburten', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 175
# Title                    : Geburtenrate (5-J.-mittel) [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_98.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_98.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,448 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5448 entries, 0 to 5447
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5448 non-null   int64
#  1   GEBIET_NAME      5448 non-null   object
#  2   THEMA_NAME       5448 non-null   object
#  3   SET_NAME         5448 non-null   object
#  4   SUBSET_NAME      5448 non-null   object
#  5   INDIKATOR_ID     5448 non-null   int64
#  6   INDIKATOR_NAME   5448 non-null   object
#  7   INDIKATOR_JAHR   5448 non-null   int64
#  8   INDIKATOR_VALUE  5448 non-null   float64
#  9   EINHEIT_KURZ     5448 non-null   object
#  10  EINHEIT_LANG     5448 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.8 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID  \
# 0  Geburten und Sterbefälle            98
# 1  Geburten und Sterbefälle            98
# 2  Geburten und Sterbefälle            98
# 3  Geburten und Sterbefälle            98
# 4  Geburten und Sterbefälle            98
#
#                                 INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]            1994
# 1  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]            1995
# 2  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]            1996
# 3  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]            1997
# 4  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]            1998
#
#    INDIKATOR_VALUE    EINHEIT_KURZ           EINHEIT_LANG
# 0             13.3  pro 1000 Einw.  pro Tausend Einwohner
# 1             12.3  pro 1000 Einw.  pro Tausend Einwohner
# 2             11.6  pro 1000 Einw.  pro Tausend Einwohner
# 3             11.3  pro 1000 Einw.  pro Tausend Einwohner
# 4             11.1  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                         5341  \
# BFS_NR                                                     0
# GEBIET_NAME                        Region Winterthur u. Umg.
# THEMA_NAME                          Bevölkerung und Soziales
# SET_NAME                                Bevölkerungsbewegung
# SUBSET_NAME                         Geburten und Sterbefälle
# INDIKATOR_ID                                              98
# INDIKATOR_NAME   Geburtenrate (5-J.-mittel) [pro 1000 Einw.]
# INDIKATOR_JAHR                                          1999
# INDIKATOR_VALUE                                         11.3
# EINHEIT_KURZ                                  pro 1000 Einw.
# EINHEIT_LANG                           pro Tausend Einwohner
#
#                                                         1011  \
# BFS_NR                                                    43
# GEBIET_NAME                                           Volken
# THEMA_NAME                          Bevölkerung und Soziales
# SET_NAME                                Bevölkerungsbewegung
# SUBSET_NAME                         Geburten und Sterbefälle
# INDIKATOR_ID                                              98
# INDIKATOR_NAME   Geburtenrate (5-J.-mittel) [pro 1000 Einw.]
# INDIKATOR_JAHR                                          2003
# INDIKATOR_VALUE                                         22.5
# EINHEIT_KURZ                                  pro 1000 Einw.
# EINHEIT_LANG                           pro Tausend Einwohner
#
#                                                         124
# BFS_NR                                                     5
# GEBIET_NAME                                         Hedingen
# THEMA_NAME                          Bevölkerung und Soziales
# SET_NAME                                Bevölkerungsbewegung
# SUBSET_NAME                         Geburten und Sterbefälle
# INDIKATOR_ID                                              98
# INDIKATOR_NAME   Geburtenrate (5-J.-mittel) [pro 1000 Einw.]
# INDIKATOR_JAHR                                          2006
# INDIKATOR_VALUE                                         11.3
# EINHEIT_KURZ                                  pro 1000 Einw.
# EINHEIT_LANG                           pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          5448                      5448                  5448
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             28                      5448                  5448
#
#                      SUBSET_NAME                               INDIKATOR_NAME  \
# count                       5448                                         5448
# unique                         1                                            1
# top     Geburten und Sterbefälle  Geburtenrate (5-J.-mittel) [pro 1000 Einw.]
# freq                        5448                                         5448
#
#           EINHEIT_KURZ           EINHEIT_LANG
# count             5448                   5448
# unique               1                      1
# top     pro 1000 Einw.  pro Tausend Einwohner
# freq              5448                   5448

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,448.00      5,448.00        5,448.00         5,448.00
# mean    107.42         98.00        2,007.41            11.00
# std      84.30          0.00            8.04             2.16
# min       0.00         98.00        1,994.00             4.00
# 25%      31.00         98.00        2,000.00             9.70
# 50%      94.00         98.00        2,007.00            10.90
# 75%     178.00         98.00        2,014.00            12.10
# max     298.00         98.00        2,021.00            23.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

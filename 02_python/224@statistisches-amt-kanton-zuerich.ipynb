# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Erwerb des Schweizer Bürgerrechts [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: in Bezug auf die Einwohnerzahl am Ende des vorhergehenden Jahres (Kantonale Erhebung). Hinweis: Ab 2011 Wechsel des Produktionsverfahrens und neue Definition der ständigen Wohnbevölkerung, die zusätzlich Personen im Asylprozess mit einer Gesamtaufenthaltsdauer von mindestens 12 Monaten umfasst.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **224@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:34:56`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['auslaender', 'auslaenderinnen', 'bevoelkerung', 'bezirke', 'buergerrecht', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 187
# Title                    : Erwerb des Schweizer Bürgerrechts [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:34:56
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_259.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_259.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,254 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6254 entries, 0 to 6253
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6254 non-null   int64
#  1   GEBIET_NAME      6254 non-null   object
#  2   THEMA_NAME       6254 non-null   object
#  3   SET_NAME         6254 non-null   object
#  4   SUBSET_NAME      6254 non-null   object
#  5   INDIKATOR_ID     6254 non-null   int64
#  6   INDIKATOR_NAME   6254 non-null   object
#  7   INDIKATOR_JAHR   6254 non-null   int64
#  8   INDIKATOR_VALUE  6254 non-null   float64
#  9   EINHEIT_KURZ     6254 non-null   object
#  10  EINHEIT_LANG     6254 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.9 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#            SUBSET_NAME  INDIKATOR_ID  \
# 0  Bürgerrechtswechsel           259
# 1  Bürgerrechtswechsel           259
# 2  Bürgerrechtswechsel           259
# 3  Bürgerrechtswechsel           259
# 4  Bürgerrechtswechsel           259
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Erwerb des Schweizer Bürgerrechts [pro 1000 Ei...            1990
# 1  Erwerb des Schweizer Bürgerrechts [pro 1000 Ei...            1991
# 2  Erwerb des Schweizer Bürgerrechts [pro 1000 Ei...            1992
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               3655  \
# BFS_NR                                                         161
# GEBIET_NAME                                               Zollikon
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                      Bevölkerungsbewegung
# SUBSET_NAME                                    Bürgerrechtswechsel
# INDIKATOR_ID                                                   259
# INDIKATOR_NAME   Erwerb des Schweizer Bürgerrechts [pro 1000 Ei...
# INDIKATOR_JAHR                                                1991
# INDIKATOR_VALUE                                                2.3
# EINHEIT_KURZ                                        pro 1000 Einw.
# EINHEIT_LANG                                 pro Tausend Einwohner
#
#                                                               2803  \
# BFS_NR                                                         116
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          6254                      6254                  6254
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             32                      6254                  6254
#
#                 SUBSET_NAME  \
# count                  6254
# unique                    1
# top     Bürgerrechtswechsel
# freq                   6254
#
#                                            INDIKATOR_NAME    EINHEIT_KURZ  \
# count                                                6254            6254
# unique                                                  1               1
# top     Erwerb des Schweizer Bürgerrechts [pro 1000 Ei...  pro 1000 Einw.
# freq                                                 6254            6254
#
#                  EINHEIT_LANG
# count                    6254
# unique                      1
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,254.00      6,254.00        6,254.00         6,254.00
# mean    108.05        259.00        2,005.45             3.78
# std      84.78          0.00            9.19             2.88
# min       0.00        259.00        1,990.00             0.00
# 25%      31.00        259.00        1,997.00             1.50
# 50%      94.50        259.00        2,005.00             3.40
# 75%     178.00        259.00        2,013.00             5.60
# max     298.00        259.00        2,021.00            22.20

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: NRW Wähleranteil BDP [%]

# %% [markdown]
# ### **Description**: Wähleranteil BDP bei Nationalsratswahlen. Hinweis: 2015 werden alle Auslandschweizer zur Stadt Zürich gezählt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **297@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-10-21T10:29:00`
# - **Startdate** `2011-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'nationalratswahlen', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 227
# Title                    : NRW Wähleranteil BDP [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-10-21T10:29:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_549.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_549.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 565 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           565 non-null    int64
#  1   GEBIET_NAME      565 non-null    object
#  2   THEMA_NAME       565 non-null    object
#  3   SET_NAME         565 non-null    object
#  4   SUBSET_NAME      565 non-null    object
#  5   INDIKATOR_ID     565 non-null    int64
#  6   INDIKATOR_NAME   565 non-null    object
#  7   INDIKATOR_JAHR   565 non-null    int64
#  8   INDIKATOR_VALUE  565 non-null    float64
#  9   EINHEIT_KURZ     565 non-null    object
#  10  EINHEIT_LANG     565 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 331.2 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  \
# 0       1     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# 1       1     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# 2       1     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# 3       2  Affoltern a.A.    Politik  Wähleranteile  Nationalrat
# 4       2  Affoltern a.A.    Politik  Wähleranteile  Nationalrat
#
#    INDIKATOR_ID            INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           549  NRW Wähleranteil BDP [%]            2011              6.8
# 1           549  NRW Wähleranteil BDP [%]            2015              2.6
# 2           549  NRW Wähleranteil BDP [%]            2019              1.3
# 3           549  NRW Wähleranteil BDP [%]            2011              6.6
# 4           549  NRW Wähleranteil BDP [%]            2015              4.2
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                       542                       271  \
# BFS_NR                                  0                       120
# GEBIET_NAME                Region Glattal                      Wald
# THEMA_NAME                        Politik                   Politik
# SET_NAME                    Wähleranteile             Wähleranteile
# SUBSET_NAME                   Nationalrat               Nationalrat
# INDIKATOR_ID                          549                       549
# INDIKATOR_NAME   NRW Wähleranteil BDP [%]  NRW Wähleranteil BDP [%]
# INDIKATOR_JAHR                       2011                      2015
# INDIKATOR_VALUE                       7.4                       3.6
# EINHEIT_KURZ                            %                         %
# EINHEIT_LANG                      Prozent                   Prozent
#
#                                       59
# BFS_NR                                 26
# GEBIET_NAME                          Dorf
# THEMA_NAME                        Politik
# SET_NAME                    Wähleranteile
# SUBSET_NAME                   Nationalrat
# INDIKATOR_ID                          549
# INDIKATOR_NAME   NRW Wähleranteil BDP [%]
# INDIKATOR_JAHR                       2019
# INDIKATOR_VALUE                       0.8
# EINHEIT_KURZ                            %
# EINHEIT_LANG                      Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  \
# count           565        565            565          565
# unique          200          1              1            1
# top     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# freq              3        565            565          565
#
#                   INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                        565          565          565
# unique                         1            1            1
# top     NRW Wähleranteil BDP [%]            %      Prozent
# freq                         565          565          565

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  565.00        565.00          565.00           565.00
# mean   109.59        549.00        2,014.85             4.46
# std     84.65          0.00            3.24             2.51
# min      0.00        549.00        2,011.00             0.30
# 25%     33.00        549.00        2,011.00             2.30
# 50%     95.00        549.00        2,015.00             4.30
# 75%    180.00        549.00        2,019.00             5.90
# max    298.00        549.00        2,019.00            21.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

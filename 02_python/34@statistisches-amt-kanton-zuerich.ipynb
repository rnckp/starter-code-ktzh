# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Verkäufe MFH [Anz.]

# %% [markdown]
# ### **Description**: Anzahl verkaufter Mehrfamilienhäuser (MFH). Die letzten drei Jahre sind provisorisch.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **34@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-17T15:56:32`
# - **Startdate** `2007-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'eigentum', 'gemeinden', 'handaenderungen', 'immobilien', 'kanton_zuerich', 'mehrfamilienhaus', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 29
# Title                    : Verkäufe MFH [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-17T15:56:32
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_191.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_191.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,790 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2790 entries, 0 to 2789
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2790 non-null   int64
#  1   GEBIET_NAME      2790 non-null   object
#  2   THEMA_NAME       2790 non-null   object
#  3   SET_NAME         2790 non-null   object
#  4   SUBSET_NAME      2790 non-null   object
#  5   INDIKATOR_ID     2790 non-null   int64
#  6   INDIKATOR_NAME   2790 non-null   object
#  7   INDIKATOR_JAHR   2790 non-null   int64
#  8   INDIKATOR_VALUE  2775 non-null   float64
#  9   EINHEIT_KURZ     2790 non-null   object
#  10  EINHEIT_LANG     2790 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel
# 1       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel
# 2       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel
# 3       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel
# 4       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel
#
#           SUBSET_NAME  INDIKATOR_ID       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Immobilienverkäufe           191  Verkäufe MFH [Anz.]            2007
# 1  Immobilienverkäufe           191  Verkäufe MFH [Anz.]            2008
# 2  Immobilienverkäufe           191  Verkäufe MFH [Anz.]            2009
# 3  Immobilienverkäufe           191  Verkäufe MFH [Anz.]            2010
# 4  Immobilienverkäufe           191  Verkäufe MFH [Anz.]            2011
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              2.0         Anz.       Anzahl
# 1              1.0         Anz.       Anzahl
# 2              4.0         Anz.       Anzahl
# 3              1.0         Anz.       Anzahl
# 4              0.0         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                 2118                 1544                 2710
# BFS_NR                           230                  156                    0
# GEBIET_NAME               Winterthur               Meilen     Region Unterland
# THEMA_NAME        Bau und Immobilien   Bau und Immobilien   Bau und Immobilien
# SET_NAME            Immobilienhandel     Immobilienhandel     Immobilienhandel
# SUBSET_NAME       Immobilienverkäufe   Immobilienverkäufe   Immobilienverkäufe
# INDIKATOR_ID                     191                  191                  191
# INDIKATOR_NAME   Verkäufe MFH [Anz.]  Verkäufe MFH [Anz.]  Verkäufe MFH [Anz.]
# INDIKATOR_JAHR                  2010                 2021                 2017
# INDIKATOR_VALUE                 69.0                  3.0                 46.0
# EINHEIT_KURZ                    Anz.                 Anz.                 Anz.
# EINHEIT_LANG                  Anzahl               Anzahl               Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME          SET_NAME         SUBSET_NAME  \
# count          2790                2790              2790                2790
# unique          186                   1                 1                   1
# top     Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Immobilienverkäufe
# freq             15                2790              2790                2790
#
#              INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                  2790         2790         2790
# unique                    1            1            1
# top     Verkäufe MFH [Anz.]         Anz.       Anzahl
# freq                   2790         2790         2790

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,790.00      2,790.00        2,790.00         2,775.00
# mean    108.84        191.00        2,014.00            12.18
# std      88.15          0.00            4.32            46.08
# min       0.00        191.00        2,007.00             0.00
# 25%      29.00        191.00        2,010.00             1.00
# 50%      92.50        191.00        2,014.00             2.00
# 75%     182.00        191.00        2,018.00             6.00
# max     298.00        191.00        2,021.00           650.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

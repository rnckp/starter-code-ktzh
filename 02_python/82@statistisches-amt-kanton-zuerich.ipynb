# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ## Dataset: **NRW Wähleranteil SP [%]**

# %% [markdown]
# ## Description
#
# Wähleranteil SP bei Nationalratswahlen. Hinweis: 2015 werden alle Auslandschweizer zur Stadt Zürich gezählt.
#
# **[Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.zhweb-noredirect.zhweb-cache.html?keywords=ogd#/datasets/82@statistisches-amt-kanton-zuerich)**

# %% [markdown]
# *Autogenerated Python starter code for data set with identifier* **82@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Metadata
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-10-21T10:29:00`
# - **Startdate** `1991-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kantonsratswahlen', 'kanton_zuerich', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for properly reading datasets
def get_dataset(url):
    data = pd.read_csv(url, on_bad_lines='warn', encoding_errors='ignore')
    # if dataframe only has one column or less the "," separator was wrong, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore')
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 68
# Title                    : NRW Wähleranteil SP [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-10-21T10:29:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_124.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,536 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1536 non-null   int64
#  1   GEBIET_NAME      1536 non-null   object
#  2   THEMA_NAME       1536 non-null   object
#  3   SET_NAME         1536 non-null   object
#  4   SUBSET_NAME      1536 non-null   object
#  5   INDIKATOR_ID     1536 non-null   int64
#  6   INDIKATOR_NAME   1536 non-null   object
#  7   INDIKATOR_JAHR   1536 non-null   int64
#  8   INDIKATOR_VALUE  1536 non-null   float64
#  9   EINHEIT_KURZ     1536 non-null   object
#  10  EINHEIT_LANG     1536 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 897.7 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  INDIKATOR_ID  \
# 0       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           124
# 1       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           124
# 2       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           124
# 3       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           124
# 4       1  Aeugst a.A.    Politik  Wähleranteile  Nationalrat           124
#
#             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  NRW Wähleranteil SP [%]            1991             13.2            %
# 1  NRW Wähleranteil SP [%]            1995             16.3            %
# 2  NRW Wähleranteil SP [%]            1999             25.3            %
# 3  NRW Wähleranteil SP [%]            2003             22.3            %
# 4  NRW Wähleranteil SP [%]            2007             19.2            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      249                      120  \
# BFS_NR                                38                       22
# GEBIET_NAME                      Rheinau                   Benken
# THEMA_NAME                       Politik                  Politik
# SET_NAME                   Wähleranteile            Wähleranteile
# SUBSET_NAME                  Nationalrat              Nationalrat
# INDIKATOR_ID                         124                      124
# INDIKATOR_NAME   NRW Wähleranteil SP [%]  NRW Wähleranteil SP [%]
# INDIKATOR_JAHR                      1999                     1991
# INDIKATOR_VALUE                     30.5                     12.4
# EINHEIT_KURZ                           %                        %
# EINHEIT_LANG                     Prozent                  Prozent
#
#                                      878
# BFS_NR                               156
# GEBIET_NAME                       Meilen
# THEMA_NAME                       Politik
# SET_NAME                   Wähleranteile
# SUBSET_NAME                  Nationalrat
# INDIKATOR_ID                         124
# INDIKATOR_NAME   NRW Wähleranteil SP [%]
# INDIKATOR_JAHR                      2015
# INDIKATOR_VALUE                     15.5
# EINHEIT_KURZ                           %
# EINHEIT_LANG                     Prozent

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME  SUBSET_NAME  \
# count          1536       1536           1536         1536
# unique          200          1              1            1
# top     Aeugst a.A.    Politik  Wähleranteile  Nationalrat
# freq              8       1536           1536         1536
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                      1536         1536         1536
# unique                        1            1            1
# top     NRW Wähleranteil SP [%]            %      Prozent
# freq                       1536         1536         1536

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,536.00      1,536.00        1,536.00         1,536.00
# mean    106.97        124.00        2,004.85            16.62
# std      82.94          0.00            9.07             5.14
# min       0.00        124.00        1,991.00             2.80
# 25%      32.00        124.00        1,995.00            12.90
# 50%      94.00        124.00        2,003.00            16.40
# 75%     177.00        124.00        2,011.00            19.80
# max     298.00        124.00        2,019.00            35.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

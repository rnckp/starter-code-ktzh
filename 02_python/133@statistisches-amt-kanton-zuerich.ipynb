# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Aerzte [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Aerzte mit Hauptberufstätigkeit im Ambulanten Sektor. Bis 2008: Ärzte mit eigener Praxis und Spitalärzte, die Privatpatienten behandeln, jeweils am Anfang eines Kalenderjahres. Für 1993 und 2003 keine Zahlen vorhanden. Aktuellstes Jahr provisorisch.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **133@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-03-17T07:40:41`
# - **Startdate** `1990-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Gesundheit']`
# - **Keyword** `['aerzte', 'aerztinnen', 'bezirke', 'gemeinden', 'gesundheit', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 99
# Title                    : Aerzte [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-03-17T07:40:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_543.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_543.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,040 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6040 non-null   int64
#  1   GEBIET_NAME      6040 non-null   object
#  2   THEMA_NAME       6040 non-null   object
#  3   SET_NAME         6040 non-null   object
#  4   SUBSET_NAME      6040 non-null   object
#  5   INDIKATOR_ID     6040 non-null   int64
#  6   INDIKATOR_NAME   6040 non-null   object
#  7   INDIKATOR_JAHR   6040 non-null   int64
#  8   INDIKATOR_VALUE  5650 non-null   float64
#  9   EINHEIT_KURZ     6040 non-null   object
#  10  EINHEIT_LANG     6040 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME    SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
#
#             SUBSET_NAME  INDIKATOR_ID           INDIKATOR_NAME  \
# 0  Aerzte und Apotheken           543  Aerzte [pro 1000 Einw.]
# 1  Aerzte und Apotheken           543  Aerzte [pro 1000 Einw.]
# 2  Aerzte und Apotheken           543  Aerzte [pro 1000 Einw.]
# 3  Aerzte und Apotheken           543  Aerzte [pro 1000 Einw.]
# 4  Aerzte und Apotheken           543  Aerzte [pro 1000 Einw.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE    EINHEIT_KURZ           EINHEIT_LANG
# 0            1990              2.6  pro 1000 Einw.  pro Tausend Einwohner
# 1            1991              2.5  pro 1000 Einw.  pro Tausend Einwohner
# 2            1992              2.4  pro 1000 Einw.  pro Tausend Einwohner
# 3            1993              NaN  pro 1000 Einw.  pro Tausend Einwohner
# 4            1994              0.8  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      3604                      2351  \
# BFS_NR                                172                        97
# GEBIET_NAME                    Fehraltorf                   Rümlang
# THEMA_NAME       Bevölkerung und Soziales  Bevölkerung und Soziales
# SET_NAME                       Gesundheit                Gesundheit
# SUBSET_NAME          Aerzte und Apotheken      Aerzte und Apotheken
# INDIKATOR_ID                          543                       543
# INDIKATOR_NAME    Aerzte [pro 1000 Einw.]   Aerzte [pro 1000 Einw.]
# INDIKATOR_JAHR                       1999                      1994
# INDIKATOR_VALUE                       0.7                       1.0
# EINHEIT_KURZ               pro 1000 Einw.            pro 1000 Einw.
# EINHEIT_LANG        pro Tausend Einwohner     pro Tausend Einwohner
#
#                                      742
# BFS_NR                                 30
# GEBIET_NAME                   Andelfingen
# THEMA_NAME       Bevölkerung und Soziales
# SET_NAME                       Gesundheit
# SUBSET_NAME          Aerzte und Apotheken
# INDIKATOR_ID                          543
# INDIKATOR_NAME    Aerzte [pro 1000 Einw.]
# INDIKATOR_JAHR                       2019
# INDIKATOR_VALUE                       2.2
# EINHEIT_KURZ               pro 1000 Einw.
# EINHEIT_LANG        pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME    SET_NAME  \
# count          6040                      6040        6040
# unique          200                         1           1
# top     Aeugst a.A.  Bevölkerung und Soziales  Gesundheit
# freq             31                      6040        6040
#
#                  SUBSET_NAME           INDIKATOR_NAME    EINHEIT_KURZ  \
# count                   6040                     6040            6040
# unique                     1                        1               1
# top     Aerzte und Apotheken  Aerzte [pro 1000 Einw.]  pro 1000 Einw.
# freq                    6040                     6040            6040
#
#                  EINHEIT_LANG
# count                    6040
# unique                      1
# top     pro Tausend Einwohner
# freq                     6040

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,040.00      6,040.00        6,040.00         5,650.00
# mean    107.48        543.00        2,004.92             1.06
# std      84.28          0.00            8.91             0.94
# min       0.00        543.00        1,990.00             0.00
# 25%      31.00        543.00        1,997.00             0.40
# 50%      94.00        543.00        2,005.00             0.90
# 75%     178.00        543.00        2,013.00             1.50
# max     298.00        543.00        2,020.00             6.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

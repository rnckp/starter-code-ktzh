# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: KRW Wähleranteil AL [%]

# %% [markdown]
# ### **Description**: Wähleranteil AL bei Kantonsratswahlen

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **7@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-03-25T10:44:00`
# - **Startdate** `2007-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kantonsratswahlen', 'kanton_zuerich', 'parteien', 'politik', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 6
# Title                    : KRW Wähleranteil AL [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-03-25T10:44:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_436.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_436.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 749 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           749 non-null    int64
#  1   GEBIET_NAME      749 non-null    object
#  2   THEMA_NAME       749 non-null    object
#  3   SET_NAME         749 non-null    object
#  4   SUBSET_NAME      749 non-null    object
#  5   INDIKATOR_ID     749 non-null    int64
#  6   INDIKATOR_NAME   749 non-null    object
#  7   INDIKATOR_JAHR   749 non-null    int64
#  8   INDIKATOR_VALUE  749 non-null    float64
#  9   EINHEIT_KURZ     749 non-null    object
#  10  EINHEIT_LANG     749 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 436.9 KB

# %%
df.head()
# Out:
#    BFS_NR     GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           436
# 1       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           436
# 2       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           436
# 3       1     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat           436
# 4       2  Affoltern a.A.    Politik  Wähleranteile  Kantonsrat           436
#
#             INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  KRW Wähleranteil AL [%]            2007              1.0            %
# 1  KRW Wähleranteil AL [%]            2011              0.6            %
# 2  KRW Wähleranteil AL [%]            2015              1.3            %
# 3  KRW Wähleranteil AL [%]            2019              0.9            %
# 4  KRW Wähleranteil AL [%]            2007              0.4            %
#
#   EINHEIT_LANG
# 0      Prozent
# 1      Prozent
# 2      Prozent
# 3      Prozent
# 4      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                      609                      413  \
# BFS_NR                               231                      151
# GEBIET_NAME                         Zell                Erlenbach
# THEMA_NAME                       Politik                  Politik
# SET_NAME                   Wähleranteile            Wähleranteile
# SUBSET_NAME                   Kantonsrat               Kantonsrat
# INDIKATOR_ID                         436                      436
# INDIKATOR_NAME   KRW Wähleranteil AL [%]  KRW Wähleranteil AL [%]
# INDIKATOR_JAHR                      2011                     2011
# INDIKATOR_VALUE                      0.5                      0.7
# EINHEIT_KURZ                           %                        %
# EINHEIT_LANG                     Prozent                  Prozent
#
#                                      342
# BFS_NR                               115
# GEBIET_NAME                       Gossau
# THEMA_NAME                       Politik
# SET_NAME                   Wähleranteile
# SUBSET_NAME                   Kantonsrat
# INDIKATOR_ID                         436
# INDIKATOR_NAME   KRW Wähleranteil AL [%]
# INDIKATOR_JAHR                      2011
# INDIKATOR_VALUE                      0.3
# EINHEIT_KURZ                           %
# EINHEIT_LANG                     Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME       SET_NAME SUBSET_NAME  \
# count           749        749            749         749
# unique          200          1              1           1
# top     Aeugst a.A.    Politik  Wähleranteile  Kantonsrat
# freq              4        749            749         749
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                       749          749          749
# unique                        1            1            1
# top     KRW Wähleranteil AL [%]            %      Prozent
# freq                        749          749          749

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  749.00        749.00          749.00           749.00
# mean   110.72        436.00        2,012.73             0.85
# std     83.90          0.00            4.39             0.88
# min      0.00        436.00        2,007.00             0.00
# 25%     35.00        436.00        2,007.00             0.30
# 50%     97.00        436.00        2,011.00             0.60
# 75%    180.00        436.00        2,015.00             1.10
# max    298.00        436.00        2,019.00             7.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

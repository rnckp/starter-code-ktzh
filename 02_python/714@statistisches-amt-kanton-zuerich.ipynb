# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Abstimmungsarchiv des Kantons Zürich ab 1831

# %% [markdown]
# ### **Description**: Alle Ergebnisse der kantonalen und eidgenössischen Abstimmungen des Kantons Zürich seit 1831.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **714@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-02-26T00:00:00`
# - **Modified** `2022-05-31T14:51:46`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['Politik']`
# - **Keyword** `['abstimmungen', 'abstimmungsergebnisse', 'eidgenoessische_volksabstimmungen', 'gemeinden', 'kantonale_volksabstimmungen', 'politik', 'politische_gemeinden', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 322
# Title                    : Abstimmungsarchiv des Kantons Zürich, Ergebnisse pro Gemeinde
# Description              : Alle Ergebnisse der kantonalen und eidgenössischen Abstimmungen pro Gemeinde.
# Issued                   : 2016-02-26T10:10:10
# Modified                 : 2022-11-29T07:52:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsarchiv_gemeinden.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsarchiv_gemeinden.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 323
# Title                    : Abstimmungsarchiv des Kantons Zürich, Ergebnisse Kanton Zürich
# Description              : Ergebnisse der kantonalen und eidgenössischen Abstimmungen auf Ebene Kanton. Die Daten enthalten Links zu den jeweiligen Abstimmungszeitungen, Gesetzestexten und Publikationen im Amtsblatt.
# Issued                   : 2016-02-26T10:10:10
# Modified                 : 2022-11-29T07:54:32
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsarchiv_kanton.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsarchiv_kanton.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,064 rows (observations) and 19 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2064 entries, 0 to 2063
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ABSTIMMUNGSTAG       2064 non-null   object
#  1   STAT_VORLAGE_ID      2064 non-null   int64
#  2   VORLAGE_KURZBEZ      2064 non-null   object
#  3   VORLAGE_LANGBEZ      2064 non-null   object
#  4   VORLAGENART          2064 non-null   object
#  5   ABSTIMMUNGSART_BEZ   2064 non-null   object
#  6   JA_ANTEIL_PROZENT    2064 non-null   float64
#  7   STIMMBETEILIGUNG     2064 non-null   float64
#  8   JA_STIMMEN           2064 non-null   int64
#  9   NEIN_STIMMEN         2064 non-null   int64
#  10  EINGELEGTE_STIMMEN   2064 non-null   int64
#  11  GÜLTIGE_STIMMEN      2064 non-null   int64
#  12  UNGÜLTIGE_STIMMEN    2064 non-null   int64
#  13  LEERE_STIMMEN        2064 non-null   int64
#  14  ANNEHMENDE_GEBIETE   1894 non-null   float64
# ...

# %%
df.head()
# Out:
#   ABSTIMMUNGSTAG  STAT_VORLAGE_ID  \
# 0     10.03.1831              800
# 1     04.02.1838              801
# 2     16.08.1840              803
# 3     16.08.1840              802
# 4     16.08.1840              804
#
#                                      VORLAGE_KURZBEZ  \
# 0                                  Kantonsverfassung
# 1  Mandatsverteilung zwischen Stadt und Landschaf...
# 2         Einführung von Ordnungs- u. Polizeistrafen
# 3  Mitgliederzahl des Regierungsrates und des Obe...
# 4                 Vermehrung der Grossratswahlkreise
#
#                                      VORLAGE_LANGBEZ  \
# 0                                  Kantonsverfassung
# 1  Mandatsverteilung zwischen Stadt und Landschaf...
# 2         Einführung von Ordnungs- u. Polizeistrafen
# 3  Mitgliederzahl des Regierungsrates und des Obe...
# 4                 Vermehrung der Grossratswahlkreise
#
#                   VORLAGENART ABSTIMMUNGSART_BEZ  JA_ANTEIL_PROZENT  \
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                   723   \
# ABSTIMMUNGSTAG                                              02.03.1952
# STAT_VORLAGE_ID                                                   1360
# VORLAGE_KURZBEZ      Volksinitiative im Sinne einer Erweiterung der...
# VORLAGE_LANGBEZ      Volksinitiative auf Abänderung des Gesetzes üb...
# VORLAGENART                                            Volksinitiative
# ABSTIMMUNGSART_BEZ                                            kantonal
# JA_ANTEIL_PROZENT                                                46.46
# STIMMBETEILIGUNG                                                 58.43
# JA_STIMMEN                                                       61860
# NEIN_STIMMEN                                                     71274
# EINGELEGTE_STIMMEN                                              141001
# GÜLTIGE_STIMMEN                                                 133134
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        ABSTIMMUNGSTAG                   VORLAGE_KURZBEZ  \
# count            2064                              2064
# unique            570                              1927
# top        13.06.1999  Gesetz über die Bezirkshauptorte
# freq               15                                 5
#
#                          VORLAGE_LANGBEZ                 VORLAGENART  \
# count                               2064                        2064
# unique                              1958                          10
# top     Gesetz über die Bezirkshauptorte  Obligatorisches Referendum
# freq                                   5                        1289
#
#        ABSTIMMUNGSART_BEZ                                URL_VOLKSABSTIMMUNG  \
# count                2064                                               1066
# unique                  2                                                366
# top              kantonal  http://www.web.statistik.zh.ch/cms_abstimmungs...
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        STAT_VORLAGE_ID  JA_ANTEIL_PROZENT  STIMMBETEILIGUNG  JA_STIMMEN  \
# count         2,064.00           2,064.00          2,064.00    2,064.00
# mean          1,127.79              59.17             53.38  121,109.93
# std             684.55              18.84             16.13   78,432.07
# min               1.00               2.49              0.00    2,666.00
# 25%             525.75              44.80             43.36   55,129.50
# 50%           1,128.50              60.44             51.04  105,438.00
# 75%           1,644.25              74.26             66.11  174,106.75
# max           2,563.00              95.92             90.88  429,462.00
#
#        NEIN_STIMMEN  EINGELEGTE_STIMMEN  GÜLTIGE_STIMMEN  UNGÜLTIGE_STIMMEN  \
# count      2,064.00            2,064.00         2,064.00           2,064.00
# mean      93,511.49          226,905.88       215,039.32             443.63
# std       81,216.71          135,665.39       132,294.93           1,243.88
# ...

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

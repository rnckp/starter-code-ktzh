# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Geburten minus Sterbefälle, pro 1000 Einw. im Fünfjahresmittel. Beispiel: Die Zahl von 2003 entspricht dem Mittelwert der Geburten minus der Sterbefälle von 1999-2003 in Bezug auf die Einwohnerzahl von 1998.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **213@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-06-27T09:02:19`
# - **Startdate** `1994-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungsbewegungen', 'bezirke', 'geburten', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 176
# Title                    : Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-06-27T09:02:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_105.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_105.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 5,448 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5448 entries, 0 to 5447
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           5448 non-null   int64
#  1   GEBIET_NAME      5448 non-null   object
#  2   THEMA_NAME       5448 non-null   object
#  3   SET_NAME         5448 non-null   object
#  4   SUBSET_NAME      5448 non-null   object
#  5   INDIKATOR_ID     5448 non-null   int64
#  6   INDIKATOR_NAME   5448 non-null   object
#  7   INDIKATOR_JAHR   5448 non-null   int64
#  8   INDIKATOR_VALUE  5448 non-null   float64
#  9   EINHEIT_KURZ     5448 non-null   object
#  10  EINHEIT_LANG     5448 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.2 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME              SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
#
#                 SUBSET_NAME  INDIKATOR_ID  \
# 0  Geburten und Sterbefälle           105
# 1  Geburten und Sterbefälle           105
# 2  Geburten und Sterbefälle           105
# 3  Geburten und Sterbefälle           105
# 4  Geburten und Sterbefälle           105
#
#                                     INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]            1994
# 1  Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]            1995
# 2  Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]            1996
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             198   \
# BFS_NR                                                         8
# GEBIET_NAME                                          Maschwanden
# THEMA_NAME                              Bevölkerung und Soziales
# SET_NAME                                    Bevölkerungsbewegung
# SUBSET_NAME                             Geburten und Sterbefälle
# INDIKATOR_ID                                                 105
# INDIKATOR_NAME   Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]
# INDIKATOR_JAHR                                              1996
# INDIKATOR_VALUE                                             11.3
# EINHEIT_KURZ                                      pro 1000 Einw.
# EINHEIT_LANG                               pro Tausend Einwohner
#
#                                                             1929  \
# BFS_NR                                                        90
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME              SET_NAME  \
# count          5448                      5448                  5448
# unique          200                         1                     1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bevölkerungsbewegung
# freq             28                      5448                  5448
#
#                      SUBSET_NAME  \
# count                       5448
# unique                         1
# top     Geburten und Sterbefälle
# freq                        5448
#
#                                          INDIKATOR_NAME    EINHEIT_KURZ  \
# count                                              5448            5448
# unique                                                1               1
# top     Geburtenüberschuss 5-J.-mittel [pro 1000 Einw.]  pro 1000 Einw.
# freq                                               5448            5448
#
#                  EINHEIT_LANG
# count                    5448
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 5,448.00      5,448.00        5,448.00         5,448.00
# mean    107.42        105.00        2,007.41             4.15
# std      84.30          0.00            8.04             2.81
# min       0.00        105.00        1,994.00            -4.70
# 25%      31.00        105.00        2,000.00             2.40
# 50%      94.00        105.00        2,007.00             4.00
# 75%     178.00        105.00        2,014.00             5.80
# max     298.00        105.00        2,021.00            18.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

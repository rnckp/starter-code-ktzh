# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Beschäftigtendichte in der Stadt Winterthur ab 1995

# %% [markdown]
# ### **Description**: Anzahl und Anteil Beschäftigte pro Einwohner:innen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1621@stadt-winterthur**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-20T17:10:34`
# - **Modified** `2022-09-21T10:06:20`
# - **Startdate** `1995-01-01`
# - **Enddate** `2019-12-31`
# - **Theme** `['Arbeit, Erwerb']`
# - **Keyword** `['arbeitskraefte', 'beschaeftigte', 'bevoelkerung', 'gemeinden', 'ogd']`
# - **Publisher** `['Stadt Winterthur']`
# - **Landingpage** `https://stadt.winterthur.ch/themen/die-stadt/winterthur/statistik/wirtschaft`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3063
# Title                    : Beschäftigtendichte Stadt Winterthur ab 1995
# Description              : Variablen: 'Jahr'; 'Beschaeftigte' = Beschäftigte in der Stadt Winterthur; 'Einwohner' = Einwohner_innen in der Stadt Winterthur; 'Beschaeftigtendichte' = Anzahl Beschäftigte geteilt durch Anzahl Einwohner_innen.
# Issued                   : 2022-09-20T17:10:34
# Modified                 : 2022-10-06T15:05:50
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001621_00003063.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001621_00003063.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 26 rows (observations) and 4 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Jahr                  26 non-null     int64
#  1   Beschaeftigte         15 non-null     float64
#  2   Einwohner_innen       26 non-null     int64
#  3   Beschaeftigtendichte  15 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 960.0 bytes

# %%
df.head()
# Out:
#    Jahr  Beschaeftigte  Einwohner_innen  Beschaeftigtendichte
# 0  1995        52587.0            87654                  0.60
# 1  1996            NaN            87467                   NaN
# 2  1997            NaN            87337                   NaN
# 3  1998        49824.0            87697                  0.57
# 4  1999            NaN            88013                   NaN

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                            4        12         18
# Jahr                   1999.0   2007.0    2013.00
# Beschaeftigte             NaN      NaN   69195.00
# Einwohner_innen       88013.0  96462.0  105676.00
# Beschaeftigtendichte      NaN      NaN       0.65

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(exclude='number'))
    except:
        pass

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr  Beschaeftigte  Einwohner_innen  Beschaeftigtendichte
# count    26.00          15.00            26.00                 15.00
# mean  2,007.50      64,828.73        98,684.08                  0.62
# std       7.65       9,282.06         9,574.02                  0.04
# min   1,995.00      49,824.00        87,337.00                  0.55
# 25%   2,001.25      54,465.50        89,625.75                  0.59
# 50%   2,007.50      69,195.00        97,350.00                  0.65
# 75%   2,013.75      71,275.50       106,502.50                  0.65
# max   2,020.00      74,618.00       117,289.00                  0.66

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtentwicklung der Stadt Winterthur | hermann.hegner@win.ch

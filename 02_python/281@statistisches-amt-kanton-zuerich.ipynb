# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Wahlbeteiligung Kantonsrat [%]

# %% [markdown]
# ### **Description**: Gültig eingelegte Listen (Wahlzettel) dividiert durch Anzahl Wahlberechtigte

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **281@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2019-03-25T11:51:06`
# - **Startdate** `2003-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['bezirke', 'gemeinden', 'kantonsratswahlen', 'kanton_zuerich', 'politik', 'wahlbeteiligung', 'wahlen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 211
# Title                    : Wahlbeteiligung Kantonsrat [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2019-03-25T11:51:06
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_803.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_803.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 945 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           945 non-null    int64
#  1   GEBIET_NAME      945 non-null    object
#  2   THEMA_NAME       945 non-null    object
#  3   SET_NAME         945 non-null    object
#  4   SUBSET_NAME      945 non-null    object
#  5   INDIKATOR_ID     945 non-null    int64
#  6   INDIKATOR_NAME   945 non-null    object
#  7   INDIKATOR_JAHR   945 non-null    int64
#  8   INDIKATOR_VALUE  945 non-null    float64
#  9   EINHEIT_KURZ     945 non-null    object
#  10  EINHEIT_LANG     945 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 495.9 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME THEMA_NAME         SET_NAME  \
# 0       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 1       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 2       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 3       1  Aeugst a.A.    Politik  Wahlbeteiligung
# 4       1  Aeugst a.A.    Politik  Wahlbeteiligung
#
#                      SUBSET_NAME  INDIKATOR_ID  \
# 0  Wahlbeteiligung Proporzwahlen           803
# 1  Wahlbeteiligung Proporzwahlen           803
# 2  Wahlbeteiligung Proporzwahlen           803
# 3  Wahlbeteiligung Proporzwahlen           803
# 4  Wahlbeteiligung Proporzwahlen           803
#
#                    INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Wahlbeteiligung Kantonsrat [%]            2003             40.9
# 1  Wahlbeteiligung Kantonsrat [%]            2007             39.7
# 2  Wahlbeteiligung Kantonsrat [%]            2011             38.4
# 3  Wahlbeteiligung Kantonsrat [%]            2015             34.5
# 4  Wahlbeteiligung Kantonsrat [%]            2019             36.7
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0            %      Prozent
# 1            %      Prozent
# 2            %      Prozent
# 3            %      Prozent
# 4            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                             856  \
# BFS_NR                                        0
# GEBIET_NAME                       Bezirk Bülach
# THEMA_NAME                              Politik
# SET_NAME                        Wahlbeteiligung
# SUBSET_NAME       Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                803
# INDIKATOR_NAME   Wahlbeteiligung Kantonsrat [%]
# INDIKATOR_JAHR                             2003
# INDIKATOR_VALUE                            31.7
# EINHEIT_KURZ                                  %
# EINHEIT_LANG                            Prozent
#
#                                             603  \
# BFS_NR                                      178
# GEBIET_NAME                            Russikon
# THEMA_NAME                              Politik
# SET_NAME                        Wahlbeteiligung
# SUBSET_NAME       Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                803
# INDIKATOR_NAME   Wahlbeteiligung Kantonsrat [%]
# INDIKATOR_JAHR                             2003
# INDIKATOR_VALUE                            37.8
# EINHEIT_KURZ                                  %
# EINHEIT_LANG                            Prozent
#
#                                             685
# BFS_NR                                      213
# GEBIET_NAME                             Brütten
# THEMA_NAME                              Politik
# SET_NAME                        Wahlbeteiligung
# SUBSET_NAME       Wahlbeteiligung Proporzwahlen
# INDIKATOR_ID                                803
# INDIKATOR_NAME   Wahlbeteiligung Kantonsrat [%]
# INDIKATOR_JAHR                             2019
# INDIKATOR_VALUE                            39.7
# EINHEIT_KURZ                                  %
# EINHEIT_LANG                            Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME THEMA_NAME         SET_NAME  \
# count           945        945              945
# unique          200          1                1
# top     Aeugst a.A.    Politik  Wahlbeteiligung
# freq              5        945              945
#
#                           SUBSET_NAME                  INDIKATOR_NAME  \
# count                             945                             945
# unique                              1                               1
# top     Wahlbeteiligung Proporzwahlen  Wahlbeteiligung Kantonsrat [%]
# freq                              945                             945
#
#        EINHEIT_KURZ EINHEIT_LANG
# count           945          945
# unique            1            1
# top               %      Prozent
# freq            945          945

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count  945.00        945.00          945.00           945.00
# mean   109.99        803.00        2,010.71            35.85
# std     83.84          0.00            5.56             6.29
# min      0.00        803.00        2,003.00             9.80
# 25%     34.00        803.00        2,007.00            31.60
# 50%     96.00        803.00        2,011.00            35.50
# 75%    180.00        803.00        2,015.00            39.70
# max    298.00        803.00        2,019.00            57.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

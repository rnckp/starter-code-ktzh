# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: ZL-Bezügerquote der Personen ab 65 Jahren [%]

# %% [markdown]
# ### **Description**: ZL-Bezügerquote der Personen ab 65 Jahren. Die ZL-Bezügerquote weist den Anteil der Personen im Rentenalter aus, der mit Zusatzleistungen zur Altersrente unterstützt wird. Bei Gemeinden, die weniger als 5 Fälle haben, wird keine Quote ausgewiesen. (Referenzpopulation im Gemeindeporträt: kantonale Bevölkerungserhebung. Das BFS verwendet für die Berechnung seiner Quoten als Referenzpopulation STATPOP des Vorjahres.)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **334@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-12-22T09:12:34`
# - **Startdate** `2010-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Soziale Sicherheit']`
# - **Keyword** `['ahv', 'bezirke', 'bezuegerquote', 'gemeinden', 'kanton_zuerich', 'sozialleistungen', 'zusatzrenten', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 257
# Title                    : ZL-Bezügerquote der Personen ab 65 Jahren [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-12-22T09:11:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_817.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_817.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,167 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2167 non-null   int64
#  1   GEBIET_NAME      2167 non-null   object
#  2   THEMA_NAME       2167 non-null   object
#  3   SET_NAME         2167 non-null   object
#  4   SUBSET_NAME      2167 non-null   object
#  5   INDIKATOR_ID     2167 non-null   int64
#  6   INDIKATOR_NAME   2167 non-null   object
#  7   INDIKATOR_JAHR   2167 non-null   int64
#  8   INDIKATOR_VALUE  1944 non-null   float64
#  9   EINHEIT_KURZ     2167 non-null   object
#  10  EINHEIT_LANG     2167 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
#
#                          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bedarfsabhängige Sozialleistungen           817
# 1  Bedarfsabhängige Sozialleistungen           817
# 2  Bedarfsabhängige Sozialleistungen           817
# 3  Bedarfsabhängige Sozialleistungen           817
# 4  Bedarfsabhängige Sozialleistungen           817
#
#                                   INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  ZL-Bezügerquote der Personen ab 65 Jahren [%]            2010
# 1  ZL-Bezügerquote der Personen ab 65 Jahren [%]            2011
# 2  ZL-Bezügerquote der Personen ab 65 Jahren [%]            2012
# 3  ZL-Bezügerquote der Personen ab 65 Jahren [%]            2013
# 4  ZL-Bezügerquote der Personen ab 65 Jahren [%]            2014
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              1.8            %      Prozent
# 1              2.8            %      Prozent
# 2              3.0            %      Prozent
# 3              3.0            %      Prozent
# 4              2.9            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                           1709  \
# BFS_NR                                                     220
# GEBIET_NAME                                          Hagenbuch
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                              Soziales
# SUBSET_NAME                  Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                               817
# INDIKATOR_NAME   ZL-Bezügerquote der Personen ab 65 Jahren [%]
# INDIKATOR_JAHR                                            2019
# INDIKATOR_VALUE                                            7.6
# EINHEIT_KURZ                                                 %
# EINHEIT_LANG                                           Prozent
#
#                                                           328   \
# BFS_NR                                                      34
# GEBIET_NAME                                    Laufen-Uhwiesen
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                              Soziales
# SUBSET_NAME                  Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                               817
# INDIKATOR_NAME   ZL-Bezügerquote der Personen ab 65 Jahren [%]
# INDIKATOR_JAHR                                            2014
# INDIKATOR_VALUE                                            3.5
# EINHEIT_KURZ                                                 %
# EINHEIT_LANG                                           Prozent
#
#                                                           161
# BFS_NR                                                      14
# GEBIET_NAME                                      Wettswil a.A.
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                              Soziales
# SUBSET_NAME                  Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                               817
# INDIKATOR_NAME   ZL-Bezügerquote der Personen ab 65 Jahren [%]
# INDIKATOR_JAHR                                            2015
# INDIKATOR_VALUE                                            2.9
# EINHEIT_KURZ                                                 %
# EINHEIT_LANG                                           Prozent

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  SET_NAME  \
# count          2167                      2167      2167
# unique          191                         1         1
# top     Aeugst a.A.  Bevölkerung und Soziales  Soziales
# freq             12                      2167      2167
#
#                               SUBSET_NAME  \
# count                                2167
# unique                                  1
# top     Bedarfsabhängige Sozialleistungen
# freq                                 2167
#
#                                        INDIKATOR_NAME EINHEIT_KURZ  \
# count                                            2167         2167
# unique                                              1            1
# top     ZL-Bezügerquote der Personen ab 65 Jahren [%]            %
# freq                                             2167         2167
#
#        EINHEIT_LANG
# count          2167
# unique            1
# top         Prozent
# freq           2167

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,167.00      2,167.00        2,167.00         1,944.00
# mean    112.87        817.00        2,015.44             7.35
# std      82.10          0.00            3.44             3.57
# min       0.00        817.00        2,010.00             0.00
# 25%      39.00        817.00        2,012.00             4.70
# 50%      99.00        817.00        2,015.00             6.70
# 75%     181.00        817.00        2,018.00             9.40
# max     298.00        817.00        2,021.00            20.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Abstimmungsparolen von kantonalzürcher und nationalen Parteien

# %% [markdown]
# ### **Description**: Parteiparolen von kantonalzürcher Parteien mit Einsitz im Zürcher Kantonsrat zu eidgenössischen und kantonalen Abstimmungen. Abweichende Parolen der jeweiligen nationalen Parteien sind ausgewiesen. Es besteht kein Anspruch auf Vollständigkeit. Im Zeitraum von 2011 bis 2016 fehlen die Parolen im Datensatz wegen eines Medienbruchs vollständig. Bitte senden Sie Ergänzungen zum Datensatz an die unter Kontakt angegebene E-Mail-Adresse.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **444@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-07-02T00:00:00`
# - **Modified** `2023-01-04T13:31:38`
# - **Startdate** `1998-11-29`
# - **Enddate** `None`
# - **Theme** `['Politik']`
# - **Keyword** `['abstimmungen', 'eidgenoessische_volksabstimmungen', 'kantonale_volksabstimmungen', 'kantonsrat', 'politik', 'regierungsrat', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 749
# Title                    : Abstimmungsparolen von kantonalzürcher und nationalen Parteien
# Description              : NA
# Issued                   : 2019-07-02T16:21:22
# Modified                 : 2023-01-03T08:48:06
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsparolen.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_abstimmungsparolen.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,773 rows (observations) and 15 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2773 entries, 0 to 2772
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ABSTIMMTAG          2773 non-null   object
#  1   STAT_VORLAGE_ID     2773 non-null   int64
#  2   BFS_VORLAGE_ID      1720 non-null   float64
#  3   VORLAGE_KURZBEZ     2773 non-null   object
#  4   VORLAGE_LANGBEZ     2773 non-null   object
#  5   VORLAGENART_ID      2773 non-null   int64
#  6   VORLAGENART_BEZ     2773 non-null   object
#  7   THEMA_ID            2710 non-null   object
#  8   THEMA               2710 non-null   object
#  9   ABSTIMMUNGSART_ID   2773 non-null   int64
#  10  ABSTIMMUNGSART_BEZ  2773 non-null   object
#  11  PARTEI_ID           2773 non-null   int64
#  12  PARTEINAME          2773 non-null   object
#  13  PAROLE_ID           2773 non-null   int64
#  14  PAROLENAME          2739 non-null   object
# dtypes: float64(1), int64(5), object(9)
# ...

# %%
df.head()
# Out:
#              ABSTIMMTAG  STAT_VORLAGE_ID  BFS_VORLAGE_ID  \
# 0  1998-11-29T00:00:00Z              150           445.0
# 1  1998-11-29T00:00:00Z              150           445.0
# 2  1998-11-29T00:00:00Z              150           445.0
# 3  1998-11-29T00:00:00Z              150           445.0
# 4  1998-11-29T00:00:00Z              150           445.0
#
#                                      VORLAGE_KURZBEZ  \
# 0  Bundesbeschluss über Bau und Finanzierung von ...
# 1  Bundesbeschluss über Bau und Finanzierung von ...
# 2  Bundesbeschluss über Bau und Finanzierung von ...
# 3  Bundesbeschluss über Bau und Finanzierung von ...
# 4  Bundesbeschluss über Bau und Finanzierung von ...
#
#                                      VORLAGE_LANGBEZ  VORLAGENART_ID  \
# 0  Bundesbeschluss über Bau und Finanzierung von ...               1
# 1  Bundesbeschluss über Bau und Finanzierung von ...               1
# 2  Bundesbeschluss über Bau und Finanzierung von ...               1
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                  251   \
# ABSTIMMTAG                                       2001-12-02T00:00:00Z
# STAT_VORLAGE_ID                                                   188
# BFS_VORLAGE_ID                                                  481.0
# VORLAGE_KURZBEZ     Volksinitiative «für eine gesicherte AHV – Ene...
# VORLAGE_LANGBEZ     Volksinitiative «für eine gesicherte AHV – Ene...
# VORLAGENART_ID                                                      3
# VORLAGENART_BEZ                                       Volksinitiative
# THEMA_ID                                                       6,7,10
# THEMA               Öffentliche Finanzen,Energie,Soziale Fragen – ...
# ABSTIMMUNGSART_ID                                                   2
# ABSTIMMUNGSART_BEZ                                      eidgenössisch
# PARTEI_ID                                                           4
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                   ABSTIMMTAG  \
# count                   2773
# unique                    72
# top     2011-05-15T00:00:00Z
# freq                     140
#
#                                           VORLAGE_KURZBEZ  \
# count                                                2773
# unique                                                312
# top     C. Stichfrage: Welche der beiden Vorlagen soll...
# freq                                                   18
#
#                                           VORLAGE_LANGBEZ  VORLAGENART_BEZ  \
# count                                                2773             2773
# unique                                                313                9
# top     C: Stichfrage: Welche der beiden Vorlagen soll...  Volksinitiative
# freq                                                   18              995
#
#        THEMA_ID                           THEMA ABSTIMMUNGSART_BEZ  \
# count      2710                            2710               2773
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        STAT_VORLAGE_ID  BFS_VORLAGE_ID  VORLAGENART_ID  ABSTIMMUNGSART_ID  \
# count         2,773.00        1,720.00        2,773.00           2,773.00
# mean          1,126.26       23,804.94            3.01               1.55
# std           1,096.40       64,643.01            2.32               0.50
# min               1.00          445.00            1.00               1.00
# 25%             240.00          508.75            2.00               1.00
# 50%             326.00          555.00            2.00               2.00
# 75%           2,473.00        6,340.00            3.00               2.00
# max           2,563.00      237,562.00           12.00               2.00
#
#        PARTEI_ID  PAROLE_ID
# count   2,773.00   2,773.00
# mean        7.12       2.90
# std         4.50      10.80
# min         1.00       1.00
# 25%         4.00       1.00
# 50%         7.00       2.00
# 75%         9.00       2.00
# max        24.00      99.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

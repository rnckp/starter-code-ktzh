# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Maturitätsquoten im Kanton Zürich

# %% [markdown]
# ### **Description**: Durchschnittliche Maturitätsquoten aller politischen Gemeinden im Kanton Zürich in den letzten vier verfügbaren Jahren. Die Quoten werden pro politische Gemeinde wie folgt berechnet: Summe der Maturitätsabschlüsse der Gemeinde in den vier letzten Jahren geteilt durch die Summe der Anzahl 19-jähriger Einwohnerinnen und Einwohner dieser Gemeinde in den letzten vier Jahren.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **672@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-03-06T17:39:00`
# - **Modified** `2022-10-21T16:34:03`
# - **Startdate** `2018-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['ausbildung', 'bildung', 'gemeinden', 'gymnasien', 'handelsschulen', 'lernende', 'matura', 'mittelschulen', 'politische_gemeinden', 'schueler', 'schuelerinnen', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1625
# Title                    : Maturitätsquoten im Kanton Zürich
# Description              : Die Daten sind differenziert nach Stand der Gemeindegrenzen, politische Gemeinde, BFS-Code der politischen Gemeinde. Ausgewiesen werden die Anzahl Abschlüsse einer Gymnasialen Maturität, die Anzahl Personen im Alter von 19 Jahren und die daraus berechnete Quote. Stand_Gemeindegrenzen: Durch die Fusionen von Gemeinden verändern sich die Gemeindegrenzen von Jahr zu Jahr. Der Stand der Gemeindegrenzen zeigt das Jahr, das für die Auswahl der Gemeinden benutzt wird. Sind Gemeinden in den Vorjahren noch nicht fusioniert, werden diese für die Berechnung zusammengefasst. Total_Abschluss_gymnasial: Die Anzahl aller in den vier relevanten Jahren erlangen gymnasialen Maturitäten. Relevant für die Zuteilung zu den Gemeinden ist der Wohnort der Schülerinnen und Schüler. Schülerinnen und Schüler, welche eine Schule ausserhalb des Kantons Zürich besuchen, sind nicht berücksichtigt. Total_19_Jahre: Als Referenz für die Quotenberechnung dient die jeweilige 19-jährige Wohnbevölkerung. Für Gemeinden, deren Anzahl 19-Jähriger kleiner als 51 ist, wird keine Maturitätsquote berechnet.
# Issued                   : 2020-03-06T17:58:24
# Modified                 : 2022-10-21T16:32:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Maturitaetsquote_Gemeinden_und_Kanton.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Maturitaetsquote_Gemeinden_und_Kanton.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 163 rows (observations) and 7 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Stand_Gemeindegrenzen       163 non-null    int64
#  1   Bezirk                      163 non-null    object
#  2   Gemeinde_BFSCode            162 non-null    float64
#  3   Gemeinde                    163 non-null    object
#  4   Total_Abschluss_gymnasial   135 non-null    float64
#  5   Total_19_Jahre_alt          163 non-null    int64
#  6   Maturitaetsquote_gymnasial  135 non-null    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 31.0 KB

# %%
df.head()
# Out:
#    Stand_Gemeindegrenzen            Bezirk  Gemeinde_BFSCode  \
# 0                   2021  Bezirk Affoltern               1.0
# 1                   2021  Bezirk Affoltern               2.0
# 2                   2021  Bezirk Affoltern               3.0
# 3                   2021  Bezirk Affoltern               4.0
# 4                   2021  Bezirk Affoltern               5.0
#
#              Gemeinde  Total_Abschluss_gymnasial  Total_19_Jahre_alt  \
# 0     Aeugst am Albis                       22.0                  95
# 1  Affoltern am Albis                       66.0                 456
# 2          Bonstetten                       56.0                 245
# 3     Hausen am Albis                       34.0                 153
# 4            Hedingen                       43.0                 181
#
#    Maturitaetsquote_gymnasial
# 0                       23.16
# 1                       14.47
# 2                       22.86
# 3                       22.22
# 4                       23.76

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                          104            51            134
# Stand_Gemeindegrenzen                   2021           2021          2021
# Bezirk                         Bezirk Horgen  Bezirk Bülach  Bezirk Uster
# Gemeinde_BFSCode                       136.0           66.0         193.0
# Gemeinde                    Langnau am Albis        Opfikon     Fällanden
# Total_Abschluss_gymnasial               63.0           57.0          74.0
# Total_19_Jahre_alt                       323            668           313
# Maturitaetsquote_gymnasial              19.5           8.53         23.64

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                     Bezirk         Gemeinde
# count                  163              163
# unique                  13              163
# top     Bezirk Andelfingen  Aeugst am Albis
# freq                    22                1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        Stand_Gemeindegrenzen  Gemeinde_BFSCode  Total_Abschluss_gymnasial  \
# count                 163.00            162.00                     135.00
# mean                2,021.00            124.97                     162.89
# std                     0.00             83.35                     975.76
# min                 2,021.00              1.00                       4.00
# 25%                 2,021.00             56.25                      23.00
# 50%                 2,021.00            112.50                      37.00
# 75%                 2,021.00            195.75                      75.50
# max                 2,021.00            298.00                  11,071.00
#
#        Total_19_Jahre_alt  Maturitaetsquote_gymnasial
# count              163.00                      135.00
# mean               689.88                       19.26
# std              4,494.14                        9.65
# min                 17.00                        3.68
# 25%                 80.00                       12.24
# 50%                186.00                       17.39
# 75%                326.00                       22.80
# max             56,225.00                       47.85

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

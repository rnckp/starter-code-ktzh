# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerb. Einkommen natürl. Pers. Median [Fr.]

# %% [markdown]
# ### **Description**: Steuerbares Einkommen Schweiz steuerpflichtiger natürlicher Personen aus der Bundessteuerstatistik. Der Median ist ein Schwellenwert: Die Hälfte der Bevölkerung liegt unter, die andere Hälfte über diesem Wert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **246@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-06T11:26:44`
# - **Startdate** `1999-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'einkommensstufen', 'gemeinden', 'kanton_zuerich', 'natuerliche_personen', 'steuerbares_einkommen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 204
# Title                    : Steuerb. Einkommen natürl. Pers. Median [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-06T11:26:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_316.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_316.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,104 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4104 entries, 0 to 4103
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4104 non-null   int64
#  1   GEBIET_NAME      4104 non-null   object
#  2   THEMA_NAME       4104 non-null   object
#  3   SET_NAME         4104 non-null   object
#  4   SUBSET_NAME      4104 non-null   object
#  5   INDIKATOR_ID     4104 non-null   int64
#  6   INDIKATOR_NAME   4104 non-null   object
#  7   INDIKATOR_JAHR   4104 non-null   int64
#  8   INDIKATOR_VALUE  4104 non-null   int64
#  9   EINHEIT_KURZ     4104 non-null   object
#  10  EINHEIT_LANG     4104 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.9 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME                SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
#
#              SUBSET_NAME  INDIKATOR_ID  \
# 0  Steuerbares Einkommen           316
# 1  Steuerbares Einkommen           316
# 2  Steuerbares Einkommen           316
# 3  Steuerbares Einkommen           316
# 4  Steuerbares Einkommen           316
#
#                                   INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Steuerb. Einkommen natürl. Pers. Median [Fr.]            1999
# 1  Steuerb. Einkommen natürl. Pers. Median [Fr.]            2000
# 2  Steuerb. Einkommen natürl. Pers. Median [Fr.]            2001
# 3  Steuerb. Einkommen natürl. Pers. Median [Fr.]            2002
# 4  Steuerb. Einkommen natürl. Pers. Median [Fr.]            2003
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            47700          Fr.      Franken
# 1            50000          Fr.      Franken
# 2            53100          Fr.      Franken
# 3            54300          Fr.      Franken
# 4            52100          Fr.      Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                           3691  \
# BFS_NR                                                       0
# GEBIET_NAME                                    Bezirk Dietikon
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                Einkommen und Vermögen
# SUBSET_NAME                              Steuerbares Einkommen
# INDIKATOR_ID                                               316
# INDIKATOR_NAME   Steuerb. Einkommen natürl. Pers. Median [Fr.]
# INDIKATOR_JAHR                                            2006
# INDIKATOR_VALUE                                          47000
# EINHEIT_KURZ                                               Fr.
# EINHEIT_LANG                                           Franken
#
#                                                           2604  \
# BFS_NR                                                     180
# GEBIET_NAME                                        Weisslingen
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                Einkommen und Vermögen
# SUBSET_NAME                              Steuerbares Einkommen
# INDIKATOR_ID                                               316
# INDIKATOR_NAME   Steuerb. Einkommen natürl. Pers. Median [Fr.]
# INDIKATOR_JAHR                                            2006
# INDIKATOR_VALUE                                          49400
# EINHEIT_KURZ                                               Fr.
# EINHEIT_LANG                                           Franken
#
#                                                           187
# BFS_NR                                                       9
# GEBIET_NAME                                     Mettmenstetten
# THEMA_NAME                            Bevölkerung und Soziales
# SET_NAME                                Einkommen und Vermögen
# SUBSET_NAME                              Steuerbares Einkommen
# INDIKATOR_ID                                               316
# INDIKATOR_NAME   Steuerb. Einkommen natürl. Pers. Median [Fr.]
# INDIKATOR_JAHR                                            2018
# INDIKATOR_VALUE                                          58600
# EINHEIT_KURZ                                               Fr.
# EINHEIT_LANG                                           Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME                SET_NAME  \
# count          4104                      4104                    4104
# unique          200                         1                       1
# top     Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# freq             21                      4104                    4104
#
#                   SUBSET_NAME                                 INDIKATOR_NAME  \
# count                    4104                                           4104
# unique                      1                                              1
# top     Steuerbares Einkommen  Steuerb. Einkommen natürl. Pers. Median [Fr.]
# freq                     4104                                           4104
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          4104         4104
# unique            1            1
# top             Fr.      Franken
# freq           4104         4104

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,104.00      4,104.00        4,104.00         4,104.00
# mean    107.71        316.00        2,008.97        51,785.36
# std      84.45          0.00            6.04         6,587.18
# min       0.00        316.00        1,999.00        35,200.00
# 25%      31.00        316.00        2,004.00        47,500.00
# 50%      94.00        316.00        2,009.00        50,800.00
# 75%     178.00        316.00        2,014.00        55,000.00
# max     298.00        316.00        2,019.00        85,900.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schül. Berufsschule [pro 1000 Einw.]

# %% [markdown]
# ### **Description**: Anzahl BerufsschülerInnen gemessen an der zivilrechtlichen Bevölkerung Ende Vorjahr

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **214@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-29T11:14:41`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['berufsschule', 'bezirke', 'gemeinden', 'kanton_zuerich', 'schueler', 'schuelerinnen', 'schulen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 177
# Title                    : Schül. Berufsschule [pro 1000 Einw.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-11-29T11:14:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_142.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_142.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,240 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6240 entries, 0 to 6239
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6240 non-null   int64
#  1   GEBIET_NAME      6240 non-null   object
#  2   THEMA_NAME       6240 non-null   object
#  3   SET_NAME         6240 non-null   object
#  4   SUBSET_NAME      6240 non-null   object
#  5   INDIKATOR_ID     6240 non-null   int64
#  6   INDIKATOR_NAME   6240 non-null   object
#  7   INDIKATOR_JAHR   6240 non-null   int64
#  8   INDIKATOR_VALUE  6240 non-null   float64
#  9   EINHEIT_KURZ     6240 non-null   object
#  10  EINHEIT_LANG     6240 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Bildung
#
#                               SUBSET_NAME  INDIKATOR_ID  \
# 0  Schüler Mittelschule und Berufsbildung           142
# 1  Schüler Mittelschule und Berufsbildung           142
# 2  Schüler Mittelschule und Berufsbildung           142
# 3  Schüler Mittelschule und Berufsbildung           142
# 4  Schüler Mittelschule und Berufsbildung           142
#
#                          INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Schül. Berufsschule [pro 1000 Einw.]            1990             13.8
# 1  Schül. Berufsschule [pro 1000 Einw.]            1991             20.0
# 2  Schül. Berufsschule [pro 1000 Einw.]            1992             19.4
# 3  Schül. Berufsschule [pro 1000 Einw.]            1993             20.1
# 4  Schül. Berufsschule [pro 1000 Einw.]            1994             13.7
#
#      EINHEIT_KURZ           EINHEIT_LANG
# 0  pro 1000 Einw.  pro Tausend Einwohner
# 1  pro 1000 Einw.  pro Tausend Einwohner
# 2  pro 1000 Einw.  pro Tausend Einwohner
# 3  pro 1000 Einw.  pro Tausend Einwohner
# 4  pro 1000 Einw.  pro Tausend Einwohner

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                    2126  \
# BFS_NR                                               87
# GEBIET_NAME                                    Hüttikon
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        142
# INDIKATOR_NAME     Schül. Berufsschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     2013
# INDIKATOR_VALUE                                    26.9
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner
#
#                                                    3279  \
# BFS_NR                                              141
# GEBIET_NAME                                     Thalwil
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        142
# INDIKATOR_NAME     Schül. Berufsschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     1996
# INDIKATOR_VALUE                                    15.7
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner
#
#                                                    3316
# BFS_NR                                              142
# GEBIET_NAME                        Wädenswil (bis 2018)
# THEMA_NAME                     Bevölkerung und Soziales
# SET_NAME                                        Bildung
# SUBSET_NAME      Schüler Mittelschule und Berufsbildung
# INDIKATOR_ID                                        142
# INDIKATOR_NAME     Schül. Berufsschule [pro 1000 Einw.]
# INDIKATOR_JAHR                                     2001
# INDIKATOR_VALUE                                    24.0
# EINHEIT_KURZ                             pro 1000 Einw.
# EINHEIT_LANG                      pro Tausend Einwohner

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME SET_NAME  \
# count          6240                      6240     6240
# unique          200                         1        1
# top     Aeugst a.A.  Bevölkerung und Soziales  Bildung
# freq             32                      6240     6240
#
#                                    SUBSET_NAME  \
# count                                     6240
# unique                                       1
# top     Schüler Mittelschule und Berufsbildung
# freq                                      6240
#
#                               INDIKATOR_NAME    EINHEIT_KURZ  \
# count                                   6240            6240
# unique                                     1               1
# top     Schül. Berufsschule [pro 1000 Einw.]  pro 1000 Einw.
# freq                                    6240            6240
#
#                  EINHEIT_LANG
# count                    6240
# unique                      1
# top     pro Tausend Einwohner
# freq                     6240

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,240.00      6,240.00        6,240.00         6,240.00
# mean    107.63        142.00        2,005.43            27.23
# std      84.42          0.00            9.20             8.67
# min       0.00        142.00        1,990.00             0.00
# 25%      31.00        142.00        1,997.00            21.40
# 50%      94.00        142.00        2,005.00            27.10
# 75%     178.00        142.00        2,013.00            32.50
# max     298.00        142.00        2,021.00            75.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

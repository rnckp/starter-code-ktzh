# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]

# %% [markdown]
# ### **Description**: Steuerbares Vermögen natürlicher Personen des Kantonalen Steueramts. Das 75%-Quantil ist ein Schwellenwert: Drei Viertel der Bevölkerung liegt unter, das andere Viertel über diesem Wert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **294@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-06T11:26:44`
# - **Startdate** `2003-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'natuerliche_personen', 'steuerbares_vermoegen', 'vermoegen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 224
# Title                    : Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-06T11:26:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_322.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_322.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,320 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3320 entries, 0 to 3319
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3320 non-null   int64
#  1   GEBIET_NAME      3320 non-null   object
#  2   THEMA_NAME       3320 non-null   object
#  3   SET_NAME         3320 non-null   object
#  4   SUBSET_NAME      3320 non-null   object
#  5   INDIKATOR_ID     3320 non-null   int64
#  6   INDIKATOR_NAME   3320 non-null   object
#  7   INDIKATOR_JAHR   3320 non-null   int64
#  8   INDIKATOR_VALUE  3320 non-null   int64
#  9   EINHEIT_KURZ     3320 non-null   object
#  10  EINHEIT_LANG     3320 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME                SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
#
#             SUBSET_NAME  INDIKATOR_ID  \
# 0  Steuerbares Vermögen           322
# 1  Steuerbares Vermögen           322
# 2  Steuerbares Vermögen           322
# 3  Steuerbares Vermögen           322
# 4  Steuerbares Vermögen           322
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]            2003
# 1  Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]            2004
# 2  Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]            2005
# 3  Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]            2006
# 4  Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]            2007
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0           463000          Fr.      Franken
# 1           479000          Fr.      Franken
# 2           465000          Fr.      Franken
# 3           524000          Fr.      Franken
# 4           507000          Fr.      Franken

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               1414  \
# BFS_NR                                                         112
# GEBIET_NAME                                                Bubikon
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                    Einkommen und Vermögen
# SUBSET_NAME                                   Steuerbares Vermögen
# INDIKATOR_ID                                                   322
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]
# INDIKATOR_JAHR                                                2009
# INDIKATOR_VALUE                                             371000
# EINHEIT_KURZ                                                   Fr.
# EINHEIT_LANG                                               Franken
#
#                                                               3252  \
# BFS_NR                                                           0
# GEBIET_NAME                              Region Winterthur u. Umg.
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                    Einkommen und Vermögen
# SUBSET_NAME                                   Steuerbares Vermögen
# INDIKATOR_ID                                                   322
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]
# INDIKATOR_JAHR                                                2003
# INDIKATOR_VALUE                                             221000
# EINHEIT_KURZ                                                   Fr.
# EINHEIT_LANG                                               Franken
#
#                                                               1466
# BFS_NR                                                         115
# GEBIET_NAME                                                 Gossau
# THEMA_NAME                                Bevölkerung und Soziales
# SET_NAME                                    Einkommen und Vermögen
# SUBSET_NAME                                   Steuerbares Vermögen
# INDIKATOR_ID                                                   322
# INDIKATOR_NAME   Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]
# INDIKATOR_JAHR                                                2010
# INDIKATOR_VALUE                                             359000
# EINHEIT_KURZ                                                   Fr.
# EINHEIT_LANG                                               Franken

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME                SET_NAME  \
# count          3320                      3320                    3320
# unique          200                         1                       1
# top     Aeugst a.A.  Bevölkerung und Soziales  Einkommen und Vermögen
# freq             17                      3320                    3320
#
#                  SUBSET_NAME  \
# count                   3320
# unique                     1
# top     Steuerbares Vermögen
# freq                    3320
#
#                                            INDIKATOR_NAME EINHEIT_KURZ  \
# count                                                3320         3320
# unique                                                  1            1
# top     Steuerb. Vermögen natürl. Pers. 75%-Quantil [Fr.]          Fr.
# freq                                                 3320         3320
#
#        EINHEIT_LANG
# count          3320
# unique            1
# top         Franken
# freq           3320

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,320.00      3,320.00        3,320.00         3,320.00
# mean    107.83        322.00        2,010.97       378,913.86
# std      84.66          0.00            4.88       181,175.73
# min       0.00        322.00        2,003.00        91,000.00
# 25%      31.00        322.00        2,007.00       254,000.00
# 50%      94.00        322.00        2,011.00       355,000.00
# 75%     178.00        322.00        2,015.00       453,250.00
# max     298.00        322.00        2,019.00     1,478,000.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

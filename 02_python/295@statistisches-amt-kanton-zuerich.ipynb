# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Sozialhilfequote [%]

# %% [markdown]
# ### **Description**: Berechnung: Die Sozialhilfequote berechnet sich aus dem Anteil der Sozialhilfeempfänger/innen zur gesamten Bevölkerung. Bei Gemeinden, die weniger als 5 Fälle haben, wird keine Quote ausgewiesen. (Referenzpopulation im Gemeindeporträt: kantonale Bevölkerungserhebung. Das BFS verwendet für die Berechnung seiner Quoten als Referenzpopulation STATPOP des Vorjahres.)

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **295@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-12-22T09:14:29`
# - **Startdate** `2007-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Soziale Sicherheit']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'sozialhilfe', 'sozialhilfefaelle', 'sozialhilfequote', 'sozialleistungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 225
# Title                    : Sozialhilfequote [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-12-22T13:45:25
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_541.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_541.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 2,719 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2719 entries, 0 to 2718
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2719 non-null   int64
#  1   GEBIET_NAME      2719 non-null   object
#  2   THEMA_NAME       2719 non-null   object
#  3   SET_NAME         2719 non-null   object
#  4   SUBSET_NAME      2719 non-null   object
#  5   INDIKATOR_ID     2719 non-null   int64
#  6   INDIKATOR_NAME   2719 non-null   object
#  7   INDIKATOR_JAHR   2719 non-null   int64
#  8   INDIKATOR_VALUE  2515 non-null   float64
#  9   EINHEIT_KURZ     2719 non-null   object
#  10  EINHEIT_LANG     2719 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  SET_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales  Soziales
#
#                          SUBSET_NAME  INDIKATOR_ID        INDIKATOR_NAME  \
# 0  Bedarfsabhängige Sozialleistungen           541  Sozialhilfequote [%]
# 1  Bedarfsabhängige Sozialleistungen           541  Sozialhilfequote [%]
# 2  Bedarfsabhängige Sozialleistungen           541  Sozialhilfequote [%]
# 3  Bedarfsabhängige Sozialleistungen           541  Sozialhilfequote [%]
# 4  Bedarfsabhängige Sozialleistungen           541  Sozialhilfequote [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2007              1.8            %      Prozent
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               306   \
# BFS_NR                                          27
# GEBIET_NAME                            Feuerthalen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME                                  Soziales
# SUBSET_NAME      Bedarfsabhängige Sozialleistungen
# INDIKATOR_ID                                   541
# INDIKATOR_NAME                Sozialhilfequote [%]
# INDIKATOR_JAHR                                2013
# INDIKATOR_VALUE                                2.8
# EINHEIT_KURZ                                     %
# EINHEIT_LANG                               Prozent
#
#                                               1212  \
# BFS_NR                                         102
# GEBIET_NAME                                 Weiach
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME                                  Soziales
# SUBSET_NAME      Bedarfsabhängige Sozialleistungen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  SET_NAME  \
# count          2719                      2719      2719
# unique          191                         1         1
# top     Aeugst a.A.  Bevölkerung und Soziales  Soziales
# freq             15                      2719      2719
#
#                               SUBSET_NAME        INDIKATOR_NAME EINHEIT_KURZ  \
# count                                2719                  2719         2719
# unique                                  1                     1            1
# top     Bedarfsabhängige Sozialleistungen  Sozialhilfequote [%]            %
# freq                                 2719                  2719         2719
#
#        EINHEIT_LANG
# count          2719
# unique            1
# top         Prozent
# freq           2719

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,719.00      2,719.00        2,719.00         2,515.00
# mean    112.64        541.00        2,013.93             1.99
# std      81.53          0.00            4.31             1.21
# min       0.00        541.00        2,007.00             0.00
# 25%      39.00        541.00        2,010.00             1.10
# 50%      99.00        541.00        2,014.00             1.70
# 75%     181.00        541.00        2,018.00             2.60
# max     298.00        541.00        2,021.00             7.70

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerung: katholisch [Pers.]

# %% [markdown]
# ### **Description**: Katholische Wohnbevölkerung (zivilrechtlicher Wohnsitz; ab 2010 inkl. vorläufig Aufgenommene, die seit mehr als einem Jahr in der Gemeinde leben, aber ohne Wochenaufenthalter und Asylbewerber).

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **115@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:16:34`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bezirke', 'gemeinden', 'kanton_zuerich', 'katholisch', 'konfession', 'religion', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 95
# Title                    : Bevölkerung: katholisch [Pers.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:16:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_406.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_406.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,260 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6260 entries, 0 to 6259
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6260 non-null   int64
#  1   GEBIET_NAME      6260 non-null   object
#  2   THEMA_NAME       6260 non-null   object
#  3   SET_NAME         6260 non-null   object
#  4   SUBSET_NAME      6260 non-null   object
#  5   INDIKATOR_ID     6260 non-null   int64
#  6   INDIKATOR_NAME   6260 non-null   object
#  7   INDIKATOR_JAHR   6260 non-null   int64
#  8   INDIKATOR_VALUE  6260 non-null   int64
#  9   EINHEIT_KURZ     6260 non-null   object
#  10  EINHEIT_LANG     6260 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 4.3 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Konfession           406
# 1  Bevölkerungsbestand und Haushalte  Konfession           406
# 2  Bevölkerungsbestand und Haushalte  Konfession           406
# 3  Bevölkerungsbestand und Haushalte  Konfession           406
# 4  Bevölkerungsbestand und Haushalte  Konfession           406
#
#                     INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerung: katholisch [Pers.]            1990              269
# 1  Bevölkerung: katholisch [Pers.]            1991              282
# 2  Bevölkerung: katholisch [Pers.]            1992              290
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               3630  \
# BFS_NR                                         160
# GEBIET_NAME                                Zumikon
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                             Konfession
# INDIKATOR_ID                                   406
# INDIKATOR_NAME     Bevölkerung: katholisch [Pers.]
# INDIKATOR_JAHR                                1998
# INDIKATOR_VALUE                               1265
# EINHEIT_KURZ                                 Pers.
# EINHEIT_LANG                              Personen
#
#                                               2310  \
# BFS_NR                                          93
# GEBIET_NAME                           Oberweningen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                             Konfession
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count          6260                      6260
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             32                      6260
#
#                                  SET_NAME SUBSET_NAME  \
# count                                6260        6260
# unique                                  1           1
# top     Bevölkerungsbestand und Haushalte  Konfession
# freq                                 6260        6260
#
#                          INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                              6260         6260         6260
# unique                                1            1            1
# top     Bevölkerung: katholisch [Pers.]        Pers.     Personen
# freq                               6260         6260         6260

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,260.00      6,260.00        6,260.00         6,260.00
# mean    108.23        406.00        2,005.45         7,913.98
# std      84.93          0.00            9.19        31,508.24
# min       0.00        406.00        1,990.00            26.00
# 25%      31.00        406.00        1,997.00           328.00
# 50%      95.00        406.00        2,005.00         1,061.00
# 75%     179.00        406.00        2,013.00         3,246.50
# max     298.00        406.00        2,021.00       397,131.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

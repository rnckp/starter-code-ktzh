# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lufttemperatur und Luftfeuchte LoRa-Sensor-Messwerte

# %% [markdown]
# ### **Description**: Seit Frühjahr 2019 betreibt das AWEL des Kantons Zürich ein Messnetz aus rund 40 Lufttemperatur und -feuchte Sensoren (LoRa). Die Sensor-Standorte befinden sich hauptsächlich im städtischen Raum, verdichtet in der Stadt Zürich, aber auch in weiteren Gemeinden im Kanton Zürich. Ziel des Messnetzes ist es, Messdaten für Stadtklima-Analysen bereitzustellen, damit Aspekte des Lokalklimas und Klimawandels stärker sichtbar werden und in der Raumplanung und Stadtentwicklung berücksichtigt werden können. Mit Hilfe dieser Daten lassen sich u.a. die Auswirkungen von Hitzewellen im städtischen Raum beschreiben. Das Messnetz wird durch das AWEL betrieben, unter Beteiligung der Stadt Zürich; die weiteren Standort-Gemeinden sind über die Messaktivität informiert.
# Der hier verfügbare Datensatz wird täglich aktualisiert und umfasst alle, für die Standorte gültigen Messwerte im 10 Minuten Mittel, inklusive entsprechender Standortinformationen. Weitere Angaben zu Datensatz-Struktur und verwendeten Sensoren sind im Datensatz-Beschrieb zu finden.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **563@awel-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-12-09T00:00:00`
# - **Modified** `2022-12-22T00:00:58`
# - **Startdate** `None`
# - **Enddate** `2022-12-21`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['luft', 'lufttemperaturen', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`45` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1628
# Title                    : LoRa-Sensor-Messwerte 2020/04
# Description              : None
# Issued                   : 2020-04-09T08:02:28
# Modified                 : 2022-08-25T12:57:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202004.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202004.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1652
# Title                    : LoRa-Sensor-Messwerte 2020/06
# Description              : None
# Issued                   : 2020-06-02T15:01:23
# Modified                 : 2022-08-25T12:57:31
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202006.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202006.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 1658
# Title                    : LoRa-Sensor-Messwerte 2020/07
# Description              : None
# Issued                   : 2020-07-06T12:16:49
# Modified                 : 2022-08-25T12:57:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202007.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202007.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 1707
# Title                    : LoRa-Sensor-Messwerte 2020/08
# Description              : None
# Issued                   : 2020-08-03T16:33:40
# Modified                 : 2022-08-25T12:57:35
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202008.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202008.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 4
# Ktzhdistid               : 1721
# Title                    : LoRa-Sensor-Messwerte 2020/09
# Description              : None
# Issued                   : 2020-09-08T10:02:54
# Modified                 : 2022-08-25T12:57:37
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202009.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202009.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 5
# Ktzhdistid               : 1733
# Title                    : LoRa-Sensor-Messwerte 2020/10
# Description              : None
# Issued                   : 2020-10-05T15:27:41
# Modified                 : 2022-08-25T12:57:39
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202010.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202010.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 6
# Ktzhdistid               : 1861
# Title                    : LoRa-Sensor-Messwerte 2021/08
# Description              : None
# Issued                   : 2021-08-19T08:35:14
# Modified                 : 2022-08-25T12:57:57
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202108.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202108.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 7
# Ktzhdistid               : 1872
# Title                    : LoRa-Sensor-Messwerte 2021/09
# Description              : None
# Issued                   : 2021-09-02T09:18:58
# Modified                 : 2022-08-25T12:57:59
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202109.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202109.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 8
# Ktzhdistid               : 1784
# Title                    : LoRa-Sensor-Messwerte 2021/02
# Description              : None
# Issued                   : 2021-02-01T08:39:41
# Modified                 : 2022-08-25T12:57:46
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202102.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202102.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 9
# Ktzhdistid               : 1860
# Title                    : LoRa-Sensor-Messwerte 2021/07
# Description              : None
# Issued                   : 2021-07-13T10:48:23
# Modified                 : 2022-08-25T12:57:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202107.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202107.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 10
# Ktzhdistid               : 1885
# Title                    : LoRa-Sensor-Messwerte 2021/10
# Description              : None
# Issued                   : 2021-10-04T09:36:12
# Modified                 : 2022-08-25T12:58:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202110.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202110.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 11
# Ktzhdistid               : 1917
# Title                    : LoRa-Sensor-Messwerte 2021/11
# Description              : None
# Issued                   : 2021-11-10T08:57:07
# Modified                 : 2022-08-25T12:58:02
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202111.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202111.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 12
# Ktzhdistid               : 1619
# Title                    : LoRa-Sensor-Messwerte 2019/09
# Description              : None
# Issued                   : 2020-03-06T15:10:40
# Modified                 : 2022-08-25T12:57:16
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201909.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201909.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 13
# Ktzhdistid               : 1620
# Title                    : LoRa-Sensor-Messwerte 2019/08
# Description              : None
# Issued                   : 2020-03-06T15:11:10
# Modified                 : 2022-08-25T12:57:14
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201908.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201908.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 14
# Ktzhdistid               : 1621
# Title                    : LoRa-Sensor-Messwerte 2019/07
# Description              : None
# Issued                   : 2020-03-06T15:11:42
# Modified                 : 2022-08-25T12:57:13
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201907.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201907.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 15
# Ktzhdistid               : 1622
# Title                    : LoRa-Sensor-Messwerte 2019/06
# Description              : None
# Issued                   : 2020-03-06T15:12:25
# Modified                 : 2022-08-25T12:57:11
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201906.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201906.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 16
# Ktzhdistid               : 1623
# Title                    : LoRa-Sensor-Messwerte 2019/05
# Description              : None
# Issued                   : 2020-03-06T15:12:53
# Modified                 : 2022-08-25T12:57:09
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201905.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201905.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 17
# Ktzhdistid               : 2077
# Title                    : LoRa-Sensor-Messwerte 2021/12
# Description              : None
# Issued                   : 2022-01-14T13:08:43
# Modified                 : 2022-08-25T12:58:04
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202112.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202112.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 18
# Ktzhdistid               : 2078
# Title                    : LoRa-Sensor-Messwerte 2022/01
# Description              : None
# Issued                   : 2022-01-14T13:08:26
# Modified                 : 2022-08-25T13:36:26
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202201.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202201.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 19
# Ktzhdistid               : 1743
# Title                    : LoRa-Sensor-Messwerte 2020/11
# Description              : None
# Issued                   : 2020-11-02T12:14:25
# Modified                 : 2022-08-25T12:57:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202011.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202011.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 20
# Ktzhdistid               : 1614
# Title                    : LoRa-Sensor-Messwerte 2020/02
# Description              : None
# Issued                   : 2020-03-06T15:06:31
# Modified                 : 2022-08-25T12:57:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202002.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202002.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 21
# Ktzhdistid               : 1615
# Title                    : LoRa-Sensor-Messwerte 2020/01
# Description              : None
# Issued                   : 2020-03-06T15:07:28
# Modified                 : 2022-08-25T12:57:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202001.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202001.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 22
# Ktzhdistid               : 1616
# Title                    : LoRa-Sensor-Messwerte 2019/12
# Description              : None
# Issued                   : 2020-03-06T15:07:58
# Modified                 : 2022-08-25T12:57:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201912.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201912.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 23
# Ktzhdistid               : 1617
# Title                    : LoRa-Sensor-Messwerte 2019/11
# Description              : None
# Issued                   : 2020-03-06T15:08:32
# Modified                 : 2022-08-25T12:57:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201911.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201911.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 24
# Ktzhdistid               : 1618
# Title                    : LoRa-Sensor-Messwerte 2019/10
# Description              : None
# Issued                   : 2020-03-06T15:09:09
# Modified                 : 2022-08-25T12:57:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201910.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201910.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 25
# Ktzhdistid               : 1632
# Title                    : LoRa-Sensor-Messwerte 2020/05
# Description              : None
# Issued                   : 2020-05-04T10:45:42
# Modified                 : 2022-08-25T12:57:30
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202005.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202005.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 26
# Ktzhdistid               : 1802
# Title                    : LoRa-Sensor-Messwerte 2021/04
# Description              : None
# Issued                   : 2021-04-07T09:25:47
# Modified                 : 2022-08-25T12:57:50
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202104.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202104.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 27
# Ktzhdistid               : 1811
# Title                    : LoRa-Sensor-Messwerte 2021/05
# Description              : None
# Issued                   : 2021-05-03T10:07:38
# Modified                 : 2022-08-25T12:57:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202105.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202105.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 28
# Ktzhdistid               : 1779
# Title                    : LoRa-Sensor-Messwerte 2020/12
# Description              : None
# Issued                   : 2021-01-11T16:26:34
# Modified                 : 2022-08-25T12:57:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202012.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202012.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 29
# Ktzhdistid               : 1780
# Title                    : LoRa-Sensor-Messwerte 2021/01
# Description              : None
# Issued                   : 2021-01-11T16:57:24
# Modified                 : 2022-08-25T12:57:44
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202101.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202101.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 30
# Ktzhdistid               : 1791
# Title                    : LoRa-Sensor-Messwerte 2021/03
# Description              : None
# Issued                   : 2021-03-03T13:50:17
# Modified                 : 2022-08-25T12:57:48
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202103.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202103.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 31
# Ktzhdistid               : 1841
# Title                    : LoRa-Sensor-Messwerte 2021/06
# Description              : None
# Issued                   : 2021-06-04T08:41:28
# Modified                 : 2022-08-25T12:57:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202106.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202106.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 32
# Ktzhdistid               : 2838
# Title                    : LoRa-Sensor-Messwerte 2022/06
# Description              : None
# Issued                   : 2022-06-02T00:01:01
# Modified                 : 2022-08-25T13:36:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202206.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202206.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 33
# Ktzhdistid               : 3440
# Title                    : LoRa-Sensor-Messwerte 2022/11
# Description              : None
# Issued                   : 2022-11-02T00:00:58
# Modified                 : 2022-12-02T01:00:57
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202211.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202211.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 34
# Ktzhdistid               : 2198
# Title                    : LoRa-Sensor-Messwerte 2022/02
# Description              : None
# Issued                   : 2022-02-16T14:28:32
# Modified                 : 2022-08-25T13:36:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202202.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202202.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 35
# Ktzhdistid               : 2959
# Title                    : LoRa-Sensor-Messwerte 2022/07
# Description              : None
# Issued                   : 2022-07-02T00:01:06
# Modified                 : 2022-08-26T12:02:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202207.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202207.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 36
# Ktzhdistid               : 2362
# Title                    : LoRa-Sensor-Messwerte 2022/03
# Description              : None
# Issued                   : 2022-03-04T10:18:32
# Modified                 : 2022-08-25T13:36:29
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202203.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202203.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 37
# Ktzhdistid               : 3340
# Title                    : LoRa-Sensor-Messwerte 2022/10
# Description              : None
# Issued                   : 2022-10-02T00:00:59
# Modified                 : 2022-11-02T01:00:57
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202210.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202210.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 38
# Ktzhdistid               : 3240
# Title                    : LoRa-Sensor-Messwerte 2022/09
# Description              : None
# Issued                   : 2022-09-02T00:01:01
# Modified                 : 2022-10-02T02:00:58
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202209.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202209.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 39
# Ktzhdistid               : 3660
# Title                    : LoRa-Sensor-Messwerte 2022/12
# Description              : None
# Issued                   : 2022-12-02T00:00:59
# Modified                 : 2022-12-22T01:00:58
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202212.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202212.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 40
# Ktzhdistid               : 1068
# Title                    : LoRa-Sensor-Messwerte 2020/03
# Description              : None
# Issued                   : 2022-03-10T14:17:33
# Modified                 : 2022-08-25T12:57:26
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202003.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202003.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 41
# Ktzhdistid               : 2518
# Title                    : LoRa-Sensor-Messwerte 2022/04
# Description              : None
# Issued                   : 2022-04-02T00:00:59
# Modified                 : 2022-08-25T13:36:31
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202204.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202204.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 42
# Ktzhdistid               : 3201
# Title                    : LoRa-Sensor-Messwerte 2019/04
# Description              : None
# Issued                   : 2022-08-25T10:57:07
# Modified                 : 2022-08-25T10:57:07
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201904.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201904.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 43
# Ktzhdistid               : 2638
# Title                    : LoRa-Sensor-Messwerte 2022/05
# Description              : None
# Issued                   : 2022-05-03T00:00:58
# Modified                 : 2022-08-25T13:36:32
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202205.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202205.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 44
# Ktzhdistid               : 3120
# Title                    : LoRa-Sensor-Messwerte 2022/08
# Description              : None
# Issued                   : 2022-08-02T00:01:01
# Modified                 : 2022-09-02T02:01:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202208.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202208.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 211,975 rows (observations) and 9 columns (variables).
# There seem to be 1988 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211975 entries, 0 to 211974
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   starttime    211975 non-null  object
#  1   site         211975 non-null  object
#  2   masl         211975 non-null  int64
#  3   magl         211975 non-null  float64
#  4   x            211975 non-null  int64
#  5   y            211975 non-null  int64
#  6   sensor       211975 non-null  int64
#  7   temperature  211975 non-null  float64
#  8   humidity     198930 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 48.6 MB

# %%
df.head()
# Out:
#           starttime                  site  masl  magl        x        y  \
# 0  2022-08-01 00:00  Bülach - Feldermösli   417   2.0  2682216  1262843
# 1  2022-08-01 00:10  Bülach - Feldermösli   417   2.0  2682216  1262843
# 2  2022-08-01 00:20  Bülach - Feldermösli   417   2.0  2682216  1262843
# 3  2022-08-01 00:30  Bülach - Feldermösli   417   2.0  2682216  1262843
# 4  2022-08-01 00:40  Bülach - Feldermösli   417   2.0  2682216  1262843
#
#    sensor  temperature  humidity
# 0     531        18.41     73.15
# 1     531        18.53     72.78
# 2     531        18.35     73.48
# 3     531        18.18     73.71
# 4     531        18.14     74.52

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                            174478              104057                34146
# starttime        2022-08-26 14:30    2022-08-10 19:50      2022-08-23 04:40
# site         Zürich - Paradeplatz  Zürich - Lindenhof  Schlieren - Brachweg
# masl                          411                 428                   391
# magl                          2.0                 2.0                   2.0
# x                         2683111             2683257               2676474
# y                         1247195             1247484               1251042
# sensor                       2680                2659                  2658
# temperature                 29.53               24.35                 14.49
# humidity                    40.91               43.22                 84.69

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                starttime                      site
# count             211975                    211975
# unique              4464                        49
# top     2022-08-25 22:00  Zürich - Schimmelstrasse
# freq                  98                      4506

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#             masl       magl            x            y     sensor  temperature  \
# count 211,975.00 211,975.00   211,975.00   211,975.00 211,975.00   211,975.00
# mean      448.95       2.13 2,684,709.60 1,250,760.48   2,351.97        21.53
# std        60.05       0.43     6,619.07     5,324.13     808.20         4.77
# min       391.00       1.00 2,676,170.00 1,244,478.00     529.00         9.58
# 25%       412.00       2.00 2,680,587.00 1,246,727.00   2,654.00        17.72
# 50%       439.00       2.00 2,682,642.00 1,249,940.00   2,684.00        20.44
# 75%       462.00       2.00 2,684,807.00 1,252,124.00   2,696.00        25.24
# max       774.00       4.00 2,703,580.00 1,262,843.00   2,816.00        38.69
#
#         humidity
# count 198,930.00
# mean       65.64
# std        18.28
# min        21.63
# 25%        50.62
# 50%        67.33
# 75%        80.72
# max       100.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Luft, Klima und Strahlung | joerg.sintermann@bd.zh.ch

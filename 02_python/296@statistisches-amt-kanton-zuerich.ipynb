# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Baulandpreis (gewichteter Median) [Fr./m2]

# %% [markdown]
# ### **Description**: Gewichteter Medianpreis aller Freihandverkäufe von unbebautem Land der Wohn- und Mischzone inkl. Abbruchliegenschaften. Die letzten drei Jahre sind provisorisch. Keine Angaben bei weniger als 4 Transaktionen. Weitere Infos: www.statistik.zh.ch/bodenpreise

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **296@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-05-17T15:56:24`
# - **Startdate** `1974-12-31`
# - **Enddate** `None`
# - **Theme** `['Preise']`
# - **Keyword** `['bauland', 'bezirke', 'bodenpreise', 'gemeinden', 'kanton_zuerich', 'wohnbauland', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 226
# Title                    : Baulandpreis (gewichteter Median) [Fr./m2]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-05-17T15:56:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_199.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_199.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 8,169 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8169 entries, 0 to 8168
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           8169 non-null   int64
#  1   GEBIET_NAME      8169 non-null   object
#  2   THEMA_NAME       8169 non-null   object
#  3   SET_NAME         8169 non-null   object
#  4   SUBSET_NAME      8169 non-null   object
#  5   INDIKATOR_ID     8169 non-null   int64
#  6   INDIKATOR_NAME   8169 non-null   object
#  7   INDIKATOR_JAHR   8169 non-null   int64
#  8   INDIKATOR_VALUE  4508 non-null   float64
#  9   EINHEIT_KURZ     8169 non-null   object
#  10  EINHEIT_LANG     8169 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 4.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 1       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 2       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 3       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# 4       1  Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
#
#    INDIKATOR_ID                              INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0           199  Baulandpreis (gewichteter Median) [Fr./m2]            1974
# 1           199  Baulandpreis (gewichteter Median) [Fr./m2]            1975
# 2           199  Baulandpreis (gewichteter Median) [Fr./m2]            1976
# 3           199  Baulandpreis (gewichteter Median) [Fr./m2]            1977
# 4           199  Baulandpreis (gewichteter Median) [Fr./m2]            1978
#
#    INDIKATOR_VALUE EINHEIT_KURZ              EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                        4198  \
# BFS_NR                                                  119
# GEBIET_NAME                                       Seegräben
# THEMA_NAME                               Bau und Immobilien
# SET_NAME                                   Immobilienhandel
# SUBSET_NAME                                    Baulandpreis
# INDIKATOR_ID                                            199
# INDIKATOR_NAME   Baulandpreis (gewichteter Median) [Fr./m2]
# INDIKATOR_JAHR                                         1996
# INDIKATOR_VALUE                                         NaN
# EINHEIT_KURZ                                         Fr./m2
# EINHEIT_LANG                       Franken pro Quadratmeter
#
#                                                        2638  \
# BFS_NR                                                   70
# GEBIET_NAME                                    Wasterkingen
# THEMA_NAME                               Bau und Immobilien
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME          SET_NAME   SUBSET_NAME  \
# count          8169                8169              8169          8169
# unique          186                   1                 1             1
# top     Aeugst a.A.  Bau und Immobilien  Immobilienhandel  Baulandpreis
# freq             48                8169              8169          8169
#
#                                     INDIKATOR_NAME EINHEIT_KURZ  \
# count                                         8169         8169
# unique                                           1            1
# top     Baulandpreis (gewichteter Median) [Fr./m2]       Fr./m2
# freq                                          8169         8169
#
#                     EINHEIT_LANG
# count                       8169
# unique                         1
# top     Franken pro Quadratmeter
# freq                        8169

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 8,169.00      8,169.00        8,169.00         4,508.00
# mean    118.96        199.00        1,998.20           589.67
# std      85.37          0.00           13.99           553.26
# min       0.00        199.00        1,974.00            16.00
# 25%      43.00        199.00        1,986.00           227.00
# 50%     100.00        199.00        1,999.00           474.50
# 75%     194.00        199.00        2,011.00           712.25
# max     298.00        199.00        2,021.00         5,800.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bauzonen im Kanton Zürich

# %% [markdown]
# ### **Description**: Übersicht über den Bauzonenstand und den Bauzonenverbrauch im Kanton Zürich. Aus technischen Gründen können die Daten in den CSV-Dateien erst ab 1996 bereitgestellt werden.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1120@are-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-02-15T10:01:05`
# - **Modified** `2022-09-28T13:31:57`
# - **Startdate** `1991-01-01`
# - **Enddate** `2021-12-31`
# - **Theme** `['Raum, Umwelt']`
# - **Keyword** `['bauzonen', 'bauzonenverbrauch', 'raum', 'ogd']`
# - **Publisher** `['Amt für Raumentwicklung des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2162
# Title                    : Überbauungsgrad Kanton Zürich ab 1996 in %
# Description              : Überbaute Bauzone in % der Bauzone. NULL-Werte bedeuten, dass für die betreffende Gemeinde oder Stadt keine Flächen in der entsprechenden Zonenkategorie im Zonenplan festgelegt sind. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Die Spalte GEBIET_NAME beinhaltet sowohl Gemeinden, Städte, Regionen als auch den ganzen Kanton Zürich. Es können keine Totale aus den Werten gerechnet werden. 
# Issued                   : 2022-02-15T10:01:05
# Modified                 : 2022-12-07T13:01:25
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002162.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002162.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 2163
# Title                    : Bauzonenverbrauch Kanton Zuerich ab 1996 in ha
# Description              : Bauzonenverbrauch im Kanton Zürich, unterteilt in 1-, 5- und 15-Jahres-Verbrauch. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Die Spalte GEBIET_NAME beinhaltet sowohl Gemeinden, Städte, Regionen als auch den ganzen Kanton Zürich.
# Issued                   : 2022-02-15T10:01:05
# Modified                 : 2022-12-07T13:01:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002163.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002163.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 2166
# Title                    : Bauzonen Kanton Zürich gruppiert fein ab 1996 in ha
# Description              : Überbaute und nicht überbaute Bauzone, unterteilt in Wohnzone, Kernzone, Zentrumszone, Wohnzone mit Gewerbeerleichterung, Arbeitszone ohne Dienstleistungen, Arbeitszone mit Dienstleistungen sowie Zone für öffentliche Bauten. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Die Spalte GEBIET_NAME beinhaltet sowohl Gemeinden, Städte, Regionen als auch den ganzen Kanton Zürich.
# Issued                   : 2022-02-15T10:01:05
# Modified                 : 2022-12-07T13:06:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002166.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002166.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 2165
# Title                    : Bauzonen Kanton Zuerich gruppiert grob ab 1996 in ha
# Description              : Überbaute und unüberbaute Bauzone, unterteilt in Wohnzone, Mischzone, Arbeitszone und Zone für öffentliche Bauten. Die Spalte "ARE_NR" ist eine kantonsinterne Nummerierung, um im Vergleich zur Spalte "BFS_NR" neben den Gemeinden und Städten zusätzlich auch die Regionen und den Kanton Zürich als Ganzes identifizieren zu können. Die Spalte GEBIET_NAME beinhaltet sowohl Gemeinden, Städte, Regionen als auch den ganzen Kanton Zürich.
# Issued                   : 2022-02-15T10:01:05
# Modified                 : 2022-12-07T13:06:03
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002165.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001120_00002165.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,968 rows (observations) and 13 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   BFS_NR                                     4552 non-null   float64
#  1   ARE_NR                                     4968 non-null   int64
#  2   GEBIET_NAME                                4968 non-null   object
#  3   JAHR                                       4968 non-null   int64
#  4   Ueberbaute_Wohnzonen                       4968 non-null   float64
#  5   Ueberbaute_Mischzonen                      4968 non-null   float64
#  6   Ueberbaute_Arbeitszonen                    4968 non-null   float64
#  7   Ueberbaute_Zone_Oeffentliche_Bauten        4968 non-null   float64
#  8   Nicht_ueberbaute_Wohnzonen                 4968 non-null   float64
#  9   Nicht_ueberbaute_Mischzonen                4968 non-null   float64
#  10  Nicht_ueberbaute_Arbeitszonen              4968 non-null   float64
#  11  Nicht_ueberbaute_Zone_Oeffentliche_Bauten  4968 non-null   float64
#  12  Einheit                                    4968 non-null   object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 1.0 MB

# %%
df.head()
# Out:
#    BFS_NR  ARE_NR GEBIET_NAME  JAHR  Ueberbaute_Wohnzonen  \
# 0   261.0       1      Zürich  1996                2235.7
# 1   261.0       1      Zürich  1997                2238.2
# 2   261.0       1      Zürich  1998                2271.1
# 3   261.0       1      Zürich  1999                2273.7
# 4   261.0       1      Zürich  2000                2219.6
#
#    Ueberbaute_Mischzonen  Ueberbaute_Arbeitszonen  \
# 0                 1336.3                    356.3
# 1                 1333.8                    368.3
# 2                 1352.2                    313.7
# 3                 1355.7                    321.7
# 4                 1179.2                    262.9
#
#    Ueberbaute_Zone_Oeffentliche_Bauten  Nicht_ueberbaute_Wohnzonen  \
# 0                                 78.0                       129.5
# 1                                 78.1                       128.3
# 2                                 78.1                       126.2
# 3                                 78.4                       124.3
# 4                                375.2                       130.9
#
#    Nicht_ueberbaute_Mischzonen  Nicht_ueberbaute_Arbeitszonen  \
# 0                         89.6                          110.4
# 1                         88.8                           99.0
# 2                         90.6                          102.3
# 3                         90.9                           94.3
# 4                        124.1                           63.5
#
#    Nicht_ueberbaute_Zone_Oeffentliche_Bauten Einheit
# 0                                       38.8      ha
# 1                                       38.9      ha
# 2                                       38.9      ha
# 3                                       38.9      ha
# 4                                       57.6      ha

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                  887          2856  \
# BFS_NR                                          139.0        180.0
# ARE_NR                                             35          113
# GEBIET_NAME                                Rüschlikon  Weisslingen
# JAHR                                             2010         1999
# Ueberbaute_Wohnzonen                             87.8         43.3
# Ueberbaute_Mischzonen                            15.5         26.8
# Ueberbaute_Arbeitszonen                          10.0          3.8
# Ueberbaute_Zone_Oeffentliche_Bauten               3.7          5.8
# Nicht_ueberbaute_Wohnzonen                        9.6          5.8
# Nicht_ueberbaute_Mischzonen                       0.5          3.5
# Nicht_ueberbaute_Arbeitszonen                     2.0          1.2
# Nicht_ueberbaute_Zone_Oeffentliche_Bauten         0.7          3.5
# Einheit                                            ha           ha
#
#                                                                      4589
# BFS_NR                                                                NaN
# ARE_NR                                                                180
# GEBIET_NAME                                Region Winterthur und Umgebung
# JAHR                                                                 2007
# Ueberbaute_Wohnzonen                                               1748.5
# Ueberbaute_Mischzonen                                              1024.7
# Ueberbaute_Arbeitszonen                                             408.5
# Ueberbaute_Zone_Oeffentliche_Bauten                                 356.2
# Nicht_ueberbaute_Wohnzonen                                          185.9
# Nicht_ueberbaute_Mischzonen                                         101.4
# Nicht_ueberbaute_Arbeitszonen                                       128.9
# Nicht_ueberbaute_Zone_Oeffentliche_Bauten                            34.2
# Einheit                                                                ha

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        GEBIET_NAME Einheit
# count         4968    4968
# unique         188       1
# top      Wädenswil      ha
# freq            49    4968

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR   ARE_NR     JAHR  Ueberbaute_Wohnzonen  Ueberbaute_Mischzonen  \
# count 4,552.00 4,968.00 4,968.00              4,968.00               4,968.00
# mean    126.49   142.82 2,008.34                218.42                 125.98
# std      81.86   259.03     7.45                972.29                 551.44
# min       1.00     1.00 1,996.00                  0.00                   3.20
# 25%      57.00    49.00 2,002.00                 18.30                  17.00
# 50%     116.00    98.00 2,008.00                 45.50                  27.60
# 75%     196.00   147.00 2,015.00                105.85                  54.05
# max     298.00 1,802.00 2,021.00             14,005.40               7,848.90
#
#        Ueberbaute_Arbeitszonen  Ueberbaute_Zone_Oeffentliche_Bauten  \
# count                 4,968.00                             4,968.00
# mean                     51.16                                39.84
# std                     224.78                               175.33
# min                       0.00                                 0.00
# 25%                       1.10                                 2.40
# 50%                       8.40                                 6.70
# 75%                      26.50                                19.10
# max                   3,047.80                             2,437.00
#
#        Nicht_ueberbaute_Wohnzonen  Nicht_ueberbaute_Mischzonen  \
# count                    4,968.00                     4,968.00
# mean                        24.88                        14.57
# std                        114.19                        65.20
# min                          0.00                         0.00
# 25%                          2.40                         1.80
# 50%                          6.30                         3.60
# 75%                         13.10                         7.40
# max                      2,402.30                     1,134.20
#
#        Nicht_ueberbaute_Arbeitszonen  \
# count                       4,968.00
# mean                           14.07
# std                            63.48
# min                             0.00
# 25%                             0.00
# 50%                             2.10
# 75%                             8.40
# max                         1,151.10
#
#        Nicht_ueberbaute_Zone_Oeffentliche_Bauten
# count                                   4,968.00
# mean                                        6.83
# std                                        29.98
# min                                         0.00
# 25%                                         0.20
# 50%                                         1.20
# 75%                                         3.80
# max                                       456.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Amt für Raumentwicklung des Kantons Zürich | Raumplanung | raumbeobachtung@bd.zh.ch

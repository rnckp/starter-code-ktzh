# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Jugendbefragung 2021 der Stadt Uster

# %% [markdown]
# ### **Description**: Befragung von Jugendlichen mit Wohnsitz in Uster zu den Schwerpunktthemen Social Media, Sicherheitsempfinden und Jugendgewalt im Jahr 2021.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1382@geschaeftsfeld-gesellschaft-stadt-uster**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-05-15T00:00:00`
# - **Modified** `2022-05-15T16:02:20`
# - **Startdate** `2021-06-24`
# - **Enddate** `2021-07-11`
# - **Theme** `['Bevölkerung', 'Bevölkerung']`
# - **Keyword** `['internet', 'internetnutzung', 'jugendberatung', 'jugend_und_sport', 'raum', 'jugendkriminalitaet', 'ogd']`
# - **Publisher** `['Geschäftsfeld Gesellschaft der Stadt Uster']`
# - **Landingpage** `https://github.com/GesellschaftStadtUster/kind-jugend-fam_jugendbefragung2021`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2679
# Title                    : Jugendbefragung 2021 - Antworten
# Description              : Antworten der Jugendbefragung 2021; Teilnehmende sind nach 'Alter', 'Geschlecht' und 'Schulstufe' kategorisiert.
# Issued                   : 2022-05-15T16:00:33
# Modified                 : 2022-05-15T16:00:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_jugendbefragung2021/main/opendata_jugendbefragung.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_jugendbefragung2021/main/opendata_jugendbefragung.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 2718
# Title                    : Jugendbefragung 2021 - Fragen
# Description              : Fragen der Jugendbefragung 2021.
# Issued                   : 2022-05-15T16:00:18
# Modified                 : 2022-05-15T16:00:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_jugendbefragung2021/main/variablen_fragen.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/GesellschaftStadtUster/kind-jugend-fam_jugendbefragung2021/main/variablen_fragen.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 76 rows (observations) and 3 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Bezeichnung  76 non-null     object
#  1   Frage        76 non-null     object
#  2   Auswahl      75 non-null     object
# dtypes: object(3)
# memory usage: 37.3 KB

# %%
df.head()
# Out:
#                Bezeichnung                                              Frage  \
# 0                  Z1Alter                       Wie alt bist du [in Jahren]?
# 1             Z2Geschlecht                                    Dein Geschlecht
# 2                 Z3Schule                     In welcher Schulstufe bist du?
# 3     A1Socialmedia_TikTok  Welche der folgenden Socialmedia- und Messange...
# 4  A1Socialmedia_Instagram  Welche der folgenden Socialmedia- und Messange...
#
#                                              Auswahl
# 0                                                NaN
# 1                      männlich, weiblich, non-binär
# 2  Sekundarstufe A, Sekundarstufe B, Sekundarstuf...
# 3  ich habe keinen Account (1), selten (2), jede ...
# 4  ich habe keinen Account (1), selten (2), jede ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             52  \
# Bezeichnung                            B4GewaltTaeter_weiblich
# Frage        Du hast angegeben, dass du schon mal bedroht/g...
# Auswahl                                       Ja (1), Nein (2)
#
#                                                             66  \
# Bezeichnung                                  E1Konsum_Cannabis
# Frage        Welche der folgenden Substanzen hast du schon ...
# Auswahl      noch nie (1),1 mal ausprobiert (2), mehrmals a...
#
#                                                             45
# Bezeichnung              B3BedrohMache_Jugendarbeit_gesprochen
# Frage        Was hast du gemacht, als du online belästigt, ...
# Auswahl                                       Ja (1), Nein (2)

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(exclude='number'))
    except:
        print("No non-numerical data in this distribution")
# Out:
#        Bezeichnung                         Frage           Auswahl
# count           76                            76                75
# unique          76                            76                 9
# top        Z1Alter  Wie alt bist du [in Jahren]?  Ja (1), Nein (2)
# freq             1                             1                41

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    try:
        display(df.describe(include='number'))
    except:
        print("No numerical data in this distribution")
# Out:
# No numerical data in this distribution

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, layout=(-1, 5), edgecolor='black');
except:
    print("No numerical data in this distribution")
# Out:
# No numerical data in this distribution

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Geschäftsfeld Gesellschaft der Stadt Uster | Kindheit, Jugend und Familie | kindheit@uster.ch

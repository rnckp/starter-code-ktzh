# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Tagesregistereinträge zum Kanton Zürich und der Schweiz aus dem Zentralen Firmenindex (Zefix) des Bundes

# %% [markdown]
# ### **Description**: Wöchentlich aktualisierte Informationen zu den im Firmenzentralregister (Zefix) des Eidgenössischen Amts für das Handelsregister (EHRA) eingetragenen Unternehmen und weiteren Rechtseinheiten mit Sitz (Domiziladresse) im Kanton Zürich. Die Daten (Ressourcen) enthalten wöchentlich aktualisierte Konkurseröffnungen nach Branche. Das Statistische Amt plant weitere Daten als weitere Ressourcen zu veröffentlichen.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1742@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-09-06T14:13:35`
# - **Modified** `2023-01-02T04:15:25`
# - **Startdate** `2017-01-01`
# - **Enddate** `2023-01-01`
# - **Theme** `['Volkswirtschaft', 'Arbeit, Erwerb']`
# - **Keyword** `['branchen', 'einzelfirmen', 'firmen', 'genossenschaften', 'gmbh', 'handelsregister', 'konkurse', 'stiftungen', 'unternehmen', 'wirtschaft', 'vereine', 'unternehmensdaten', 'shab', 'ehra', 'zefix', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3261
# Title                    : Konkurseröffnungen nach Branchen im Kanton Zürich und der Schweiz insgesamt, wöchentlich aktualisiert
# Description              : NA
# Issued                   : 2022-09-06T14:13:35
# Modified                 : 2023-01-02T05:15:33
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_ZEFIX_Konkurse.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_ZEFIX_Konkurse.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 65,700 rows (observations) and 5 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65700 entries, 0 to 65699
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   br_abschnitt_red  65700 non-null  object
#  1   location          65700 non-null  object
#  2   date              65700 non-null  object
#  3   value             65700 non-null  int64
#  4   cumsum_diff       10920 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 15.2 MB

# %%
df.head()
# Out:
#   br_abschnitt_red location        date  value  cumsum_diff
# 0    Alle Branchen       CH  2022-01-01      0        -20.5
# 1    Alle Branchen       CH  2022-01-02      0        -20.5
# 2    Alle Branchen       CH  2022-01-03      0         -8.5
# 3    Alle Branchen       CH  2022-01-04      3         -1.0
# 4    Alle Branchen       CH  2022-01-05      2          4.0

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               39765  \
# br_abschnitt_red  Erbringung von freiberuflichen, wissenschaftli...
# location                                                         ZH
# date                                                     2022-12-12
# value                                                             2
# cumsum_diff                                                2.333333
#
#                                                               38712  \
# br_abschnitt_red  Erbringung von Finanz- und Versicherungsdienst...
# location                                                         ZH
# date                                                     2018-01-23
# value                                                             0
# cumsum_diff                                                     NaN
#
#                                 65460
# br_abschnitt_red  Verkehr und Lagerei
# location                           ZH
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        br_abschnitt_red location        date
# count             65700    65700       65700
# unique               15        2        2190
# top       Alle Branchen       CH  2022-01-01
# freq               4380    32850          30

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           value  cumsum_diff
# count 65,700.00    10,920.00
# mean       1.14         0.18
# std        3.87         4.90
# min        0.00       -59.00
# 25%        0.00        -1.00
# 50%        0.00         0.00
# 75%        1.00         1.33
# max       69.00        61.33

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Fachstelle Open Government Data des Kantons Zürich |  | info@open.zh.ch

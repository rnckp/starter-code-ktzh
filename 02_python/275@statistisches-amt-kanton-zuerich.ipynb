# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Restaurants pro 1000 Einwohner [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Restaurants, Imbissstuben, Tea-Rooms und Gelaterias inkl. Restaurants mit begrenzten Übernachtungsmöglichkeiten (2008: NOGA2008 561001 und 561002; bis 2005: NOGA2002 HA 553) gemessen an der Bevölkerungszahl Ende des Vorjahres. Bruch in der Reihe zwischen 2008 und 2011 aufgrund des Übergangs von der alten BZ-Methodik auf STATENT. Daten des aktuellsten Jahres provisorisch.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **275@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-11-11T07:39:53`
# - **Startdate** `1995-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Industrie, Dienstleistungen']`
# - **Keyword** `['bezirke', 'gastgewerbe', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 207
# Title                    : Restaurants pro 1000 Einwohner [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-01T14:17:28
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_305.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_305.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,960 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1960 non-null   int64
#  1   GEBIET_NAME      1960 non-null   object
#  2   THEMA_NAME       1960 non-null   object
#  3   SET_NAME         1960 non-null   object
#  4   SUBSET_NAME      1960 non-null   object
#  5   INDIKATOR_ID     1960 non-null   int64
#  6   INDIKATOR_NAME   1960 non-null   object
#  7   INDIKATOR_JAHR   1960 non-null   int64
#  8   INDIKATOR_VALUE  1960 non-null   float64
#  9   EINHEIT_KURZ     1960 non-null   object
#  10  EINHEIT_LANG     1960 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME                   SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
#
#                  SUBSET_NAME  INDIKATOR_ID  \
# 0  Gastronomie (Restaurants)           305
# 1  Gastronomie (Restaurants)           305
# 2  Gastronomie (Restaurants)           305
# 3  Gastronomie (Restaurants)           305
# 4  Gastronomie (Restaurants)           305
#
#                           INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Restaurants pro 1000 Einwohner [Anz.]            2011              1.6
# 1  Restaurants pro 1000 Einwohner [Anz.]            2012              1.5
# 2  Restaurants pro 1000 Einwohner [Anz.]            2013              1.5
# 3  Restaurants pro 1000 Einwohner [Anz.]            2014              1.5
# 4  Restaurants pro 1000 Einwohner [Anz.]            2015              1.5
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0         Anz.       Anzahl
# 1         Anz.       Anzahl
# 2         Anz.       Anzahl
# 3         Anz.       Anzahl
# 4         Anz.       Anzahl

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                   170   \
# BFS_NR                                              24
# GEBIET_NAME                                  Buch a.I.
# THEMA_NAME                      Arbeit und Unternehmen
# SET_NAME                     Beherbergung, Gastronomie
# SUBSET_NAME                  Gastronomie (Restaurants)
# INDIKATOR_ID                                       305
# INDIKATOR_NAME   Restaurants pro 1000 Einwohner [Anz.]
# INDIKATOR_JAHR                                    2011
# INDIKATOR_VALUE                                    1.1
# EINHEIT_KURZ                                      Anz.
# EINHEIT_LANG                                    Anzahl
#
#                                                   1242  \
# BFS_NR                                             191
# GEBIET_NAME                                  Dübendorf
# THEMA_NAME                      Arbeit und Unternehmen
# SET_NAME                     Beherbergung, Gastronomie
# SUBSET_NAME                  Gastronomie (Restaurants)
# INDIKATOR_ID                                       305
# INDIKATOR_NAME   Restaurants pro 1000 Einwohner [Anz.]
# INDIKATOR_JAHR                                    2013
# INDIKATOR_VALUE                                    2.1
# EINHEIT_KURZ                                      Anz.
# EINHEIT_LANG                                    Anzahl
#
#                                                   1140
# BFS_NR                                             161
# GEBIET_NAME                                   Zollikon
# THEMA_NAME                      Arbeit und Unternehmen
# SET_NAME                     Beherbergung, Gastronomie
# SUBSET_NAME                  Gastronomie (Restaurants)
# INDIKATOR_ID                                       305
# INDIKATOR_NAME   Restaurants pro 1000 Einwohner [Anz.]
# INDIKATOR_JAHR                                    2019
# INDIKATOR_VALUE                                    0.8
# EINHEIT_KURZ                                      Anz.
# EINHEIT_LANG                                    Anzahl

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME                   SET_NAME  \
# count          1960                    1960                       1960
# unique          202                       1                          1
# top     Aeugst a.A.  Arbeit und Unternehmen  Beherbergung, Gastronomie
# freq             10                    1960                       1960
#
#                       SUBSET_NAME                         INDIKATOR_NAME  \
# count                        1960                                   1960
# unique                          1                                      1
# top     Gastronomie (Restaurants)  Restaurants pro 1000 Einwohner [Anz.]
# freq                         1960                                   1960
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          1960         1960
# unique            1            1
# top            Anz.       Anzahl
# freq           1960         1960

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,960.00      1,960.00        1,960.00         1,960.00
# mean    110.28        305.00        2,015.42             1.75
# std      87.24          0.00            2.86             0.89
# min       0.00        305.00        2,011.00             0.00
# 25%      31.75        305.00        2,013.00             1.20
# 50%      95.00        305.00        2,015.00             1.60
# 75%     181.25        305.00        2,018.00             2.00
# max     298.00        305.00        2,020.00             7.40

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

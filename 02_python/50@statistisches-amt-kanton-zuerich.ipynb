# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Schweine [Anz.]

# %% [markdown]
# ### **Description**: Anzahl Schweine

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **50@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T13:59:49`
# - **Startdate** `1985-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Land- und Forstwirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'landwirtschaft', 'nutztiere', 'viehbestand', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 43
# Title                    : Schweine [Anz.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T13:59:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_270.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_270.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 3,870 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           3870 non-null   int64
#  1   GEBIET_NAME      3870 non-null   object
#  2   THEMA_NAME       3870 non-null   object
#  3   SET_NAME         3870 non-null   object
#  4   SUBSET_NAME      3870 non-null   object
#  5   INDIKATOR_ID     3870 non-null   int64
#  6   INDIKATOR_NAME   3870 non-null   object
#  7   INDIKATOR_JAHR   3870 non-null   int64
#  8   INDIKATOR_VALUE  3870 non-null   int64
#  9   EINHEIT_KURZ     3870 non-null   object
#  10  EINHEIT_LANG     3870 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 1.9 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME        SET_NAME SUBSET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
#
#    INDIKATOR_ID   INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           270  Schweine [Anz.]            1985              309
# 1           270  Schweine [Anz.]            1990              147
# 2           270  Schweine [Anz.]            1996               39
# 3           270  Schweine [Anz.]            2000               71
# 4           270  Schweine [Anz.]            2005               55
#
#   EINHEIT_KURZ EINHEIT_LANG
# 0         Anz.       Anzahl
# 1         Anz.       Anzahl
# 2         Anz.       Anzahl
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                    1105                    3853  \
# BFS_NR                               68                       0
# GEBIET_NAME                      Rorbas  Zürich - ganzer Kanton
# THEMA_NAME       Arbeit und Unternehmen  Arbeit und Unternehmen
# SET_NAME                 Landwirtschaft          Landwirtschaft
# SUBSET_NAME                        Vieh                    Vieh
# INDIKATOR_ID                        270                     270
# INDIKATOR_NAME          Schweine [Anz.]         Schweine [Anz.]
# INDIKATOR_JAHR                     2019                    2000
# INDIKATOR_VALUE                       0                   41961
# EINHEIT_KURZ                       Anz.                    Anz.
# EINHEIT_LANG                     Anzahl                  Anzahl
#
#                                    3307
# BFS_NR                              292
# GEBIET_NAME                   Stammheim
# THEMA_NAME       Arbeit und Unternehmen
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME              THEMA_NAME        SET_NAME SUBSET_NAME  \
# count          3870                    3870            3870        3870
# unique          200                       1               1           1
# top     Aeugst a.A.  Arbeit und Unternehmen  Landwirtschaft        Vieh
# freq             20                    3870            3870        3870
#
#          INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count              3870         3870         3870
# unique                1            1            1
# top     Schweine [Anz.]         Anz.       Anzahl
# freq               3870         3870         3870

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 3,870.00      3,870.00        3,870.00         3,870.00
# mean    107.59        270.00        2,009.18           839.89
# std      84.84          0.00            9.63         3,249.84
# min       0.00        270.00        1,985.00             0.00
# 25%      31.00        270.00        2,005.00             0.00
# 50%      94.00        270.00        2,011.00            33.00
# 75%     178.00        270.00        2,016.00           530.75
# max     298.00        270.00        2,021.00        60,138.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

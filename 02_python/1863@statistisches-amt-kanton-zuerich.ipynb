# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bruttolastgang elektrische Energie der Stadt Winterthur

# %% [markdown]
# ### **Description**: Der Bruttolastgang entspricht der im Netzgebiet von Stadtwerk Winterthur an Endverbraucher abgegebenen elektrischen Energie in einer Auflösung von 15 Minuten. Die Berechnung erfolgt täglich gemäss dem Metering Code Schweiz mit den verfügbaren Daten und wird zwischen dem 5. und 10. Arbeitstag für den Vormonat plausibilisiert. Aufgrund der grossen Anzahl an Datensätzen, die der Berechnung der Bruttolastgangsumme zugrunde liegen, können die Werte im Verlauf der Zeit, bis max. 6 Monate zurück, noch nachträglich angepasst werden. Dargestellt sind die Stromverbrauchsdaten seit 2013.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1863@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-11-25T09:02:55`
# - **Modified** `2023-01-07T09:10:05`
# - **Startdate** `2013-01-01`
# - **Enddate** `2023-01-07`
# - **Theme** `['Energie']`
# - **Keyword** `['gemeinden', 'strom', 'stromverbrauch', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3562
# Title                    : Energieverbrauch als Bruttolastgang ab 2022
# Description              : NA
# Issued                   : 2022-11-25T09:02:55
# Modified                 : 2023-01-07T10:10:12
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003562.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003562.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 3561
# Title                    : Energieverbrauch als Bruttolastgang 2013-2015
# Description              : Der Bruttolastgang wird pro Viertelstunde in Kilowattstunden zusammengefasst.
# Issued                   : 2022-11-25T09:02:55
# Modified                 : 2022-11-25T09:02:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003561.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003561.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 3563
# Title                    : Energieverbrauch als Bruttolastgang 2016-2018
# Description              : Der Bruttolastgang wird pro Viertelstunde in Kilowattstunden zusammengefasst.
# Issued                   : 2022-11-25T09:02:55
# Modified                 : 2022-11-25T09:02:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003563.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003563.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 3564
# Title                    : Energieverbrauch als Bruttolastgang 2019-2021
# Description              : Der Bruttolastgang wird pro Viertelstunde in Kilowattstunden zusammengefasst.
# Issued                   : 2022-11-25T09:02:55
# Modified                 : 2022-11-25T09:02:55
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003564.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001863_00003564.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 105,216 rows (observations) and 2 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105216 entries, 0 to 105215
# Data columns (total 2 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   zeitpunkt           105216 non-null  object
#  1   bruttolastgang_kwh  105216 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 9.0 MB

# %%
df.head()
# Out:
#                    zeitpunkt  bruttolastgang_kwh
# 0  2019-01-01T00:15:00+01:00           11795.997
# 1  2019-01-01T00:30:00+01:00           11648.920
# 2  2019-01-01T00:45:00+01:00           13243.324
# 3  2019-01-01T01:00:00+01:00           13216.786
# 4  2019-01-01T01:15:00+01:00           12727.016

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         16762                      88555  \
# zeitpunkt           2019-06-24T14:45:00+01:00  2021-07-11T11:00:00+01:00
# bruttolastgang_kwh                  18054.626                  12285.701
#
#                                         74587
# zeitpunkt           2021-02-15T23:00:00+01:00
# bruttolastgang_kwh                  14751.007

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                         zeitpunkt
# count                      105216
# unique                     105216
# top     2019-01-01T00:15:00+01:00
# freq                            1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        bruttolastgang_kwh
# count          105,216.00
# mean            14,644.44
# std              3,431.68
# min              8,098.18
# 25%             11,688.37
# 50%             14,431.30
# 75%             17,389.09
# max             23,795.35

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Stadt Winterthur | Stadtwerk Winterthur | stadtwerk.messdaten@win.ch

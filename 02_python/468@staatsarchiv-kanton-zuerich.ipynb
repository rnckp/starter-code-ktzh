# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Zürcher Ehedaten des 16. bis 18. Jahrhunderts

# %% [markdown]
# ### **Description**: Enthält in standardisierter Kurzform alle Eheeinträge, die in den überlieferten Kirchenbüchern der Kirchgemeinden des heutigen Kantons Zürich von der Reformation bis zum Jahr 1800 verzeichnet sind. Die Daten stehen sowohl im Format CSV wie auch als 'Linked Open Data' über den Linked Data Service (LINDAS) im Format RDF bereit. Unter "Weitere Informationen" sind sechs SPARQL-Beispielabfragen der RDF-Daten auf LINDAS verlinkt.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **468@staatsarchiv-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-08-26T00:00:00`
# - **Modified** `2022-08-22T16:30:17`
# - **Startdate** `1525-01-01`
# - **Enddate** `1800-12-31`
# - **Theme** `['Kultur, Medien, Informationsgesellschaft, Sport', 'Bevölkerung']`
# - **Keyword** `['ehe', 'eheschliessungen', 'gemeinden', 'heiraten', 'kirchgemeinden', 'verheiratet', 'linked-data', 'sparql', 'rdf', 'ogd']`
# - **Publisher** `['Staatsarchiv des Kantons Zürich']`
# - **Landingpage** `https://zenodo.org/record/5827549`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 787
# Title                    : Zürcher Ehedaten des 16. bis 18. Jahrhunderts als tabellarische Daten
# Description              : Tabellen mit Daten zu Eheeinträgen im Kanton Zürich des 16., 17. und 18. Jahrhunderts. Enthaltene Informationen (Spalten): Signatur; Nachname Mann; Vorname Mann; Herkunft Mann; Nachname Frau; Vorname Frau; Herkunft Frau; Zusatzinformationen Mann; Zusatzinformationen Frau; Datum; Kirchgemeinde; Band; Webseite (zum Eintrag in der Archivdatenbank); ID.
# Issued                   : 2019-08-26T17:57:34
# Modified                 : 2022-06-30T09:53:41
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://zenodo.org/record/5827549/files/EDB_16_18_Jh_Stand_2022_01_07.csv?download=1', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://zenodo.org/record/5827549/files/EDB_16_18_Jh_Stand_2022_01_07.csv?download=1', sep=';', on_bad_lines='warn', encoding_errors='ignore')
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 296,206 rows (observations) and 16 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296206 entries, 0 to 296205
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Signatur         296206 non-null  object
#  1   Nachname_Mann    296206 non-null  object
#  2   Vorname_Mann     296206 non-null  object
#  3   Herkunft_Mann    192632 non-null  object
#  4   Nachname_Frau    296206 non-null  object
#  5   Vorname_Frau     296206 non-null  object
#  6   Herkunft_Frau    205553 non-null  object
#  7   Zusatzinfo_Mann  191995 non-null  object
#  8   Zusatzinfo_Frau  191883 non-null  object
#  9   Datum            296206 non-null  object
#  10  Datum_Von        296206 non-null  object
#  11  Datum_Bis        296206 non-null  object
#  12  Kirchgemeinde    296206 non-null  object
#  13  Band             234058 non-null  object
#  14  Webseite         296206 non-null  object
#  15  ID               296206 non-null  int64
# dtypes: int64(1), object(15)
# memory usage: 298.3 MB

# %%
df.head()
# Out:
#                                        Signatur Nachname_Mann Vorname_Mann  \
# 0   TAI 1.725; StadtA Winterthur B 3 m/1, EDB 1       Iringer     Heinrich
# 1  TAI 1.725; StadtA Winterthur B 3 m/1, EDB 10       Kräutli       Oswald
# 2  TAI 1.725; StadtA Winterthur B 3 m/1, EDB 11    Nussbaumer     Jeremias
# 3  TAI 1.725; StadtA Winterthur B 3 m/1, EDB 12     Geilinger     Wolfgang
# 4  TAI 1.725; StadtA Winterthur B 3 m/1, EDB 13        Wehrli         Marx
#
#   Herkunft_Mann Nachname_Frau Vorname_Frau Herkunft_Frau  \
# 0   Richterswil        Studer         Anna           NaN
# 1           NaN     Eschliker         Sara           NaN
# 2           NaN    Goldschmid     Kleophea           NaN
# 3           NaN          Graf       Ursula    St. Gallen
# 4           NaN      Schickli      Barbara           NaN
#
#                                      Zusatzinfo_Mann Zusatzinfo_Frau  \
# 0                                             Iriger               -
# 1                                   Oschwald Krüttli               -
# 2                                                NaN             NaN
# 3  Herr; "H. Wolfgang Geilinger"; Angaben von Her...               -
# 4                                             Weerly               -
#
#         Datum   Datum_Von   Datum_Bis Kirchgemeinde Band  \
# 0  1553.07.23  1553-07-23  1553-07-23    Winterthur  NaN
# 1  1553.10.23  1553-10-23  1553-10-23    Winterthur  NaN
# 2  1554.04.01  1554-04-01  1554-04-01    Winterthur  NaN
# 3  1562.06.15  1562-06-15  1562-06-15    Winterthur  NaN
# 4  1563.05.03  1563-05-03  1563-05-03    Winterthur  NaN
#
#                                             Webseite       ID
# 0  https://suche.staatsarchiv.djiktzh.ch/detail.a...  1944829
# 1  https://suche.staatsarchiv.djiktzh.ch/detail.a...  1944838
# 2  https://suche.staatsarchiv.djiktzh.ch/detail.a...  1944839
# 3  https://suche.staatsarchiv.djiktzh.ch/detail.a...  1944840
# 4  https://suche.staatsarchiv.djiktzh.ch/detail.a...  1944841

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                             284355  \
# Signatur                                       E III 62.1, EDB 964
# Nachname_Mann                                               Horner
# Vorname_Mann                                                  Beat
# Herkunft_Mann                                          Wollishofen
# Nachname_Frau                                                Wetli
# Vorname_Frau                                               Barbara
# Herkunft_Frau                                             Küsnacht
# Zusatzinfo_Mann                                               Batt
# Zusatzinfo_Frau                                                  -
# Datum                                                   1612.10.25
# Datum_Von                                               1612-10-25
# Datum_Bis                                               1612-10-25
# Kirchgemeinde                                            Kilchberg
# Band                                                         S. 97
# Webseite         https://suche.staatsarchiv.djiktzh.ch/detail.a...
# ID                                                         2015585
#
#                                                             113458  \
# Signatur                                     E III 117.1, EDB 2425
# Nachname_Mann                                              Gabriel
# Vorname_Mann                                              Johannes
# Herkunft_Mann                                       Unterstammheim
# Nachname_Frau                                                  Hug
# Vorname_Frau                                            Margaretha
# Herkunft_Frau                                       Unterstammheim
# Zusatzinfo_Mann                                                  -
# Zusatzinfo_Frau                                             Haugin
# Datum                                                   1727.12.09
# Datum_Von                                               1727-12-09
# Datum_Bis                                               1727-12-09
# Kirchgemeinde                                            Stammheim
# Band                                                        S. 587
# Webseite         https://suche.staatsarchiv.djiktzh.ch/detail.a...
# ID                                                         4426175
#
#                                                             171837
# Signatur                                       E III 86.1, EDB 445
# Nachname_Mann                                         Wiesendanger
# Vorname_Mann                                                 Georg
# Herkunft_Mann                                              Werdhof
# Nachname_Frau                                                 Sigg
# Vorname_Frau                                            Margaretha
# Herkunft_Frau                                             Ossingen
# Zusatzinfo_Mann                                           im Werdt
# Zusatzinfo_Frau                                 Sigg genannt "Joß"
# Datum                                                   1604.03.18
# Datum_Von                                               1604-03-18
# Datum_Bis                                               1604-03-18
# Kirchgemeinde                                             Ossingen
# Band                                                         S. 29
# Webseite         https://suche.staatsarchiv.djiktzh.ch/detail.a...
# ID                                                         2034236

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#                                            Signatur Nachname_Mann  \
# count                                        296206        296206
# unique                                       296206          4814
# top     TAI 1.725; StadtA Winterthur B 3 m/1, EDB 1         Meier
# freq                                              1          9022
#
#        Vorname_Mann Herkunft_Mann Nachname_Frau Vorname_Frau Herkunft_Frau  \
# count        296206        192632        296206       296206        205553
# unique          863          4798          6313          649          5515
# top        Heinrich        Zürich         Meier         Anna        Zürich
# freq          39645          5372          9100        54881          5764
#
#        Zusatzinfo_Mann Zusatzinfo_Frau       Datum   Datum_Von   Datum_Bis  \
# count           191995          191883      296206      296206      296206
# unique           77671           73714       56337       54756       54795
# top                  -               -  1798.11.12  1798-11-12  1798-11-12
# freq             31940           75289         105         105         105
#
#        Kirchgemeinde    Band  \
# count         296206  234058
# unique           157    1522
# top     Grossmünster  Teil 2
# freq           30675    1706
#
#                                                  Webseite
# count                                              296206
# unique                                             296206
# top     https://suche.staatsarchiv.djiktzh.ch/detail.a...
# freq                                                    1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#                 ID
# count   296,206.00
# mean  3,449,520.06
# std   1,191,613.68
# min   1,944,829.00
# 25%   2,024,639.25
# 50%   4,371,985.50
# 75%   4,446,583.75
# max   4,528,000.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Staatsarchiv des Kantons Zürich |  | staatsarchivzh@ji.zh.ch

# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Lernende der Volksschule im Kanton Zürich nach Erstsprache (Deutsch/nicht Deutsch) ab 2000

# %% [markdown]
# ### **Description**: Schüler/innen an öffentlichen Volksschulen im Kanton Zürich, die nach kantonalem Lehrplan unterrichtet werden. Mit Volksschule wird die Schulbildung während der obligatorischen Schulzeit bezeichnet. Die obligatorische Schulzeit umfasst den Kindergarten, sechs Jahre Primarschule und drei Jahre Sekundarstufe I. Nicht mitgezählt sind Lernende der Mittelschulen, Lernende in in Heim-/Sonderschulen, und Lernende in Privatschulen. Es gilt das Schulortprinzip, gezählt werden Schülerinnen und Schüler, welche eine Schule innerhalb des Kantons Zürich besuchen.
#
# Die Daten werden jährlich für den Stichtag 15.9. erhoben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1581@bildungsstatistik-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-10-24T11:33:24`
# - **Modified** `2022-10-25T09:16:01`
# - **Startdate** `2000-09-15`
# - **Enddate** `2021-09-15`
# - **Theme** `['Bildung, Wissenschaft']`
# - **Keyword** `['ausbildung', 'bildung', 'hauptsprache', 'kindergarten', 'lernende', 'primarschule', 'schueler', 'schuelerinnen', 'schulgemeinden', 'sekundarschule', 'sekundarstufe', 'sprache', 'volksschule', 'bildungsdaten', 'ogd']`
# - **Publisher** `['Bildungsstatistik des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3019
# Title                    : Lernende der Volksschule im Kanton Zürich nach Erstsprache (Deutsch/nicht Deutsch) ab 2000
# Description              : Die Daten sind differenziert nach Jahr, zuständiger Schulgemeinde und Erstsprache. Bei Zellen kleiner 5 wird nur der Wert "1-5" ausgewiesen. Jahr: Das Jahr ist jeweils das Kalenderjahr der Erhebung, wobei der Stichtag der 15.9. ist. Die Daten für das Jahr 2021 sind somit im Schuljahr 2021/22 erhoben worden und zeigen den Datenstand am 15. September 2021. Schulgemeinde: Hier wir die zuständige Schulgemeinde dargestellt. Das ist üblicherweise die Schulgemeinde des Wohnort. Es entspricht aber nicht in jedem Fall der Schulgemeinde des Schulstandorts der effektiv besucht wird. Erstsprache: Als Erstsprache gilt diejenige Sprache, die als erste erlernt wird. Die Bildungsstatistik erhebt seit 2010 die Erstsprache als Merkmal der Lernenden. Bis zum Jahr 2009 wurde die Muttersprache erhoben. Anzahl: Anzahl der Schülerinnen und Schüler mit der entsprechenden Merkmalskombination.
# Issued                   : 2022-10-24T11:33:24
# Modified                 : 2022-10-24T11:33:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Regional_Erstsprache.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/bista/ZH_Lernende_Volksschule_Regional_Erstsprache.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 8,287 rows (observations) and 6 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stand          8287 non-null   object
#  1   Kanton         8287 non-null   object
#  2   Jahr           8287 non-null   int64
#  3   Schulgemeinde  8287 non-null   object
#  4   Erstsprache    8287 non-null   object
#  5   Anzahl         8287 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 2.8 MB

# %%
df.head()
# Out:
#         Stand Kanton  Jahr Schulgemeinde      Erstsprache Anzahl
# 0  2022-10-21     zh  2021       Adlikon          Deutsch     49
# 1  2022-10-21     zh  2021       Adlikon  Übrige Sprachen      6
# 2  2022-10-21     zh  2021      Adliswil          Deutsch    765
# 3  2022-10-21     zh  2021      Adliswil  Übrige Sprachen   1119
# 4  2022-10-21     zh  2021         Aesch          Deutsch    135

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                           4953             194         6893
# Stand               2022-10-21       2022-10-21  2022-10-21
# Kanton                      zh               zh          zh
# Jahr                      2008             2021        2003
# Schulgemeinde    Hombrechtikon  Oberengstringen      Lindau
# Erstsprache    Übrige Sprachen          Deutsch     Deutsch
# Anzahl                     261              212         468

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#              Stand Kanton Schulgemeinde Erstsprache   Anzahl
# count         8287   8287          8287        8287     8287
# unique           1      1           227           3     1450
# top     2022-10-21     zh    Bonstetten     Deutsch  1 bis 5
# freq          8287   8287            47        4164      420

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#           Jahr
# count 8,287.00
# mean  2,010.32
# std       6.32
# min   2,000.00
# 25%   2,005.00
# 50%   2,010.00
# 75%   2,016.00
# max   2,021.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Bildungsstatistik des Kantons Zürich |  | bista@bi.zh.ch

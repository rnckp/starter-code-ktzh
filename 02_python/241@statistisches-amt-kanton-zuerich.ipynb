# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Anteil 6+ Zi.-Wohnungen [%]

# %% [markdown]
# ### **Description**: Anteil 6+ Zi.-Wohnungen am Wohnungsbestand. Wohnungsbestand gemäss GWS. Wohnungsbestand bis 2009 aus Fortschreibung des Wohnungsbestandes der GWZ aufgrund der WBT.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **241@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-10-10T12:59:34`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'wohnungen', 'wohnungsbestand', 'zimmerzahl', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 202
# Title                    : Anteil 6+ Zi.-Wohnungen [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-10-10T12:59:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_365.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_365.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,190 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6190 entries, 0 to 6189
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6190 non-null   int64
#  1   GEBIET_NAME      6190 non-null   object
#  2   THEMA_NAME       6190 non-null   object
#  3   SET_NAME         6190 non-null   object
#  4   SUBSET_NAME      6190 non-null   object
#  5   INDIKATOR_ID     6190 non-null   int64
#  6   INDIKATOR_NAME   6190 non-null   object
#  7   INDIKATOR_JAHR   6190 non-null   int64
#  8   INDIKATOR_VALUE  6190 non-null   float64
#  9   EINHEIT_KURZ     6190 non-null   object
#  10  EINHEIT_LANG     6190 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 3.5 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID               INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Wohnungsbestand           365  Anteil 6+ Zi.-Wohnungen [%]            1990
# 1  Wohnungsbestand           365  Anteil 6+ Zi.-Wohnungen [%]            1991
# 2  Wohnungsbestand           365  Anteil 6+ Zi.-Wohnungen [%]            1992
# 3  Wohnungsbestand           365  Anteil 6+ Zi.-Wohnungen [%]            1993
# 4  Wohnungsbestand           365  Anteil 6+ Zi.-Wohnungen [%]            1994
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         1991                         1850  \
# BFS_NR                                    83                           71
# GEBIET_NAME                            Buchs                          Wil
# THEMA_NAME                Bau und Immobilien           Bau und Immobilien
# SET_NAME         Wohnungen, Wohnbautätigkeit  Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                  Wohnungsbestand              Wohnungsbestand
# INDIKATOR_ID                             365                          365
# INDIKATOR_NAME   Anteil 6+ Zi.-Wohnungen [%]  Anteil 6+ Zi.-Wohnungen [%]
# INDIKATOR_JAHR                          2006                         1993
# INDIKATOR_VALUE                          7.4                         23.4
# EINHEIT_KURZ                               %                            %
# EINHEIT_LANG                         Prozent                      Prozent
#
#                                         570
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          6190                6190                         6190
# unique          200                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             32                6190                         6190
#
#             SUBSET_NAME               INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count              6190                         6190         6190         6190
# unique                1                            1            1            1
# top     Wohnungsbestand  Anteil 6+ Zi.-Wohnungen [%]            %      Prozent
# freq               6190                         6190         6190         6190

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,190.00      6,190.00        6,190.00         6,190.00
# mean    106.11        365.00        2,005.45            15.02
# std      83.04          0.00            9.20             6.97
# min       0.00        365.00        1,990.00             2.00
# 25%      31.00        365.00        1,997.00             9.30
# 50%      93.50        365.00        2,005.00            14.60
# 75%     177.00        365.00        2,013.00            20.10
# max     298.00        365.00        2,021.00            38.80

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

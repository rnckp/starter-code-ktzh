# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Neuerstellte MFH-Wohnungen [Whg.]

# %% [markdown]
# ### **Description**: Neu erstellte Wohnungen in Mehrfamilienhäusern

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **230@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-08-26T14:01:34`
# - **Startdate** `1971-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Bau- und Wohnungswesen']`
# - **Keyword** `['bezirke', 'gemeinden', 'immobilien', 'kanton_zuerich', 'mehrfamilienhaus', 'wohnbautaetigkeit', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 192
# Title                    : Neuerstellte MFH-Wohnungen [Whg.]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-08-26T14:01:34
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_372.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_372.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 9,760 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9760 entries, 0 to 9759
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           9760 non-null   int64
#  1   GEBIET_NAME      9760 non-null   object
#  2   THEMA_NAME       9760 non-null   object
#  3   SET_NAME         9760 non-null   object
#  4   SUBSET_NAME      9760 non-null   object
#  5   INDIKATOR_ID     9760 non-null   int64
#  6   INDIKATOR_NAME   9760 non-null   object
#  7   INDIKATOR_JAHR   9760 non-null   int64
#  8   INDIKATOR_VALUE  9760 non-null   int64
#  9   EINHEIT_KURZ     9760 non-null   object
#  10  EINHEIT_LANG     9760 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 6.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#         SUBSET_NAME  INDIKATOR_ID                     INDIKATOR_NAME  \
# 0  Wohnbautätigkeit           372  Neuerstellte MFH-Wohnungen [Whg.]
# 1  Wohnbautätigkeit           372  Neuerstellte MFH-Wohnungen [Whg.]
# 2  Wohnbautätigkeit           372  Neuerstellte MFH-Wohnungen [Whg.]
# 3  Wohnbautätigkeit           372  Neuerstellte MFH-Wohnungen [Whg.]
# 4  Wohnbautätigkeit           372  Neuerstellte MFH-Wohnungen [Whg.]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               4808  \
# BFS_NR                                         134
# GEBIET_NAME                      Hütten (bis 2018)
# THEMA_NAME                      Bau und Immobilien
# SET_NAME               Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                       Wohnbautätigkeit
# INDIKATOR_ID                                   372
# INDIKATOR_NAME   Neuerstellte MFH-Wohnungen [Whg.]
# INDIKATOR_JAHR                                1991
# INDIKATOR_VALUE                                  0
# EINHEIT_KURZ                                  Whg.
# EINHEIT_LANG                             Wohnungen
#
#                                               306   \
# BFS_NR                                           7
# GEBIET_NAME                                 Knonau
# THEMA_NAME                      Bau und Immobilien
# SET_NAME               Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                       Wohnbautätigkeit
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          9760                9760                         9760
# unique          202                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq             50                9760                         9760
#
#              SUBSET_NAME                     INDIKATOR_NAME EINHEIT_KURZ  \
# count               9760                               9760         9760
# unique                 1                                  1            1
# top     Wohnbautätigkeit  Neuerstellte MFH-Wohnungen [Whg.]         Whg.
# freq                9760                               9760         9760
#
#        EINHEIT_LANG
# count          9760
# unique            1
# top       Wohnungen
# freq           9760

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 9,760.00      9,760.00        9,760.00         9,760.00
# mean    107.07        372.00        1,995.50           104.32
# std      83.64          0.00           14.41           423.61
# min       0.00        372.00        1,971.00             0.00
# 25%      31.00        372.00        1,983.00             0.00
# 50%      94.00        372.00        1,996.00             9.00
# 75%     178.00        372.00        2,008.00            50.00
# max     298.00        372.00        2,020.00         9,903.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

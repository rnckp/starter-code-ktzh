# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: COVID_19 Abwassermonitoring im Kanton Zürich ab 30.05.2021

# %% [markdown]
# ### **Description**: Dreimal* wöchentliche SARS-CoV-2-RNA-Messungen aus Proben von dreizehn über den Kanton Zürich verteilten Abwasserreinigungsanlagen (ARA). Die analysierten Werte werden einige Tage darauf publiziert (einmal wöchentlich jeweils am Mittwoch). *ARA Winterthur: Fünfmal wöchentliche Messungen. Daten enhalten: 'SARS-CoV-2 RNA im Rohabwasser pro 100'000 Personen', 'Zufluss zur ARA in Kubikmeter pro Tag', 'Einzugsgebiet (Anzahl an die ARA angeschlossene Einwohner:innen)'. Wichtiger Hinweis: Die Messungen von SARS-CoV-2-RNA im Abwasser unterliegen teilweise erheblichen Messfehlern. Eine Interpretation der Abwassermessungen von SARS-CoV-2 im Vergleich zu den Fallzahlen ist daher nur über längere Zeiträume aussagekräftig und hängt von der gewählten Skala ab. Die Daten sollten daher mit Vorsicht interpretiert werden, da ein grosser Spielraum für Fehlinterpretationen besteht. Im Zeitraum von Januar bis Anfang März 2022 wurde die Aktualisierung der Daten pausiert, um die Abweichungen des Abwassermonitorings von den gemeldeten positiven Fallzahlen zu untersuchen. Nachdem die Methode an die vorherrschende Virusvariante angepasst worden ist, werden die Daten rückwirkend ab Januar 2022 weiter aktualisiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **728@gesundheitsdirektion-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2021-07-06T00:00:00`
# - **Modified** `2022-05-25T01:58:48`
# - **Startdate** `2021-05-30`
# - **Enddate** `None`
# - **Theme** `['Gesundheit']`
# - **Keyword** `['bezirke', 'gesundheit', 'kanton_zuerich', 'krankheiten', 'wasser', 'corona', 'covid-19', 'sars-cov-2', 'covid19', 'ogd']`
# - **Publisher** `['Gesundheitsdirektion des Kantons Zürich']`
# - **Landingpage** `https://github.com/openZH/covid_19_wastewater_monitoring_ZH`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1851
# Title                    : SARS-CoV-2-RNA-Abwassermonitoring
# Description              : SARS-CoV-2-RNA-Messungen aus Proben von dreizehn ins Monitoring integrierten Abwasserreinigungsanlagen (ARA). Variabeln: 'date' = Tag der Entnahme der Probe; 'SARS_CoV_2_RNA_copies_d_100000' = SARS-CoV-2 RNA im Rohabwasser pro 100'000 Personen; 'quantification_flag' = 'Q': über Quantifizierungsgrenze (>LOQ), 'D': über Nachweisgrenze (>LOD), 'N': unter Nachweisgrenze (<LOD); 'flow_m3_d' = Zufluss zur ARA in Kubikmeter pro Tag; 'sample_origin' = Abkürzung der ARA ('ARA_code' gemäss Ressource "Liste der Abwasserreinigungsanlagen mit Einzugsgebiet").
# Issued                   : 2021-07-06T11:41:06
# Modified                 : 2022-03-21T10:05:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_wastewater_monitoring_ZH/master/COVID19_Abwassermonitoring.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_wastewater_monitoring_ZH/master/COVID19_Abwassermonitoring.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 1850
# Title                    : Liste der Abwasserreinigungsanlagen mit Einzugsgebiet
# Description              : Ausgewählte, ins SARS-CoV-2-RNA-Abwassermonitoring integrierte Abwasserreinigungsanlagen (ARA). Variabeln: 'ARA_code' = Abkürzung der ARA; 'catchment_area' = Einzugsgebiet (Anzahl an die ARA angeschlossene Einwohner:innen); 'ARA_name' = Ausgeschriebener Name der ARA; 'district' = Kantonaler Bezirk, in dem die ARA liegt.
# Issued                   : 2021-07-06T10:11:03
# Modified                 : 2021-09-28T08:00:01
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_wastewater_monitoring_ZH/master/ara_einzugsgebiet.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://raw.githubusercontent.com/openZH/covid_19_wastewater_monitoring_ZH/master/ara_einzugsgebiet.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 13 rows (observations) and 4 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ARA_code        13 non-null     object
#  1   catchment_area  13 non-null     int64
#  2   ARA_name        13 non-null     object
#  3   district        13 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0 KB

# %%
df.head()
# Out:
#   ARA_code  catchment_area             ARA_name    district
# 0    ARAZH          473361  Zürich (Werdhölzli)      Zürich
# 1    ARAWi          140403           Winterthur  Winterthur
# 2    ARADi           83367             Dietikon    Dietikon
# 3    ARADü           48797            Dübendorf       Uster
# 4    ARANi           43596          Niederglatt   Dielsdorf

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                        2       6       8
# ARA_code           ARADi   ARABü   ARAHo
# catchment_area     83367   35612   26952
# ARA_name        Dietikon  Bülach  Horgen
# district        Dietikon  Bülach  Horgen

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        ARA_code             ARA_name district
# count        13                   13       13
# unique       13                   13       12
# top       ARAZH  Zürich (Werdhölzli)    Uster
# freq          1                    1        2

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        catchment_area
# count           13.00
# mean        76,661.54
# std        124,093.63
# min          7,150.00
# 25%         26,447.00
# 50%         35,612.00
# 75%         48,797.00
# max        473,361.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Gesundheitsdirektion des Kantons Zürich | Coronavirus-Hotline | gdstab@gd.zh.ch

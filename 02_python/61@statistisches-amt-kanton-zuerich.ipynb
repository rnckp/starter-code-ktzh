# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bevölkerungsdichte [Einw./km2]

# %% [markdown]
# ### **Description**: Bevölkerung pro Gemeindefläche [Einwohner pro Quadratkilometer]

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **61@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2022-02-09T10:15:05`
# - **Startdate** `1962-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bevölkerung']`
# - **Keyword** `['bevoelkerung', 'bevoelkerungsdichte', 'bezirke', 'flaeche', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 54
# Title                    : Bevölkerungsdichte [Einw./km2]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2022-02-09T10:15:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 11,878 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11878 entries, 0 to 11877
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           11878 non-null  int64
#  1   GEBIET_NAME      11878 non-null  object
#  2   THEMA_NAME       11878 non-null  object
#  3   SET_NAME         11878 non-null  object
#  4   SUBSET_NAME      11878 non-null  object
#  5   INDIKATOR_ID     11878 non-null  int64
#  6   INDIKATOR_NAME   11878 non-null  object
#  7   INDIKATOR_JAHR   11878 non-null  int64
#  8   INDIKATOR_VALUE  11878 non-null  float64
#  9   EINHEIT_KURZ     11878 non-null  object
#  10  EINHEIT_LANG     11878 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 9.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
#
#                    INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Bevölkerungsdichte [Einw./km2]            1962             90.2
# 1  Bevölkerungsdichte [Einw./km2]            1963             91.5
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                               4009  \
# BFS_NR                                          87
# GEBIET_NAME                               Hüttikon
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# INDIKATOR_ID                                   460
# INDIKATOR_NAME      Bevölkerungsdichte [Einw./km2]
# INDIKATOR_JAHR                                2020
# INDIKATOR_VALUE                              591.9
# EINHEIT_KURZ                             Einw./km2
# EINHEIT_LANG        Einwohner pro Quadratkilometer
#
#                                               3033  \
# BFS_NR                                          63
# GEBIET_NAME                               Lufingen
# THEMA_NAME                Bevölkerung und Soziales
# SET_NAME         Bevölkerungsbestand und Haushalte
# SUBSET_NAME                    Bevölkerungsbestand
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME                THEMA_NAME  \
# count         11878                     11878
# unique          200                         1
# top     Aeugst a.A.  Bevölkerung und Soziales
# freq             60                     11878
#
#                                  SET_NAME          SUBSET_NAME  \
# count                               11878                11878
# unique                                  1                    1
# top     Bevölkerungsbestand und Haushalte  Bevölkerungsbestand
# freq                                11878                11878
#
#                         INDIKATOR_NAME EINHEIT_KURZ  \
# count                            11878        11878
# unique                               1            1
# top     Bevölkerungsdichte [Einw./km2]    Einw./km2
# freq                             11878        11878
#
#                           EINHEIT_LANG
# count                            11878
# unique                               1
# ...

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#          BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 11,878.00     11,878.00       11,878.00        11,878.00
# mean     110.34        460.00        1,991.42           625.61
# std       86.82          0.00           17.24           741.02
# min        0.00        460.00        1,962.00            38.00
# 25%       32.00        460.00        1,976.25           151.30
# 50%       96.00        460.00        1,991.00           369.30
# 75%      181.00        460.00        2,006.00           809.92
# max      298.00        460.00        2,021.00         5,014.60

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

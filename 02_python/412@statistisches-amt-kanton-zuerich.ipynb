# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Total Kirchensteuerpflichtige [Anz.]

# %% [markdown]
# ### **Description**: Total Kirchensteuerpflichtige

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **412@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2019-07-01T20:19:00`
# - **Modified** `2022-05-13T09:49:19`
# - **Startdate** `1990-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'kirchensteuer', 'oeffentliche_finanzen', 'steuerpflichtige', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 728
# Title                    : Total Kirchensteuerpflichtige [Anz.]
# Description              : None
# Issued                   : 2019-07-01T20:19:00
# Modified                 : 2022-05-13T09:49:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_838.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_838.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 6,388 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6388 entries, 0 to 6387
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           6388 non-null   int64
#  1   GEBIET_NAME      6388 non-null   object
#  2   THEMA_NAME       6388 non-null   object
#  3   SET_NAME         6388 non-null   object
#  4   SUBSET_NAME      6388 non-null   object
#  5   INDIKATOR_ID     6388 non-null   int64
#  6   INDIKATOR_NAME   6388 non-null   object
#  7   INDIKATOR_JAHR   6388 non-null   int64
#  8   INDIKATOR_VALUE  6388 non-null   int64
#  9   EINHEIT_KURZ     6388 non-null   object
#  10  EINHEIT_LANG     6388 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 3.7 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME            THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
# 1       1  Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
# 2       1  Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
# 3       1  Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
# 4       1  Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
#
#                SUBSET_NAME  INDIKATOR_ID  \
# 0  Kirchensteuerpflichtige           838
# 1  Kirchensteuerpflichtige           838
# 2  Kirchensteuerpflichtige           838
# 3  Kirchensteuerpflichtige           838
# 4  Kirchensteuerpflichtige           838
#
#                          INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0  Total Kirchensteuerpflichtige [Anz.]            1990              739
# 1  Total Kirchensteuerpflichtige [Anz.]            1991              739
# 2  Total Kirchensteuerpflichtige [Anz.]            1992              789
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                  4646  \
# BFS_NR                                            220
# GEBIET_NAME                                 Hagenbuch
# THEMA_NAME                       Öffentliche Finanzen
# SET_NAME                             Steuerpflichtige
# SUBSET_NAME                   Kirchensteuerpflichtige
# INDIKATOR_ID                                      838
# INDIKATOR_NAME   Total Kirchensteuerpflichtige [Anz.]
# INDIKATOR_JAHR                                   1996
# INDIKATOR_VALUE                                   548
# EINHEIT_KURZ                                     Anz.
# EINHEIT_LANG                                   Anzahl
#
#                                                  891   \
# BFS_NR                                             34
# GEBIET_NAME                           Laufen-Uhwiesen
# THEMA_NAME                       Öffentliche Finanzen
# SET_NAME                             Steuerpflichtige
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME            THEMA_NAME          SET_NAME  \
# count          6388                  6388              6388
# unique          202                     1                 1
# top     Aeugst a.A.  Öffentliche Finanzen  Steuerpflichtige
# freq             32                  6388              6388
#
#                     SUBSET_NAME                        INDIKATOR_NAME  \
# count                      6388                                  6388
# unique                        1                                     1
# top     Kirchensteuerpflichtige  Total Kirchensteuerpflichtige [Anz.]
# freq                       6388                                  6388
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          6388         6388
# unique            1            1
# top            Anz.       Anzahl
# freq           6388         6388

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 6,388.00      6,388.00        6,388.00         6,388.00
# mean    111.39        838.00        2,005.34        15,062.06
# std      87.09          0.00            9.17        59,295.70
# min       0.00        838.00        1,990.00           112.00
# 25%      32.00        838.00        1,997.00           952.00
# 50%      97.00        838.00        2,005.00         2,395.00
# 75%     182.00        838.00        2,013.00         6,426.50
# max     298.00        838.00        2,021.00       787,714.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch

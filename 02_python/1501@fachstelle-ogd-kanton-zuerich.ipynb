# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Web Analytics des Daten- und Publikationskatalogs des Kantons Zürich ab April 2021 bis März 2022

# %% [markdown]
# ### **Description**: Nutzungsstatistiken der Metadatensätze von Verwaltungseinheiten und Organen des Kantons Zürich, die im Daten- und Publikationskatalogs des Kantons Zürich findbar sind. Verfügbar sind: von Nutzenden verwendete Suchbegriffe. Hinweise: Die Ressourcen zum Jahr 2020 beginnen ab dem Zeitpunkt der Einführung des neuen kantonalen Webauftritts per Anfang Juli 2020. Die Ressourcen zum Jahr 2021 umfassen alle vier Quartale. Die Ressourcen zum Jahr 2022 umfassen nur das erste Quartal. Ab April 2022 ist die Aktualisierung aufgrund der Einführung einer neuen Version des Katalogs pausiert.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **1501@fachstelle-ogd-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2022-06-28T16:40:53`
# - **Modified** `2022-06-29T09:37:51`
# - **Startdate** `2021-04-01`
# - **Enddate** `2022-03-31`
# - **Theme** `['Volkswirtschaft']`
# - **Keyword** `['kantonale_verwaltung', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2940
# Title                    : Suchbegriffe 2021, 4. Quartal
# Description              : Maximal 1000 häufgste Suchbegriffe, die von Nutzenden im Quartal verwendet worden sind. Personennamen, Beleidigungen oder diskriminierenden Äusserungen wurden entfernt.
# Issued                   : 2022-06-28T16:40:53
# Modified                 : 2022-06-28T16:40:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002940.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002940.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 1
# Ktzhdistid               : 2941
# Title                    : Suchbegriffe 2021, 3. Quartal
# Description              : Maximal 1000 häufgste Suchbegriffe, die von Nutzenden im Quartal verwendet worden sind. Personennamen, Beleidigungen oder diskriminierenden Äusserungen wurden entfernt.
# Issued                   : 2022-06-28T16:56:53
# Modified                 : 2022-06-28T16:56:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002941.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002941.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 2
# Ktzhdistid               : 2942
# Title                    : Suchbegriffe 2021, 2. Quartal
# Description              : Maximal 1000 häufgste Suchbegriffe, die von Nutzenden im Quartal verwendet worden sind. Personennamen, Beleidigungen oder diskriminierenden Äusserungen wurden entfernt.
# Issued                   : 2022-06-28T17:12:46
# Modified                 : 2022-06-28T17:12:46
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002942.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002942.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %%
# Distribution 3
# Ktzhdistid               : 2878
# Title                    : Suchbegriffe 2022, 1. Quartal
# Description              : Maximal 1000 häufgste Suchbegriffe, die von Nutzenden im Quartal verwendet worden sind. Personennamen, Beleidigungen oder diskriminierenden Äusserungen wurden entfernt.
# Issued                   : 2022-06-28T16:40:53
# Modified                 : 2022-06-28T16:40:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002878.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001501_00002878.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 995 rows (observations) and 39 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 39 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   label                             995 non-null    object
#  1   nb_visits                         995 non-null    int64
#  2   nb_hits                           995 non-null    int64
#  3   nb_hits_with_time_generation      995 non-null    int64
#  4   min_time_generation               995 non-null    float64
#  5   max_time_generation               995 non-null    float64
#  6   sum_time_spent                    995 non-null    int64
#  7   bounce_count                      995 non-null    int64
#  8   exit_nb_visits                    995 non-null    int64
#  9   sum_daily_nb_uniq_visitors        995 non-null    int64
#  10  sum_time_network                  818 non-null    float64
#  11  nb_hits_with_time_network         818 non-null    float64
#  12  min_time_network                  818 non-null    float64
#  13  max_time_network                  818 non-null    float64
#  14  sum_time_server                   818 non-null    float64
#  15  nb_hits_with_time_server          818 non-null    float64
#  16  min_time_server                   818 non-null    float64
#  17  max_time_server                   818 non-null    float64
#  18  sum_time_transfer                 818 non-null    float64
#  19  nb_hits_with_time_transfer        818 non-null    float64
#  20  min_time_transfer                 818 non-null    float64
#  21  max_time_transfer                 818 non-null    float64
#  22  sum_time_dom_processing           818 non-null    float64
#  23  nb_hits_with_time_dom_processing  818 non-null    float64
#  24  min_time_dom_processing           818 non-null    float64
#  25  max_time_dom_processing           818 non-null    float64
#  26  sum_time_dom_completion           818 non-null    float64
#  27  nb_hits_with_time_dom_completion  818 non-null    float64
#  28  min_time_dom_completion           818 non-null    float64
#  29  max_time_dom_completion           818 non-null    float64
#  30  sum_time_on_load                  818 non-null    float64
#  31  nb_hits_with_time_on_load         818 non-null    float64
#  32  min_time_on_load                  818 non-null    float64
#  33  max_time_on_load                  818 non-null    float64
#  34  avg_time_on_dimension             995 non-null    object
#  35  bounce_rate                       995 non-null    object
#  36  exit_rate                         995 non-null    object
#  37  avg_time_generation               995 non-null    object
#  38  Metadaten: segment                995 non-null    object
# dtypes: float64(26), int64(7), object(6)
# memory usage: 709.7 KB

# %%
df.head()
# Out:
#                                                label  nb_visits  nb_hits  \
# 0                                                  !          2        2
# 1                                               27,3          2        2
# 2                                            27,3.22          2        2
# 3  Einwohnerbestand, die Einwohnerinnen und Einwo...          2        2
# 4                        Goethestrasse 8, 8712 Stäfa          2        6
#
#    nb_hits_with_time_generation  min_time_generation  max_time_generation  \
# 0                             1                0.765                0.765
# 1                             0                0.000                0.000
# 2                             0                0.000                0.000
# 3                             0                0.000                0.000
# 4                             0                0.000                0.000
#
#    sum_time_spent  bounce_count  exit_nb_visits  sum_daily_nb_uniq_visitors  \
# 0               4             0               0                           2
# 1               5             0               0                           2
# 2               8             0               0                           2
# 3              21             0               0                           2
# 4              70             0               0                           2
#
#    ...  max_time_dom_completion  sum_time_on_load  nb_hits_with_time_on_load  \
# 0  ...                      NaN               NaN                        NaN
# 1  ...                      0.0               0.0                        0.0
# 2  ...                      0.0               0.0                        0.0
# 3  ...                      0.0               0.0                        0.0
# 4  ...                      0.0               0.0                        0.0
#
#    min_time_on_load  max_time_on_load  avg_time_on_dimension  bounce_rate  \
# 0               NaN               NaN               00:00:02          0 %
# 1               0.0               0.0               00:00:03          0 %
# 2               0.0               0.0               00:00:04          0 %
# 3               0.0               0.0               00:00:11          0 %
# 4               0.0               0.0               00:00:12          0 %
#
#    exit_rate  avg_time_generation  \
# 0        0 %            0,77 Sek.
# 1        0 %               0 Sek.
# 2        0 %               0 Sek.
# 3        0 %               0 Sek.
# 4        0 %               0 Sek.
#
#                                   Metadaten: segment
# 0                                    dimension2==%21
# 1                                 dimension2==27%2C3
# 2                              dimension2==27%2C3.22
# 3  dimension2==Einwohnerbestand%2C+die+Einwohneri...
# 4     dimension2==Goethestrasse+8%2C+8712+St%C3%A4fa
#
# [5 rows x 39 columns]

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                                  157  \
# label                                              bevölkerung alter
# nb_visits                                                          2
# nb_hits                                                            4
# nb_hits_with_time_generation                                       0
# min_time_generation                                              0.0
# max_time_generation                                              0.0
# sum_time_spent                                                    11
# bounce_count                                                       0
# exit_nb_visits                                                     0
# sum_daily_nb_uniq_visitors                                         2
# sum_time_network                                                 0.0
# nb_hits_with_time_network                                        0.0
# min_time_network                                                 0.0
# max_time_network                                                 0.0
# sum_time_server                                                  0.0
# nb_hits_with_time_server                                         0.0
# min_time_server                                                  0.0
# max_time_server                                                  0.0
# sum_time_transfer                                                0.0
# nb_hits_with_time_transfer                                       0.0
# min_time_transfer                                                0.0
# max_time_transfer                                                0.0
# sum_time_dom_processing                                          0.0
# nb_hits_with_time_dom_processing                                 0.0
# min_time_dom_processing                                          0.0
# max_time_dom_processing                                          0.0
# sum_time_dom_completion                                          0.0
# nb_hits_with_time_dom_completion                                 0.0
# min_time_dom_completion                                          0.0
# max_time_dom_completion                                          0.0
# sum_time_on_load                                                 0.0
# nb_hits_with_time_on_load                                        0.0
# min_time_on_load                                                 0.0
# max_time_on_load                                                 0.0
# avg_time_on_dimension                                       00:00:03
# bounce_rate                                                      0 %
# exit_rate                                                        0 %
# avg_time_generation                                           0 Sek.
# Metadaten: segment                dimension2==bev%C3%B6lkerung+alter
#
#                                                  960                   366
# label                                         Wil ZH              Geburten
# nb_visits                                          2                     4
# nb_hits                                            4                     6
# nb_hits_with_time_generation                       0                     0
# min_time_generation                              0.0                   0.0
# max_time_generation                              0.0                   0.0
# sum_time_spent                                    10                   147
# bounce_count                                       0                     0
# exit_nb_visits                                     1                     0
# sum_daily_nb_uniq_visitors                         2                     4
# sum_time_network                                 0.0                   NaN
# nb_hits_with_time_network                        0.0                   NaN
# min_time_network                                 0.0                   NaN
# max_time_network                                 0.0                   NaN
# sum_time_server                                  0.0                   NaN
# nb_hits_with_time_server                         0.0                   NaN
# min_time_server                                  0.0                   NaN
# max_time_server                                  0.0                   NaN
# sum_time_transfer                                0.0                   NaN
# nb_hits_with_time_transfer                       0.0                   NaN
# min_time_transfer                                0.0                   NaN
# max_time_transfer                                0.0                   NaN
# sum_time_dom_processing                          0.0                   NaN
# nb_hits_with_time_dom_processing                 0.0                   NaN
# min_time_dom_processing                          0.0                   NaN
# max_time_dom_processing                          0.0                   NaN
# sum_time_dom_completion                          0.0                   NaN
# nb_hits_with_time_dom_completion                 0.0                   NaN
# min_time_dom_completion                          0.0                   NaN
# max_time_dom_completion                          0.0                   NaN
# sum_time_on_load                                 0.0                   NaN
# nb_hits_with_time_on_load                        0.0                   NaN
# min_time_on_load                                 0.0                   NaN
# max_time_on_load                                 0.0                   NaN
# avg_time_on_dimension                       00:00:03              00:00:25
# bounce_rate                                      0 %                   0 %
# exit_rate                                       50 %                   0 %
# avg_time_generation                           0 Sek.                0 Sek.
# Metadaten: segment                dimension2==Wil+ZH  dimension2==Geburten

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#        label avg_time_on_dimension bounce_rate exit_rate avg_time_generation  \
# count    995                   995         995       995                 995
# unique   995                   163          12        31                  13
# top        !              00:00:00         0 %       0 %              0 Sek.
# freq       1                   105         975       645                 978
#
#        Metadaten: segment
# count                 995
# unique                995
# top       dimension2==%21
# freq                    1

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#        nb_visits  nb_hits  nb_hits_with_time_generation  min_time_generation  \
# count     995.00   995.00                        995.00               995.00
# mean        3.81     5.85                          0.03                 0.01
# std         5.27     9.92                          0.28                 0.13
# min         2.00     2.00                          0.00                 0.00
# 25%         2.00     2.00                          0.00                 0.00
# 50%         2.00     4.00                          0.00                 0.00
# 75%         4.00     6.00                          0.00                 0.00
# max        78.00   153.00                          6.00                 2.17
#
#        max_time_generation  sum_time_spent  bounce_count  exit_nb_visits  \
# count               995.00          995.00        995.00          995.00
# mean                  0.01          181.59          0.03            0.47
# std                   0.13          442.67          0.20            0.85
# min                   0.00            0.00          0.00            0.00
# 25%                   0.00            7.00          0.00            0.00
# 50%                   0.00           21.00          0.00            0.00
# 75%                   0.00          105.50          0.00            1.00
# max                   2.17        5,052.00          3.00            9.00
#
#        sum_daily_nb_uniq_visitors  sum_time_network  ...  \
# count                      995.00            818.00  ...
# mean                         3.77              0.00  ...
# std                          5.20              0.05  ...
# min                          2.00              0.00  ...
# 25%                          2.00              0.00  ...
# 50%                          2.00              0.00  ...
# 75%                          4.00              0.00  ...
# max                         78.00              1.49  ...
#
#        min_time_dom_processing  max_time_dom_processing  \
# count                   818.00                   818.00
# mean                      0.02                     0.02
# std                       0.19                     0.19
# min                       0.00                     0.00
# 25%                       0.00                     0.00
# 50%                       0.00                     0.00
# 75%                       0.00                     0.00
# max                       3.92                     3.92
#
#        sum_time_dom_completion  nb_hits_with_time_dom_completion  \
# count                   818.00                            818.00
# mean                      0.08                              0.02
# std                       1.45                              0.17
# min                       0.00                              0.00
# 25%                       0.00                              0.00
# 50%                       0.00                              0.00
# 75%                       0.00                              0.00
# max                      40.55                              2.00
#
#        min_time_dom_completion  max_time_dom_completion  sum_time_on_load  \
# count                   818.00                   818.00            818.00
# mean                      0.08                     0.08              0.00
# std                       1.44                     1.44              0.00
# min                       0.00                     0.00              0.00
# 25%                       0.00                     0.00              0.00
# 50%                       0.00                     0.00              0.00
# 75%                       0.00                     0.00              0.00
# max                      40.55                    40.55              0.02
#
#        nb_hits_with_time_on_load  min_time_on_load  max_time_on_load
# count                     818.00            818.00            818.00
# mean                        0.02              0.00              0.00
# std                         0.17              0.00              0.00
# min                         0.00              0.00              0.00
# 25%                         0.00              0.00              0.00
# 50%                         0.00              0.00              0.00
# 75%                         0.00              0.00              0.00
# max                         2.00              0.02              0.02
#
# [8 rows x 33 columns]

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Fachstelle Open Government Data des Kantons Zürich |  | info@open.zh.ch

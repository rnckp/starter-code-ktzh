# %% [markdown]
# # Open Government Data, Canton Zurich

# %% [markdown]
# ### **Dataset**: Bestand Dieselmotor [%]

# %% [markdown]
# ### **Description**: Anteil der Personenwagen (PW) mit Dieselmotor an allen am 30. September eingelösten Personenwagen. Hinweis: Der Wert für den ganzen Kanton umfasst alle Autos mit einem Zürcher Kennzeichen; diese können auch Personen oder Unternehmen gehören, die ihr Domizil nicht im Kanton Zürich haben.

# %% [markdown]
# *Autogenerated Jupyter Notebook and basic Python code for data set* **681@statistisches-amt-kanton-zuerich**.

# %% [markdown]
# ## Dataset profile
# - **Issued** `2020-05-25T00:00:00`
# - **Modified** `2022-11-03T12:45:40`
# - **Startdate** `2002-12-31`
# - **Enddate** `2022-12-31`
# - **Theme** `['Mobilität und Verkehr']`
# - **Keyword** `['bezirke', 'fahrzeuge', 'gemeinden', 'kanton_zuerich', 'motorfahrzeugbestand', 'motorfahrzeuge', 'personenwagen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Import Python modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1641
# Title                    : Bestand Dieselmotor [%]
# Description              : None
# Issued                   : 2020-05-25T00:00:00
# Modified                 : 2022-11-03T12:45:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_605.csv', on_bad_lines='warn', encoding_errors='ignore')
if df.shape[1] <= 1:
    df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_605.csv', sep=';', on_bad_lines='warn', encoding_errors='ignore')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 4,150 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4150 entries, 0 to 4149
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           4150 non-null   int64
#  1   GEBIET_NAME      4150 non-null   object
#  2   THEMA_NAME       4150 non-null   object
#  3   SET_NAME         4150 non-null   object
#  4   SUBSET_NAME      4150 non-null   object
#  5   INDIKATOR_ID     4150 non-null   int64
#  6   INDIKATOR_NAME   4150 non-null   object
#  7   INDIKATOR_JAHR   4150 non-null   int64
#  8   INDIKATOR_VALUE  4150 non-null   float64
#  9   EINHEIT_KURZ     4150 non-null   object
#  10  EINHEIT_LANG     4150 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.1 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME       THEMA_NAME SET_NAME                  SUBSET_NAME  \
# 0       1  Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
# 1       1  Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
# 2       1  Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
# 3       1  Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
# 4       1  Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
#
#    INDIKATOR_ID           INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0           605  Bestand Dieselmotor [%]            2002              5.8
# 1           605  Bestand Dieselmotor [%]            2003              6.8
# 2           605  Bestand Dieselmotor [%]            2004              7.1
# 3           605  Bestand Dieselmotor [%]            2005              8.0
# 4           605  Bestand Dieselmotor [%]            2006              8.7
#
#   EINHEIT_KURZ EINHEIT_LANG
# ...

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                         2155                         1768  \
# BFS_NR                                   142                          113
# GEBIET_NAME             Wädenswil (bis 2018)                      Dürnten
# THEMA_NAME                   Raum und Umwelt              Raum und Umwelt
# SET_NAME                             Verkehr                      Verkehr
# SUBSET_NAME      PW-Bestand nach Antriebsart  PW-Bestand nach Antriebsart
# INDIKATOR_ID                             605                          605
# INDIKATOR_NAME       Bestand Dieselmotor [%]      Bestand Dieselmotor [%]
# INDIKATOR_JAHR                          2003                         2018
# INDIKATOR_VALUE                          5.4                         27.2
# EINHEIT_KURZ                               %                            %
# EINHEIT_LANG                         Prozent                      Prozent
#
#                                         2935
# ...

# %%
# describe non-numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(exclude='number'))
# Out:
#         GEBIET_NAME       THEMA_NAME SET_NAME                  SUBSET_NAME  \
# count          4150             4150     4150                         4150
# unique          202                1        1                            1
# top     Aeugst a.A.  Raum und Umwelt  Verkehr  PW-Bestand nach Antriebsart
# freq             21             4150     4150                         4150
#
#                  INDIKATOR_NAME EINHEIT_KURZ EINHEIT_LANG
# count                      4150         4150         4150
# unique                        1            1            1
# top     Bestand Dieselmotor [%]            %      Prozent
# freq                       4150         4150         4150

# %%
# describe numerical features
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df.describe(include='number'))
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 4,150.00      4,150.00        4,150.00         4,150.00
# mean    110.91        605.00        2,011.84            19.16
# std      87.21          0.00            6.01             8.71
# min       0.00        605.00        2,002.00             1.80
# 25%      32.00        605.00        2,007.00            11.20
# 50%      96.00        605.00        2,012.00            20.20
# 75%     182.00        605.00        2,017.00            27.10
# max     298.00        605.00        2,022.00            40.00

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
df.hist(bins=25, layout=(-1, 5), edgecolor='black');

# %%
# continue your code here...

# %% [markdown]
# **Contact**: Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch
